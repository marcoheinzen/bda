# %% [markdown]
# # NB08cV4: Full-Manifest Parquet Audit Sweep v1 (V4 per-point kernel sample unit)
#
# > Copyright (C) 2024-2026 Marco Heinzen - SPDX-License-Identifier: AGPL-3.0-or-later
# > Part of the Master Thesis "Building Damage Assessment with Multimodal Satellite Time Series and Machine Learning in the Russia-Ukraine War 2022-2026"
# > Code hosted at https://github.com/marcoheinzen/bda
# > Parts of this code were written or improved with the assistance of Claude (Anthropic); all other code, and the concept, research, architecture, design, execution, testing and validation throughout, are the author's work.
#
# ## NB08cV4 v1 vs NB08cV3 v1 vs NB08cV2 v8
#
# Same audit protocol (LightGBM-MIA + GroupKFold + 5 folds), same direction-aware
# temporal aggregation, same parquet inventory (28 atomic + 8 fusion = 36 logical
# parquets per tier), same metadata-leakage filter, same OOF schema. The single
# change is the sample unit and its spatial extent:
#
# - **V2 (footprint):** one row per (city, building_id), feature value is the
#   v29 statistic-aware zonal aggregate over the Overture footprint pixels.
# - **V3 (point):** one row per (city, point_id), feature value is the
#   single-pixel sample at the point's (row, col).
# - **V4 (point + 3x3 kernel):** one row per (city, point_id), feature value is
#   the v29 statistic-aware aggregate (mean, p10, p50, p90, std, min, max,
#   max_abs_delta) over a KERNEL_SIZE x KERNEL_SIZE window centered on the
#   point. Default KERNEL_SIZE = 3, so 9 pixels per point.
#
# Source for the architectural distinction: `DECISION_V3.md`,
# `METHODOLOGY_Pivot_PointFirst_and_Aggregation.md`, and the V4 kernel rationale
# in NB05bV4 v1's markdown header.
#
# ### Why a V4 audit
#
# The V2 audit produced honest per-footprint AUCs across 36 parquets.
# The V3 audit (NB08cV3 v1) produced honest per-point AUCs and revealed the
# matched-filter spatial-distribution effect: V3 wins on raw per-scene optical
# parquets (where V2 footprint mean attenuated the per-pixel anomaly) but
# collapses on every wide accumulator and SAR parquet (where V2's spatial
# distribution and multi-look filtering preserved signal that single-pixel
# sampling discarded).
#
# V4 sits between V2 and V3: a fixed 9-pixel spatial extent at every point,
# regardless of building size. The audit answers:
#
# > Is *some* spatial context (the V4 3x3 kernel) sufficient to recover the V2
# > wide-accumulator AUCs that V3 lost, while keeping the V3 per-scene optical
# > wins? Or does the V2 advantage on wide accumulators specifically require
# > the building-shaped, variable-extent footprint aggregation?
#
# If V4 lands between V3 and V2 on the wide accumulators (e.g. A14 coh_drop, A15
# block_stats, F3 fusion_card_cohdrop) but matches V3 on the per-scene optical
# parquets, the spatial-extent gradient is the dominant explanatory variable.
# If V4 matches V2 on both, the building-shaped aggregation was unnecessary
# detail and a uniform kernel is the better architecture going forward. If V4
# matches V3 on both, the V2 advantage is intrinsically tied to building
# geometry — a less likely outcome that would warrant deeper investigation.
#
# ### Changes from NB08cV3 v1 (purely surgical)
#
# Dataset path: `STACK_DIR / 'dataset' / 'v3'` -> `STACK_DIR / 'dataset' / 'v4'`.
# Variable names: `DATASET_ROOT_V3` -> `DATASET_ROOT_V4`, `MANIFEST_V3_PATH` ->
# `MANIFEST_V4_PATH`. Output dir: `OUTPUTS_DIR / 'NB08c_v3'` -> `'NB08c_v4'`.
# Registry tag: `'NB08c_v3'` -> `'NB08c_v4'`. parquet_name suffix:
# `_v3` -> `_v4`.
#
# The sample-unit column `'point_id'` is unchanged (V4 uses the same point
# inventory as V3). The sample-unit parquet filename `bda_points_t{tier}.parquet`
# is unchanged (V4 reuses V3's identity table).
#
# Final cell CELL CMP extended from a 2-way V2 vs V3 comparison to a 3-way
# V2 vs V3 vs V4 comparison: reads all three audit logs from disk if available,
# produces a side-by-side AUC table with per-architecture columns and pairwise
# delta columns (V3-V2, V4-V2, V4-V3).
#
# ### What this notebook does NOT do
#
# - It does not modify the V4 dataset builder (NB05bV4 v1). V4 parquets must
#   already exist in `STACK_DIR/dataset/v4/` with a valid `parquet_manifest.json`.
# - It does not touch any V2 or V3 outputs. NB08cV2 v8 and NB08cV3 v1 audit logs
#   and OOF predictions remain in their respective output directories and are
#   read by the final 3-way comparison cell only.
#
# ## NB08cV3 v1 vs NB08cV2 v8
#
# Same audit protocol (LightGBM-MIA + GroupKFold + 5 folds), same direction-aware temporal aggregation,
# same parquet inventory (28 atomic + 8 fusion = 36 logical parquets per tier), same metadata-leakage
# filter, same OOF schema. The single change is the sample unit:
#
# - **V2 (footprint-based):** one row per (city, building_id), where building_id identifies an Overture
#   Maps building footprint and the feature value is the zonal aggregate (mean, p10, p50, p90, std,
#   min, max, max_abs_delta) over the footprint's pixels.
# - **V3 (point-based):** one row per (city, point_id), where point_id identifies a UNOSAT damage point
#   or a sampled non-UNOSAT centroid, and the feature value is the single-pixel sample at the point's
#   (row, col) coordinate.
#
# Source for the architectural distinction: `DECISION_V3.md` and `METHODOLOGY_Pivot_PointFirst_and_Aggregation.md`.
#
# ### Why a parallel V3 audit
#
# The V2 audit (NB08cV2 v8) produces honest per-footprint AUCs. The V3 audit produces per-point AUCs
# under the same protocol. The two are not directly comparable cell-by-cell — they predict different
# units — but the pair lets us answer the methodology question that drove the pivot:
#
# > Did the per-footprint sample unit (with its 15 m UNOSAT-to-Overture match in NB01b, its
# > binary-collapse-per-building label, and its mean-zonal-of-mean-temporal aggregation chain)
# > attenuate the damage signal that Dietrich 2025 picks up at per-pixel granularity?
#
# If V3 AUCs sit systematically higher than V2 for the same parquet, the per-footprint architecture
# was the bottleneck. If they sit at similar levels, V2 was already extracting most of the signal
# that the data carries and the methodology pivot is not the route to higher numbers.
#
# ### Changes from v8 (purely surgical)
#
# Sample-unit column: `building_id` -> `point_id` everywhere it is a column accessor (load_v2 merge,
# prepare_features_mia, evaluate_audit OOF schema, leakage_delta cell). Variable names like
# `building_ids`, `bid`, `df_bldg` left unchanged per project convention (no rename if not strictly
# needed).
#
# Dataset path: `STACK_DIR / 'dataset' / 'V2'` -> `STACK_DIR / 'dataset' / 'v3'` (lowercase per
# DECISION_V3.md). Variable name `DATASET_ROOT_V2` -> `DATASET_ROOT_V3`, `MANIFEST_V2_PATH` ->
# `MANIFEST_V3_PATH`.
#
# Sample-unit parquet: `bda_buildings_t{tier}.parquet` -> `bda_points_t{tier}.parquet` (DECISION_V3.md).
#
# Output dir: `OUTPUTS_DIR / 'NB08c_v2'` -> `OUTPUTS_DIR / 'NB08c_v3'`. Registry tag: `'NB08c_v2'` ->
# `'NB08c_v3'`. parquet_name suffix: `_v2` -> `_v3`.
#
# New final cell (CELL CMP): cross-architecture comparison reading both V2 v8 and V3 v1 audit logs,
# producing a side-by-side AUC table with delta column. Runs only when both audit logs exist on disk.
#
# ### What this notebook does NOT do
#
# - It does not modify the V3 dataset builder (NB05bV3 v5). V3 parquets must already exist in
#   `STACK_DIR/dataset/v3/` with a valid `parquet_manifest.json`. If they don't, run NB05bV3 first.
# - It does not touch any V2 outputs. NB08cV2 v8 audit log and OOF predictions remain in their V2
#   output directory and are read by the final comparison cell only.
# - It does not propose to merge V2 and V3 OOFs into one parquet. They predict different units and
#   belong in separate OOF directories. NB12 will handle cross-architecture overlap analysis later.
#
# ## v8 changes vs v7
#
# Replaces universal `mean+std` temporal aggregation in `aggregate_long_to_wide()` with
# direction-aware temporal reductions per matched-filter principle (Kay 1998,
# Glaz-Naus-Wallenstein 2001), aligning NB08c with the methodology already
# implemented in NB05b v29 (statistic-aware spatial aggregation) and NB03e v47/v48
# (per-pixel temporal extremum at multiple scopes via R3/R4/R5/R7 + R2b + P1d).
#
# Reference: `DECISION_Rolling_Block_Accumulators.md` Sec 5 (operator formulas) and
# `DECISION_NB05b_v29_Zonal_Aggregation.md` Sec 1 (the empirical case for matched
# filter at the temporal axis).
#
# Per-column temporal reductions dispatched via modality token in column name:
#
# - **drop modalities** (coh_vv, coh_vh, vv, b08, b8a, ndvi, savi, ndbi, ibi, baei, ui)
#   -> temporal `min, mean, std`. Min is the Neyman-Pearson optimal detector for a
#   1-of-N drop spike on stationary noise.
# - **rise modalities** (b11, b12, bsi) -> temporal `max, mean, std`. Max is the
#   N-P optimal detector for a 1-of-N rise spike (rubble exposure).
# - **mixed-sign modalities** (vh, nbr, mndwi, ndsi) -> temporal `min, max, mean, std`.
# - **unknown / non-mappable** (raw VIS bands b02/b03/b04/b05/b07, aux columns,
#   fire products, landuse fractions) -> temporal `mean, std` (legacy v7 fallback).
#
# Accumulator-derived long parquets (manifest keys A23 `rolling_accum_coh`,
# A24 `rolling_accum_card`, A25 `rolling_accum_ms`) keep universal `mean + std`
# because their pixel-temporal axis was already extremized inside NB03e R2b. Applying
# another temporal extremum here would just collapse to A14/A19/A20/A21 full-post-battle
# accumulators, making A23-A25 redundant.
#
# Categorical long parquets (A4 `scene_landuse`, A12 `composite_vs_scenes_landuse`)
# still flow through the `unknown -> mean+std` path. Per-class trajectory aggregators
# (modal trajectory, persistence, urban_or_bare_frac temporal extremum) are flagged
# as a TODO for a follow-up release; the numeric class-fraction columns currently
# get mean+std, which is defensible for fractions but not optimal.
#
# No change to: leakage filter, classifier, CV protocol, audit-runner output schema,
# ranking, or save_oof contract. The single change is the per-column dispatch inside
# `aggregate_long_to_wide()`, plus passing `manifest_key` through from `audit_parquet()`.
#
#
# ## v7 changes vs v6
#
# Adds 6 new atomic parquets from NB05b v29 (NB03e v47 R2b/P1d outputs):
#
# - **C5b (new):** A23 rolling_accum_coh, A24 rolling_accum_card, A25 rolling_accum_ms (long format, per-date)
# - **C6b (new):** A26 block_accum_coh, A27 block_accum_card, A28 block_accum_ms (wide format, per block × op)
# - **C10 ALL_KEYS extended:** clean-vs-leaky AUC delta now also computed for A23–A28
#
# ## Metadata-leakage protection (centralized in metadata_filter.py)
#
# v29 introduced two new metadata categories that the audit pipeline now rejects via the central `metadata_filter` module:
#
# - **Battle-calendar columns (date_first_drop, date_worst_drop, date_first_swir_rise, date_persistent_loss, etc.)** — encoded as substrings in the column prefix; their reductions (`__min_nonzero`, `__max`, `__count_unique`) are tagged METADATA regardless of suffix shape. The `__max` suffix here is a date max, not a value max, so substring-on-prefix is the correct discrimination.
# - **Geometry-dependent counts (`__n_pixels_valid`)** — emitted by every v29 aggregation helper; suffix-match `__n_pixels_valid$` rejects them.
#
# These join the existing leakage rules (`was_observed_*`, `scenes_observed_*`, `qa__cloud_freq__*`, `visibility__*__freq__*`, `blk*__count_*`) under one centralized module — no per-notebook hand-curation.
#
# ## Audit protocol (unchanged from v6)
#
# Single protocol over all v2 parquets. One AUC per parquet for direct comparison.
#
# - Classifier: LightGBM native NaN, class_weight balanced, n_estimators=300
# - CV: GroupKFold by city, 5 folds
# - Long-format parquets aggregated to per-building mean + std
# - Leakage filter: `metadata_filter.is_non_feature()` (covers v28 + v29 patterns)
# - Feature set: `MANIFEST['parquets'][key]['feature_columns']` minus leakage minus count-stats
#
# Output:
# - `RESULTS_ROOT/nb08c/parquet_ranking.csv` — one row per parquet
# - Diagnostic flags: BROKEN, EMPTY, STALE, LEAKAGE_DOMINATED
# - Registry tags: `['nb08c_audit']`
#
#
# Single protocol over all 26 v2 parquets. Produces one AUC per parquet for direct comparison.
#
# - Classifier: LightGBM native NaN, class_weight balanced, n_estimators=300
# - CV: GroupKFold by city, 5 folds
# - Long-format parquets aggregated to per-building mean + std
# - Leakage filter: scenes_observed, obs_count, cloud_freq, visibility__cloud__freq
# - Feature set: `MANIFEST['parquets'][key]['feature_columns']` minus leakage minus count-stats
#
# Output:
# - `RESULTS_ROOT/nb08c/parquet_ranking.csv` — one row per parquet
# - Diagnostic flags: BROKEN, EMPTY, STALE, LEAKAGE_DOMINATED
# - Registry tags: `['nb08c_audit']`

# %% [markdown]
# # CELL 1: NB08c CONFIG

# %%
# @title CELL 1: NB08c CONFIG
TIER_SELECTION = [0,1,2]
CITY_FILTER = None
CITY_SELECTION = None
REQUIRE_UNOSAT = True
RANDOM_STATE = 42
N_FOLDS = 5

USE_V2 = True

# %% [markdown]
# # CELL 2: LOAD GLOBAL SETUP

# %%
# @title CELL 2: LOAD GLOBAL SETUP
import platform, os, json
if platform.system() == "Windows":
    _setup = r"F:\PROJECTS\masterthesis\gdrive\masterthesis\notebooks\global_setup.py"
elif os.path.exists("/content/drive_f"):
    _setup = "/content/drive_f/masterthesis/notebooks/global_setup.py"
else:
    _setup = "/mnt/f/PROJECTS/masterthesis/gdrive/masterthesis/notebooks/global_setup.py"
with open(_setup) as f:
    exec(f.read())
# Out:
# /home/alpineobotics/miniconda3/envs/bda/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
# ======================================================================
# BDA GLOBAL SETUP
# ======================================================================
# Started: 2026-04-27 19:03:22
# Python: 3.12.12
# ======================================================================
#
# [1/7] Directory Structure
# ----------------------------------------------------------------------
#   GDrive (G:):       /content/drive_f/masterthesis OK
#   GDrive (F:):       /content/drive_f/masterthesis OK
#   Local data (G:):   /content/masterthesis_local/data OK
#   Data stack (F:):   /mnt/f/PROJECTS/masterthesis/data_stack OK
#
#   TIER_SELECTION: [0, 1, 2]
#   CITY_SELECTION: None (tier filter)
#   REQUIRE_UNOSAT: True
#   CITIES_TO_PROCESS: 21 cities
#
# [2/7] Credentials
# ----------------------------------------------------------------------
#   Copernicus: inf***
#   OpenTopography: OK
#   Earthdata: marcoheinzen
#
# [3/7] Python Packages
# ----------------------------------------------------------------------
# <string>:564: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   Already installed: 23
#   Newly installed:   0
#   Failed:            0
#
# [4/7] Global Imports & Configuration
# ----------------------------------------------------------------------
#   All imports loaded
#
# [5/7] Processing Config & SNAP
# ----------------------------------------------------------------------
#   GPT: Usage:
#   Temporal baseline: 10-24 days
#   Wavelength: 0.0555
#
# [6/7] GPU Status
# ----------------------------------------------------------------------
#   CUDA available: NVIDIA GeForce RTX 2070 SUPER
#     CUDA version: 12.8
#
# [7/7] Disk Space
# ----------------------------------------------------------------------
#   GDrive (G:)     909.8/7452.0 GB (6542.2 GB free)
#   GDrive (F:)     1389.6/3726.0 GB (2336.4 GB free)
#   Local data      11557.6/14901.9 GB (3344.3 GB free)
#   Data stack      1389.6/3726.0 GB (2336.4 GB free)
#   WSL ext4        68.6/1006.9 GB (887.1 GB free)
#
# ======================================================================
# GLOBAL SETUP COMPLETE
# ======================================================================
#   Torch device: cuda
#   Cities: 21, CITY=Avdiivka
#   Functions: load_aoi(), load_aoi_gdf(), load_aoi_bbox(), load_buildings()
#   Functions: set_city_paths(), resolve_cities(), load_tracker(), load_dietrich_tracker()
#   Completed: 2026-04-27 19:04:08
# ======================================================================

# %% [markdown]
# # CELL S0: MANIFEST + BUILDINGS + SHARED HELPERS
#
# Same pattern as NB09a v2 S0. Defines `load_v2()`, `drop_leakage()`,
# `aggregate_long_to_wide()`, `prepare_features()`, `evaluate_groupkfold()`.

# %%
# @title CELL S0: LOAD MANIFEST + BUILDINGS + SHARED HELPERS
import sys, importlib, re, gc, time
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import GroupKFold
from sklearn.metrics import (roc_auc_score, f1_score, precision_score,
                             recall_score)
from sklearn.base import clone
import warnings
warnings.filterwarnings("ignore")

print("=" * 70)
print("CELL S0: NB08c v4 - LOAD MANIFEST + BUILDINGS + SHARED HELPERS")
print("=" * 70)

if str(NOTEBOOKS_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOKS_DIR))

import metadata_filter
importlib.reload(metadata_filter)
from metadata_filter import (
    ID_COLS, LABEL_COLS, META_COLS_SET,
    is_metadata, is_non_feature,
    select_feature_columns, build_role_overrides,
)

# --- load v2 manifest -------------------------------------------------
# --- v1: V3 dataset path (DATASET_ROOT_V2 lives in global_setup.py for V2 builds;
# V3 path is set explicitly here so this notebook is self-contained for V3).
DATASET_ROOT_V4 = STACK_DIR / 'dataset' / 'v4'
MANIFEST_V4_PATH = DATASET_ROOT_V4 / 'parquet_manifest.json'
if not MANIFEST_V4_PATH.exists():
    raise FileNotFoundError(f"V4 manifest not found: {MANIFEST_V4_PATH}")
with open(MANIFEST_V4_PATH) as _f:
    MANIFEST = json.load(_f)
print(f"  Manifest: {MANIFEST_V4_PATH}")
print(f"  Version: {MANIFEST['version']}  Created: {MANIFEST['created']}")
print(f"  Parquets in manifest: {len(MANIFEST['parquets'])}")

# --- load building metadata (v2 path) --------------------------------
_tiers = TIER_SELECTION if isinstance(TIER_SELECTION, list) else [0, 1, 2]
_bldg_pattern = str(DATASET_ROOT_V4 / 'bda_points_t{tier}.parquet')
df_bldg = load_tier_parquets(_bldg_pattern, _tiers)
CITIES_TO_PROCESS, _battle_dates = resolve_cities(
    tier_selection=TIER_SELECTION,
    city_selection=[CITY_FILTER] if isinstance(CITY_FILTER, str) else CITY_FILTER,
    require_unosat=REQUIRE_UNOSAT,
)
df_bldg = df_bldg[df_bldg['city'].isin(CITIES_TO_PROCESS)].copy()
df_bldg = df_bldg[df_bldg['damage_binary'] >= 0].copy()
print(f"  Cities: {len(CITIES_TO_PROCESS)}")
print(f"  Buildings: {len(df_bldg)} (damaged={int((df_bldg['damage_binary']==1).sum())}, "
      f"undamaged={int((df_bldg['damage_binary']==0).sum())})")

TARGET_COL = 'damage_binary'
AUDIT_LOG = {}

# ---- NB12 overlap-analysis: canonical OOF predictions schema (V4: point_id sample unit, kernel-aggregated features) ----
import hashlib as _hashlib, datetime as _dt
EXPERIMENT_ID = _dt.datetime.now().strftime('%Y%m%d_%H%M%S') + '_' + _hashlib.md5(
    f'nb08c_{TIER_SELECTION}_{REQUIRE_UNOSAT}'.encode()).hexdigest()[:6]
print(f"  EXPERIMENT_ID: {EXPERIMENT_ID}")

def save_oof_from_result(res, model_id, oof_dir, variant_id='',
                         is_final=False, threshold=0.5):
    '''Canonical OOF schema: point_id, city, fold_id, y_true, y_proba, y_pred,
       cm_class, model_id, experiment_id, variant_id, is_final.'''
    if res is None:
        return None
    needed = ('y_true', 'y_proba', 'groups', 'point_id', 'fold_id')
    if not all(k in res for k in needed):
        print(f"    [save_oof] skipped {model_id}: missing keys (need {needed})")
        return None
    y_proba = np.asarray(res['y_proba'])
    yt = np.asarray(res['y_true']).astype(int)
    fold = np.asarray(res['fold_id']).astype(int)
    bid = np.asarray(res['point_id'])
    cty = np.asarray(res['groups'])
    yp = (y_proba >= threshold).astype(int)
    cm_class = np.where(yt == 1,
                        np.where(yp == 1, 'TP', 'FN'),
                        np.where(yp == 1, 'FP', 'TN'))
    oof_df = pd.DataFrame({
        'point_id':   bid,
        'city':          cty,
        'fold_id':       fold,
        'y_true':        yt,
        'y_proba':       y_proba.astype(float),
        'y_pred':        yp,
        'cm_class':      cm_class,
        'model_id':      model_id,
        'experiment_id': EXPERIMENT_ID,
        'variant_id':    variant_id,
        'is_final':      bool(is_final),
    })
    oof_dir = Path(oof_dir)
    oof_dir.mkdir(parents=True, exist_ok=True)
    out = oof_dir / f'oof_{model_id}__{EXPERIMENT_ID}.parquet'
    oof_df.to_parquet(out, index=False)
    n_tp = int((cm_class == 'TP').sum()); n_fn = int((cm_class == 'FN').sum())
    n_fp = int((cm_class == 'FP').sum()); n_tn = int((cm_class == 'TN').sum())
    print(f"    saved oof -> {out.name}  TP={n_tp} FN={n_fn} FP={n_fp} TN={n_tn}")
    return out

# --- leakage filter ---------------------------------------------------
LEAKAGE_EXCLUDE_PATTERNS = [
    r's1__coh__scenes_observed',
    r's1__vv__scenes_observed',
    r's2__scenes_observed',
    r's2__lu__scenes_observed',
    r's2__obs_count__',
    r's2__qa__cloud_freq__',
    r's2__visibility__cloud__freq',
    r'was_observed_',
]
# -- leaky filter (legacy NB08c behavior, keeps was_observed_ flags; used by C10 for delta comparison) --
LEAKAGE_LEAKY_PATTERNS = [
    r's1__coh__scenes_observed',
    r's1__vv__scenes_observed',
    r's2__scenes_observed',
    r's2__lu__scenes_observed',
    r's2__obs_count__',
    r's2__qa__cloud_freq__',
    r's2__visibility__cloud__freq',
]
_LEAKAGE_LEAKY_RE = [re.compile(p) for p in LEAKAGE_LEAKY_PATTERNS]

def drop_leakage_leaky(cols):
    '''LEGACY filter that keeps was_observed_* flags. For C10 delta only. Do not use elsewhere.'''
    return [c for c in cols if not any(rx.search(c) for rx in _LEAKAGE_LEAKY_RE)]
_LEAKAGE_RE = [re.compile(p) for p in LEAKAGE_EXCLUDE_PATTERNS]

def drop_leakage(cols):
    return [c for c in cols if not any(rx.search(c) for rx in _LEAKAGE_RE)]

def _has_count_stat(c):
    parts = c.split('__')
    if len(parts) < 4:
        return False
    return parts[3].split('_')[0] == 'count'

# --- v2 manifest-driven loader (copy of NB09a v2 signature) ----------
def load_v2(manifest_key, tiers=None, columns=None, sample_frac=None):
    '''Load a v2 parquet by manifest key, merge with buildings, return df.'''
    if manifest_key not in MANIFEST['parquets']:
        raise KeyError(f"Manifest key not found: {manifest_key}")
    info = MANIFEST['parquets'][manifest_key]
    fname_tmpl = Path(info['pattern']).name
    tiers = tiers if tiers is not None else _tiers

    frames = []
    for t in tiers:
        pf = DATASET_ROOT_V4 / fname_tmpl.format(tier=t)
        if not pf.exists():
            continue
        if columns is not None:
            join_cols = info.get('join_keys', ['city', 'point_id'])
            read_cols = list(dict.fromkeys(join_cols + list(columns)))
            try:
                df_t = pd.read_parquet(pf, columns=read_cols)
            except Exception:
                df_t = pd.read_parquet(pf)
                keep = [c for c in read_cols if c in df_t.columns]
                df_t = df_t[keep]
        else:
            df_t = pd.read_parquet(pf)
        if sample_frac is not None and 0 < sample_frac < 1:
            df_t = df_t.sample(frac=sample_frac, random_state=RANDOM_STATE)
        frames.append(df_t)
    if not frames:
        raise FileNotFoundError(f"No v2 parquets found for key={manifest_key} tiers={tiers}")
    df = pd.concat(frames, ignore_index=True)
    del frames

    df = df.loc[:, ~df.columns.duplicated()]
    df = df[df['city'].isin(CITIES_TO_PROCESS)].copy()
    if TARGET_COL not in df.columns:
        df = df.merge(df_bldg[['point_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['point_id', 'city'], how='inner')
    df = df[df[TARGET_COL] >= 0].copy()
    df = df.loc[:, ~df.columns.duplicated()]
    return df

# --- v8: direction-aware temporal aggregation (matched-filter principle) ---
# Damage at the temporal axis is a sparse-event spike. Per Kay 1998 (Detection
# Theory) and Glaz-Naus-Wallenstein 2001 (Scan Statistics), the rolling extremum
# is the Neyman-Pearson optimal detector for a 1-of-N spike on stationary noise.
# v7 universal mean+std attenuated the spike; v8 dispatches per modality direction.
# Reference: DECISION_Rolling_Block_Accumulators.md Sec 5; DECISION_NB05b_v29 Sec 1.

DIRECTION_BY_MODALITY = {
    # SAR drop signals (damage -> coherence loss, VV backscatter loss on rough->smooth or rubble)
    'coh_vv': 'drop', 'coh_vh': 'drop',
    'vv': 'drop',
    # SAR mixed-sign (volume scattering can go either direction with rubble)
    'vh': 'mixed',
    # MS visible bands -- no clean damage direction (illumination + atmosphere dominate)
    'b02': 'unknown', 'b03': 'unknown', 'b04': 'unknown',
    'b05': 'unknown', 'b07': 'unknown',
    # MS NIR -- vegetation loss after damage drives NIR drop
    'b08': 'drop', 'b8a': 'drop',
    # MS SWIR -- rubble / bare soil exposure drives SWIR rise (Aimaiti 2022)
    'b11': 'rise', 'b12': 'rise',
    # MS derived indices
    'nbr':   'mixed',  # burn / vegetation loss / rubble (sign depends on land cover)
    'ndvi':  'drop',   # vegetation loss
    'savi':  'drop',   # soil-adjusted vegetation
    'bsi':   'rise',   # bare-soil exposure rises with rubble
    'mndwi': 'mixed',  # water -- flood-rise vs drying-drop
    'ndbi':  'drop',   # built-up index drops with built-up loss
    'ndsi':  'mixed',  # snow seasonal noise, no damage direction
    'ibi':   'drop',   # built-up index variant
    'baei':  'drop',   # built-up area extraction index
    'ui':    'drop',   # urban index
}

# Manifest keys whose long parquets are already pixel-temporal-extremized in NB03e R2b.
# For these, mean+std-over-time preserves the per-rolling-window pattern; a second
# temporal extremum would collapse to the full-post-battle accumulators (A14/A19/A20/A21),
# making A23/A24/A25 redundant.
ACCUM_LONG_KEYS = {'rolling_accum_coh', 'rolling_accum_card', 'rolling_accum_ms'}

def _parse_modality_token(col):
    '''Return the modality token (second `__`-separated piece) of a feature column.
       Examples:
         s2__b02__mean              -> b02
         s1__coh_vv__zscore__mean   -> coh_vv
         s1__vv__roll7__min         -> vv
         s2__landuse__urban_frac    -> landuse  (returns 'landuse', falls into 'unknown')
       Returns None if the column has fewer than 2 `__`-separated pieces.'''
    parts = col.split('__')
    if len(parts) < 2:
        return None
    return parts[1].lower()

def _temporal_reductions_for_column(col):
    '''Return the list of pandas agg names to apply over the date axis for `col`,
       chosen by modality direction:
         drop    -> [min, mean, std]
         rise    -> [max, mean, std]
         mixed   -> [min, max, mean, std]
         unknown -> [mean, std]   (legacy v7 fallback for non-mappable columns)
       The `mean` and `std` slots are kept in every direction so v7 features are
       a strict subset of v8 features (additive change, no information lost).'''
    modality = _parse_modality_token(col)
    direction = DIRECTION_BY_MODALITY.get(modality, 'unknown')
    if direction == 'drop':
        return ['min', 'mean', 'std']
    if direction == 'rise':
        return ['max', 'mean', 'std']
    if direction == 'mixed':
        return ['min', 'max', 'mean', 'std']
    return ['mean', 'std']

# --- long-format aggregation (v8: direction-aware temporal collapse) ---------
def aggregate_long_to_wide(df, feat_cols, manifest_key=None):
    '''Collapse a long-format per-scene parquet to per-building summary.

    v8: direction-aware temporal aggregation per matched-filter principle.
    - manifest_key in ACCUM_LONG_KEYS  -> universal mean+std (already extremized in R2b)
    - otherwise                        -> per-column dispatch via _temporal_reductions_for_column

    Backward compatible call: `aggregate_long_to_wide(df, feat_cols)` (manifest_key=None)
    falls through to per-column dispatch with v7-equivalent fallback for unknown columns.
    '''
    feat_cols = [c for c in feat_cols if c in df.columns]
    if not feat_cols:
        return (df.groupby(['city', 'point_id'], sort=False, observed=True)
                  .size().reset_index()[['city', 'point_id']])

    if manifest_key in ACCUM_LONG_KEYS:
        agg_dict = {c: ['mean', 'std'] for c in feat_cols}
    else:
        agg_dict = {c: _temporal_reductions_for_column(c) for c in feat_cols}

    agg = df.groupby(['city', 'point_id'], sort=False, observed=True).agg(agg_dict)
    agg.columns = [f"{a}_{b}" for a, b in agg.columns]
    agg = agg.reset_index()
    return agg

# --- manifest-derived feature set for a given parquet ----------------
def get_parquet_features(manifest_key, df):
    '''Return the cleaned feature column list for a parquet: manifest features,
       intersected with df columns, minus leakage, minus count stats, minus all-NaN.

       Uses metadata_filter.select_feature_columns() so that id/label/metadata
       columns (including any was_observed_* flag, regardless of suffix) are
       excluded centrally rather than by a locally-maintained list.'''
    info = MANIFEST['parquets'][manifest_key]
    raw = [c for c in info.get('feature_columns', []) if c in df.columns]
    if not raw:
        # fallback: metadata_filter picks numeric features, excluding id/label/meta
        # and any was_observed_* via the centralized pattern rule.
        raw = select_feature_columns(df)
    else:
        # manifest-declared features: still scrub in case the manifest lists a
        # column that is actually metadata (defensive, typically a no-op).
        raw = [c for c in raw if not is_non_feature(c)]
    clean = drop_leakage(raw)
    clean = [c for c in clean if not _has_count_stat(c)]
    nan_rate = df[clean].isna().mean() if clean else pd.Series(dtype=float)
    clean = [c for c in clean if nan_rate.get(c, 1.0) < 1.0]
    return clean

# --- LightGBM feature prep (no imputation, native NaN) --------------
def prepare_features_mia(df, feat_cols):
    '''Return X (with NaN preserved), y, groups, building_ids, clean_cols.'''
    if not feat_cols:
        return None
    X = df[feat_cols].to_numpy(dtype=np.float32, copy=False)
    y = df[TARGET_COL].values
    groups = df['city'].values
    building_ids = df['point_id'].values
    return X, y, groups, building_ids, feat_cols

# --- single-protocol GroupKFold evaluator ---------------------------
def evaluate_audit(clf, X, y, groups, experiment_name, n_folds=N_FOLDS,
                   building_ids=None):
    n_cities = len(np.unique(groups))
    n_folds_actual = min(n_folds, n_cities)
    if n_folds_actual < 2:
        print(f"    SKIP {experiment_name}: only {n_cities} cities")
        return None
    gkf = GroupKFold(n_splits=n_folds_actual)
    y_proba_oof = np.full(len(y), np.nan)
    fold_id = np.full(len(y), -1, dtype=int)
    fold_aucs = []
    for fold_idx, (tr, te) in enumerate(gkf.split(X, y, groups)):
        clf_c = clone(clf)
        clf_c.fit(X[tr], y[tr])
        proba = clf_c.predict_proba(X[te])[:, 1]
        y_proba_oof[te] = proba
        fold_id[te] = fold_idx
        if len(np.unique(y[te])) > 1:
            fold_aucs.append(roc_auc_score(y[te], proba))
    valid = ~np.isnan(y_proba_oof)
    y_v, p_v = y[valid], y_proba_oof[valid]
    pred_v = (p_v >= 0.5).astype(int)
    bid_v = np.asarray(building_ids)[valid] if building_ids is not None else np.arange(len(y))[valid].astype(str)
    result = {
        'experiment': experiment_name,
        'auc_groupkfold': roc_auc_score(y_v, p_v),
        'f1_groupkfold': f1_score(y_v, pred_v),
        'precision': precision_score(y_v, pred_v, zero_division=0),
        'recall': recall_score(y_v, pred_v, zero_division=0),
        'fold_aucs': fold_aucs,
        'auc_mean': float(np.mean(fold_aucs)) if fold_aucs else float('nan'),
        'auc_std': float(np.std(fold_aucs)) if fold_aucs else float('nan'),
        'n_features': X.shape[1], 'n_buildings': int(valid.sum()),
        'n_cities': int(len(np.unique(groups))),
        'y_true': y_v, 'y_proba': p_v, 'groups': groups[valid],
        'point_id': bid_v, 'fold_id': fold_id[valid],
    }
    AUDIT_LOG[experiment_name] = result
    print(f"    {experiment_name:40s} AUC={result['auc_groupkfold']:.3f}  "
          f"F1={result['f1_groupkfold']:.3f}  n={result['n_buildings']:,}  "
          f"cities={result['n_cities']}  nfeat={result['n_features']}")
    return result

# --- output paths + registry ----------------------------------------
import matplotlib.pyplot as plt
from datetime import datetime as _dt

OUT_DIR = OUTPUTS_DIR / "NB08c_v4"
OUT_DIR.mkdir(parents=True, exist_ok=True)

def save_result(data, name, cell_id, fmt='csv'):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    if fmt == 'csv' and isinstance(data, pd.DataFrame):
        path = cell_dir / f"{name}_{ts}.csv"
        data.to_csv(path, index=False)
    elif fmt == 'json':
        path = cell_dir / f"{name}_{ts}.json"
        with open(path, 'w') as fh:
            json.dump(data, fh, indent=2, default=str)
    else:
        raise ValueError(f"Unknown fmt={fmt}")
    print(f"  Saved: {path.relative_to(OUT_DIR)} ({path.stat().st_size / 1024:.1f} KB)")
    return path

def save_fig(fig, name, cell_id, dpi=150):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    path = cell_dir / f"{name}_{ts}.png"
    fig.savefig(path, dpi=dpi, bbox_inches='tight', facecolor='white')
    plt.show()
    print(f"  Plot: {path.relative_to(OUT_DIR)}")
    return path

from bda_results import ResultRegistry
registry = ResultRegistry(RESULTS_ROOT, notebook='NB08c_v4')

def log_audit(res, cell_id, manifest_key, note=''):
    if res is None:
        return
    registry.log_experiment(
        cell_id=cell_id, experiment_name=res['experiment'],
        parquet_name=f'bda_{manifest_key}_v4', feature_set_name='manifest_default_minus_leakage',
        classifier_name='LightGBM-300-MIA', classifier_params=LGBM_PARAMS,
        feature_cols=[], cv_method='GroupKFold', n_folds=N_FOLDS,
        imputation='native_nan', y_true=res['y_true'], y_proba=res['y_proba'],
        groups=res['groups'], note=note, tags=['nb08c_audit'],
    )

print(f"  Helpers: load_v2(), get_parquet_features(), aggregate_long_to_wide(), evaluate_audit()")
print(f"  Output:  {OUT_DIR}")
print(f"  Registry: NB08c_v4")
# Out:
# ======================================================================
# CELL S0: NB08c v4 - LOAD MANIFEST + BUILDINGS + SHARED HELPERS
# ======================================================================
#   Manifest: /mnt/f/PROJECTS/masterthesis/data_stack/dataset/v4/parquet_manifest.json
#   Version: v3  Created: 2026-04-27T20:28:13.921770
#   Parquets in manifest: 36
#   load_tier_parquets: 3 tiers, 63243 rows
#   Cities: 21
#   Buildings: 63243 (damaged=8247, undamaged=54996)
#   EXPERIMENT_ID: 20260427_203607_115af1
#   ResultRegistry: /content/drive_f/masterthesis/results/registry (run_id=20260427_203607)
#   Helpers: load_v2(), get_parquet_features(), aggregate_long_to_wide(), evaluate_audit()
#   Output:  /content/drive_f/masterthesis/data/outputs/NB08c_v4
#   Registry: NB08c_v4

# %%
# @title CELL S0b: OOF PLOT + SUMMARY HELPERS
# TP=red, TN=green, FP=pink, FN=gold
import matplotlib.pyplot as plt

CM_COLORS = {'TP': '#d62728', 'TN': '#2ca02c', 'FP': '#ff9ecb', 'FN': '#ffd700'}
CM_LABELS = {'TP': 'Destroyed (TP)', 'TN': 'Not destroyed (TN)',
             'FP': 'False positive (FP)', 'FN': 'False negative (FN)'}

# alias df_bldg to df_buildings for plotting helper compatibility
df_buildings = df_bldg

def print_cm_summary(oof_path_or_df):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else '(unknown)'
    print(f"  model_id: {model_id}   n={len(oof)}")
    overall = oof['cm_class'].value_counts()
    for cls in ['TP', 'TN', 'FP', 'FN']:
        n = int(overall.get(cls, 0))
        pct = 100.0 * n / len(oof) if len(oof) else 0
        print(f"    {cls:3s} {CM_LABELS[cls]:28s}  n={n:6d}  ({pct:5.1f}%)")
    by_city = (oof.groupby('city')['cm_class']
                 .value_counts().unstack(fill_value=0))
    for cls in ['TP', 'TN', 'FP', 'FN']:
        if cls not in by_city.columns:
            by_city[cls] = 0
    by_city = by_city[['TP', 'TN', 'FP', 'FN']]
    by_city['recall']    = by_city['TP'] / (by_city['TP'] + by_city['FN']).replace(0, np.nan)
    by_city['precision'] = by_city['TP'] / (by_city['TP'] + by_city['FP']).replace(0, np.nan)
    print(f"\n  Per-city:")
    print(by_city.to_string(float_format=lambda x: f'{x:.3f}' if pd.notna(x) else '-'))
    return by_city

def plot_cm_spatial(oof_path_or_df, save_name=None, figsize=(14, 10),
                    buildings_df=None, point_size=4):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    bdf = buildings_df if buildings_df is not None else df_buildings
    if 'centroid_x' not in bdf.columns or 'centroid_y' not in bdf.columns:
        print("  plot_cm_spatial: no centroid_x/centroid_y in buildings_df")
        return None
    plot_df = oof.merge(bdf[['point_id', 'city', 'centroid_x', 'centroid_y']],
                        on=['point_id', 'city'], how='inner')
    if len(plot_df) == 0:
        print("  plot_cm_spatial: no building matches")
        return None
    cities = sorted(plot_df['city'].unique())
    ncols = min(3, len(cities))
    nrows = (len(cities) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, squeeze=False)
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else ''
    fig.suptitle(f'Confusion-matrix map: {model_id}', fontsize=11)
    draw_order = ['TN', 'FP', 'FN', 'TP']
    for i, city in enumerate(cities):
        ax = axes[i // ncols][i % ncols]
        cdf = plot_df[plot_df['city'] == city]
        for cls in draw_order:
            pts = cdf[cdf['cm_class'] == cls]
            if len(pts) == 0:
                continue
            ax.scatter(pts['centroid_x'], pts['centroid_y'],
                       c=CM_COLORS[cls], s=point_size, alpha=0.75,
                       edgecolors='none',
                       label=f"{CM_LABELS[cls]} (n={len(pts)})")
        ax.set_title(f"{city}  (n={len(cdf)})", fontsize=9)
        ax.set_aspect('equal')
        ax.legend(loc='best', fontsize=6, markerscale=2, framealpha=0.85)
        ax.tick_params(labelsize=7)
    for j in range(len(cities), nrows * ncols):
        axes[j // ncols][j % ncols].axis('off')
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    if save_name:
        fig.savefig(OUT_DIR / f'{save_name}.png', dpi=150, bbox_inches='tight')
        plt.close(fig)
    return fig

def plot_cm_oof_all(oof_dir, skip_variants=()):
    d = Path(oof_dir)
    files = sorted(d.glob('oof_*.parquet'))
    print(f"  Found {len(files)} OOF parquets in {d}")
    for p in files:
        oof = pd.read_parquet(p)
        v = oof['variant_id'].iloc[0] if 'variant_id' in oof.columns else ''
        if any(sv in v for sv in skip_variants):
            print(f"  skip {p.name}  (variant_id={v})")
            continue
        print(f"\n  {p.name}")
        print_cm_summary(oof)
        plot_cm_spatial(oof, save_name=p.stem)

# %% [markdown]
# # CELL H: CLASSIFIER (LightGBM native NaN)
#
# Single classifier for the entire audit sweep. LightGBM is chosen because it natively handles NaN
# (critical for parquets with structural missingness like A15 block_stats where only 6/21 cities have
# data). RF-200 from NB09a would require median imputation, which produces artifactual differences
# between parquets driven by imputation behaviour, not by the parquet itself.

# %%
# @title CELL H: CLASSIFIER (LightGBM native NaN)
try:
    from lightgbm import LGBMClassifier
except ImportError:
    raise ImportError("LightGBM required for NB08c single-protocol audit. pip install lightgbm")

LGBM_PARAMS = {
    'n_estimators': 150,
    'max_depth': 6,
    'learning_rate': 0.05,
    'num_leaves': 31,
    'min_child_samples': 20,
    'random_state': RANDOM_STATE,
    'n_jobs': -1,
    'verbose': -1,
    'is_unbalance': True,
    'force_col_wise': True,
}
LGBM = LGBMClassifier(**LGBM_PARAMS)

print(f"  Classifier: LightGBM n_estimators={LGBM_PARAMS['n_estimators']} "
      f"max_depth={LGBM_PARAMS['max_depth']} is_unbalance=True native_nan=MIA")
# Out:
#   Classifier: LightGBM n_estimators=150 max_depth=6 is_unbalance=True native_nan=MIA

# %% [markdown]
# # CELL AUDIT_RUN: parquet runner
#
# One function that handles both wide and long parquets. Called once per parquet by the C1-C7 cells.

# %%
# @title CELL AUDIT_RUN: parquet audit runner
def audit_parquet(manifest_key, cell_id, pq_id=None):
    '''Run the single audit protocol on one manifest parquet (v8: direction-aware temporal collapse).
    - load parquet
    - if long-format (date column present), aggregate to per-building mean+std
    - select manifest features, drop leakage + count stats + all-NaN
    - fit LightGBM with GroupKFold
    - log to AUDIT_LOG and registry
    Returns: result dict or None (skip).
    '''
    info = MANIFEST['parquets'].get(manifest_key)
    if info is None:
        print(f"\n  [{manifest_key}] SKIP: not in manifest")
        return None
    _pq_id = pq_id or info.get('id', '?')
    print(f"\n  --- [{_pq_id}] {manifest_key} ---")

    try:
        df = load_v2(manifest_key)
    except (FileNotFoundError, KeyError) as e:
        print(f"    SKIP load: {e}")
        return None
    if len(df) == 0:
        print(f"    SKIP: empty dataframe")
        del df; gc.collect()
        return None

    is_long = 'date' in df.columns
    n_rows_raw = len(df)
    n_cities_raw = df['city'].nunique()

    # manifest feature set, cleaned
    feat_cols = get_parquet_features(manifest_key, df)
    if is_long and feat_cols:
        print(f"    Long format: {n_rows_raw:,} rows, {n_cities_raw} cities -> aggregating per-building")
        df = aggregate_long_to_wide(df, feat_cols, manifest_key=manifest_key)
        # re-merge target after aggregation
        df = df.merge(df_bldg[['point_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['point_id', 'city'], how='inner')
        df = df[df[TARGET_COL] >= 0].copy()
        feat_cols = [c for c in df.columns
                     if c not in ('city', 'point_id', TARGET_COL)]
        feat_cols = drop_leakage(feat_cols)
        feat_cols = [c for c in feat_cols if not _has_count_stat(c)]
        nan_rate = df[feat_cols].isna().mean()
        feat_cols = [c for c in feat_cols if nan_rate[c] < 1.0]

    n_rows = len(df)
    n_cities = df['city'].nunique()
    print(f"    Wide: {n_rows:,} rows, {n_cities} cities, {len(feat_cols)} features")

    if len(feat_cols) < 2:
        print(f"    SKIP: {len(feat_cols)} feature columns after cleaning")
        del df; gc.collect()
        return None

    # overall NaN rate on the post-cleaning feature matrix
    overall_nan = float(df[feat_cols].isna().mean().mean())
    print(f"    Overall NaN rate: {overall_nan*100:.1f}%")

    prep = prepare_features_mia(df, feat_cols)
    if prep is None:
        del df; gc.collect()
        return None
    X, y, groups, building_ids, clean = prep

    exp_name = f"C_{_pq_id}_{manifest_key}"
    res = evaluate_audit(LGBM, X, y, groups, exp_name, building_ids=building_ids)
    if res is not None:
        res['manifest_key'] = manifest_key
        res['parquet_id'] = _pq_id
        res['format'] = 'long->wide' if is_long else 'wide'
        res['overall_nan_pct'] = overall_nan * 100
        res['n_rows_raw'] = n_rows_raw
        res['n_cities_raw'] = n_cities_raw
        log_audit(res, cell_id=cell_id, manifest_key=manifest_key,
                  note=f'{_pq_id} {manifest_key} audit sweep')

    del df, X, y, groups
    gc.collect()
    return res

# %%
print(df_bldg['damage_binary'].value_counts(dropna=False).to_dict())
print(df_bldg['point_source'].value_counts(dropna=False).to_dict() if 'point_source' in df_bldg.columns else 'no point_source col')
print(f"  positive rate: {df_bldg['damage_binary'].mean():.4f}")
# Out:
# {0: 54996, 1: 8247}
# {'building_centroid': 41235, 'unosat': 22008}
#   positive rate: 0.1304

# %% [markdown]
# # CELL C1: SCENE ATOMICS (A1, A2, A3, A4, A5, A6)
#
# Six long-format per-scene parquets. Each aggregated to per-building mean+std before
# classification. A4 scene_landuse is categorical; if `landuse_class` is the only
# feature column it will be skipped (needs one-hot before audit; deferred to Phase C
# landuse work).

# %%
# @title CELL C1: SCENE ATOMICS AUDIT
print("=" * 70)
print("CELL C1: SCENE ATOMICS (A1 A2 A3 A4 A5 A6)")
print("=" * 70)

C1_KEYS = [
    ('A1',  'scene_ms'),
    ('A2',  'scene_card'),
    ('A3',  'scene_coh'),
    ('A4',  'scene_landuse'),
    ('A5',  'scene_indices'),
    ('A6',  'scene_nbr'),
]

for pq_id, mkey in C1_KEYS:
    audit_parquet(mkey, cell_id='cell_c1', pq_id=pq_id)

c1_rows = [AUDIT_LOG[k] for k in AUDIT_LOG if k.startswith('C_A') and any(k.endswith(m) for _,m in C1_KEYS)]
print(f"\n  C1 completed: {len(c1_rows)} parquets")
# Out:
# ======================================================================
# CELL C1: SCENE ATOMICS (A1 A2 A3 A4 A5 A6)
# ======================================================================
#
#   --- [A1] scene_ms ---
#     Long format: 695,385 rows, 19 cities -> aggregating per-building
#     Wide: 62,043 rows, 19 cities, 224 features
#     Overall NaN rate: 10.9%
#     C_A1_scene_ms                            AUC=0.658  F1=0.292  n=62,043  cities=19  nfeat=224
#   REG: C_A1_scene_ms                                 AUC=0.6579 F1=0.2919 n=62043 feat=0 cities=19 [NB08c_v4/cell_c1]
#
#   --- [A2] scene_card ---
#     Long format: 834,134 rows, 21 cities -> aggregating per-building
#     Wide: 63,243 rows, 21 cities, 56 features
#     Overall NaN rate: 0.6%
#     C_A2_scene_card                          AUC=0.547  F1=0.216  n=63,243  cities=21  nfeat=56
#   REG: C_A2_scene_card                               AUC=0.5469 F1=0.2158 n=63243 feat=0 cities=21 [NB08c_v4/cell_c1]
#
#   --- [A3] scene_coh ---
#     Long format: 468,995 rows, 18 cities -> aggregating per-building
#     Wide: 60,769 rows, 18 cities, 72 features
#     Overall NaN rate: 21.8%
#     C_A3_scene_coh                           AUC=0.522  F1=0.193  n=60,769  cities=18  nfeat=72
#   REG: C_A3_scene_coh                                AUC=0.5222 F1=0.1929 n=60769 feat=0 cities=18 [NB08c_v4/cell_c1]
#
#   --- [A4] scene_landuse ---
#     Long format: 794,205 rows, 19 cities -> aggregating per-building
#     Wide: 62,043 rows, 19 cities, 2 features
#     Overall NaN rate: 0.0%
#     C_A4_scene_landuse                       AUC=0.583  F1=0.235  n=62,043  cities=19  nfeat=2
#   REG: C_A4_scene_landuse                            AUC=0.5831 F1=0.2355 n=62043 feat=0 cities=19 [NB08c_v4/cell_c1]
#
#   --- [A5] scene_indices ---
#     Long format: 794,205 rows, 19 cities -> aggregating per-building
#     Wide: 62,043 rows, 19 cities, 232 features
#     Overall NaN rate: 0.0%
#     C_A5_scene_indices                       AUC=0.645  F1=0.279  n=62,043  cities=19  nfeat=232
#   REG: C_A5_scene_indices                            AUC=0.6452 F1=0.2788 n=62043 feat=0 cities=19 [NB08c_v4/cell_c1]
#
#   --- [A6] scene_nbr ---
#     Long format: 794,205 rows, 19 cities -> aggregating per-building
#     Wide: 62,043 rows, 19 cities, 32 features
#     Overall NaN rate: 0.0%
#     C_A6_scene_nbr                           AUC=0.651  F1=0.289  n=62,043  cities=19  nfeat=32
#   REG: C_A6_scene_nbr                                AUC=0.6508 F1=0.2886 n=62043 feat=0 cities=19 [NB08c_v4/cell_c1]
#
#   C1 completed: 6 parquets

# %% [markdown]
# # CELL C2: ROLLING LONG-FORMAT (A7 rolling_coh, A8 rolling_card)

# %%
# @title CELL C2: ROLLING LONG AUDIT
print("=" * 70)
print("CELL C2: ROLLING LONG-FORMAT (A7 A8)")
print("=" * 70)

C2_KEYS = [
    ('A7', 'rolling_coh'),
    ('A8', 'rolling_card'),
]

for pq_id, mkey in C2_KEYS:
    audit_parquet(mkey, cell_id='cell_c2', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C2: ROLLING LONG-FORMAT (A7 A8)
# ======================================================================
#
#   --- [A7] rolling_coh ---
#     Long format: 350,960 rows, 16 cities -> aggregating per-building
#     Wide: 57,266 rows, 16 cities, 72 features
#     Overall NaN rate: 55.6%
#     C_A7_rolling_coh                         AUC=0.521  F1=0.193  n=57,266  cities=16  nfeat=72
#   REG: C_A7_rolling_coh                              AUC=0.5206 F1=0.1932 n=57266 feat=0 cities=16 [NB08c_v4/cell_c2]
#
#   --- [A8] rolling_card ---
#     Long format: 711,255 rows, 21 cities -> aggregating per-building
#     Wide: 63,243 rows, 21 cities, 168 features
#     Overall NaN rate: 18.2%
#     C_A8_rolling_card                        AUC=0.524  F1=0.185  n=63,243  cities=21  nfeat=168
#   REG: C_A8_rolling_card                             AUC=0.5239 F1=0.1852 n=63243 feat=0 cities=21 [NB08c_v4/cell_c2]

# %% [markdown]
# # CELL C3: COMPOSITE WIDE PRE/POST (A9, A10)
#
# A9 is the primary optical composite parquet. A10 landuse composite is a single
# categorical column; may skip if `landuse_*` not numeric.

# %%
# @title CELL C3: COMPOSITE WIDE AUDIT
print("=" * 70)
print("CELL C3: COMPOSITE WIDE PRE/POST (A9 A10)")
print("=" * 70)

C3_KEYS = [
    ('A9',  'composite_prepost_bands'),
    ('A10', 'composite_prepost_landuse'),
]

for pq_id, mkey in C3_KEYS:
    audit_parquet(mkey, cell_id='cell_c3', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C3: COMPOSITE WIDE PRE/POST (A9 A10)
# ======================================================================
#
#   --- [A9] composite_prepost_bands ---
#     Wide: 62,043 rows, 19 cities, 405 features
#     Overall NaN rate: 0.0%
#     C_A9_composite_prepost_bands             AUC=0.679  F1=0.323  n=62,043  cities=19  nfeat=405
#   REG: C_A9_composite_prepost_bands                  AUC=0.6792 F1=0.3234 n=62043 feat=0 cities=19 [NB08c_v4/cell_c3]
#
#   --- [A10] composite_prepost_landuse ---
#     Wide: 62,043 rows, 19 cities, 4 features
#     Overall NaN rate: 0.0%
#     C_A10_composite_prepost_landuse          AUC=0.593  F1=0.258  n=62,043  cities=19  nfeat=4
#   REG: C_A10_composite_prepost_landuse               AUC=0.5934 F1=0.2580 n=62043 feat=0 cities=19 [NB08c_v4/cell_c3]

# %% [markdown]
# # CELL C4: TRAJECTORY LONG-FORMAT (A11, A12)
#
# Composite-vs-scenes parquets. Per-scene deltas against the pre-battle composite.
# Aggregated to per-building mean+std (same protocol).

# %%
# @title CELL C4: TRAJECTORY LONG AUDIT
print("=" * 70)
print("CELL C4: TRAJECTORY LONG-FORMAT (A11 A12)")
print("=" * 70)

C4_KEYS = [
    ('A11', 'composite_vs_scenes_bands'),
    ('A12', 'composite_vs_scenes_landuse'),
]

for pq_id, mkey in C4_KEYS:
    audit_parquet(mkey, cell_id='cell_c4', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C4: TRAJECTORY LONG-FORMAT (A11 A12)
# ======================================================================
#
#   [composite_vs_scenes_bands] SKIP: not in manifest
#
#   --- [A12] composite_vs_scenes_landuse ---
#     Long format: 356,046 rows, 18 cities -> aggregating per-building
#     Wide: 61,863 rows, 18 cities, 6 features
#     Overall NaN rate: 0.4%
#     C_A12_composite_vs_scenes_landuse        AUC=0.597  F1=0.256  n=61,863  cities=18  nfeat=6
#   REG: C_A12_composite_vs_scenes_landuse             AUC=0.5972 F1=0.2561 n=61863 feat=0 cities=18 [NB08c_v4/cell_c4]

# %% [markdown]
# # CELL C5: PREPOST SINGLE CARD + COH DROP (A13, A14)

# %%
# @title CELL C5: PREPOST + ACCUMULATOR AUDIT
print("=" * 70)
print("CELL C5: PREPOST + ACCUMULATORS (A13 A14 A19 A20 A21 A22)")
print("=" * 70)

C5_KEYS = [
    ('A13', 'prepost_single_card'),
    ('A14', 'coh_drop'),
    ('A19', 'card_drop'),
    ('A20', 'ms_change'),
    ('A21', 'ms_maha'),
    ('A22', 'lu_change'),
]

for pq_id, mkey in C5_KEYS:
    audit_parquet(mkey, cell_id='cell_c5', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C5: PREPOST + ACCUMULATORS (A13 A14 A19 A20 A21 A22)
# ======================================================================
#
#   --- [A13] prepost_single_card ---
#     Wide: 63,243 rows, 21 cities, 48 features
#     Overall NaN rate: 0.0%
#     C_A13_prepost_single_card                AUC=0.532  F1=0.199  n=63,243  cities=21  nfeat=48
#   REG: C_A13_prepost_single_card                     AUC=0.5319 F1=0.1990 n=63243 feat=0 cities=21 [NB08c_v4/cell_c5]
#
#   --- [A14] coh_drop ---
#     Wide: 51,800 rows, 12 cities, 41 features
#     Overall NaN rate: 0.0%
#     C_A14_coh_drop                           AUC=0.515  F1=0.201  n=51,800  cities=12  nfeat=41
#   REG: C_A14_coh_drop                                AUC=0.5147 F1=0.2010 n=51800 feat=0 cities=12 [NB08c_v4/cell_c5]
#
#   --- [A19] card_drop ---
#     Wide: 62,043 rows, 19 cities, 41 features
#     Overall NaN rate: 0.0%
#     C_A19_card_drop                          AUC=0.505  F1=0.171  n=62,043  cities=19  nfeat=41
#   REG: C_A19_card_drop                               AUC=0.5052 F1=0.1714 n=62043 feat=0 cities=19 [NB08c_v4/cell_c5]
#
#   --- [A20] ms_change ---
#     Wide: 39,428 rows, 18 cities, 33 features
#     Overall NaN rate: 74.0%
#     C_A20_ms_change                          AUC=0.475  F1=0.145  n=39,428  cities=18  nfeat=33
#   REG: C_A20_ms_change                               AUC=0.4748 F1=0.1453 n=39428 feat=0 cities=18 [NB08c_v4/cell_c5]
#
#   --- [A21] ms_maha ---
#     Wide: 39,428 rows, 18 cities, 33 features
#     Overall NaN rate: 0.0%
#     C_A21_ms_maha                            AUC=0.527  F1=0.200  n=39,428  cities=18  nfeat=33
#   REG: C_A21_ms_maha                                 AUC=0.5270 F1=0.1996 n=39428 feat=0 cities=18 [NB08c_v4/cell_c5]
#
#   --- [A22] lu_change ---
#     Wide: 62,043 rows, 19 cities, 42 features
#     Overall NaN rate: 0.0%
#     C_A22_lu_change                          AUC=0.596  F1=0.260  n=62,043  cities=19  nfeat=42
#   REG: C_A22_lu_change                               AUC=0.5963 F1=0.2603 n=62043 feat=0 cities=19 [NB08c_v4/cell_c5]

# %% [markdown]
# # CELL C5b: ROLLING ACCUMULATORS LONG (A23, A24, A25) — v7 addition
#
# New v29 atomic parquets. Long format (per-date), one row per (city, building_id, date).
# Source TIFs: `data_stack/{city}/temporal/{COH,CARD,MS}/rolling_accum/`.
# Operators per pixel: running_min, running_max, max_abs_delta over rolling windows N=3,7,13.
# Each operator's pixel-level output then aggregated per building via `extract_zonal_aware`.
#
# Methodological note: A23/A24/A25 supersede A7/A8 for the same modality — A7/A8 (rolling MEANS) attenuate sparse damage signals, A23/A24/A25 (rolling EXTREMA + max_abs_delta) preserve them. A7/A8 retained as historical baselines for ablation.

# %%
# @title CELL C5b: ROLLING ACCUMULATORS LONG AUDIT
print("=" * 70)
print("CELL C5b: ROLLING ACCUMULATORS LONG (A23 A24 A25)")
print("=" * 70)

C5B_KEYS = [
    ('A23', 'rolling_accum_coh'),
    ('A24', 'rolling_accum_card'),
    ('A25', 'rolling_accum_ms'),
]

for pq_id, mkey in C5B_KEYS:
    audit_parquet(mkey, cell_id='cell_c5b', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C5b: ROLLING ACCUMULATORS LONG (A23 A24 A25)
# ======================================================================
#
#   --- [A23] rolling_accum_coh ---
#     Long format: 350,960 rows, 16 cities -> aggregating per-building
#     Wide: 57,266 rows, 16 cities, 144 features
#     Overall NaN rate: 58.3%
#     C_A23_rolling_accum_coh                  AUC=0.527  F1=0.196  n=57,266  cities=16  nfeat=144
#   REG: C_A23_rolling_accum_coh                       AUC=0.5274 F1=0.1963 n=57266 feat=0 cities=16 [NB08c_v4/cell_c5b]
#
#   --- [A24] rolling_accum_card ---
#     Long format: 707,648 rows, 21 cities -> aggregating per-building
#     Wide: 63,243 rows, 21 cities, 288 features
#     Overall NaN rate: 19.6%
#     C_A24_rolling_accum_card                 AUC=0.512  F1=0.160  n=63,243  cities=21  nfeat=288
#   REG: C_A24_rolling_accum_card                      AUC=0.5118 F1=0.1599 n=63243 feat=0 cities=21 [NB08c_v4/cell_c5b]
#
#   --- [A25] rolling_accum_ms ---
#     Long format: 670,119 rows, 19 cities -> aggregating per-building
#     Wide: 62,043 rows, 19 cities, 720 features
#     Overall NaN rate: 79.1%
#     C_A25_rolling_accum_ms                   AUC=0.538  F1=0.233  n=62,043  cities=19  nfeat=720
#   REG: C_A25_rolling_accum_ms                        AUC=0.5376 F1=0.2329 n=62043 feat=0 cities=19 [NB08c_v4/cell_c5b]

# %%
df_a20 = pd.read_parquet(DATASET_ROOT_V4 / 'bda_ms_change_t0.parquet')
print(df_a20.isna().mean().sort_values(ascending=False).head(15))
print()
# does NaN correlate with city?
per_city_nan = df_a20.groupby('city').apply(lambda d: d.isna().mean().mean())
print(per_city_nan.sort_values(ascending=False))
# Out:
# s2__swir_rise_count__mean             1.0
# s2__swir_rise_count__p10              1.0
# s2__swir_rise_count__p50              1.0
# s2__swir_rise_count__p90              1.0
# s2__swir_rise_count__std              1.0
# s2__swir_rise_count__min              1.0
# s2__swir_rise_count__max              1.0
# s2__swir_rise_count__max_abs_delta    1.0
# s2__nbr_anomaly_count__mean           1.0
# s2__nbr_anomaly_count__p10            1.0
# s2__nbr_anomaly_count__p50            1.0
# s2__nbr_anomaly_count__p90            1.0
# s2__nbr_anomaly_count__std            1.0
# s2__nbr_anomaly_count__min            1.0
# s2__nbr_anomaly_count__max            1.0
# dtype: float64
#
# city
# Lysychansk         0.966102
# Rubizhne           0.966102
# Sievierodonetsk    0.966102
# dtype: float64

# %% [markdown]
# # CELL C6: BLOCK STATS + ROLLING STATS WIDE (A15, A16, A17, A18)

# %%
# @title CELL C6: BLOCK + ROLLING STATS WIDE AUDIT
print("=" * 70)
print("CELL C6: BLOCK STATS + ROLLING STATS WIDE (A15 A16 A17 A18)")
print("=" * 70)

C6_KEYS = [
    ('A15', 'block_stats'),
    ('A16', 'rolling_stats_roll3'),
    ('A17', 'rolling_stats_roll7'),
    ('A18', 'rolling_stats_roll13'),
]

for pq_id, mkey in C6_KEYS:
    audit_parquet(mkey, cell_id='cell_c6', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C6: BLOCK STATS + ROLLING STATS WIDE (A15 A16 A17 A18)
# ======================================================================
#
#   --- [A15] block_stats ---
#     Wide: 63,243 rows, 21 cities, 2096 features
#     Overall NaN rate: 74.8%
#     C_A15_block_stats                        AUC=0.545  F1=0.173  n=63,243  cities=21  nfeat=2096
#   REG: C_A15_block_stats                             AUC=0.5453 F1=0.1729 n=63243 feat=0 cities=21 [NB08c_v4/cell_c6]
#
#   --- [A16] rolling_stats_roll3 ---
#     Wide: 63,243 rows, 21 cities, 248 features
#     Overall NaN rate: 30.1%
#     C_A16_rolling_stats_roll3                AUC=0.516  F1=0.175  n=63,243  cities=21  nfeat=248
#   REG: C_A16_rolling_stats_roll3                     AUC=0.5161 F1=0.1747 n=63243 feat=0 cities=21 [NB08c_v4/cell_c6]
#
#   --- [A17] rolling_stats_roll7 ---
#     Wide: 63,243 rows, 21 cities, 168 features
#     Overall NaN rate: 8.9%
#     C_A17_rolling_stats_roll7                AUC=0.513  F1=0.175  n=63,243  cities=21  nfeat=168
#   REG: C_A17_rolling_stats_roll7                     AUC=0.5133 F1=0.1749 n=63243 feat=0 cities=21 [NB08c_v4/cell_c6]
#
#   --- [A18] rolling_stats_roll13 ---
#     Wide: 63,243 rows, 21 cities, 152 features
#     Overall NaN rate: 0.0%
#     C_A18_rolling_stats_roll13               AUC=0.513  F1=0.179  n=63,243  cities=21  nfeat=152
#   REG: C_A18_rolling_stats_roll13                    AUC=0.5127 F1=0.1789 n=63243 feat=0 cities=21 [NB08c_v4/cell_c6]

# %% [markdown]
# # CELL C6b: BLOCK ACCUMULATORS WIDE (A26, A27, A28) — v7 addition
#
# New v29 atomic parquets. Wide format, one row per (city, building_id), columns per (block × op).
# Source TIFs: `data_stack/{city}/temporal/{COH,CARD,MS}/block_accum/`.
# Operators per 3-month block:
# - COH VV: `max_abs_delta`, `drop_count` (extrema already in P1c block_stats)
# - CARD VV: same as COH; CARD VH adds `rise_count`
# - MS B11/B12/B08/B8A/NBR: full op set `running_min`, `running_max`, `max_abs_delta`, `drop_count`, `rise_count` (P1c does not cover MS)
#
# Compares directly against A15 (block_stats Dietrich 7-stat) on the question: does the matched-filter operator outperform Dietrich's seven-stat block table at block scope?

# %%
# @title CELL C6b: BLOCK ACCUMULATORS WIDE AUDIT
print("=" * 70)
print("CELL C6b: BLOCK ACCUMULATORS WIDE (A26 A27 A28)")
print("=" * 70)

C6B_KEYS = [
    ('A26', 'block_accum_coh'),
    ('A27', 'block_accum_card'),
    ('A28', 'block_accum_ms'),
]

for pq_id, mkey in C6B_KEYS:
    audit_parquet(mkey, cell_id='cell_c6b', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C6b: BLOCK ACCUMULATORS WIDE (A26 A27 A28)
# ======================================================================
#
#   --- [A26] block_accum_coh ---
#     Wide: 60,076 rows, 17 cities, 144 features
#     Overall NaN rate: 75.6%
#     C_A26_block_accum_coh                    AUC=0.513  F1=0.187  n=60,076  cities=17  nfeat=144
#   REG: C_A26_block_accum_coh                         AUC=0.5129 F1=0.1867 n=60076 feat=0 cities=17 [NB08c_v4/cell_c6b]
#
#   --- [A27] block_accum_card ---
#     Wide: 63,243 rows, 21 cities, 656 features
#     Overall NaN rate: 83.0%
#     C_A27_block_accum_card                   AUC=0.490  F1=0.150  n=63,243  cities=21  nfeat=656
#   REG: C_A27_block_accum_card                        AUC=0.4898 F1=0.1497 n=63243 feat=0 cities=21 [NB08c_v4/cell_c6b]
#
#   --- [A28] block_accum_ms ---
#     Wide: 62,043 rows, 19 cities, 1708 features
#     Overall NaN rate: 56.1%
#     C_A28_block_accum_ms                     AUC=0.507  F1=0.175  n=62,043  cities=19  nfeat=1708
#   REG: C_A28_block_accum_ms                          AUC=0.5071 F1=0.1747 n=62043 feat=0 cities=19 [NB08c_v4/cell_c6b]

# %% [markdown]
# # CELL C7: FUSIONS (F1 F2 F3 F4 F5 F6 F7 F8)
#
# All 8 fusion parquets. F1-F6 are only scanned by NB06 today; this cell is their
# first contact with a GroupKFold-evaluated classifier.

# %%
# @title CELL C7: FUSIONS AUDIT
print("=" * 70)
print("CELL C7: FUSIONS (F1..F8)")
print("=" * 70)

C7_KEYS = [
    ('F1', 'fusion_ms_card'),
    ('F2', 'fusion_ms_card_cohdrop'),
    ('F3', 'fusion_card_cohdrop'),
    ('F4', 'fusion_ms_cohdrop'),
    ('F5', 'fusion_indices_card'),
    ('F6', 'fusion_indices_card_cohdrop'),
    ('F7', 'fusion_composite_cohdrop'),
    ('F8', 'fusion_composite_blockstats'),
]

for pq_id, mkey in C7_KEYS:
    audit_parquet(mkey, cell_id='cell_c7', pq_id=pq_id)
# Out:
# ======================================================================
# CELL C7: FUSIONS (F1..F8)
# ======================================================================
#
#   --- [F1] fusion_ms_card ---
#     Long format: 1,493,681 rows, 19 cities -> aggregating per-building
#     Wide: 62,043 rows, 19 cities, 280 features
#     Overall NaN rate: 8.8%
#     C_F1_fusion_ms_card                      AUC=0.653  F1=0.286  n=62,043  cities=19  nfeat=280
#   REG: C_F1_fusion_ms_card                           AUC=0.6528 F1=0.2864 n=62043 feat=0 cities=19 [NB08c_v4/cell_c7]
#
#   --- [F2] fusion_ms_card_cohdrop ---
#     Long format: 1,195,249 rows, 11 cities -> aggregating per-building
#     Wide: 51,293 rows, 11 cities, 362 features
#     Overall NaN rate: 6.9%
#     C_F2_fusion_ms_card_cohdrop              AUC=0.670  F1=0.310  n=51,293  cities=11  nfeat=362
#   REG: C_F2_fusion_ms_card_cohdrop                   AUC=0.6699 F1=0.3096 n=51293 feat=0 cities=11 [NB08c_v4/cell_c7]
#
#   --- [F3] fusion_card_cohdrop ---
#     Long format: 658,108 rows, 12 cities -> aggregating per-building
#     Wide: 51,800 rows, 12 cities, 138 features
#     Overall NaN rate: 0.3%
#     C_F3_fusion_card_cohdrop                 AUC=0.558  F1=0.230  n=51,800  cities=12  nfeat=138
#   REG: C_F3_fusion_card_cohdrop                      AUC=0.5579 F1=0.2300 n=51800 feat=0 cities=12 [NB08c_v4/cell_c7]
#
#   --- [F4] fusion_ms_cohdrop ---
#     Long format: 569,716 rows, 11 cities -> aggregating per-building
#     Wide: 51,293 rows, 11 cities, 306 features
#     Overall NaN rate: 8.0%
#     C_F4_fusion_ms_cohdrop                   AUC=0.673  F1=0.307  n=51,293  cities=11  nfeat=306
#   REG: C_F4_fusion_ms_cohdrop                        AUC=0.6731 F1=0.3069 n=51293 feat=0 cities=11 [NB08c_v4/cell_c7]
#
#   --- [F5] fusion_indices_card ---
#     Long format: 1,592,501 rows, 19 cities -> aggregating per-building
#     Wide: 62,043 rows, 19 cities, 288 features
#     Overall NaN rate: 0.1%
#     C_F5_fusion_indices_card                 AUC=0.655  F1=0.292  n=62,043  cities=19  nfeat=288
#   REG: C_F5_fusion_indices_card                      AUC=0.6551 F1=0.2917 n=62043 feat=0 cities=19 [NB08c_v4/cell_c7]
#
#   --- [F6] fusion_indices_card_cohdrop ---
#     Long format: 1,269,080 rows, 11 cities -> aggregating per-building
#     Wide: 51,293 rows, 11 cities, 370 features
#     Overall NaN rate: 0.1%
#     C_F6_fusion_indices_card_cohdrop         AUC=0.652  F1=0.293  n=51,293  cities=11  nfeat=370
#   REG: C_F6_fusion_indices_card_cohdrop              AUC=0.6524 F1=0.2928 n=51293 feat=0 cities=11 [NB08c_v4/cell_c7]
#
#   --- [F7] fusion_composite_cohdrop ---
#     Wide: 51,293 rows, 11 cities, 446 features
#     Overall NaN rate: 0.0%
#     C_F7_fusion_composite_cohdrop            AUC=0.661  F1=0.311  n=51,293  cities=11  nfeat=446
#   REG: C_F7_fusion_composite_cohdrop                 AUC=0.6612 F1=0.3111 n=51293 feat=0 cities=11 [NB08c_v4/cell_c7]
#
#   --- [F8] fusion_composite_blockstats ---
#     Wide: 62,043 rows, 19 cities, 2501 features
#     Overall NaN rate: 63.3%
#     C_F8_fusion_composite_blockstats         AUC=0.677  F1=0.311  n=62,043  cities=19  nfeat=2501
#   REG: C_F8_fusion_composite_blockstats              AUC=0.6769 F1=0.3107 n=62043 feat=0 cities=19 [NB08c_v4/cell_c7]

# %% [markdown]
# # CELL C8: RANKING TABLE + DIAGNOSTIC FLAGS
#
# Produces `parquet_ranking.csv` and assigns one of the following flags to every parquet:
#
# - **OK**: AUC >= 0.60 and n_features > 0 and n_cities >= 10
# - **WEAK**: 0.55 <= AUC < 0.60
# - **BROKEN**: AUC < 0.55 with n_features > 0. Candidate for NB03e / NB05a rebuild.
# - **EMPTY**: overall NaN > 90% OR n_features == 0. NB05a build issue.
# - **STALE**: n_cities < 10 (likely missing per-tier build). NB05a coverage issue.
# - **LEAKAGE_DOMINATED**: placeholder; set during Phase B (NB09a R9) comparing clean vs leaky F7.

# %%
# @title CELL C8: RANKING + DIAGNOSTIC FLAGS
import matplotlib.pyplot as plt

print("=" * 70)
print("CELL C8: RANKING TABLE + DIAGNOSTIC FLAGS")
print("=" * 70)

if not AUDIT_LOG:
    print("  SKIP: AUDIT_LOG is empty. Run C1..C7 first.")
else:
    rows = []
    for exp_name, res in AUDIT_LOG.items():
        auc = res.get('auc_groupkfold', float('nan'))
        nfeat = res.get('n_features', 0)
        ncity = res.get('n_cities', 0)
        nan_pct = res.get('overall_nan_pct', float('nan'))

        # diagnostic flag
        if nfeat == 0 or (isinstance(nan_pct, float) and nan_pct > 90):
            flag = 'EMPTY'
        elif ncity < 10:
            flag = 'STALE'
        elif auc < 0.55:
            flag = 'BROKEN'
        elif auc < 0.60:
            flag = 'WEAK'
        else:
            flag = 'OK'

        rows.append({
            'parquet_id': res.get('parquet_id', '?'),
            'manifest_key': res.get('manifest_key', ''),
            'format': res.get('format', ''),
            'auc': auc,
            'auc_mean_fold': res.get('auc_mean', float('nan')),
            'auc_std_fold': res.get('auc_std', float('nan')),
            'f1': res.get('f1_groupkfold', float('nan')),
            'precision': res.get('precision', float('nan')),
            'recall': res.get('recall', float('nan')),
            'n_features': nfeat,
            'n_buildings': res.get('n_buildings', 0),
            'n_cities': ncity,
            'n_rows_raw': res.get('n_rows_raw', 0),
            'n_cities_raw': res.get('n_cities_raw', 0),
            'overall_nan_pct': nan_pct,
            'flag': flag,
        })

    rank_df = pd.DataFrame(rows).sort_values('auc', ascending=False).reset_index(drop=True)

    print(f"\n  {'Rank':>4s}  {'ID':<4s} {'Parquet':<35s} {'Format':<10s} "
          f"{'AUC':>6s} {'F1':>6s} {'nFeat':>6s} {'nCity':>5s} {'NaN%':>6s}  {'Flag'}")
    print("  " + "-" * 100)
    for idx, r in rank_df.iterrows():
        nan_s = f"{r['overall_nan_pct']:5.1f}" if pd.notna(r['overall_nan_pct']) else '  nan'
        print(f"  {idx+1:>4d}  {r['parquet_id']:<4s} {r['manifest_key']:<35s} "
              f"{r['format']:<10s} {r['auc']:6.3f} {r['f1']:6.3f} "
              f"{int(r['n_features']):>6d} {int(r['n_cities']):>5d} {nan_s}  {r['flag']}")

    # save master ranking
    save_result(rank_df, 'parquet_ranking', 'cell_c8')

    # diagnostic breakdown
    print(f"\n  Flag counts:")
    for flag, n in rank_df['flag'].value_counts().items():
        print(f"    {flag:<20s} {n}")

    # rebuild candidates
    broken = rank_df[rank_df['flag'] == 'BROKEN']
    empty = rank_df[rank_df['flag'] == 'EMPTY']
    stale = rank_df[rank_df['flag'] == 'STALE']

    print(f"\n  NB03e / NB05a rebuild candidates:")
    if len(broken):
        print(f"    BROKEN (AUC<0.55 despite having features - suspect aggregation / composite window):")
        for _, r in broken.iterrows():
            print(f"      [{r['parquet_id']}] {r['manifest_key']}  AUC={r['auc']:.3f}  NaN={r['overall_nan_pct']:.1f}%")
    if len(empty):
        print(f"    EMPTY (no usable features - NB05a build issue):")
        for _, r in empty.iterrows():
            print(f"      [{r['parquet_id']}] {r['manifest_key']}  nfeat={int(r['n_features'])}  NaN={r['overall_nan_pct']:.1f}%")
    if len(stale):
        print(f"    STALE (fewer than 10 cities - missing per-tier build):")
        for _, r in stale.iterrows():
            print(f"      [{r['parquet_id']}] {r['manifest_key']}  nCity={int(r['n_cities'])}/{int(r['n_cities_raw'])}")

    # ranking bar plot
    fig, ax = plt.subplots(figsize=(10, max(6, len(rank_df) * 0.32)))
    colors = {'OK': '#2ca02c', 'WEAK': '#ff7f0e', 'BROKEN': '#d62728',
              'EMPTY': '#7f7f7f', 'STALE': '#9467bd'}
    bar_labels = [f"[{r['parquet_id']}] {r['manifest_key']}" for _, r in rank_df.iterrows()]
    bar_colors = [colors.get(r['flag'], '#1f77b4') for _, r in rank_df.iterrows()]
    ax.barh(range(len(rank_df)), rank_df['auc'].values, color=bar_colors, edgecolor='black')
    ax.set_yticks(range(len(rank_df)))
    ax.set_yticklabels(bar_labels, fontsize=9)
    ax.invert_yaxis()
    ax.axvline(0.5, color='black', linestyle=':', linewidth=1, label='random')
    ax.axvline(0.813, color='red', linestyle='--', linewidth=1.5, label='Dietrich 0.813')
    ax.set_xlabel('AUC (GroupKFold, LightGBM-300-MIA)')
    ax.set_xlim(0.4, 1.0)
    ax.set_title(f'NB08c v2: Full Manifest Audit ({len(rank_df)} parquets, uniform protocol)')
    ax.legend(loc='lower right')
    # legend for flags
    from matplotlib.patches import Patch
    flag_handles = [Patch(facecolor=col, edgecolor='black', label=flg) for flg, col in colors.items()
                    if flg in rank_df['flag'].values]
    ax2 = ax.twinx()
    ax2.set_yticks([])
    ax2.legend(handles=flag_handles, loc='lower left', title='flag')
    save_fig(fig, 'parquet_ranking', 'cell_c8')
# Out:
# ======================================================================
# CELL C8: RANKING TABLE + DIAGNOSTIC FLAGS
# ======================================================================
#
#   Rank  ID   Parquet                             Format        AUC     F1  nFeat nCity   NaN%  Flag
#   ----------------------------------------------------------------------------------------------------
#      1  A9   composite_prepost_bands             wide        0.679  0.323    405    19   0.0  OK
#      2  F8   fusion_composite_blockstats         wide        0.677  0.311   2501    19  63.3  OK
#      3  F4   fusion_ms_cohdrop                   long->wide  0.673  0.307    306    11   8.0  OK
#      4  F2   fusion_ms_card_cohdrop              long->wide  0.670  0.310    362    11   6.9  OK
#      5  F7   fusion_composite_cohdrop            wide        0.661  0.311    446    11   0.0  OK
#      6  A1   scene_ms                            long->wide  0.658  0.292    224    19  10.9  OK
#      7  F5   fusion_indices_card                 long->wide  0.655  0.292    288    19   0.1  OK
#      8  F1   fusion_ms_card                      long->wide  0.653  0.286    280    19   8.8  OK
#      9  F6   fusion_indices_card_cohdrop         long->wide  0.652  0.293    370    11   0.1  OK
#     10  A6   scene_nbr                           long->wide  0.651  0.289     32    19   0.0  OK
#     11  A5   scene_indices                       long->wide  0.645  0.279    232    19   0.0  OK
#     12  A12  composite_vs_scenes_landuse         long->wide  0.597  0.256      6    18   0.4  WEAK
#     13  A22  lu_change                           wide        0.596  0.260     42    19   0.0  WEAK
#     14  A10  composite_prepost_landuse           wide        0.593  0.258      4    19   0.0  WEAK
#     15  A4   scene_landuse                       long->wide  0.583  0.235      2    19   0.0  WEAK
#     16  F3   fusion_card_cohdrop                 long->wide  0.558  0.230    138    12   0.3  WEAK
#     17  A2   scene_card                          long->wide  0.547  0.216     56    21   0.6  BROKEN
#     18  A15  block_stats                         wide        0.545  0.173   2096    21  74.8  BROKEN
#     19  A25  rolling_accum_ms                    long->wide  0.538  0.233    720    19  79.1  BROKEN
#     20  A13  prepost_single_card                 wide        0.532  0.199     48    21   0.0  BROKEN
#     21  A23  rolling_accum_coh                   long->wide  0.527  0.196    144    16  58.3  BROKEN
#     22  A21  ms_maha                             wide        0.527  0.200     33    18   0.0  BROKEN
#     23  A8   rolling_card                        long->wide  0.524  0.185    168    21  18.2  BROKEN
#     24  A3   scene_coh                           long->wide  0.522  0.193     72    18  21.8  BROKEN
#     25  A7   rolling_coh                         long->wide  0.521  0.193     72    16  55.6  BROKEN
#     26  A16  rolling_stats_roll3                 wide        0.516  0.175    248    21  30.1  BROKEN
#     27  A14  coh_drop                            wide        0.515  0.201     41    12   0.0  BROKEN
#     28  A17  rolling_stats_roll7                 wide        0.513  0.175    168    21   8.9  BROKEN
#     29  A26  block_accum_coh                     wide        0.513  0.187    144    17  75.6  BROKEN
#     30  A18  rolling_stats_roll13                wide        0.513  0.179    152    21   0.0  BROKEN
#     31  A24  rolling_accum_card                  long->wide  0.512  0.160    288    21  19.6  BROKEN
#     32  A28  block_accum_ms                      wide        0.507  0.175   1708    19  56.1  BROKEN
#     33  A19  card_drop                           wide        0.505  0.171     41    19   0.0  BROKEN
#     34  A27  block_accum_card                    wide        0.490  0.150    656    21  83.0  BROKEN
#     35  A20  ms_change                           wide        0.475  0.145     33    18  74.0  BROKEN
#   Saved: cell_c8/parquet_ranking_20260427_204551.csv (6.5 KB)
#
#   Flag counts:
#     BROKEN               19
#     OK                   11
#     WEAK                 5
#
#   NB03e / NB05a rebuild candidates:
#     BROKEN (AUC<0.55 despite having features - suspect aggregation / composite window):
#       [A2] scene_card  AUC=0.547  NaN=0.6%
#       [A15] block_stats  AUC=0.545  NaN=74.8%
#       [A25] rolling_accum_ms  AUC=0.538  NaN=79.1%
#       [A13] prepost_single_card  AUC=0.532  NaN=0.0%
#       [A23] rolling_accum_coh  AUC=0.527  NaN=58.3%
#       [A21] ms_maha  AUC=0.527  NaN=0.0%
#       [A8] rolling_card  AUC=0.524  NaN=18.2%
#       [A3] scene_coh  AUC=0.522  NaN=21.8%
#       [A7] rolling_coh  AUC=0.521  NaN=55.6%
#       [A16] rolling_stats_roll3  AUC=0.516  NaN=30.1%
#       [A14] coh_drop  AUC=0.515  NaN=0.0%
#       [A17] rolling_stats_roll7  AUC=0.513  NaN=8.9%
#       [A26] block_accum_coh  AUC=0.513  NaN=75.6%
#       [A18] rolling_stats_roll13  AUC=0.513  NaN=0.0%
#       [A24] rolling_accum_card  AUC=0.512  NaN=19.6%
#       [A28] block_accum_ms  AUC=0.507  NaN=56.1%
#       [A19] card_drop  AUC=0.505  NaN=0.0%
#       [A27] block_accum_card  AUC=0.490  NaN=83.0%
#       [A20] ms_change  AUC=0.475  NaN=74.0%
#   Plot: cell_c8/parquet_ranking_20260427_204551.png

# %% [markdown]
# # CELL C9: SAVE AUDIT LOG + REGISTRY FLUSH
#
# Persist AUDIT_LOG to JSON for NB13 aggregation.

# %%
# @title CELL C9: SAVE AUDIT LOG + REGISTRY
print("=" * 70)
print("CELL C9: SAVE AUDIT LOG + REGISTRY FLUSH")
print("=" * 70)

if AUDIT_LOG:
    audit_summary = {}
    for name, res in AUDIT_LOG.items():
        summary = {k: v for k, v in res.items()
                   if k not in ('y_true', 'y_proba', 'groups', 'fold_aucs')}
        if 'fold_aucs' in res:
            summary['fold_aucs'] = [float(x) for x in res['fold_aucs']]
        audit_summary[name] = summary
    save_result(audit_summary, 'audit_log', 'cell_c9', fmt='json')

# OOF parquets per parquet key (for NB11 stacking + NB12 overlap analysis)
OOF_DIR = OUT_DIR / 'oof_predictions'
OOF_DIR.mkdir(parents=True, exist_ok=True)
oof_count = 0
for name, res in AUDIT_LOG.items():
    if 'y_true' in res and 'y_proba' in res and len(res['y_true']) > 0:
        out = save_oof_from_result(res, model_id=name, oof_dir=OOF_DIR,
                                    variant_id=f'audit_sweep;parquet={res.get("manifest_key", "?")}')
        if out is not None:
            oof_count += 1
print(f"  Saved: {oof_count} OOF prediction parquets -> {OOF_DIR}")

# OOF inventory (for NB12a discovery)
oof_files = sorted(OOF_DIR.glob('oof_*.parquet'))
if oof_files:
    inv_rows = []
    for p in oof_files:
        head = pd.read_parquet(p, columns=['model_id', 'variant_id', 'cm_class'])
        cm = head['cm_class'].value_counts()
        inv_rows.append({
            'file':       p.name,
            'model_id':   head['model_id'].iloc[0],
            'variant_id': head['variant_id'].iloc[0],
            'n_rows':     len(head),
            'TP':         int(cm.get('TP', 0)),
            'FN':         int(cm.get('FN', 0)),
            'FP':         int(cm.get('FP', 0)),
            'TN':         int(cm.get('TN', 0)),
        })
    inv_df = pd.DataFrame(inv_rows)
    save_result(inv_df, 'nb08c_oof_inventory', 'cell_c9')
    print(f"  OOF inventory:\n{inv_df.to_string(index=False)}")

try:
    registry.save()
    print(f"  Registry flushed: {len(AUDIT_LOG)} experiments logged under NB08c_v3")
except Exception as e:
    print(f"  registry.save() error: {e}")

print(f"\n  NB08c complete. Outputs in: {OUT_DIR}")
# Out:
# ======================================================================
# CELL C9: SAVE AUDIT LOG + REGISTRY FLUSH
# ======================================================================
#   Saved: cell_c9/audit_log_20260427_204552.json (32.0 KB)
#     saved oof -> oof_C_A1_scene_ms__20260427_203607_115af1.parquet  TP=3749 FN=4331 FP=13856 TN=40107
#     saved oof -> oof_C_A2_scene_card__20260427_203607_115af1.parquet  TP=2828 FN=5419 FP=15132 TN=39864
#     saved oof -> oof_C_A3_scene_coh__20260427_203607_115af1.parquet  TP=2330 FN=5576 FP=13920 TN=38943
#     saved oof -> oof_C_A4_scene_landuse__20260427_203607_115af1.parquet  TP=3691 FN=4389 FP=19578 TN=34385
#     saved oof -> oof_C_A5_scene_indices__20260427_203607_115af1.parquet  TP=3244 FN=4836 FP=11950 TN=42013
#     saved oof -> oof_C_A6_scene_nbr__20260427_203607_115af1.parquet  TP=4526 FN=3554 FP=18759 TN=35204
#     saved oof -> oof_C_A7_rolling_coh__20260427_203607_115af1.parquet  TP=2466 FN=4983 FP=15609 TN=34208
#     saved oof -> oof_C_A8_rolling_card__20260427_203607_115af1.parquet  TP=1928 FN=6319 FP=10649 TN=44347
#     saved oof -> oof_C_A9_composite_prepost_bands__20260427_203607_115af1.parquet  TP=3757 FN=4323 FP=11397 TN=42566
#     saved oof -> oof_C_A10_composite_prepost_landuse__20260427_203607_115af1.parquet  TP=4450 FN=3630 FP=21968 TN=31995
#     saved oof -> oof_C_A12_composite_vs_scenes_landuse__20260427_203607_115af1.parquet  TP=3181 FN=4874 FP=13605 TN=40203
#     saved oof -> oof_C_A13_prepost_single_card__20260427_203607_115af1.parquet  TP=2573 FN=5674 FP=15045 TN=39951
#     saved oof -> oof_C_A14_coh_drop__20260427_203607_115af1.parquet  TP=2639 FN=4296 FP=16688 TN=28177
#     saved oof -> oof_C_A19_card_drop__20260427_203607_115af1.parquet  TP=2248 FN=5832 FP=15904 TN=38059
#     saved oof -> oof_C_A20_ms_change__20260427_203607_115af1.parquet  TP=1031 FN=3738 FP=8389 TN=26270
#     saved oof -> oof_C_A21_ms_maha__20260427_203607_115af1.parquet  TP=1739 FN=3030 FP=10918 TN=23741
#     saved oof -> oof_C_A22_lu_change__20260427_203607_115af1.parquet  TP=2928 FN=5152 FP=11490 TN=42473
#     saved oof -> oof_C_A23_rolling_accum_coh__20260427_203607_115af1.parquet  TP=2402 FN=5047 FP=14625 TN=35192
#     saved oof -> oof_C_A24_rolling_accum_card__20260427_203607_115af1.parquet  TP=1507 FN=6740 FP=9093 TN=45903
#     saved oof -> oof_C_A25_rolling_accum_ms__20260427_203607_115af1.parquet  TP=5717 FN=2363 FP=35294 TN=18669
#     saved oof -> oof_C_A15_block_stats__20260427_203607_115af1.parquet  TP=1688 FN=6559 FP=9594 TN=45402
#     saved oof -> oof_C_A16_rolling_stats_roll3__20260427_203607_115af1.parquet  TP=1921 FN=6326 FP=11826 TN=43170
#     saved oof -> oof_C_A17_rolling_stats_roll7__20260427_203607_115af1.parquet  TP=1912 FN=6335 FP=11703 TN=43293
#     saved oof -> oof_C_A18_rolling_stats_roll13__20260427_203607_115af1.parquet  TP=1980 FN=6267 FP=11913 TN=43083
#     saved oof -> oof_C_A26_block_accum_coh__20260427_203607_115af1.parquet  TP=2649 FN=5158 FP=17925 TN=34344
#     saved oof -> oof_C_A27_block_accum_card__20260427_203607_115af1.parquet  TP=1708 FN=6539 FP=12862 TN=42134
#     saved oof -> oof_C_A28_block_accum_ms__20260427_203607_115af1.parquet  TP=2393 FN=5687 FP=16923 TN=37040
#     saved oof -> oof_C_F1_fusion_ms_card__20260427_203607_115af1.parquet  TP=3570 FN=4510 FP=13278 TN=40685
#     saved oof -> oof_C_F2_fusion_ms_card_cohdrop__20260427_203607_115af1.parquet  TP=3466 FN=3401 FP=12054 TN=32372
#     saved oof -> oof_C_F3_fusion_card_cohdrop__20260427_203607_115af1.parquet  TP=2588 FN=4347 FP=12984 TN=31881
#     saved oof -> oof_C_F4_fusion_ms_cohdrop__20260427_203607_115af1.parquet  TP=3035 FN=3832 FP=9875 TN=34551
#     saved oof -> oof_C_F5_fusion_indices_card__20260427_203607_115af1.parquet  TP=3382 FN=4698 FP=11727 TN=42236
#     saved oof -> oof_C_F6_fusion_indices_card_cohdrop__20260427_203607_115af1.parquet  TP=3403 FN=3464 FP=12974 TN=31452
#     saved oof -> oof_C_F7_fusion_composite_cohdrop__20260427_203607_115af1.parquet  TP=2996 FN=3871 FP=9397 TN=35029
#     saved oof -> oof_C_F8_fusion_composite_blockstats__20260427_203607_115af1.parquet  TP=3108 FN=4972 FP=8820 TN=45143
#   Saved: 35 OOF prediction parquets -> /content/drive_f/masterthesis/data/outputs/NB08c_v4/oof_predictions
#   Saved: cell_c9/nb08c_oof_inventory_20260427_204555.csv (5.0 KB)
#   OOF inventory:
#                                                                  file                          model_id                                      variant_id  n_rows   TP   FN    FP    TN
#   oof_C_A10_composite_prepost_landuse__20260427_203607_115af1.parquet   C_A10_composite_prepost_landuse   audit_sweep;parquet=composite_prepost_landuse   62043 4450 3630 21968 31995
# oof_C_A12_composite_vs_scenes_landuse__20260427_203607_115af1.parquet C_A12_composite_vs_scenes_landuse audit_sweep;parquet=composite_vs_scenes_landuse   61863 3181 4874 13605 40203
#         oof_C_A13_prepost_single_card__20260427_203607_115af1.parquet         C_A13_prepost_single_card         audit_sweep;parquet=prepost_single_card   63243 2573 5674 15045 39951
#                    oof_C_A14_coh_drop__20260427_203607_115af1.parquet                    C_A14_coh_drop                    audit_sweep;parquet=coh_drop   51800 2639 4296 16688 28177
#                 oof_C_A15_block_stats__20260427_203607_115af1.parquet                 C_A15_block_stats                 audit_sweep;parquet=block_stats   63243 1688 6559  9594 45402
#         oof_C_A16_rolling_stats_roll3__20260427_203607_115af1.parquet         C_A16_rolling_stats_roll3         audit_sweep;parquet=rolling_stats_roll3   63243 1921 6326 11826 43170
#         oof_C_A17_rolling_stats_roll7__20260427_203607_115af1.parquet         C_A17_rolling_stats_roll7         audit_sweep;parquet=rolling_stats_roll7   63243 1912 6335 11703 43293
#        oof_C_A18_rolling_stats_roll13__20260427_203607_115af1.parquet        C_A18_rolling_stats_roll13        audit_sweep;parquet=rolling_stats_roll13   63243 1980 6267 11913 43083
#                   oof_C_A19_card_drop__20260427_203607_115af1.parquet                   C_A19_card_drop                   audit_sweep;parquet=card_drop   62043 2248 5832 15904 38059
#                     oof_C_A1_scene_ms__20260427_203607_115af1.parquet                     C_A1_scene_ms                    audit_sweep;parquet=scene_ms   62043 3749 4331 13856 40107
#                   oof_C_A20_ms_change__20260427_203607_115af1.parquet                   C_A20_ms_change                   audit_sweep;parquet=ms_change   39428 1031 3738  8389 26270
#                     oof_C_A21_ms_maha__20260427_203607_115af1.parquet                     C_A21_ms_maha                     audit_sweep;parquet=ms_maha   39428 1739 3030 10918 23741
#                   oof_C_A22_lu_change__20260427_203607_115af1.parquet                   C_A22_lu_change                   audit_sweep;parquet=lu_change   62043 2928 5152 11490 42473
#           oof_C_A23_rolling_accum_coh__20260427_203607_115af1.parquet           C_A23_rolling_accum_coh           audit_sweep;parquet=rolling_accum_coh   57266 2402 5047 14625 35192
#          oof_C_A24_rolling_accum_card__20260427_203607_115af1.parquet          C_A24_rolling_accum_card          audit_sweep;parquet=rolling_accum_card   63243 1507 6740  9093 45903
#            oof_C_A25_rolling_accum_ms__20260427_203607_115af1.parquet            C_A25_rolling_accum_ms            audit_sweep;parquet=rolling_accum_ms   62043 5717 2363 35294 18669
#             oof_C_A26_block_accum_coh__20260427_203607_115af1.parquet             C_A26_block_accum_coh             audit_sweep;parquet=block_accum_coh   60076 2649 5158 17925 34344
#            oof_C_A27_block_accum_card__20260427_203607_115af1.parquet            C_A27_block_accum_card            audit_sweep;parquet=block_accum_card   63243 1708 6539 12862 42134
#              oof_C_A28_block_accum_ms__20260427_203607_115af1.parquet              C_A28_block_accum_ms              audit_sweep;parquet=block_accum_ms   62043 2393 5687 16923 37040
#                   oof_C_A2_scene_card__20260427_203607_115af1.parquet                   C_A2_scene_card                  audit_sweep;parquet=scene_card   63243 2828 5419 15132 39864
#                    oof_C_A3_scene_coh__20260427_203607_115af1.parquet                    C_A3_scene_coh                   audit_sweep;parquet=scene_coh   60769 2330 5576 13920 38943
#                oof_C_A4_scene_landuse__20260427_203607_115af1.parquet                C_A4_scene_landuse               audit_sweep;parquet=scene_landuse   62043 3691 4389 19578 34385
#                oof_C_A5_scene_indices__20260427_203607_115af1.parquet                C_A5_scene_indices               audit_sweep;parquet=scene_indices   62043 3244 4836 11950 42013
#                    oof_C_A6_scene_nbr__20260427_203607_115af1.parquet                    C_A6_scene_nbr                   audit_sweep;parquet=scene_nbr   62043 4526 3554 18759 35204
#                  oof_C_A7_rolling_coh__20260427_203607_115af1.parquet                  C_A7_rolling_coh                 audit_sweep;parquet=rolling_coh   57266 2466 4983 15609 34208
#                 oof_C_A8_rolling_card__20260427_203607_115af1.parquet                 C_A8_rolling_card                audit_sweep;parquet=rolling_card   63243 1928 6319 10649 44347
#      oof_C_A9_composite_prepost_bands__20260427_203607_115af1.parquet      C_A9_composite_prepost_bands     audit_sweep;parquet=composite_prepost_bands   62043 3757 4323 11397 42566
#               oof_C_F1_fusion_ms_card__20260427_203607_115af1.parquet               C_F1_fusion_ms_card              audit_sweep;parquet=fusion_ms_card   62043 3570 4510 13278 40685
#       oof_C_F2_fusion_ms_card_cohdrop__20260427_203607_115af1.parquet       C_F2_fusion_ms_card_cohdrop      audit_sweep;parquet=fusion_ms_card_cohdrop   51293 3466 3401 12054 32372
#          oof_C_F3_fusion_card_cohdrop__20260427_203607_115af1.parquet          C_F3_fusion_card_cohdrop         audit_sweep;parquet=fusion_card_cohdrop   51800 2588 4347 12984 31881
#            oof_C_F4_fusion_ms_cohdrop__20260427_203607_115af1.parquet            C_F4_fusion_ms_cohdrop           audit_sweep;parquet=fusion_ms_cohdrop   51293 3035 3832  9875 34551
#          oof_C_F5_fusion_indices_card__20260427_203607_115af1.parquet          C_F5_fusion_indices_card         audit_sweep;parquet=fusion_indices_card   62043 3382 4698 11727 42236
#  oof_C_F6_fusion_indices_card_cohdrop__20260427_203607_115af1.parquet  C_F6_fusion_indices_card_cohdrop audit_sweep;parquet=fusion_indices_card_cohdrop   51293 3403 3464 12974 31452
#     oof_C_F7_fusion_composite_cohdrop__20260427_203607_115af1.parquet     C_F7_fusion_composite_cohdrop    audit_sweep;parquet=fusion_composite_cohdrop   51293 2996 3871  9397 35029
#  oof_C_F8_fusion_composite_blockstats__20260427_203607_115af1.parquet  C_F8_fusion_composite_blockstats audit_sweep;parquet=fusion_composite_blockstats   62043 3108 4972  8820 45143
#   SAVED: NB08c_v4_experiments_20260427_203607.json (35 experiments)
#   SAVED: NB08c_v4_experiments_20260427_203607.csv
#   Registry flushed: 35 experiments logged under NB08c_v3
#
#   NB08c complete. Outputs in: /content/drive_f/masterthesis/data/outputs/NB08c_v4

# %% [markdown]
# # CELL C10: DELTA — `was_observed_*` LEAKAGE CONTRIBUTION PER PARQUET
#
# Quantifies the per-parquet AUC contribution of `was_observed_*` modality-availability flags.
#
# Mode A (CLEAN, already run C1-C7): `was_observed_*` excluded. Stored in `AUDIT_LOG`.
# Mode B (LEAKY, this cell): `was_observed_*` kept as features. Stored in `AUDIT_LOG_LEAKY`.
#
# Delta = AUC_leaky - AUC_clean. If positive and large, the flag is leaking city identity
# via modality-availability. If near zero, the flag carries no city-proxy signal.
#
# Runs the same protocol as C1-C7 (LightGBM-300-MIA, GroupKFold, manifest features, long-aggregated)
# but with the LEAKY filter. Outputs a combined ranking table with both AUCs + delta column.

# %%
# @title CELL C10: was_observed_* leakage delta (clean vs leaky, same protocol)
print("=" * 70)
print("CELL C10: was_observed_* LEAKAGE DELTA")
print("=" * 70)

AUDIT_LOG_LEAKY = {}

def audit_parquet_leaky(manifest_key, cell_id, pq_id=None):
    '''Same as audit_parquet but uses drop_leakage_leaky (keeps was_observed_* flags).'''
    info = MANIFEST['parquets'].get(manifest_key)
    if info is None:
        return None
    _pq_id = pq_id or info.get('id', '?')
    print(f"\n  --- [{_pq_id}] {manifest_key} (LEAKY mode) ---")

    try:
        df = load_v2(manifest_key)
    except (FileNotFoundError, KeyError) as e:
        print(f"    SKIP load: {e}")
        return None
    if len(df) == 0:
        del df; gc.collect()
        return None

    is_long = 'date' in df.columns

    # --- LEAKY feature selection (keeps was_observed_*) ---
    raw = [c for c in info.get('feature_columns', []) if c in df.columns]
    clean = drop_leakage_leaky(raw)
    clean = [c for c in clean if not _has_count_stat(c)]
    if clean:
        nan_rate = df[clean].isna().mean()
        clean = [c for c in clean if nan_rate.get(c, 1.0) < 1.0]
    feat_cols = clean

    if is_long and feat_cols:
        df = aggregate_long_to_wide(df, feat_cols)
        df = df.merge(df_bldg[['point_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['point_id', 'city'], how='inner')
        df = df[df[TARGET_COL] >= 0].copy()
        feat_cols = [c for c in df.columns
                     if c not in ('city', 'point_id', TARGET_COL)]
        feat_cols = drop_leakage_leaky(feat_cols)
        feat_cols = [c for c in feat_cols if not _has_count_stat(c)]
        nan_rate = df[feat_cols].isna().mean()
        feat_cols = [c for c in feat_cols if nan_rate[c] < 1.0]

    if len(feat_cols) < 2:
        print(f"    SKIP: {len(feat_cols)} feature columns after cleaning")
        del df; gc.collect()
        return None

    overall_nan = float(df[feat_cols].isna().mean().mean())
    X = df[feat_cols].to_numpy(dtype=np.float32, copy=False)
    y = df[TARGET_COL].values
    groups = df['city'].values
    building_ids = df['point_id'].values

    exp_name = f"C10_leaky_{_pq_id}_{manifest_key}"
    # reuse evaluate_audit but write into AUDIT_LOG_LEAKY instead of AUDIT_LOG
    n_cities = len(np.unique(groups))
    n_folds_actual = min(N_FOLDS, n_cities)
    if n_folds_actual < 2:
        del df, X, y, groups; gc.collect()
        return None
    gkf = GroupKFold(n_splits=n_folds_actual)
    y_proba_oof = np.full(len(y), np.nan)
    fold_id = np.full(len(y), -1, dtype=int)
    fold_aucs = []
    for fold_idx, (tr, te) in enumerate(gkf.split(X, y, groups)):
        clf_c = clone(LGBM)
        clf_c.fit(X[tr], y[tr])
        y_proba_oof[te] = clf_c.predict_proba(X[te])[:, 1]
        fold_id[te] = fold_idx
        if len(np.unique(y[te])) > 1:
            fold_aucs.append(roc_auc_score(y[te], y_proba_oof[te]))
    valid = ~np.isnan(y_proba_oof)
    y_v, p_v = y[valid], y_proba_oof[valid]
    pred_v = (p_v >= 0.5).astype(int)
    was_obs_feats = [c for c in feat_cols if 'was_observed_' in c]
    result = {
        'experiment': exp_name,
        'auc_groupkfold': roc_auc_score(y_v, p_v),
        'f1_groupkfold': f1_score(y_v, pred_v),
        'n_features': X.shape[1], 'n_buildings': int(valid.sum()),
        'n_cities': int(len(np.unique(groups))),
        'manifest_key': manifest_key, 'parquet_id': _pq_id,
        'overall_nan_pct': overall_nan * 100,
        'n_was_observed_feats': len(was_obs_feats),
        'y_true': y_v, 'y_proba': p_v, 'groups': groups[valid],
        'point_id': building_ids[valid], 'fold_id': fold_id[valid],
    }
    AUDIT_LOG_LEAKY[exp_name] = result
    print(f"    {exp_name:50s} AUC={result['auc_groupkfold']:.3f}  nfeat={X.shape[1]} (was_observed={len(was_obs_feats)})")

    del df, X, y, groups; gc.collect()
    return result

# run same set as C1-C7 (full manifest minus anything that skipped)
ALL_KEYS = [
    ('A1','scene_ms'), ('A2','scene_card'), ('A3','scene_coh'), ('A4','scene_landuse'),
    ('A5','scene_indices'), ('A6','scene_nbr'),
    ('A7','rolling_coh'), ('A8','rolling_card'),
    ('A9','composite_prepost_bands'), ('A10','composite_prepost_landuse'),
    ('A11','composite_vs_scenes_bands'), ('A12','composite_vs_scenes_landuse'),
    ('A13','prepost_single_card'), ('A14','coh_drop'),
    ('A19','card_drop'), ('A20','ms_change'), ('A21','ms_maha'), ('A22','lu_change'),
    ('A15','block_stats'),
    ('A16','rolling_stats_roll3'), ('A17','rolling_stats_roll7'), ('A18','rolling_stats_roll13'),
    # v7 additions: NB05b v29 R2b/P1d output parquets
    ('A23','rolling_accum_coh'), ('A24','rolling_accum_card'), ('A25','rolling_accum_ms'),
    ('A26','block_accum_coh'), ('A27','block_accum_card'), ('A28','block_accum_ms'),
    ('F1','fusion_ms_card'), ('F2','fusion_ms_card_cohdrop'), ('F3','fusion_card_cohdrop'),
    ('F4','fusion_ms_cohdrop'), ('F5','fusion_indices_card'), ('F6','fusion_indices_card_cohdrop'),
    ('F7','fusion_composite_cohdrop'), ('F8','fusion_composite_blockstats'),
]

for pq_id, mkey in ALL_KEYS:
    audit_parquet_leaky(mkey, cell_id='cell_c10', pq_id=pq_id)

# --- delta table ---
print("\n" + "=" * 70)
print("DELTA TABLE: LEAKY - CLEAN (positive = was_observed_ inflates AUC)")
print("=" * 70)

rows = []
for pq_id, mkey in ALL_KEYS:
    clean_key = f"C_{pq_id}_{mkey}"
    leaky_key = f"C10_leaky_{pq_id}_{mkey}"
    if clean_key not in AUDIT_LOG or leaky_key not in AUDIT_LOG_LEAKY:
        continue
    clean_auc = AUDIT_LOG[clean_key]['auc_groupkfold']
    leaky_auc = AUDIT_LOG_LEAKY[leaky_key]['auc_groupkfold']
    delta = leaky_auc - clean_auc
    n_wo = AUDIT_LOG_LEAKY[leaky_key].get('n_was_observed_feats', 0)
    rows.append({
        'parquet_id': pq_id,
        'manifest_key': mkey,
        'auc_clean': clean_auc,
        'auc_leaky': leaky_auc,
        'delta': delta,
        'n_was_observed': n_wo,
    })

delta_df = pd.DataFrame(rows).sort_values('delta', ascending=False).reset_index(drop=True)

print(f"\n  {'ID':<4s} {'Parquet':<35s} {'AUC_clean':>10s} {'AUC_leaky':>10s} {'delta':>7s} {'nWO':>4s}")
print("  " + "-" * 80)
for _, r in delta_df.iterrows():
    print(f"  {r['parquet_id']:<4s} {r['manifest_key']:<35s} "
          f"{r['auc_clean']:>10.3f} {r['auc_leaky']:>10.3f} "
          f"{r['delta']:>+7.3f} {int(r['n_was_observed']):>4d}")

save_result(delta_df, 'was_observed_delta', 'cell_c10')

# summary
mean_delta = delta_df['delta'].mean()
max_delta = delta_df['delta'].max()
print(f"\n  Mean delta: {mean_delta:+.3f}")
print(f"  Max delta:  {max_delta:+.3f}  (parquet: {delta_df.iloc[0]['manifest_key']})")
print(f"  Parquets with delta > 0.05 (material leakage): "
      f"{int((delta_df['delta'] > 0.05).sum())}")
print(f"  Parquets with delta > 0.10 (severe leakage):   "
      f"{int((delta_df['delta'] > 0.10).sum())}")

# ---- OOF parquets for leaky-mode audits (marked with leakage_demo variant) ----
OOF_DIR_LEAKY = OUT_DIR / 'oof_predictions'
OOF_DIR_LEAKY.mkdir(parents=True, exist_ok=True)
leaky_oof_count = 0
for name, res in AUDIT_LOG_LEAKY.items():
    if 'y_true' in res and 'y_proba' in res and len(res['y_true']) > 0:
        out = save_oof_from_result(res, model_id=name, oof_dir=OOF_DIR_LEAKY,
                                    variant_id=f'leakage_demo_with_leaks;parquet={res.get("manifest_key", "?")}')
        if out is not None:
            leaky_oof_count += 1
print(f"\n  Saved: {leaky_oof_count} LEAKY OOF parquets -> {OOF_DIR_LEAKY}")
# Out:
# ======================================================================
# CELL C10: was_observed_* LEAKAGE DELTA
# ======================================================================
#
#   --- [A1] scene_ms (LEAKY mode) ---
#     C10_leaky_A1_scene_ms                              AUC=0.658  nfeat=224 (was_observed=0)
#
#   --- [A2] scene_card (LEAKY mode) ---
#     C10_leaky_A2_scene_card                            AUC=0.547  nfeat=56 (was_observed=0)
#
#   --- [A3] scene_coh (LEAKY mode) ---
#     C10_leaky_A3_scene_coh                             AUC=0.522  nfeat=72 (was_observed=0)
#
#   --- [A4] scene_landuse (LEAKY mode) ---
#     C10_leaky_A4_scene_landuse                         AUC=0.583  nfeat=2 (was_observed=0)
#
#   --- [A5] scene_indices (LEAKY mode) ---
#     C10_leaky_A5_scene_indices                         AUC=0.645  nfeat=232 (was_observed=0)
#
#   --- [A6] scene_nbr (LEAKY mode) ---
#     C10_leaky_A6_scene_nbr                             AUC=0.651  nfeat=32 (was_observed=0)
#
#   --- [A7] rolling_coh (LEAKY mode) ---
#     C10_leaky_A7_rolling_coh                           AUC=0.521  nfeat=72 (was_observed=0)
#
#   --- [A8] rolling_card (LEAKY mode) ---
#     C10_leaky_A8_rolling_card                          AUC=0.524  nfeat=168 (was_observed=0)
#
#   --- [A9] composite_prepost_bands (LEAKY mode) ---
#     C10_leaky_A9_composite_prepost_bands               AUC=0.676  nfeat=432 (was_observed=0)
#
#   --- [A10] composite_prepost_landuse (LEAKY mode) ---
#     C10_leaky_A10_composite_prepost_landuse            AUC=0.593  nfeat=4 (was_observed=0)
#
#   --- [A12] composite_vs_scenes_landuse (LEAKY mode) ---
#     C10_leaky_A12_composite_vs_scenes_landuse          AUC=0.597  nfeat=6 (was_observed=0)
#
#   --- [A13] prepost_single_card (LEAKY mode) ---
#     C10_leaky_A13_prepost_single_card                  AUC=0.532  nfeat=48 (was_observed=0)
#
#   --- [A14] coh_drop (LEAKY mode) ---
#     C10_leaky_A14_coh_drop                             AUC=0.515  nfeat=41 (was_observed=0)
#
#   --- [A19] card_drop (LEAKY mode) ---
#     C10_leaky_A19_card_drop                            AUC=0.505  nfeat=41 (was_observed=0)
#
#   --- [A20] ms_change (LEAKY mode) ---
#     C10_leaky_A20_ms_change                            AUC=0.475  nfeat=33 (was_observed=0)
#
#   --- [A21] ms_maha (LEAKY mode) ---
#     C10_leaky_A21_ms_maha                              AUC=0.527  nfeat=33 (was_observed=0)
#
#   --- [A22] lu_change (LEAKY mode) ---
#     C10_leaky_A22_lu_change                            AUC=0.596  nfeat=42 (was_observed=0)
#
#   --- [A15] block_stats (LEAKY mode) ---
#     C10_leaky_A15_block_stats                          AUC=0.545  nfeat=2096 (was_observed=0)
#
#   --- [A16] rolling_stats_roll3 (LEAKY mode) ---
#     C10_leaky_A16_rolling_stats_roll3                  AUC=0.516  nfeat=248 (was_observed=0)
#
#   --- [A17] rolling_stats_roll7 (LEAKY mode) ---
#     C10_leaky_A17_rolling_stats_roll7                  AUC=0.513  nfeat=168 (was_observed=0)
#
#   --- [A18] rolling_stats_roll13 (LEAKY mode) ---
#     C10_leaky_A18_rolling_stats_roll13                 AUC=0.513  nfeat=152 (was_observed=0)
#
#   --- [A23] rolling_accum_coh (LEAKY mode) ---
#     C10_leaky_A23_rolling_accum_coh                    AUC=0.528  nfeat=216 (was_observed=0)
#
#   --- [A24] rolling_accum_card (LEAKY mode) ---
#     C10_leaky_A24_rolling_accum_card                   AUC=0.504  nfeat=504 (was_observed=0)
#
#   --- [A25] rolling_accum_ms (LEAKY mode) ---
#     C10_leaky_A25_rolling_accum_ms                     AUC=0.532  nfeat=1152 (was_observed=0)
#
#   --- [A26] block_accum_coh (LEAKY mode) ---
#     C10_leaky_A26_block_accum_coh                      AUC=0.513  nfeat=144 (was_observed=0)
#
#   --- [A27] block_accum_card (LEAKY mode) ---
#     C10_leaky_A27_block_accum_card                     AUC=0.490  nfeat=656 (was_observed=0)
#
#   --- [A28] block_accum_ms (LEAKY mode) ---
#     C10_leaky_A28_block_accum_ms                       AUC=0.507  nfeat=1708 (was_observed=0)
#
#   --- [F1] fusion_ms_card (LEAKY mode) ---
#     C10_leaky_F1_fusion_ms_card                        AUC=0.653  nfeat=280 (was_observed=0)
#
#   --- [F2] fusion_ms_card_cohdrop (LEAKY mode) ---
#     C10_leaky_F2_fusion_ms_card_cohdrop                AUC=0.670  nfeat=362 (was_observed=0)
#
#   --- [F3] fusion_card_cohdrop (LEAKY mode) ---
#     C10_leaky_F3_fusion_card_cohdrop                   AUC=0.558  nfeat=138 (was_observed=0)
#
#   --- [F4] fusion_ms_cohdrop (LEAKY mode) ---
#     C10_leaky_F4_fusion_ms_cohdrop                     AUC=0.673  nfeat=306 (was_observed=0)
#
#   --- [F5] fusion_indices_card (LEAKY mode) ---
#     C10_leaky_F5_fusion_indices_card                   AUC=0.655  nfeat=288 (was_observed=0)
#
#   --- [F6] fusion_indices_card_cohdrop (LEAKY mode) ---
#     C10_leaky_F6_fusion_indices_card_cohdrop           AUC=0.652  nfeat=370 (was_observed=0)
#
#   --- [F7] fusion_composite_cohdrop (LEAKY mode) ---
#     C10_leaky_F7_fusion_composite_cohdrop              AUC=0.657  nfeat=473 (was_observed=0)
#
#   --- [F8] fusion_composite_blockstats (LEAKY mode) ---
#     C10_leaky_F8_fusion_composite_blockstats           AUC=0.674  nfeat=2528 (was_observed=0)
#
# ======================================================================
# DELTA TABLE: LEAKY - CLEAN (positive = was_observed_ inflates AUC)
# ======================================================================
#
#   ID   Parquet                              AUC_clean  AUC_leaky   delta  nWO
#   --------------------------------------------------------------------------------
#   A23  rolling_accum_coh                        0.527      0.528  +0.001    0
#   A2   scene_card                               0.547      0.547  +0.000    0
#   A1   scene_ms                                 0.658      0.658  +0.000    0
#   A3   scene_coh                                0.522      0.522  +0.000    0
#   A4   scene_landuse                            0.583      0.583  +0.000    0
#   A6   scene_nbr                                0.651      0.651  +0.000    0
#   A5   scene_indices                            0.645      0.645  +0.000    0
#   A8   rolling_card                             0.524      0.524  +0.000    0
#   A10  composite_prepost_landuse                0.593      0.593  +0.000    0
#   A12  composite_vs_scenes_landuse              0.597      0.597  +0.000    0
#   A7   rolling_coh                              0.521      0.521  +0.000    0
#   A21  ms_maha                                  0.527      0.527  +0.000    0
#   A14  coh_drop                                 0.515      0.515  +0.000    0
#   A19  card_drop                                0.505      0.505  +0.000    0
#   A20  ms_change                                0.475      0.475  +0.000    0
#   A15  block_stats                              0.545      0.545  +0.000    0
#   A22  lu_change                                0.596      0.596  +0.000    0
#   A16  rolling_stats_roll3                      0.516      0.516  +0.000    0
#   A13  prepost_single_card                      0.532      0.532  +0.000    0
#   F5   fusion_indices_card                      0.655      0.655  +0.000    0
#   A17  rolling_stats_roll7                      0.513      0.513  +0.000    0
#   A18  rolling_stats_roll13                     0.513      0.513  +0.000    0
#   A26  block_accum_coh                          0.513      0.513  +0.000    0
#   A28  block_accum_ms                           0.507      0.507  +0.000    0
#   A27  block_accum_card                         0.490      0.490  +0.000    0
#   F2   fusion_ms_card_cohdrop                   0.670      0.670  +0.000    0
#   F1   fusion_ms_card                           0.653      0.653  +0.000    0
#   F3   fusion_card_cohdrop                      0.558      0.558  +0.000    0
#   F6   fusion_indices_card_cohdrop              0.652      0.652  +0.000    0
#   F4   fusion_ms_cohdrop                        0.673      0.673  +0.000    0
#   F8   fusion_composite_blockstats              0.677      0.674  -0.003    0
#   A9   composite_prepost_bands                  0.679      0.676  -0.003    0
#   F7   fusion_composite_cohdrop                 0.661      0.657  -0.004    0
#   A25  rolling_accum_ms                         0.538      0.532  -0.005    0
#   A24  rolling_accum_card                       0.512      0.504  -0.008    0
#   Saved: cell_c10/was_observed_delta_20260427_205532.csv (2.4 KB)
#
#   Mean delta: -0.001
#   Max delta:  +0.001  (parquet: rolling_accum_coh)
#   Parquets with delta > 0.05 (material leakage): 0
#   Parquets with delta > 0.10 (severe leakage):   0
#     saved oof -> oof_C10_leaky_A1_scene_ms__20260427_203607_115af1.parquet  TP=3749 FN=4331 FP=13856 TN=40107
#     saved oof -> oof_C10_leaky_A2_scene_card__20260427_203607_115af1.parquet  TP=2828 FN=5419 FP=15132 TN=39864
#     saved oof -> oof_C10_leaky_A3_scene_coh__20260427_203607_115af1.parquet  TP=2330 FN=5576 FP=13920 TN=38943
#     saved oof -> oof_C10_leaky_A4_scene_landuse__20260427_203607_115af1.parquet  TP=3691 FN=4389 FP=19578 TN=34385
#     saved oof -> oof_C10_leaky_A5_scene_indices__20260427_203607_115af1.parquet  TP=3244 FN=4836 FP=11950 TN=42013
#     saved oof -> oof_C10_leaky_A6_scene_nbr__20260427_203607_115af1.parquet  TP=4526 FN=3554 FP=18759 TN=35204
#     saved oof -> oof_C10_leaky_A7_rolling_coh__20260427_203607_115af1.parquet  TP=2466 FN=4983 FP=15609 TN=34208
#     saved oof -> oof_C10_leaky_A8_rolling_card__20260427_203607_115af1.parquet  TP=1928 FN=6319 FP=10649 TN=44347
#     saved oof -> oof_C10_leaky_A9_composite_prepost_bands__20260427_203607_115af1.parquet  TP=3745 FN=4335 FP=11390 TN=42573
#     saved oof -> oof_C10_leaky_A10_composite_prepost_landuse__20260427_203607_115af1.parquet  TP=4450 FN=3630 FP=21968 TN=31995
#     saved oof -> oof_C10_leaky_A12_composite_vs_scenes_landuse__20260427_203607_115af1.parquet  TP=3181 FN=4874 FP=13605 TN=40203
#     saved oof -> oof_C10_leaky_A13_prepost_single_card__20260427_203607_115af1.parquet  TP=2573 FN=5674 FP=15045 TN=39951
#     saved oof -> oof_C10_leaky_A14_coh_drop__20260427_203607_115af1.parquet  TP=2639 FN=4296 FP=16688 TN=28177
#     saved oof -> oof_C10_leaky_A19_card_drop__20260427_203607_115af1.parquet  TP=2248 FN=5832 FP=15904 TN=38059
#     saved oof -> oof_C10_leaky_A20_ms_change__20260427_203607_115af1.parquet  TP=1031 FN=3738 FP=8389 TN=26270
#     saved oof -> oof_C10_leaky_A21_ms_maha__20260427_203607_115af1.parquet  TP=1739 FN=3030 FP=10918 TN=23741
#     saved oof -> oof_C10_leaky_A22_lu_change__20260427_203607_115af1.parquet  TP=2928 FN=5152 FP=11490 TN=42473
#     saved oof -> oof_C10_leaky_A15_block_stats__20260427_203607_115af1.parquet  TP=1688 FN=6559 FP=9594 TN=45402
#     saved oof -> oof_C10_leaky_A16_rolling_stats_roll3__20260427_203607_115af1.parquet  TP=1921 FN=6326 FP=11826 TN=43170
#     saved oof -> oof_C10_leaky_A17_rolling_stats_roll7__20260427_203607_115af1.parquet  TP=1912 FN=6335 FP=11703 TN=43293
#     saved oof -> oof_C10_leaky_A18_rolling_stats_roll13__20260427_203607_115af1.parquet  TP=1980 FN=6267 FP=11913 TN=43083
#     saved oof -> oof_C10_leaky_A23_rolling_accum_coh__20260427_203607_115af1.parquet  TP=2414 FN=5035 FP=14368 TN=35449
#     saved oof -> oof_C10_leaky_A24_rolling_accum_card__20260427_203607_115af1.parquet  TP=1494 FN=6753 FP=8993 TN=46003
#     saved oof -> oof_C10_leaky_A25_rolling_accum_ms__20260427_203607_115af1.parquet  TP=5473 FN=2607 FP=33236 TN=20727
#     saved oof -> oof_C10_leaky_A26_block_accum_coh__20260427_203607_115af1.parquet  TP=2649 FN=5158 FP=17925 TN=34344
#     saved oof -> oof_C10_leaky_A27_block_accum_card__20260427_203607_115af1.parquet  TP=1708 FN=6539 FP=12862 TN=42134
#     saved oof -> oof_C10_leaky_A28_block_accum_ms__20260427_203607_115af1.parquet  TP=2393 FN=5687 FP=16923 TN=37040
#     saved oof -> oof_C10_leaky_F1_fusion_ms_card__20260427_203607_115af1.parquet  TP=3570 FN=4510 FP=13278 TN=40685
#     saved oof -> oof_C10_leaky_F2_fusion_ms_card_cohdrop__20260427_203607_115af1.parquet  TP=3466 FN=3401 FP=12054 TN=32372
#     saved oof -> oof_C10_leaky_F3_fusion_card_cohdrop__20260427_203607_115af1.parquet  TP=2588 FN=4347 FP=12984 TN=31881
#     saved oof -> oof_C10_leaky_F4_fusion_ms_cohdrop__20260427_203607_115af1.parquet  TP=3035 FN=3832 FP=9875 TN=34551
#     saved oof -> oof_C10_leaky_F5_fusion_indices_card__20260427_203607_115af1.parquet  TP=3382 FN=4698 FP=11727 TN=42236
#     saved oof -> oof_C10_leaky_F6_fusion_indices_card_cohdrop__20260427_203607_115af1.parquet  TP=3403 FN=3464 FP=12974 TN=31452
#     saved oof -> oof_C10_leaky_F7_fusion_composite_cohdrop__20260427_203607_115af1.parquet  TP=2971 FN=3896 FP=9187 TN=35239
#     saved oof -> oof_C10_leaky_F8_fusion_composite_blockstats__20260427_203607_115af1.parquet  TP=3150 FN=4930 FP=9196 TN=44767
#
#   Saved: 35 LEAKY OOF parquets -> /content/drive_f/masterthesis/data/outputs/NB08c_v4/oof_predictions

# %%
import pandas as pd
from pathlib import Path
V2_DIR = Path(STACK_DIR) / 'dataset' / 'v2'  # same derivation as NB05b cell 4
df_f1 = pd.read_parquet(V2_DIR / 'bda_fusion_ms_card_t1.parquet')
flag_cols = [c for c in df_f1.columns if c.startswith('was_observed_')]
print(f"Flag columns: {flag_cols}")
for fc in flag_cols:
    per_city = df_f1.groupby('city')[fc].agg(['mean','std','count']).round(3)
    print(f"\n{fc}:")
    print(per_city.to_string())
# Out:
# Flag columns: ['was_observed_scene_ms', 'was_observed_scene_card']
#
# was_observed_scene_ms:
#               mean    std    count
# city
# Bucha        0.403  0.490   295239
# Chernihiv    0.283  0.451  1113894
# Dmytrivka    0.361  0.480   232050
# Hostomel     0.274  0.446   336566
# Irpin        0.296  0.457   282976
# Makariv      0.304  0.460   131614
# Moschun      0.274  0.446   349605
# Okhtyrka     0.323  0.468   662472
# Trostianets  0.243  0.429   373120
# Volnovakha   0.365  0.481   277760
#
# was_observed_scene_card:
#               mean    std    count
# city
# Bucha        0.363  0.481   295239
# Chernihiv    0.315  0.464  1113894
# Dmytrivka    0.364  0.481   232050
# Hostomel     0.391  0.488   336566
# Irpin        0.423  0.494   282976
# Makariv      0.343  0.475   131614
# Moschun      0.392  0.488   349605
# Okhtyrka     0.231  0.421   662472
# Trostianets  0.201  0.401   373120
# Volnovakha   0.243  0.429   277760

# %% [markdown]
# # CELL CMP: V2 vs V3 vs V4 cross-architecture comparison
#
# Reads the latest audit log from each of the three architectures (V2 v8, V3 v1, V4 v1)
# and produces a 3-way side-by-side AUC table per parquet with three pairwise delta
# columns. Saves CSV. Runs only when at least V4's audit log exists; V2 and V3
# columns are filled when their logs are present, NaN otherwise.

# %%
# @title CELL CMP: V2 vs V3 vs V4 cross-architecture comparison
import pandas as pd
from pathlib import Path
from datetime import datetime as _dt
import json as _json

print("=" * 70)
print("CELL CMP: V2 vs V3 vs V4 CROSS-ARCHITECTURE COMPARISON")
print("=" * 70)

V2_OUT = OUTPUTS_DIR / "NB08c_v2" / "cell_c9"
V3_OUT = OUTPUTS_DIR / "NB08c_v3" / "cell_c9"
V4_OUT = OUTPUTS_DIR / "NB08c_v4" / "cell_c9"

def _latest(audit_dir, glob='audit_log_*.json'):
    if not audit_dir.exists():
        return None
    files = sorted(audit_dir.glob(glob), key=lambda p: p.stat().st_mtime)
    return files[-1] if files else None

v2_log = _latest(V2_OUT)
v3_log = _latest(V3_OUT)
v4_log = _latest(V4_OUT)

print(f"  V2 audit log: {v2_log if v2_log else '(missing - run NB08cV2 v8 first)'}")
print(f"  V3 audit log: {v3_log if v3_log else '(missing - run NB08cV3 v1 first)'}")
print(f"  V4 audit log: {v4_log if v4_log else '(missing - this notebook has not finished yet)'}")

if v4_log is None:
    print("\n  SKIP: V4 audit log not found. Run NB08cV4 v1 cells C1-C9 first.")
else:
    def _to_df(data, arch):
        rows = []
        for exp_name, summary in data.items():
            rows.append({
                'arch':       arch,
                'experiment': exp_name,
                'parquet_id': summary.get('parquet_id', '?'),
                'manifest_key': summary.get('manifest_key', exp_name.replace(f'C_{summary.get("parquet_id","?")}_', '')),
                'format':     summary.get('format', '-'),
                'auc':        summary.get('auc_groupkfold', float('nan')),
                'f1':         summary.get('f1_groupkfold', float('nan')),
                'n_features': summary.get('n_features', 0),
                'n_samples':  summary.get('n_buildings', 0),
                'n_cities':   summary.get('n_cities', 0),
                'nan_pct':    summary.get('overall_nan_pct', float('nan')),
            })
        return pd.DataFrame(rows)

    dfs = {}
    for arch, log in [('V2', v2_log), ('V3', v3_log), ('V4', v4_log)]:
        if log is None:
            continue
        with open(log) as fh:
            data = _json.load(fh)
        dfs[arch] = _to_df(data, arch)

    # Pick merge key — prefer parquet_id if present, fall back to manifest_key
    use_pid = all(df['parquet_id'].notna().all() for df in dfs.values())
    merge_key = 'parquet_id' if use_pid else 'manifest_key'

    # Start from V4 (always present at this branch) and outer-merge V2, V3
    base = dfs['V4'].rename(columns={
        'auc': 'auc_v4', 'f1': 'f1_v4',
        'n_features': 'n_features_v4', 'n_samples': 'n_samples_v4',
        'n_cities': 'n_cities_v4', 'nan_pct': 'nan_pct_v4',
        'format': 'format_v4',
    }).drop(columns=['arch', 'experiment'])

    if 'V3' in dfs:
        v3_df = dfs['V3'].rename(columns={
            'auc': 'auc_v3', 'f1': 'f1_v3',
            'n_features': 'n_features_v3', 'n_samples': 'n_samples_v3',
            'n_cities': 'n_cities_v3', 'nan_pct': 'nan_pct_v3',
            'format': 'format_v3',
        }).drop(columns=['arch', 'experiment'])
        if merge_key == 'parquet_id':
            v3_df = v3_df.drop(columns=['manifest_key'])
        else:
            v3_df = v3_df.drop(columns=['parquet_id'])
        base = base.merge(v3_df, on=[merge_key], how='outer')

    if 'V2' in dfs:
        v2_df = dfs['V2'].rename(columns={
            'auc': 'auc_v2', 'f1': 'f1_v2',
            'n_features': 'n_features_v2', 'n_samples': 'n_samples_v2',
            'n_cities': 'n_cities_v2', 'nan_pct': 'nan_pct_v2',
            'format': 'format_v2',
        }).drop(columns=['arch', 'experiment'])
        if merge_key == 'parquet_id':
            v2_df = v2_df.drop(columns=['manifest_key'])
        else:
            v2_df = v2_df.drop(columns=['parquet_id'])
        base = base.merge(v2_df, on=[merge_key], how='outer')

    # pairwise deltas
    if 'auc_v2' in base.columns and 'auc_v3' in base.columns:
        base['delta_v3_v2'] = base['auc_v3'] - base['auc_v2']
    if 'auc_v2' in base.columns and 'auc_v4' in base.columns:
        base['delta_v4_v2'] = base['auc_v4'] - base['auc_v2']
    if 'auc_v3' in base.columns and 'auc_v4' in base.columns:
        base['delta_v4_v3'] = base['auc_v4'] - base['auc_v3']

    # sort by parquet_id where available
    if merge_key in base.columns:
        base = base.sort_values(merge_key)

    # column order for display
    pref_cols = [merge_key]
    if 'manifest_key' in base.columns and merge_key != 'manifest_key':
        pref_cols.append('manifest_key')
    for arch in ['v2', 'v3', 'v4']:
        for s in ['auc_', 'f1_', 'n_features_', 'nan_pct_']:
            col = s + arch
            if col in base.columns:
                pref_cols.append(col)
    for d in ['delta_v3_v2', 'delta_v4_v2', 'delta_v4_v3']:
        if d in base.columns:
            pref_cols.append(d)
    pref_cols = [c for c in pref_cols if c in base.columns]
    other_cols = [c for c in base.columns if c not in pref_cols]
    cmp_df = base[pref_cols + other_cols]

    # compact print
    print()
    hdr = f"  {'ID':5s} {'parquet':30s} {'AUC_v2':>7s} {'AUC_v3':>7s} {'AUC_v4':>7s} "
    hdr += f"{'d_v3v2':>7s} {'d_v4v2':>7s} {'d_v4v3':>7s}"
    print(hdr)
    print('  ' + '-' * (len(hdr) - 2))
    for _, r in cmp_df.iterrows():
        pid = str(r.get(merge_key, ''))[:5]
        mk = ''
        if 'manifest_key' in cmp_df.columns:
            mk = str(r.get('manifest_key', ''))[:30]
        a2 = r.get('auc_v2', float('nan'))
        a3 = r.get('auc_v3', float('nan'))
        a4 = r.get('auc_v4', float('nan'))
        d32 = r.get('delta_v3_v2', float('nan'))
        d42 = r.get('delta_v4_v2', float('nan'))
        d43 = r.get('delta_v4_v3', float('nan'))
        a2s = f"{a2:.3f}" if pd.notna(a2) else '-'
        a3s = f"{a3:.3f}" if pd.notna(a3) else '-'
        a4s = f"{a4:.3f}" if pd.notna(a4) else '-'
        d32s = f"{d32:+.3f}" if pd.notna(d32) else '-'
        d42s = f"{d42:+.3f}" if pd.notna(d42) else '-'
        d43s = f"{d43:+.3f}" if pd.notna(d43) else '-'
        print(f"  {pid:5s} {mk:30s} {a2s:>7s} {a3s:>7s} {a4s:>7s} {d32s:>7s} {d42s:>7s} {d43s:>7s}")

    # Summary stats (only on rows where both members of a pair are present)
    print()
    if 'auc_v2' in cmp_df.columns and 'auc_v4' in cmp_df.columns:
        v42 = cmp_df.dropna(subset=['auc_v2', 'auc_v4'])
        if len(v42) > 0:
            print(f"  V2 vs V4 pairs: {len(v42)} | mean V2={v42['auc_v2'].mean():.3f}, mean V4={v42['auc_v4'].mean():.3f}, mean delta_v4_v2={v42['delta_v4_v2'].mean():+.3f}")
            print(f"    V4 wins (delta>+0.01): {(v42['delta_v4_v2'] > 0.01).sum()} / {len(v42)}")
            print(f"    V2 wins (delta<-0.01): {(v42['delta_v4_v2'] < -0.01).sum()} / {len(v42)}")
    if 'auc_v3' in cmp_df.columns and 'auc_v4' in cmp_df.columns:
        v43 = cmp_df.dropna(subset=['auc_v3', 'auc_v4'])
        if len(v43) > 0:
            print(f"  V3 vs V4 pairs: {len(v43)} | mean V3={v43['auc_v3'].mean():.3f}, mean V4={v43['auc_v4'].mean():.3f}, mean delta_v4_v3={v43['delta_v4_v3'].mean():+.3f}")
            print(f"    V4 wins (delta>+0.01): {(v43['delta_v4_v3'] > 0.01).sum()} / {len(v43)}")
            print(f"    V3 wins (delta<-0.01): {(v43['delta_v4_v3'] < -0.01).sum()} / {len(v43)}")

    # save CSV next to V4's cell_c9
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    out_dir = V4_OUT.parent / 'cell_cmp'
    out_dir.mkdir(parents=True, exist_ok=True)
    out_path = out_dir / f'v2_vs_v3_vs_v4_audit_comparison_{ts}.csv'
    cmp_df.to_csv(out_path, index=False)
    print(f"\n  Saved: {out_path.relative_to(OUTPUTS_DIR)} ({out_path.stat().st_size / 1024:.1f} KB)")
# Out:
# ======================================================================
# CELL CMP: V2 vs V3 vs V4 CROSS-ARCHITECTURE COMPARISON
# ======================================================================
#   V2 audit log: /content/drive_f/masterthesis/data/outputs/NB08c_v2/cell_c9/audit_log_20260427_015812.json
#   V3 audit log: /content/drive_f/masterthesis/data/outputs/NB08c_v3/cell_c9/audit_log_20260427_022146.json
#   V4 audit log: /content/drive_f/masterthesis/data/outputs/NB08c_v4/cell_c9/audit_log_20260427_204552.json
#
#   ID    parquet                         AUC_v2  AUC_v3  AUC_v4  d_v3v2  d_v4v2  d_v4v3
#   ------------------------------------------------------------------------------------
#   A1    scene_ms                         0.622   0.678   0.658  +0.056  +0.036  -0.020
#   A10   composite_prepost_landuse        0.773   0.626   0.593  -0.146  -0.179  -0.033
#   A11   nan                              0.763       -       -       -       -       -
#   A12   composite_vs_scenes_landuse      0.785   0.631   0.597  -0.154  -0.188  -0.034
#   A13   prepost_single_card              0.802   0.520   0.532  -0.283  -0.270  +0.012
#   A14   coh_drop                         0.807   0.538   0.515  -0.270  -0.293  -0.023
#   A15   block_stats                      0.823   0.508   0.545  -0.315  -0.277  +0.037
#   A16   rolling_stats_roll3              0.824   0.504   0.516  -0.320  -0.308  +0.012
#   A17   rolling_stats_roll7              0.823   0.502   0.513  -0.321  -0.310  +0.012
#   A18   rolling_stats_roll13             0.823   0.502   0.513  -0.321  -0.311  +0.011
#   A19   card_drop                        0.802   0.502   0.505  -0.301  -0.297  +0.004
#   A2    scene_card                       0.600   0.535   0.547  -0.066  -0.053  +0.012
#   A20   ms_change                        0.781   0.466   0.475  -0.314  -0.306  +0.008
#   A21   ms_maha                          0.445   0.520   0.527  +0.075  +0.082  +0.007
#   A22   lu_change                        0.813   0.562   0.596  -0.250  -0.216  +0.034
#   A23   rolling_accum_coh                0.704   0.518   0.527  -0.186  -0.177  +0.009
#   A24   rolling_accum_card               0.664   0.502   0.512  -0.162  -0.152  +0.010
#   A25   rolling_accum_ms                 0.604   0.519   0.538  -0.085  -0.067  +0.018
#   A26   block_accum_coh                  0.653   0.503   0.513  -0.150  -0.140  +0.010
#   A27   block_accum_card                 0.683   0.495   0.490  -0.188  -0.194  -0.006
#   A28   block_accum_ms                   0.610   0.507   0.507  -0.102  -0.103  -0.000
#   A3    scene_coh                        0.588   0.513   0.522  -0.076  -0.066  +0.010
#   A4    scene_landuse                    0.606   0.623   0.583  +0.017  -0.023  -0.040
#   A5    scene_indices                    0.620   0.630   0.645  +0.010  +0.025  +0.015
#   A6    scene_nbr                        0.601   0.637   0.651  +0.035  +0.049  +0.014
#   A7    rolling_coh                      0.532   0.513   0.521  -0.019  -0.011  +0.008
#   A8    rolling_card                     0.621   0.519   0.524  -0.102  -0.098  +0.005
#   A9    composite_prepost_bands          0.786   0.670   0.679  -0.116  -0.107  +0.009
#   F1    fusion_ms_card                   0.623   0.675   0.653  +0.053  +0.030  -0.023
#   F2    fusion_ms_card_cohdrop           0.814   0.667   0.670  -0.147  -0.144  +0.003
#   F3    fusion_card_cohdrop              0.842   0.572   0.558  -0.270  -0.284  -0.014
#   F4    fusion_ms_cohdrop                0.813   0.678   0.673  -0.134  -0.140  -0.005
#   F5    fusion_indices_card              0.627   0.642   0.655  +0.015  +0.028  +0.013
#   F6    fusion_indices_card_cohdrop      0.815   0.652   0.652  -0.164  -0.163  +0.001
#   F7    fusion_composite_cohdrop         0.813   0.643   0.661  -0.170  -0.152  +0.018
#   F8    fusion_composite_blockstats      0.805   0.643   0.677  -0.162  -0.128  +0.034
#
#   V2 vs V4 pairs: 35 | mean V2=0.713, mean V4=0.573, mean delta_v4_v2=-0.140
#     V4 wins (delta>+0.01): 6 / 35
#     V2 wins (delta<-0.01): 29 / 35
#   V3 vs V4 pairs: 35 | mean V3=0.569, mean V4=0.573, mean delta_v4_v3=+0.004
#     V4 wins (delta>+0.01): 13 / 35
#     V3 wins (delta<-0.01): 7 / 35
#
#   Saved: NB08c_v4/cell_cmp/v2_vs_v3_vs_v4_audit_comparison_20260427_205537.csv (11.1 KB)

# %%
print(df_bldg['damage_binary'].value_counts(dropna=False).to_dict())
print(df_bldg['point_source'].value_counts(dropna=False).to_dict() if 'point_source' in df_bldg.columns else 'no point_source col')
print(f"  positive rate: {df_bldg['damage_binary'].mean():.4f}")
# Out:
# {0: 54996, 1: 8247}
# {'building_centroid': 41235, 'unosat': 22008}
#   positive rate: 0.1304
