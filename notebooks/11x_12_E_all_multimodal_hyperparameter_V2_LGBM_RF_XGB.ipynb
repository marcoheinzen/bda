# %% [markdown]
# # NB11e_all_multimodal -- R5 classifier sweep on `fusion_composite_blockstats` / `all_multimodal`
#
# > Copyright (C) 2024-2026 Marco Heinzen - SPDX-License-Identifier: AGPL-3.0-or-later
# > Part of the Master Thesis "Building Damage Assessment with Multimodal Satellite Time Series and Machine Learning in the Russia-Ukraine War 2022-2026"
# > Code hosted at https://github.com/marcoheinzen/bda
# > Parts of this code were written or improved with the assistance of Claude (Anthropic); all other code, and the concept, research, architecture, design, execution, testing and validation throughout, are the author's work.
#
#
# | Classifier | Baseline AUC |
# |---|---|
# | RF-200 | 0.774 |
# | ExtraTrees | 0.785 |
# | LightGBM | 0.792 |
# | XGBoost | 0.805 |
#
# **Source experiment:** NB09a v7 CELL R5 (verbatim CONFIG, S0 with `prepare_features`+`evaluate_groupkfold`+median imputation, CLASSIFIER PARAMS, `f8_feature_groups`).
#
# **Classifiers tuned:** RF-200, ExtraTrees, LightGBM, XGBoost. GBM excluded (LightGBM serves same gradient-boosting role at lower wall cost on 1 CPU).
#
# **Strategy:** lift `run_classifiers` from R5 verbatim, replicate the all_multimodal leg with classifier filter, assert all baselines within +/- 0.005, run Optuna per classifier with PATIENCE=40 and RESUME-IF-EXISTS SQLite. Refit best params per classifier, persist OOF/model/JSON/registry with `mean_folds_auc`/`std_folds_auc`/`fold_aucs`.
#
# **Output dir:** `OUTPUTS_DIR / "NB11_V2"`.

# %% [markdown]
# ## CELL 1 -- CONFIG (verbatim NB09a v7) + NB11 additions

# %%
# @title CELL 3: NB09a CONFIG
TIER_SELECTION = [0,1,2]
CITY_FILTER = None
CITY_SELECTION = None
REQUIRE_UNOSAT = True
RANDOM_STATE = 42
N_FOLDS = 5

# v2 parquet system (manifest-driven). Set to False to fall back to v1 paths.
USE_V2 = True

# === NB11 ADDITIONS ===
NB11_NAME = 'NB11e_all_multimodal'
NB11_PARQUET_ID = 'F8'
NB11_MANIFEST_KEY = 'fusion_composite_blockstats'
NB11_FEATURE_SET = 'all_multimodal'
NB11_PARQUET_NAME = 'bda_fusion_composite_blockstats_v2'
NB11_CELL_ID = 'cell_r5'

# Classifiers to tune (GBM excluded; LightGBM serves same gradient-boosting role)
NB11_CLASSIFIERS = ['RF-200', 'ExtraTrees', 'LightGBM', 'XGBoost']

NB11_BASELINE_AUC = {
    'RF-200': 0.774,
    'ExtraTrees': 0.785,
    'LightGBM': 0.792,
    'XGBoost': 0.805,
}
NB11_BASELINE_TOL = 0.005

OPTUNA_BASE_BUDGET = 200
OPTUNA_LOW_AUC_BUDGET = 100
OPTUNA_LOW_AUC_CUTOFF = 0.70
OPTUNA_PATIENCE = 40
OPTUNA_DIRECTION = 'maximize'
OPTUNA_SEED = 42

# === THREAD BUDGET (avoid oversubscription when running parallel notebooks) ===
import os as _os, multiprocessing as _mp
NB11_PARALLEL_NOTEBOOKS = 1                                  # set to N if running N notebooks concurrently
NB11_CORES_TOTAL = _mp.cpu_count()
NB11_THREADS_PER_NB = max(1, NB11_CORES_TOTAL // NB11_PARALLEL_NOTEBOOKS)
# Env vars must be set BEFORE numpy/BLAS imports (i.e. before CELL 2 global_setup).
# Run with a fresh kernel for these to take effect at numpy import time.
_os.environ['OMP_NUM_THREADS']      = str(NB11_THREADS_PER_NB)
_os.environ['MKL_NUM_THREADS']      = str(NB11_THREADS_PER_NB)
_os.environ['OPENBLAS_NUM_THREADS'] = str(NB11_THREADS_PER_NB)
_os.environ['NUMEXPR_NUM_THREADS']  = str(NB11_THREADS_PER_NB)
_os.environ['BLIS_NUM_THREADS']     = str(NB11_THREADS_PER_NB)
print(f"[threads] cores={NB11_CORES_TOTAL}  parallel_nbs={NB11_PARALLEL_NOTEBOOKS}  "
      f"threads_per_nb={NB11_THREADS_PER_NB}")
# Out:
# [threads] cores=24  parallel_nbs=1  threads_per_nb=24

# %% [markdown]
# ## CELL 1b -- enforce thread cap dynamically (BLAS/OpenMP)
#
# Belt-and-suspenders to the env vars: if numpy/BLAS were imported on an earlier kernel state with no env-var limit, `threadpoolctl` clamps the active pools NOW without a kernel restart. Without this, LightGBM/XGBoost's OpenMP and sklearn's BLAS still spawn 24 threads each.
#
# Set `NB11_PARALLEL_NOTEBOOKS` in CELL 1 to match the number of NB11 notebooks you'll run concurrently:
# - 1 notebook  -> 24 threads per nb (no contention)
# - 2 notebooks -> 12 threads each
# - 3 notebooks ->  8 threads each
# - 4 notebooks ->  6 threads each

# %%
# @title CELL 1b: dynamic thread cap via threadpoolctl
try:
    from threadpoolctl import threadpool_limits, threadpool_info
    _tp_limit = threadpool_limits(limits=NB11_THREADS_PER_NB)
    print(f"[threadpoolctl] limited BLAS/OpenMP pools to {NB11_THREADS_PER_NB} threads")
    for info in threadpool_info():
        print(f"  {info.get('prefix'):20s} ({info.get('user_api')})  "
              f"current_threads={info.get('num_threads')}  max={info.get('num_threads')}")
except ImportError:
    print("[threadpoolctl] NOT INSTALLED -- run: pip install threadpoolctl")
    print("                env vars only; may not affect pools loaded before this cell.")
# Out:
# [threadpoolctl] limited BLAS/OpenMP pools to 24 threads

# %% [markdown]
# ## CELL 2 -- LOAD GLOBAL SETUP (verbatim NB09a v7)

# %%
# @title CELL 4: LOAD GLOBAL SETUP
import platform, os, json
if platform.system() == "Windows":
    _setup = r"F:\PROJECTS\masterthesis\gdrive\masterthesis\notebooks\global_setup.py"
elif os.path.exists("/content/drive_f"):
    _setup = "/content/drive_f/masterthesis/notebooks/global_setup.py"
else:
    _setup = "/mnt/f/PROJECTS/masterthesis/gdrive/masterthesis/notebooks/global_setup.py"
with open(_setup) as f:
    exec(f.read())
# Out:
# ======================================================================
# BDA GLOBAL SETUP
# ======================================================================
# Started: 2026-05-21 18:33:05
# Python: 3.12.12
# ======================================================================
#
# [1/7] Directory Structure
# ----------------------------------------------------------------------
# /home/alpineobotics/miniconda3/envs/bda/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
#   GDrive (G:):       /content/drive_f/masterthesis OK
#   GDrive (F:):       /content/drive_f/masterthesis OK
#   Local data (G:):   /content/masterthesis_local/data OK
#   Data stack (F:):   /mnt/f/PROJECTS/masterthesis/data_stack OK
#
#   TIER_SELECTION: [0, 1, 2]
#   CITY_SELECTION: None (tier filter)
#   REQUIRE_UNOSAT: True
#   CITIES_TO_PROCESS: 21 cities
#
# [2/7] Credentials
# ----------------------------------------------------------------------
#   Copernicus: inf***
#   OpenTopography: OK
#   Earthdata: marcoheinzen
#
# [3/7] Python Packages
# ----------------------------------------------------------------------
# <string>:564: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   Already installed: 23
#   Newly installed:   0
#   Failed:            0
#
# [4/7] Global Imports & Configuration
# ----------------------------------------------------------------------
#   All imports loaded
#
# [5/7] Processing Config & SNAP
# ----------------------------------------------------------------------
#   GPT: Usage:
#   Temporal baseline: 10-24 days
#   Wavelength: 0.0555
#
# [6/7] GPU Status
# ----------------------------------------------------------------------
#   CUDA available: NVIDIA GeForce RTX 2070 SUPER
#     CUDA version: 12.8
#
# [7/7] Disk Space
# ----------------------------------------------------------------------
#   GDrive (G:)     910.8/7452.0 GB (6541.2 GB free)
#   GDrive (F:)     1404.0/3726.0 GB (2322.0 GB free)
#   Local data      11563.0/14901.9 GB (3338.9 GB free)
#   Data stack      1404.0/3726.0 GB (2322.0 GB free)
#   WSL ext4        69.1/1006.9 GB (886.5 GB free)
#
# ======================================================================
# GLOBAL SETUP COMPLETE
# ======================================================================
#   Torch device: cuda
#   Cities: 21, CITY=Avdiivka
#   Functions: load_aoi(), load_aoi_gdf(), load_aoi_bbox(), load_buildings()
#   Functions: set_city_paths(), resolve_cities(), load_tracker(), load_dietrich_tracker()
#   Completed: 2026-05-21 18:33:48
# ======================================================================

# %% [markdown]
# ## CELL S0 -- MANIFEST + BUILDINGS + SHARED HELPERS (verbatim NB09a v7)
#
# Contains `load_v2`, `drop_leakage` (via `metadata_filter.is_non_feature`), `filter_dietrich28`, `prepare_features` (median imputation), `evaluate_groupkfold`, `log_result`, `save_oof_from_result`.

# %%
# @title CELL S0: LOAD MANIFEST + BUILDINGS + SHARED HELPERS
import sys, importlib, re, gc, time
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import GroupKFold, StratifiedKFold
from sklearn.metrics import (roc_auc_score, f1_score, precision_score,
                             recall_score, precision_recall_curve, roc_curve)
from sklearn.impute import SimpleImputer
from sklearn.base import clone
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

print("=" * 70)
print("CELL S0: NB09a v2 — LOAD MANIFEST + BUILDINGS + SHARED HELPERS")
print("=" * 70)

if str(NOTEBOOKS_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOKS_DIR))

# --- load v2 manifest -------------------------------------------------
MANIFEST_V2_PATH = DATASET_ROOT_V2 / 'parquet_manifest.json'
if not MANIFEST_V2_PATH.exists():
    raise FileNotFoundError(f"V2 manifest not found: {MANIFEST_V2_PATH}")
with open(MANIFEST_V2_PATH) as _f:
    MANIFEST = json.load(_f)
print(f"  Manifest: {MANIFEST_V2_PATH}")
print(f"  Version: {MANIFEST['version']}  Created: {MANIFEST['created']}")
print(f"  Parquets in manifest: {len(MANIFEST['parquets'])}")

# --- load building metadata (v2 path) --------------------------------
_tiers = TIER_SELECTION if isinstance(TIER_SELECTION, list) else [0, 1, 2]
_bldg_pattern = str(DATASET_ROOT_V2 / 'bda_buildings_t{tier}.parquet')
df_bldg = load_tier_parquets(_bldg_pattern, _tiers)
CITIES_TO_PROCESS, _battle_dates = resolve_cities(
    tier_selection=TIER_SELECTION,
    city_selection=[CITY_FILTER] if isinstance(CITY_FILTER, str) else CITY_FILTER,
    require_unosat=REQUIRE_UNOSAT,
)
df_bldg = df_bldg[df_bldg['city'].isin(CITIES_TO_PROCESS)].copy()
df_bldg = df_bldg[df_bldg['damage_binary'] >= 0].copy()
print(f"  Cities: {len(CITIES_TO_PROCESS)}")
print(f"  Buildings: {len(df_bldg)} (damaged={int((df_bldg['damage_binary']==1).sum())}, undamaged={int((df_bldg['damage_binary']==0).sum())})")

TARGET_COL = 'damage_binary'
EXPERIMENT_LOG = {}
DIETRICH_PAPER = {'auc': 0.813, 'f1': 0.749, 'precision': 0.671, 'recall': 0.846}

# ---- NB12 overlap-analysis: canonical OOF predictions schema ----
import hashlib as _hashlib, datetime as _dt
EXPERIMENT_ID = _dt.datetime.now().strftime('%Y%m%d_%H%M%S') + '_' + _hashlib.md5(
    f'nb09a_{TIER_SELECTION}_{REQUIRE_UNOSAT}'.encode()).hexdigest()[:6]
print(f"  EXPERIMENT_ID: {EXPERIMENT_ID}")

def save_oof_from_result(res, model_id, oof_dir, variant_id='',
                         is_final=False, threshold=0.5):
    '''Canonical OOF schema from a result dict that contains:
       y_true, y_proba, groups, building_id, fold_id (all same length, valid-masked).'''
    if res is None:
        return None
    needed = ('y_true', 'y_proba', 'groups', 'building_id', 'fold_id')
    if not all(k in res for k in needed):
        print(f"    [save_oof] skipped {model_id}: missing keys (need {needed})")
        return None
    y_proba = np.asarray(res['y_proba'])
    yt = np.asarray(res['y_true']).astype(int)
    fold = np.asarray(res['fold_id']).astype(int)
    bid = np.asarray(res['building_id'])
    cty = np.asarray(res['groups'])
    yp = (y_proba >= threshold).astype(int)
    cm_class = np.where(yt == 1,
                        np.where(yp == 1, 'TP', 'FN'),
                        np.where(yp == 1, 'FP', 'TN'))
    oof_df = pd.DataFrame({
        'building_id':   bid,
        'city':          cty,
        'fold_id':       fold,
        'y_true':        yt,
        'y_proba':       y_proba.astype(float),
        'y_pred':        yp,
        'cm_class':      cm_class,
        'model_id':      model_id,
        'experiment_id': EXPERIMENT_ID,
        'variant_id':    variant_id,
        'is_final':      bool(is_final),
    })
    oof_dir = Path(oof_dir)
    oof_dir.mkdir(parents=True, exist_ok=True)
    out = oof_dir / f'oof_{model_id}__{EXPERIMENT_ID}.parquet'
    oof_df.to_parquet(out, index=False)
    n_tp = int((cm_class == 'TP').sum()); n_fn = int((cm_class == 'FN').sum())
    n_fp = int((cm_class == 'FP').sum()); n_tn = int((cm_class == 'TN').sum())
    print(f"    saved oof -> {out.name}  TP={n_tp} FN={n_fn} FP={n_fp} TN={n_tn}")
    return out

# --- metadata filter: single source of truth for leakage exclusion ----
# Previous hardcoded LEAKAGE_EXCLUDE_PATTERNS (4 patterns) covered only a
# subset of leakage vectors -- missing was_observed_*, s1__vv__scenes_observed,
# s2__scenes_observed, s2__lu__scenes_observed, s2__visibility__{fire,smoke,
# clear}__freq, block __count_*, rolling __count_*, and the full dietrich
# pixel-count family. metadata_filter.is_non_feature() catches all of them
# via pattern rules and a name-based metadata whitelist.
import importlib
import metadata_filter
importlib.reload(metadata_filter)
from metadata_filter import is_non_feature

def drop_leakage(cols):
    # Thin wrapper so existing prepare_features() and experiment cells keep
    # working. Strictly MORE restrictive than the old 4-pattern filter.
    return [c for c in cols if not is_non_feature(c)]

# --- Dietrich-28 stat filter (NOT a metadata leak filter) ------------
# Used by filter_dietrich28() to exclude the 'count' stat from the
# Dietrich-28 feature subset. Separate concern from metadata leakage:
# this is about matching Dietrich et al. 2025's replication spec.
EXCLUDE_CARD_STATS = ['count']

# --- dietrich column filter (from NB07 D1b, proven to work) ----------
def filter_dietrich28(cols):
    """Keep 7 backscatter stats x _mean zonal agg. Drop count (metadata)."""
    out = []
    for c in cols:
        parts = c.split('__')
        if len(parts) < 4:
            continue
        stat_agg = parts[3]
        stat_name = stat_agg.split('_')[0]
        zonal_agg = stat_agg.split('_')[-1]
        if stat_name in EXCLUDE_CARD_STATS:
            continue
        if zonal_agg != 'mean':
            continue
        out.append(c)
    return out

# --- v2 manifest-driven loader ---------------------------------------
def load_v2(manifest_key, tiers=None, columns=None, sample_frac=None):
    '''Load a v2 parquet by manifest key, merge with buildings, return df.'''
    if manifest_key not in MANIFEST['parquets']:
        raise KeyError(f"Manifest key not found: {manifest_key}")
    info = MANIFEST['parquets'][manifest_key]
    fname_tmpl = Path(info['pattern']).name
    tiers = tiers if tiers is not None else _tiers

    frames = []
    for t in tiers:
        pf = DATASET_ROOT_V2 / fname_tmpl.format(tier=t)
        if not pf.exists():
            print(f"  WARNING: {pf.name} not found, skipping tier {t}")
            continue
        if columns is not None:
            join_cols = info.get('join_keys', ['city', 'building_id'])
            read_cols = list(dict.fromkeys(join_cols + list(columns)))
            try:
                df_t = pd.read_parquet(pf, columns=read_cols)
            except Exception:
                df_t = pd.read_parquet(pf)
                keep = [c for c in read_cols if c in df_t.columns]
                df_t = df_t[keep]
        else:
            df_t = pd.read_parquet(pf)
        if sample_frac is not None and 0 < sample_frac < 1:
            df_t = df_t.sample(frac=sample_frac, random_state=RANDOM_STATE)
        frames.append(df_t)
    if not frames:
        raise FileNotFoundError(f"No v2 parquets found for key={manifest_key} tiers={tiers}")
    df = pd.concat(frames, ignore_index=True)
    del frames

    df = df.loc[:, ~df.columns.duplicated()]
    df = df[df['city'].isin(CITIES_TO_PROCESS)].copy()
    if TARGET_COL not in df.columns:
        df = df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['building_id', 'city'], how='inner')
    df = df[df[TARGET_COL] >= 0].copy()
    df = df.loc[:, ~df.columns.duplicated()]
    print(f"  load_v2('{manifest_key}'): {len(df):,} rows, {df.shape[1]} cols, {df['city'].nunique()} cities")
    return df

# --- legacy v1 loader kept intact (some cells may still use it) ------
def load_and_merge(parquet_fmt, **kwargs):
    """V1 loader: load per-tier v1 parquets by path fmt, merge with buildings."""
    if isinstance(parquet_fmt, Path) and parquet_fmt.exists():
        df = pd.read_parquet(parquet_fmt)
    else:
        df = load_tier_parquets(str(parquet_fmt), _tiers, **kwargs)
    df = df[df['city'].isin(CITIES_TO_PROCESS)].copy()
    if TARGET_COL not in df.columns:
        df = df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['building_id', 'city'], how='inner')
    df = df[df[TARGET_COL] >= 0].copy()
    return df

# --- feature prep + evaluation helpers (unchanged from v20) ----------
def prepare_features(df, feat_cols, drop_all_nan=True):
    """Extract X, y, groups from df, drop all-NaN columns, median-impute."""
    feat_cols = [c for c in feat_cols if c in df.columns]
    feat_cols = drop_leakage(feat_cols)
    if not feat_cols:
        print(f"    SKIP: no non-leakage feature columns")
        return None
    if drop_all_nan:
        nan_rate = df[feat_cols].isna().mean()
        feat_cols = [c for c in feat_cols if nan_rate[c] < 1.0]
    if len(feat_cols) < 2:
        print(f"    SKIP: {len(feat_cols)} feature columns after NaN drop")
        return None
    X = df[feat_cols].values
    y = df[TARGET_COL].values
    groups = df['city'].values
    building_ids = df['building_id'].values
    imp = SimpleImputer(strategy='median')
    X = imp.fit_transform(X)
    return X, y, groups, building_ids, feat_cols


def evaluate_groupkfold(clf, X, y, groups, experiment_name, n_folds=N_FOLDS, needs_scaling=False,
                        building_ids=None):
    n_cities = len(np.unique(groups))
    n_folds_actual = min(n_folds, n_cities)
    if n_folds_actual < 2:
        print(f"    SKIP {experiment_name}: only {n_cities} cities")
        return None
    gkf = GroupKFold(n_splits=n_folds_actual)
    y_proba_oof = np.full(len(y), np.nan)
    fold_id = np.full(len(y), -1, dtype=int)
    fold_aucs = []
    for fold_idx, (tr, te) in enumerate(gkf.split(X, y, groups)):
        Xtr, Xte = X[tr], X[te]
        ytr, yte = y[tr], y[te]
        if needs_scaling:
            scaler = StandardScaler()
            Xtr = scaler.fit_transform(Xtr); Xte = scaler.transform(Xte)
        clf_c = clone(clf)
        clf_c.fit(Xtr, ytr)
        proba = clf_c.predict_proba(Xte)[:, 1] if hasattr(clf_c, 'predict_proba') else 1.0 / (1.0 + np.exp(-clf_c.decision_function(Xte)))
        y_proba_oof[te] = proba
        fold_id[te] = fold_idx
        if len(np.unique(yte)) > 1:
            fold_aucs.append(roc_auc_score(yte, proba))
    valid = ~np.isnan(y_proba_oof)
    y_v, p_v = y[valid], y_proba_oof[valid]
    pred_v = (p_v >= 0.5).astype(int)
    bid_v = np.asarray(building_ids)[valid] if building_ids is not None else np.arange(len(y))[valid].astype(str)
    result = {
        'experiment': experiment_name,
        'auc_groupkfold': roc_auc_score(y_v, p_v),
        'f1_groupkfold': f1_score(y_v, pred_v),
        'precision': precision_score(y_v, pred_v, zero_division=0),
        'recall': recall_score(y_v, pred_v, zero_division=0),
        'fold_aucs': fold_aucs,
        'auc_mean': float(np.mean(fold_aucs)) if fold_aucs else float('nan'),
        'auc_std': float(np.std(fold_aucs)) if fold_aucs else float('nan'),
        'n_features': X.shape[1], 'n_buildings': len(y), 'n_cities': len(np.unique(groups)),
        'y_true': y_v, 'y_proba': p_v, 'groups': groups[valid],
        'building_id': bid_v, 'fold_id': fold_id[valid],
    }
    EXPERIMENT_LOG[experiment_name] = result
    print(f"    {experiment_name:45s} AUC={result['auc_groupkfold']:.3f}  F1={result['f1_groupkfold']:.3f}  n={valid.sum():,} cities={result['n_cities']}")
    return result


# --- result logging / output paths -----------------------------------
import matplotlib.pyplot as plt
from datetime import datetime as _dt

OUT_DIR = OUTPUTS_DIR / "NB09a_v2"
OUT_DIR.mkdir(parents=True, exist_ok=True)


def save_result(data, name, cell_id, fmt='csv'):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    if fmt == 'csv' and isinstance(data, pd.DataFrame):
        path = cell_dir / f"{name}_{ts}.csv"
        data.to_csv(path, index=False)
    elif fmt == 'json':
        path = cell_dir / f"{name}_{ts}.json"
        with open(path, 'w') as fh:
            json.dump(data, fh, indent=2, default=str)
    else:
        raise ValueError(f"Unknown fmt={fmt}")
    print(f"  Saved: {path.relative_to(OUT_DIR)} ({path.stat().st_size / 1024:.1f} KB)")
    return path


def save_fig(fig, name, cell_id, dpi=150):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    path = cell_dir / f"{name}_{ts}.png"
    fig.savefig(path, dpi=dpi, bbox_inches='tight', facecolor='white')
    plt.show()
    print(f"  Plot: {path.relative_to(OUT_DIR)}")
    return path


from bda_results import ResultRegistry
registry = ResultRegistry(RESULTS_ROOT, notebook='NB09a_v2')


def log_result(res, cell_id, parquet_name, feature_set_name, feature_cols,
               classifier_name='RF-200', classifier_params=None, cv_method='GroupKFold',
               note='', tags=None):
    if res is None:
        return
    registry.log_experiment(
        cell_id=cell_id, experiment_name=res['experiment'],
        parquet_name=parquet_name, feature_set_name=feature_set_name,
        classifier_name=classifier_name, classifier_params=classifier_params or {},
        feature_cols=feature_cols, cv_method=cv_method, n_folds=N_FOLDS,
        imputation='median', y_true=res['y_true'], y_proba=res['y_proba'],
        groups=res['groups'], note=note, tags=tags or [],
    )


print(f"  Helpers: load_v2(), load_and_merge(), prepare_features(), evaluate_groupkfold()")
print(f"  Output:  {OUT_DIR}")
print(f"  Registry: NB09a_v2")
# Out:
# ======================================================================
# CELL S0: NB09a v2 — LOAD MANIFEST + BUILDINGS + SHARED HELPERS
# ======================================================================
#   Manifest: /mnt/f/PROJECTS/masterthesis/data_stack/dataset/V2/parquet_manifest.json
#   Version: v2  Created: 2026-04-26T16:31:26.125203
#   Parquets in manifest: 37
#   load_tier_parquets: 3 tiers, 907371 rows
#   Cities: 21
#   Buildings: 598595 (damaged=7332, undamaged=591263)
#   EXPERIMENT_ID: 20260521_183421_7bcb82
#   ResultRegistry: /content/drive_f/masterthesis/results/registry (run_id=20260521_183421)
#   Helpers: load_v2(), load_and_merge(), prepare_features(), evaluate_groupkfold()
#   Output:  /content/drive_f/masterthesis/data/outputs/NB09a_v2
#   Registry: NB09a_v2

# %% [markdown]
# ## CELL S0b -- OOF + SUMMARY HELPERS (verbatim NB09a v7)

# %%
# @title CELL S0b: OOF PLOT + SUMMARY HELPERS
# TP=red, TN=green, FP=pink, FN=gold
import matplotlib.pyplot as plt

CM_COLORS = {'TP': '#d62728', 'TN': '#2ca02c', 'FP': '#ff9ecb', 'FN': '#ffd700'}
CM_LABELS = {'TP': 'Destroyed (TP)', 'TN': 'Not destroyed (TN)',
             'FP': 'False positive (FP)', 'FN': 'False negative (FN)'}

# alias df_bldg -> df_buildings for plotting helper compatibility
df_buildings = df_bldg

def print_cm_summary(oof_path_or_df):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else '(unknown)'
    print(f"  model_id: {model_id}   n={len(oof)}")
    overall = oof['cm_class'].value_counts()
    for cls in ['TP', 'TN', 'FP', 'FN']:
        n = int(overall.get(cls, 0))
        pct = 100.0 * n / len(oof) if len(oof) else 0
        print(f"    {cls:3s} {CM_LABELS[cls]:28s}  n={n:6d}  ({pct:5.1f}%)")
    by_city = (oof.groupby('city')['cm_class']
                 .value_counts().unstack(fill_value=0))
    for cls in ['TP', 'TN', 'FP', 'FN']:
        if cls not in by_city.columns:
            by_city[cls] = 0
    by_city = by_city[['TP', 'TN', 'FP', 'FN']]
    by_city['recall']    = by_city['TP'] / (by_city['TP'] + by_city['FN']).replace(0, np.nan)
    by_city['precision'] = by_city['TP'] / (by_city['TP'] + by_city['FP']).replace(0, np.nan)
    print(f"\n  Per-city:")
    print(by_city.to_string(float_format=lambda x: f'{x:.3f}' if pd.notna(x) else '-'))
    return by_city

def plot_cm_spatial(oof_path_or_df, save_name=None, figsize=(14, 10),
                    buildings_df=None, point_size=4):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    bdf = buildings_df if buildings_df is not None else df_buildings
    if 'centroid_x' not in bdf.columns or 'centroid_y' not in bdf.columns:
        print("  plot_cm_spatial: no centroid_x/centroid_y in buildings_df")
        return None
    plot_df = oof.merge(bdf[['building_id', 'city', 'centroid_x', 'centroid_y']],
                        on=['building_id', 'city'], how='inner')
    if len(plot_df) == 0:
        print("  plot_cm_spatial: no building matches")
        return None
    cities = sorted(plot_df['city'].unique())
    ncols = min(3, len(cities))
    nrows = (len(cities) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, squeeze=False)
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else ''
    fig.suptitle(f'Confusion-matrix map: {model_id}', fontsize=11)
    draw_order = ['TN', 'FP', 'FN', 'TP']
    for i, city in enumerate(cities):
        ax = axes[i // ncols][i % ncols]
        cdf = plot_df[plot_df['city'] == city]
        for cls in draw_order:
            pts = cdf[cdf['cm_class'] == cls]
            if len(pts) == 0:
                continue
            ax.scatter(pts['centroid_x'], pts['centroid_y'],
                       c=CM_COLORS[cls], s=point_size, alpha=0.75,
                       edgecolors='none',
                       label=f"{CM_LABELS[cls]} (n={len(pts)})")
        ax.set_title(f"{city}  (n={len(cdf)})", fontsize=9)
        ax.set_aspect('equal')
        ax.legend(loc='best', fontsize=6, markerscale=2, framealpha=0.85)
        ax.tick_params(labelsize=7)
    for j in range(len(cities), nrows * ncols):
        axes[j // ncols][j % ncols].axis('off')
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    if save_name:
        fig.savefig(OUT_DIR / f'{save_name}.png', dpi=150, bbox_inches='tight')
        plt.close(fig)
    return fig

def plot_cm_oof_all(oof_dir, skip_variants=()):
    d = Path(oof_dir)
    files = sorted(d.glob('oof_*.parquet'))
    print(f"  Found {len(files)} OOF parquets in {d}")
    for p in files:
        oof = pd.read_parquet(p)
        v = oof['variant_id'].iloc[0] if 'variant_id' in oof.columns else ''
        if any(sv in v for sv in skip_variants):
            print(f"  skip {p.name}  (variant_id={v})")
            continue
        print(f"\n  {p.name}")
        print_cm_summary(oof)
        plot_cm_spatial(oof, save_name=p.stem)

# %% [markdown]
# ## CELL H -- CLASSIFIER PARAMS + HELPERS (verbatim NB09a v7)
#
# Includes `RF_PARAMS`, `CLASSIFIERS` dict, `GBM_MAX_FEATURES`. NB11 filters out GBM in BASELINE.

# %%
# @title CELL H: CLASSIFIER PARAMS + HELPERS

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score

RF_PARAMS = dict(n_estimators=200, min_samples_leaf=3,
                 random_state=RANDOM_STATE, n_jobs=-1, class_weight='balanced')

# sklearn GBM is single-threaded — unusable above ~100 features
GBM_MAX_FEATURES = 100

CLASSIFIERS = {
    'RF-200': RandomForestClassifier(**RF_PARAMS),
    'ExtraTrees': ExtraTreesClassifier(n_estimators=200, min_samples_leaf=3,
                                        random_state=RANDOM_STATE, n_jobs=-1, class_weight='balanced'),
    'GBM': GradientBoostingClassifier(n_estimators=200, max_depth=5, learning_rate=0.1,
                                       random_state=RANDOM_STATE),
}

try:
    from lightgbm import LGBMClassifier
    CLASSIFIERS['LightGBM'] = LGBMClassifier(n_estimators=200, max_depth=7, learning_rate=0.1,
                                              random_state=RANDOM_STATE, n_jobs=-1, verbose=-1,
                                              is_unbalance=True)
except ImportError:
    print("  LightGBM not available")

try:
    from xgboost import XGBClassifier
    CLASSIFIERS['XGBoost'] = XGBClassifier(n_estimators=200, max_depth=7, learning_rate=0.1,
                                            random_state=RANDOM_STATE, n_jobs=-1, verbosity=0,
                                            scale_pos_weight=1, use_label_encoder=False, eval_metric='logloss')
except ImportError:
    print("  XGBoost not available")

print(f"  Classifiers: {list(CLASSIFIERS.keys())}")
print(f"  GBM_MAX_FEATURES: {GBM_MAX_FEATURES} (sklearn GBM skipped above this)")
# Out:
#   Classifiers: ['RF-200', 'ExtraTrees', 'GBM', 'LightGBM', 'XGBoost']
#   GBM_MAX_FEATURES: 100 (sklearn GBM skipped above this)

# %% [markdown]
# ## CELL f8_feature_groups (verbatim NB09a v7 -- kept for prep-chain fidelity)

# %%
def f8_feature_groups(df):
    """Modality subsets of fusion_composite_blockstats F8 columns.
    Conventions:
      CARD  = s1__ (excluding s1__coh)
      COH   = s1__coh
      MS    = s2__
    """
    cols = list(df.columns)
    card = [c for c in cols if c.startswith('s1__') and not c.startswith('s1__coh')]
    coh  = [c for c in cols if c.startswith('s1__coh')]
    ms   = [c for c in cols if c.startswith('s2__')]

    groups = {
        'card_only':       drop_leakage(card),
        'coh_only':        drop_leakage(coh),
        'ms_only':         drop_leakage(ms),
        'card_coh':        drop_leakage(card + coh),
        'card_ms':         drop_leakage(card + ms),
        'coh_ms':          drop_leakage(coh + ms),
        'all_multimodal':  drop_leakage(card + coh + ms),
    }
    return groups

# %% [markdown]
# ## CELL BASELINE -- replicate R5 leg verbatim (single feature_set, classifier filter)

# %%
# @title CELL BASELINE: replicate R5 leg verbatim (single feature_set)
print("=" * 70)
print(f"CELL BASELINE: {NB11_NAME} baseline replication")
print("=" * 70)

# --- Verbatim run_classifiers function (lifted from R5) ---
def run_classifiers(df, feat_cols, feature_set_name, parquet_name, classifier_filter=None):
    result = prepare_features(df, feat_cols)
    if not result:
        return
    X, y, groups, building_ids, clean = result
    n_feat = len(clean)
    print(f"    n_features after leakage drop: {n_feat} (from {len(feat_cols)} raw)")

    for clf_name, clf in CLASSIFIERS.items():
        if classifier_filter is not None and clf_name not in classifier_filter:
            continue
        exp_name = f"R5_{clf_name}_{feature_set_name}"

        if exp_name in EXPERIMENT_LOG:
            print(f"    {exp_name:50s} SKIP (already logged)")
            continue

        if clf_name == 'GBM' and n_feat > GBM_MAX_FEATURES:
            print(f"    {exp_name:50s} SKIP (sklearn GBM too slow for {n_feat} features)")
            continue

        res = evaluate_groupkfold(clf, X, y, groups, exp_name,
                                  building_ids=building_ids)
        log_result(res, cell_id='cell_r5', parquet_name=parquet_name,
                   feature_set_name=feature_set_name, classifier_name=clf_name,
                   feature_cols=clean,
                   note=f'Classifier comparison: {clf_name} on {feature_set_name}',
                   tags=['classifier_comparison', clf_name, feature_set_name])

# --- Replicate the R5 leg for this notebook's feature_set ---
df_bd = load_v2(NB11_MANIFEST_KEY)

if NB11_FEATURE_SET == 'dietrich28':
    all_card = [c for c in df_bd.columns
                if c.startswith('s1__') and not c.startswith('s1__coh')]
    baseline_cols = [c for c in all_card if '__baseline__' in c]
    blk01_cols = [c for c in all_card if '__blk01__' in c]
    feat_cols = filter_dietrich28(baseline_cols) + filter_dietrich28(blk01_cols)
elif NB11_FEATURE_SET == 'all_multimodal':
    info = MANIFEST['parquets'][NB11_MANIFEST_KEY]
    feat_cols = [c for c in info['feature_columns'] if c in df_bd.columns]
else:
    raise ValueError(f"Unknown NB11_FEATURE_SET: {NB11_FEATURE_SET}")

# Filter to NB11_CLASSIFIERS only (no GBM)
run_classifiers(df_bd, feat_cols, NB11_FEATURE_SET, NB11_PARQUET_NAME,
                classifier_filter=set(NB11_CLASSIFIERS))

# --- Assert each baseline matches within tolerance ---
print("\n  --- baseline assertion ---")
baseline_results = {}
for clf_name in NB11_CLASSIFIERS:
    expected = NB11_BASELINE_AUC[clf_name]
    exp_key = f"R5_{clf_name}_{NB11_FEATURE_SET}"
    if exp_key not in EXPERIMENT_LOG:
        raise AssertionError(f"{exp_key} missing from EXPERIMENT_LOG")
    got = EXPERIMENT_LOG[exp_key]['auc_groupkfold']
    delta = got - expected
    ok = abs(delta) <= NB11_BASELINE_TOL
    flag = 'OK' if ok else 'FAIL'
    print(f"    {clf_name:12s} got={got:.4f}  expected={expected:.4f}  delta={delta:+.4f}  [{flag}]")
    if not ok:
        raise AssertionError(
            f"Baseline AUC mismatch for {clf_name}: got {got:.4f}, expected {expected:.4f} "
            f"(tol {NB11_BASELINE_TOL}). Do not proceed to Optuna."
        )
    baseline_results[clf_name] = EXPERIMENT_LOG[exp_key]
print("  -> All baselines match source; safe to proceed to Optuna.\n")

# --- Rebuild X/y/groups EXACTLY as run_classifiers built them ---
print("  Rebuilding X, y, groups, building_ids for Optuna (same prep path)...")
_prep = prepare_features(df_bd, feat_cols)
assert _prep is not None
X_NB11, y_NB11, groups_NB11, building_ids_NB11, clean_cols_NB11 = _prep
print(f"  X shape: {X_NB11.shape}  y shape: {y_NB11.shape}  "
      f"cities: {len(np.unique(groups_NB11))}  n_feat: {len(clean_cols_NB11)}")

del df_bd
gc.collect()
# Out:
# ======================================================================
# CELL BASELINE: NB11e_all_multimodal baseline replication
# ======================================================================
#   load_v2('fusion_composite_blockstats'): 480,313 rows, 2414 cols, 19 cities
#     n_features after leakage drop: 915 (from 1086 raw)
#     R5_RF-200_all_multimodal                      AUC=0.774  F1=0.101  n=480,313 cities=19
#   REG: R5_RF-200_all_multimodal                      AUC=0.7737 F1=0.1014 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]
#     R5_ExtraTrees_all_multimodal                  AUC=0.785  F1=0.102  n=480,313 cities=19
#   REG: R5_ExtraTrees_all_multimodal                  AUC=0.7846 F1=0.1016 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]
#     R5_LightGBM_all_multimodal                    AUC=0.792  F1=0.098  n=480,313 cities=19
#   REG: R5_LightGBM_all_multimodal                    AUC=0.7921 F1=0.0981 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]
#     R5_XGBoost_all_multimodal                     AUC=0.805  F1=0.002  n=480,313 cities=19
#   REG: R5_XGBoost_all_multimodal                     AUC=0.8054 F1=0.0019 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]
#
#   --- baseline assertion ---
#     RF-200       got=0.7737  expected=0.7740  delta=-0.0003  [OK]
#     ExtraTrees   got=0.7846  expected=0.7850  delta=-0.0004  [OK]
#     LightGBM     got=0.7921  expected=0.7920  delta=+0.0001  [OK]
#     XGBoost      got=0.8054  expected=0.8050  delta=+0.0004  [OK]
#   -> All baselines match source; safe to proceed to Optuna.
#
#   Rebuilding X, y, groups, building_ids for Optuna (same prep path)...
#   X shape: (480313, 915)  y shape: (480313,)  cities: 19  n_feat: 915
# 279

# %% [markdown]
# ## CELL OPTUNA -- per-classifier tuning on the feature_set
#
# Each classifier gets its own SQLite-persisted study. PATIENCE=40. RESUME-IF-EXISTS.

# %%
# @title CELL OPTUNA: per-classifier tuning on the feature_set
import optuna
from optuna.samplers import TPESampler
import joblib
import json as _json

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
try:
    from lightgbm import LGBMClassifier
except ImportError:
    LGBMClassifier = None
try:
    from xgboost import XGBClassifier
except ImportError:
    XGBClassifier = None

NB11_OUT_DIR = OUTPUTS_DIR / "NB11_V2"
(NB11_OUT_DIR / "studies").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "oof").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "models").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "best_params").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "summary").mkdir(parents=True, exist_ok=True)

def _oof_auc(clf, X, y, groups):
    gkf = GroupKFold(n_splits=min(N_FOLDS, len(np.unique(groups))))
    y_proba_oof = np.full(len(y), np.nan)
    for tr, te in gkf.split(X, y, groups):
        clf_c = clone(clf)
        clf_c.fit(X[tr], y[tr])
        y_proba_oof[te] = clf_c.predict_proba(X[te])[:, 1]
    valid = ~np.isnan(y_proba_oof)
    return roc_auc_score(y[valid], y_proba_oof[valid])

def make_rf(params):
    return RandomForestClassifier(
        random_state=RANDOM_STATE, n_jobs=NB11_THREADS_PER_NB, class_weight='balanced', **params)

def make_et(params):
    return ExtraTreesClassifier(
        random_state=RANDOM_STATE, n_jobs=NB11_THREADS_PER_NB, class_weight='balanced', **params)

def make_lgbm(params):
    return LGBMClassifier(
        random_state=RANDOM_STATE, n_jobs=NB11_THREADS_PER_NB, verbose=-1, is_unbalance=True, **params)

def make_xgb(params):
    return XGBClassifier(
        random_state=RANDOM_STATE, n_jobs=NB11_THREADS_PER_NB, verbosity=0,
        scale_pos_weight=1, use_label_encoder=False, eval_metric='logloss', **params)

def suggest_rf(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 800),
        'max_depth': trial.suggest_categorical('max_depth', [3, 5, 7, 10, 15, None]),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', 0.3, 0.5, 0.7]),
    }

def suggest_et(trial):
    return suggest_rf(trial)

def suggest_lgbm(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 800),
        'num_leaves': trial.suggest_int('num_leaves', 15, 255),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 2.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 2.0),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 0, 10),
    }

def suggest_xgb(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 800),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 2.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 2.0),
    }

BASELINE_TRIALS = {
    'RF-200':     dict(n_estimators=200, max_depth=None, min_samples_leaf=3,
                       min_samples_split=2, max_features='sqrt'),
    'ExtraTrees': dict(n_estimators=200, max_depth=None, min_samples_leaf=3,
                       min_samples_split=2, max_features='sqrt'),
    'LightGBM':   dict(n_estimators=200, num_leaves=31, max_depth=7,
                       learning_rate=0.1, min_child_samples=20,
                       reg_alpha=0.0, reg_lambda=0.0,
                       feature_fraction=1.0, bagging_fraction=1.0, bagging_freq=0),
    'XGBoost':    dict(n_estimators=200, max_depth=7, learning_rate=0.1,
                       min_child_weight=1, subsample=1.0, colsample_bytree=1.0,
                       reg_alpha=0.0, reg_lambda=1.0),
}

CLF_FACTORIES = {
    'RF-200':     (suggest_rf,   make_rf),
    'ExtraTrees': (suggest_et,   make_et),
    'LightGBM':   (suggest_lgbm, make_lgbm),
    'XGBoost':    (suggest_xgb,  make_xgb),
}

def patience_stop_factory(patience):
    def cb(study, trial):
        best = study.best_trial
        if (trial.number - best.number) >= patience:
            print(f"      [patience] no improvement for {patience} trials -> stopping")
            study.stop()
    return cb

NB11_OPTUNA_RESULTS = {}
for clf_name in NB11_CLASSIFIERS:
    if clf_name == 'LightGBM' and LGBMClassifier is None:
        print(f"\n  SKIP {clf_name}: not installed"); continue
    if clf_name == 'XGBoost' and XGBClassifier is None:
        print(f"\n  SKIP {clf_name}: not installed"); continue

    suggest_fn, make_clf = CLF_FACTORIES[clf_name]

    baseline_auc = baseline_results[clf_name]['auc_groupkfold']
    n_trials = OPTUNA_BASE_BUDGET if baseline_auc >= OPTUNA_LOW_AUC_CUTOFF else OPTUNA_LOW_AUC_BUDGET

    STUDY_TAG = f"{NB11_NAME}__{NB11_MANIFEST_KEY}__{clf_name}"
    STUDY_DB  = NB11_OUT_DIR / "studies" / f"{STUDY_TAG}.sqlite"
    storage_url = f"sqlite:///{STUDY_DB.as_posix()}"

    print(f"\n  === {clf_name} ===")
    print(f"    baseline_auc = {baseline_auc:.4f}   budget = {n_trials} trials   patience = {OPTUNA_PATIENCE}")
    print(f"    DB: {STUDY_DB}")

    def objective(trial, _sf=suggest_fn, _mc=make_clf):
        params = _sf(trial)
        clf = _mc(params)
        return _oof_auc(clf, X_NB11, y_NB11, groups_NB11)

    study = optuna.create_study(
        direction=OPTUNA_DIRECTION,
        storage=storage_url,
        study_name=STUDY_TAG,
        load_if_exists=True,
        sampler=TPESampler(seed=OPTUNA_SEED),
    )

    completed_trials = [t for t in study.trials if t.state.name == 'COMPLETE']
    if len(completed_trials) > 0:
        best = study.best_trial
        n_trials_done = len(study.trials)
        print(f"    RESUME: {n_trials_done} trials in study ({len(completed_trials)} complete) -- using as-is")
        print(f"    Best AUC: {best.value:.4f}  (trial {best.number})")
        print(f"    Best params: {best.params}")
        print(f"    Delta vs baseline: {best.value - baseline_auc:+.4f}")
    else:
        study.enqueue_trial(BASELINE_TRIALS[clf_name])
        print(f"    enqueued baseline params as trial 0: {BASELINE_TRIALS[clf_name]}")
        study.optimize(objective, n_trials=n_trials,
                       callbacks=[patience_stop_factory(OPTUNA_PATIENCE)],
                       show_progress_bar=False)
        n_trials_done = len(study.trials)
        best = study.best_trial
        print(f"    Optuna done: {n_trials_done} trials")
        print(f"    Best AUC: {best.value:.4f}  (trial {best.number})")
        print(f"    Best params: {best.params}")
        print(f"    Delta vs baseline: {best.value - baseline_auc:+.4f}")

    NB11_OPTUNA_RESULTS[clf_name] = {
        'baseline_auc': baseline_auc,
        'tuned_auc': best.value,
        'best_params': best.params,
        'n_trials_done': n_trials_done,
        'n_trials_requested': n_trials,
        'study_tag': STUDY_TAG,
        'study_db': STUDY_DB,
        'make_clf': make_clf,
    }
# Out:
#   === RF-200 ===
#     baseline_auc = 0.7737   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11e_all_multimodal__fusion_composite_blockstats__RF-200.sqlite
# [I 2026-05-21 19:02:08,067] Using an existing study with name 'NB11e_all_multimodal__fusion_composite_blockstats__RF-200' instead of creating a new one.
#     RESUME: 20 trials in study (19 complete) -- using as-is
#     Best AUC: 0.8129  (trial 16)
#     Best params: {'n_estimators': 299, 'max_depth': 10, 'min_samples_leaf': 11, 'min_samples_split': 11, 'max_features': 'log2'}
#     Delta vs baseline: +0.0392
#
#   === ExtraTrees ===
#     baseline_auc = 0.7846   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11e_all_multimodal__fusion_composite_blockstats__ExtraTrees.sqlite
# [I 2026-05-21 19:02:08,329] A new study created in RDB with name: NB11e_all_multimodal__fusion_composite_blockstats__ExtraTrees
#     enqueued baseline params as trial 0: {'n_estimators': 200, 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'max_features': 'sqrt'}
# [I 2026-05-21 19:10:17,769] Trial 0 finished with value: 0.7845573690635039 and parameters: {'n_estimators': 200, 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.7845573690635039.
# [I 2026-05-21 19:28:05,158] Trial 1 finished with value: 0.801391356054042 and parameters: {'n_estimators': 362, 'max_depth': 3, 'min_samples_leaf': 18, 'min_samples_split': 13, 'max_features': 0.3}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 20:14:33,672] Trial 2 finished with value: 0.7756414707684676 and parameters: {'n_estimators': 227, 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 7, 'max_features': 0.3}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 20:21:33,677] Trial 3 finished with value: 0.7904754734195094 and parameters: {'n_estimators': 515, 'max_depth': None, 'min_samples_leaf': 17, 'min_samples_split': 7, 'max_features': 'log2'}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 20:22:10,588] Trial 4 finished with value: 0.7423295304468769 and parameters: {'n_estimators': 124, 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 20, 'max_features': 'log2'}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 21:32:28,780] Trial 5 finished with value: 0.7876447507375135 and parameters: {'n_estimators': 162, 'max_depth': None, 'min_samples_leaf': 8, 'min_samples_split': 7, 'max_features': 0.7}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 21:35:50,950] Trial 6 finished with value: 0.74931126799055 and parameters: {'n_estimators': 641, 'max_depth': 7, 'min_samples_leaf': 2, 'min_samples_split': 8, 'max_features': 'log2'}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 21:38:14,804] Trial 7 finished with value: 0.7595299637848174 and parameters: {'n_estimators': 317, 'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 16, 'max_features': 'log2'}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 21:42:45,175] Trial 8 finished with value: 0.7901865876554661 and parameters: {'n_estimators': 117, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 9, 'max_features': 'sqrt'}. Best is trial 1 with value: 0.801391356054042.
# [I 2026-05-21 22:07:10,818] Trial 9 finished with value: 0.8040164293261785 and parameters: {'n_estimators': 751, 'max_depth': None, 'min_samples_leaf': 11, 'min_samples_split': 17, 'max_features': 'sqrt'}. Best is trial 9 with value: 0.8040164293261785.
# [I 2026-05-22 01:34:59,707] Trial 10 finished with value: 0.8050481998711781 and parameters: {'n_estimators': 786, 'max_depth': 15, 'min_samples_leaf': 11, 'min_samples_split': 20, 'max_features': 0.5}. Best is trial 10 with value: 0.8050481998711781.
# [I 2026-05-22 04:53:06,218] Trial 11 finished with value: 0.805005735858052 and parameters: {'n_estimators': 756, 'max_depth': 15, 'min_samples_leaf': 11, 'min_samples_split': 20, 'max_features': 0.5}. Best is trial 10 with value: 0.8050481998711781.
# [I 2026-05-22 08:21:24,622] Trial 12 finished with value: 0.8052937710064956 and parameters: {'n_estimators': 795, 'max_depth': 15, 'min_samples_leaf': 12, 'min_samples_split': 20, 'max_features': 0.5}. Best is trial 12 with value: 0.8052937710064956.
# [I 2026-05-22 11:00:44,489] Trial 13 finished with value: 0.8055670142084941 and parameters: {'n_estimators': 613, 'max_depth': 15, 'min_samples_leaf': 14, 'min_samples_split': 16, 'max_features': 0.5}. Best is trial 13 with value: 0.8055670142084941.
# [I 2026-05-22 12:12:28,085] Trial 14 finished with value: 0.8076585641407144 and parameters: {'n_estimators': 587, 'max_depth': 5, 'min_samples_leaf': 14, 'min_samples_split': 16, 'max_features': 0.5}. Best is trial 14 with value: 0.8076585641407144.
# [I 2026-05-22 13:18:42,786] Trial 15 finished with value: 0.8077293952428803 and parameters: {'n_estimators': 542, 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 14, 'max_features': 0.5}. Best is trial 15 with value: 0.8077293952428803.
# [I 2026-05-22 14:19:19,397] Trial 16 finished with value: 0.8078835240247325 and parameters: {'n_estimators': 495, 'max_depth': 5, 'min_samples_leaf': 19, 'min_samples_split': 13, 'max_features': 0.5}. Best is trial 16 with value: 0.8078835240247325.
# [I 2026-05-22 15:37:39,911] Trial 17 finished with value: 0.8076853102952557 and parameters: {'n_estimators': 463, 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 11, 'max_features': 0.7}. Best is trial 16 with value: 0.8078835240247325.
# [I 2026-05-22 16:25:39,525] Trial 18 finished with value: 0.8078415117908461 and parameters: {'n_estimators': 389, 'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 13, 'max_features': 0.5}. Best is trial 16 with value: 0.8078835240247325.
# [I 2026-05-22 17:11:03,230] Trial 19 finished with value: 0.8078970932847851 and parameters: {'n_estimators': 369, 'max_depth': 5, 'min_samples_leaf': 17, 'min_samples_split': 11, 'max_features': 0.5}. Best is trial 19 with value: 0.8078970932847851.
# [I 2026-05-22 17:47:05,545] Trial 20 finished with value: 0.8076942958784397 and parameters: {'n_estimators': 287, 'max_depth': 5, 'min_samples_leaf': 17, 'min_samples_split': 10, 'max_features': 0.5}. Best is trial 19 with value: 0.8078970932847851.
# [I 2026-05-22 18:35:51,562] Trial 21 finished with value: 0.8079445692238507 and parameters: {'n_estimators': 398, 'max_depth': 5, 'min_samples_leaf': 19, 'min_samples_split': 13, 'max_features': 0.5}. Best is trial 21 with value: 0.8079445692238507.
# [I 2026-05-22 19:27:39,867] Trial 22 finished with value: 0.8079281139886036 and parameters: {'n_estimators': 422, 'max_depth': 5, 'min_samples_leaf': 18, 'min_samples_split': 12, 'max_features': 0.5}. Best is trial 21 with value: 0.8079445692238507.
# [I 2026-05-22 20:19:47,264] Trial 23 finished with value: 0.8079568619722497 and parameters: {'n_estimators': 411, 'max_depth': 5, 'min_samples_leaf': 16, 'min_samples_split': 5, 'max_features': 0.5}. Best is trial 23 with value: 0.8079568619722497.
# [I 2026-05-22 21:53:03,241] Trial 24 finished with value: 0.8099135943320944 and parameters: {'n_estimators': 443, 'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 4, 'max_features': 0.5}. Best is trial 24 with value: 0.8099135943320944.
# [I 2026-05-22 22:31:23,090] Trial 25 finished with value: 0.8101797834836346 and parameters: {'n_estimators': 290, 'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 3, 'max_features': 0.3}. Best is trial 25 with value: 0.8101797834836346.
# [I 2026-05-22 23:05:49,093] Trial 26 finished with value: 0.8102534499711327 and parameters: {'n_estimators': 260, 'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 3, 'max_features': 0.3}. Best is trial 26 with value: 0.8102534499711327.
# [I 2026-05-22 23:43:06,316] Trial 27 finished with value: 0.8102300033345013 and parameters: {'n_estimators': 282, 'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 2, 'max_features': 0.3}. Best is trial
 'max_features': 0.3}. Best is trial 47 with value: 0.8106303147419311.
# [I 2026-05-24 01:27:23,409] Trial 81 finished with value: 0.8105513586725026 and parameters: {'n_estimators': 177, 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 4, 'max_features': 0.3}. Best is trial 47 with value: 0.8106303147419311.
# [I 2026-05-24 01:51:04,533] Trial 82 finished with value: 0.8104744409039404 and parameters: {'n_estimators': 180, 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 4, 'max_features': 0.3}. Best is trial 47 with value: 0.8106303147419311.
# [I 2026-05-24 02:10:10,354] Trial 83 finished with value: 0.8100729356345746 and parameters: {'n_estimators': 142, 'max_depth': 10, 'min_samples_leaf': 9, 'min_samples_split': 3, 'max_features': 0.3}. Best is trial 47 with value: 0.8106303147419311.
# [I 2026-05-24 02:49:30,871] Trial 84 finished with value: 0.8099941198637772 and parameters: {'n_estimators': 302, 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 6, 'max_features': 0.3}. Best is trial 47 with value: 0.8106303147419311.
# [I 2026-05-24 02:52:17,435] Trial 85 finished with value: 0.770089001116107 and parameters: {'n_estimators': 271, 'max_depth': 15, 'min_samples_leaf': 7, 'min_samples_split': 4, 'max_features': 'log2'}. Best is trial 47 with value: 0.8106303147419311.
# [I 2026-05-24 03:24:27,451] Trial 86 finished with value: 0.8100602487558496 and parameters: {'n_estimators': 244, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'max_features': 0.3}. Best is trial 47 with value: 0.8106303147419311.
# [I 2026-05-24 03:50:39,783] Trial 87 finished with value: 0.8102590069146054 and parameters: {'n_estimators': 198, 'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 2, 'max_features': 0.3}. Best is trial 47 with value: 0.8106303147419311.
#       [patience] no improvement for 40 trials -> stopping
#     Optuna done: 88 trials
#     Best AUC: 0.8106  (trial 47)
#     Best params: {'n_estimators': 206, 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 2, 'max_features': 0.3}
#     Delta vs baseline: +0.0261
#
#   === LightGBM ===
#     baseline_auc = 0.7921   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11e_all_multimodal__fusion_composite_blockstats__LightGBM.sqlite
# [I 2026-05-24 03:50:40,051] A new study created in RDB with name: NB11e_all_multimodal__fusion_composite_blockstats__LightGBM
#     enqueued baseline params as trial 0: {'n_estimators': 200, 'num_leaves': 31, 'max_depth': 7, 'learning_rate': 0.1, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}
# [I 2026-05-24 03:53:16,535] Trial 0 finished with value: 0.7920682278937149 and parameters: {'n_estimators': 200, 'num_leaves': 31, 'max_depth': 7, 'learning_rate': 0.1, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}. Best is trial 0 with value: 0.7920682278937149.
# [I 2026-05-24 04:01:33,712] Trial 1 finished with value: 0.7599149273455656 and parameters: {'n_estimators': 362, 'num_leaves': 244, 'max_depth': 10, 'learning_rate': 0.060099747183803134, 'min_child_samples': 19, 'reg_alpha': 0.3119890406724053, 'reg_lambda': 0.11616722433639892, 'feature_fraction': 0.9330880728874675, 'bagging_fraction': 0.8005575058716043, 'bagging_freq': 7}. Best is trial 0 with value: 0.7920682278937149.
# [I 2026-05-24 04:04:25,505] Trial 2 finished with value: 0.8012639243075037 and parameters: {'n_estimators': 114, 'num_leaves': 248, 'max_depth': 11, 'learning_rate': 0.018891200276189388, 'min_child_samples': 22, 'reg_alpha': 0.36680901970686763, 'reg_lambda': 0.6084844859190754, 'feature_fraction': 0.762378215816119, 'bagging_fraction': 0.7159725093210578, 'bagging_freq': 3}. Best is trial 2 with value: 0.8012639243075037.
# [I 2026-05-24 04:08:25,946] Trial 3 finished with value: 0.8069919600490018 and parameters: {'n_estimators': 528, 'num_leaves': 48, 'max_depth': 5, 'learning_rate': 0.029967309097101588, 'min_child_samples': 48, 'reg_alpha': 1.5703519227860272, 'reg_lambda': 0.39934756431671947, 'feature_fraction': 0.7571172192068059, 'bagging_fraction': 0.7962072844310213, 'bagging_freq': 0}. Best is trial 3 with value: 0.8069919600490018.
# [I 2026-05-24 04:11:03,213] Trial 4 finished with value: 0.42350400750627437 and parameters: {'n_estimators': 525, 'num_leaves': 56, 'max_depth': 3, 'learning_rate': 0.17160445029754812, 'min_child_samples': 97, 'reg_alpha': 1.6167946962329223, 'reg_lambda': 0.6092275383467414, 'feature_fraction': 0.5488360570031919, 'bagging_fraction': 0.8421165132560784, 'bagging_freq': 4}. Best is trial 3 with value: 0.8069919600490018.
# [I 2026-05-24 04:12:48,087] Trial 5 finished with value: 0.42976687398268903 and parameters: {'n_estimators': 185, 'num_leaves': 134, 'max_depth': 3, 'learning_rate': 0.15242391728466367, 'min_child_samples': 29, 'reg_alpha': 1.325044568707964, 'reg_lambda': 0.6234221521788219, 'feature_fraction': 0.7600340105889054, 'bagging_fraction': 0.7733551396716398, 'bagging_freq': 2}. Best is trial 3 with value: 0.8069919600490018.
# [I 2026-05-24 04:17:25,173] Trial 6 finished with value: 0.7763936739374317 and parameters: {'n_estimators': 779, 'num_leaves': 201, 'max_depth': 12, 'learning_rate': 0.1459476894296684, 'min_child_samples': 62, 'reg_alpha': 1.8437484700462337, 'reg_lambda': 0.176985004103839, 'feature_fraction': 0.5979914312095727, 'bagging_fraction': 0.522613644455269, 'bagging_freq': 3}. Best is trial 3 with value: 0.8069919600490018.
# [I 2026-05-24 04:23:17,870] Trial 7 finished with value: 0.7871142902902479 and parameters: {'n_estimators': 372, 'num_leaves': 80, 'max_depth': 11, 'learning_rate': 0.02911701023242742, 'min_child_samples': 31, 'reg_alpha': 1.085392166316497, 'reg_lambda': 0.2818484499495253, 'feature_fraction': 0.9010984903770198, 'bagging_fraction': 0.5372753218398854, 'bagging_freq': 10}. Best is trial 3 with value: 0.8069919600490018.
# [I 2026-05-24 04:26:04,598] Trial 8 finished with value: 0.8014099054743062 and parameters: {'n_estimators': 641, 'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.11506408247250169, 'min_child_samples': 72, 'reg_alpha': 1.4580143360819746, 'reg_lambda': 1.5425406933718915, 'feature_fraction': 0.5370223258670452, 'bagging_fraction': 0.6792328642721364, 'bagging_freq': 1}. Best is trial 3 with value: 0.8069919600490018.
# [I 2026-05-24 04:32:32,300] Trial 9 finished with value: 0.8077856035216887 and parameters: {'n_estimators': 705, 'num_leaves': 165, 'max_depth': 6, 'learning_rate': 0.012097379927033842, 'min_child_samples': 34, 'reg_alpha': 0.6503666440534941, 'reg_lambda': 1.4592123566761281, 'feature_fraction': 0.8187787356776066, 'bagging_fraction': 0.9436063712881633, 'bagging_freq': 5}. Best is trial 9 with value: 0.8077856035216887.
# [I 2026-05-24 04:42:11,409] Trial 10 finished with value: 0.7995831708258996 and parameters: {'n_estimators': 786, 'num_leaves': 154, 'max_depth': 8, 'learning_rate': 0.010552829926879401, 'min_child_samples': 7, 'reg_alpha': 0.7233570602390595, 'reg_lambda': 1.9221720315568283, 'feature_fraction': 0.6626799989856424, 'bagging_fraction': 0.9848950858668689, 'bagging_freq': 6}. Best is trial 9 with value: 0.8077856035216887.
# [I 2026-05-24 04:48:04,356] Trial 11 finished with value: 0.8084979758504713 and parameters: {'n_estimators': 603, 'num_leaves': 121, 'max_depth': 6, 'learning_rate': 0.01123400184800387, 'min_child_samples': 48, 'reg_alpha': 0.84931611282338, 'reg_lambda': 1.2143685480664512, 'feature_fraction': 0.826815807376933, 'bagging_fraction': 0.8971778072825249, 'bagging_freq': 8}. Best is trial 11 with value: 0.8084979758504713.
# [I 2026-05-24 04:54:14,101] Trial 12 finished with value: 0.8088453876149432 and parameters: {'n_estimators': 654, 'num_leaves': 118, 'max_depth': 6, 'learning_rate': 0.011455356310090994, 'min_child_samples': 44, 'reg_alpha': 0.8257281319576956, 'reg_lambda': 1.2618969927431096, 'feature_fraction': 0.8559889011067058, 'bagging_fraction': 0.8892800317025393, 'bagging_freq': 8}. Best is trial 12 with value: 0.8088453876149432.
# [I 2026-05-24 04:59:04,457] Trial 13 finished with value: 0.8097494964060054 and parameters: {'n_estimators': 612, 'num_leaves': 115, 'max_depth': 5, 'learning_rate': 0.016622174418636712, 'min_child_samples': 48, 'reg_alpha': 0.9228096789737753, 'reg_lambda': 1.1349086386298943, 'feature_fraction': 0.8503032038947455, 'bagging_fraction': 0.8924098193658432, 'bagging_freq': 9}. Best is trial 13 with value: 0.8097494964060054.
# [I 2026-05-24 05:03:15,876] Trial 14 finished with value: 0.8091672976766722 and parameters: {'n_estimators': 459, 'num_leaves': 108, 'max_depth': 5, 'learning_rate': 0.019365032879138655, 'min_child_samples': 76, 'reg_alpha': 1.1211970080651221, 'reg_lambda': 1.1414330430371167, 'feature_fraction': 0.8632343512963981, 'bagging_fraction': 0.8809031730635826, 'bagging_freq': 10}. Best is trial 13 with value: 0.8097494964060054.
# [I 2026-05-24 05:06:15,664] Trial 15 finished with value: 0.8097166724088808 and parameters: {'n_estimators': 409, 'num_leaves': 96, 'max_depth': 5, 'learning_rate': 0.02034843418516271, 'min_child_samples': 79, 'reg_alpha': 1.1231639625040235, 'reg_lambda': 0.9358142502895346, 'feature_fraction': 0.6763905431730481, 'bagging_fraction': 0.627528534606948, 'bagging_freq': 10}. Best is trial 13 with value: 0.8097494964060054.
# [I 2026-05-24 05:10:24,446] Trial 16 finished with value: 0.8010407868350538 and parameters: {'n_estimators': 340, 'num_leaves': 86, 'max_depth': 8, 'learning_rate': 0.018944712426268714, 'min_child_samples': 91, 'reg_alpha': 1.2506906090515173, 'reg_lambda': 0.8718121013608952, 'feature_fraction': 0.6648408206455402, 'bagging_fraction': 0.6221247497465149, 'bagging_freq': 9}. Best is trial 13 with value: 0.8097494964060054.
# [I 2026-05-24 05:13:10,701] Trial 17 finished with value: 0.8074604271784129 and parameters: {'n_estimators': 487, 'num_leaves': 176, 'max_depth': 4, 'learning_rate': 0.04489977116005677, 'min_child_samples': 63, 'reg_alpha': 0.48588730258873003, 'reg_lambda': 0.9263041722219287, 'feature_fraction': 0.67455198366465, 'bagging_fraction': 0.6100404103948398, 'bagging_freq': 9}. Best is trial 13 with value: 0.8097494964060054.
# [I 2026-05-24 05:15:24,157] Trial 18 finished with value: 0.8113907815590898 and parameters: {'n_estimators': 268, 'num_leaves': 17, 'max_depth': 5, 'learning_rate': 0.02632621616032259, 'min_child_samples': 81, 'reg_alpha': 0.9638139161928047, 'reg_lambda': 1.7259679907898855, 'feature_fraction': 0.699132495073797, 'bagging_fraction': 0.6360629502431113, 'bagging_freq': 7}. Best is trial 18 with value: 0.8113907815590898.
# [I 2026-05-24 05
. Best is trial 18 with value: 0.8113907815590898.
# [I 2026-05-24 05:34:30,214] Trial 26 finished with value: 0.8088867960058747 and parameters: {'n_estimators': 224, 'num_leaves': 187, 'max_depth': 6, 'learning_rate': 0.02411060285721708, 'min_child_samples': 80, 'reg_alpha': 1.8544383378589293, 'reg_lambda': 1.8878923636124896, 'feature_fraction': 0.6130200844661129, 'bagging_fraction': 0.5670435467480909, 'bagging_freq': 5}. Best is trial 18 with value: 0.8113907815590898.
# [I 2026-05-24 05:36:10,006] Trial 27 finished with value: 0.8045676088223288 and parameters: {'n_estimators': 143, 'num_leaves': 211, 'max_depth': 4, 'learning_rate': 0.051865293768950965, 'min_child_samples': 99, 'reg_alpha': 1.6300144819323892, 'reg_lambda': 1.554620928952526, 'feature_fraction': 0.7120212177029033, 'bagging_fraction': 0.7399354398179516, 'bagging_freq': 4}. Best is trial 18 with value: 0.8113907815590898.
# [I 2026-05-24 05:39:44,310] Trial 28 finished with value: 0.8062812313025052 and parameters: {'n_estimators': 309, 'num_leaves': 41, 'max_depth': 9, 'learning_rate': 0.024003538705671176, 'min_child_samples': 68, 'reg_alpha': 1.1813368607625077, 'reg_lambda': 1.7889776325064746, 'feature_fraction': 0.7172266153934637, 'bagging_fraction': 0.6488407597140968, 'bagging_freq': 7}. Best is trial 18 with value: 0.8113907815590898.
# [I 2026-05-24 05:42:40,113] Trial 29 finished with value: 0.788481671631847 and parameters: {'n_estimators': 233, 'num_leaves': 38, 'max_depth': 8, 'learning_rate': 0.07886912180677128, 'min_child_samples': 86, 'reg_alpha': 0.10595991600936217, 'reg_lambda': 1.349246162633205, 'feature_fraction': 0.9763551405686438, 'bagging_fraction': 0.5765089884838234, 'bagging_freq': 4}. Best is trial 18 with value: 0.8113907815590898.
# [I 2026-05-24 05:44:49,236] Trial 30 finished with value: 0.8012652019956659 and parameters: {'n_estimators': 165, 'num_leaves': 157, 'max_depth': 7, 'learning_rate': 0.03566461951002441, 'min_child_samples': 37, 'reg_alpha': 1.4268277433381618, 'reg_lambda': 1.9993767145488845, 'feature_fraction': 0.6172267003098161, 'bagging_fraction': 0.5030211506714958, 'bagging_freq': 6}. Best is trial 18 with value: 0.8113907815590898.
# [I 2026-05-24 05:46:44,835] Trial 31 finished with value: 0.8121220847909972 and parameters: {'n_estimators': 223, 'num_leaves': 222, 'max_depth': 4, 'learning_rate': 0.0348372447162183, 'min_child_samples': 43, 'reg_alpha': 1.3300006986421264, 'reg_lambda': 1.6314015027899587, 'feature_fraction': 0.7974956407774155, 'bagging_fraction': 0.6595836412123554, 'bagging_freq': 5}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 05:48:46,586] Trial 32 finished with value: 0.8092360493001767 and parameters: {'n_estimators': 241, 'num_leaves': 229, 'max_depth': 4, 'learning_rate': 0.032833753777511146, 'min_child_samples': 24, 'reg_alpha': 1.0270473527074002, 'reg_lambda': 1.636953665909352, 'feature_fraction': 0.812787273138881, 'bagging_fraction': 0.7064652369457658, 'bagging_freq': 7}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 05:51:31,509] Trial 33 finished with value: 0.8105876974885812 and parameters: {'n_estimators': 326, 'num_leaves': 234, 'max_depth': 5, 'learning_rate': 0.024550900955884004, 'min_child_samples': 16, 'reg_alpha': 1.2806796409350132, 'reg_lambda': 1.8330657391324887, 'feature_fraction': 0.8865205548638048, 'bagging_fraction': 0.6447269237512996, 'bagging_freq': 5}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 05:53:01,330] Trial 34 finished with value: 0.8050599170128245 and parameters: {'n_estimators': 138, 'num_leaves': 252, 'max_depth': 3, 'learning_rate': 0.04515073336471454, 'min_child_samples': 39, 'reg_alpha': 1.514316146411545, 'reg_lambda': 1.582641328171119, 'feature_fraction': 0.7853286735126958, 'bagging_fraction': 0.6961682039068637, 'bagging_freq': 3}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 05:55:24,207] Trial 35 finished with value: 0.8087654379841399 and parameters: {'n_estimators': 208, 'num_leaves': 201, 'max_depth': 5, 'learning_rate': 0.026745474410476092, 'min_child_samples': 52, 'reg_alpha': 1.2173216422479647, 'reg_lambda': 1.3958643412099137, 'feature_fraction': 0.9328669828383724, 'bagging_fraction': 0.7618982322801465, 'bagging_freq': 6}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 05:56:52,645] Trial 36 finished with value: 0.811720766586473 and parameters: {'n_estimators': 100, 'num_leaves': 214, 'max_depth': 3, 'learning_rate': 0.01414600227870902, 'min_child_samples': 58, 'reg_alpha': 1.7189900984493425, 'reg_lambda': 1.7741846723654136, 'feature_fraction': 0.7341262180121724, 'bagging_fraction': 0.8085199672743099, 'bagging_freq': 4}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 05:58:16,993] Trial 37 finished with value: 0.8114606476302109 and parameters: {'n_estimators': 103, 'num_leaves': 215, 'max_depth': 3, 'learning_rate': 0.01540907103770713, 'min_child_samples': 46, 'reg_alpha': 1.7377108301268278, 'reg_lambda': 1.6549607737495955, 'feature_fraction': 0.7800198033366608, 'bagging_fraction': 0.592424555270126, 'bagging_freq': 4}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 05:59:46,171] Trial 38 finished with value: 0.8116894955804845 and parameters: {'n_estimators': 103, 'num_leaves': 216, 'max_depth': 3, 'learning_rate': 0.014168632687645856, 'min_child_samples': 54, 'reg_alpha': 1.9915682890470843, 'reg_lambda': 1.3183657231450294, 'feature_fraction': 0.7390474186239008, 'bagging_fraction': 0.8186413341591483, 'bagging_freq': 3}. Best is trial 31 with value: 0.8121220847909972.
# [I 2026-05-24 06:01:17,857] Trial 39 finished with value: 0.8121436028361737 and parameters: {'n_estimators': 111, 'num_leaves': 239, 'max_depth': 3, 'learning_rate': 0.013509842194535708, 'min_child_samples': 52, 'reg_alpha': 1.7310455468984765, 'reg_lambda': 1.2885902376940122, 'feature_fraction': 0.7690865885442313, 'bagging_fraction': 0.8083600357767562, 'bagging_freq': 3}. Best is trial 39 with value: 0.8121436028361737.
# [I 2026-05-24 06:02:58,138] Trial 40 finished with value: 0.8104099776536869 and parameters: {'n_estimators': 151, 'num_leaves': 239, 'max_depth': 3, 'learning_rate': 0.013199062060209672, 'min_child_samples': 53, 'reg_alpha': 1.9104413551162744, 'reg_lambda': 1.0606376519154164, 'feature_fraction': 0.7349423273895865, 'bagging_fraction': 0.8141783843644557, 'bagging_freq': 2}. Best is trial 39 with value: 0.8121436028361737.
# [I 2026-05-24 06:04:26,339] Trial 41 finished with value: 0.8126957191271666 and parameters: {'n_estimators': 104, 'num_leaves': 219, 'max_depth': 3, 'learning_rate': 0.015472953291188495, 'min_child_samples': 45, 'reg_alpha': 1.9977856314895446, 'reg_lambda': 1.3170171672731077, 'feature_fraction': 0.7599833703300971, 'bagging_fraction': 0.8241012917547152, 'bagging_freq': 2}. Best is trial 41 with value: 0.8126957191271666.
# [I 2026-05-24 06:06:04,229] Trial 42 finished with value: 0.8129674544865404 and parameters: {'n_estimators': 124, 'num_leaves': 253, 'max_depth': 3, 'learning_rate': 0.013360553688430992, 'min_child_samples': 51, 'reg_alpha': 1.991934293977063, 'reg_lambda': 1.3080149112793413, 'feature_fraction': 0.7507699466449117, 'bagging_fraction': 0.8419543530708935, 'bagging_freq': 2}. Best is trial 42 with value: 0.8129674544865404.
# [I 2026-05-24 06
. Best is trial 42 with value: 0.8129674544865404.
# [I 2026-05-24 06:27:16,678] Trial 51 finished with value: 0.8125027582137319 and parameters: {'n_estimators': 123, 'num_leaves': 239, 'max_depth': 3, 'learning_rate': 0.010040523166350346, 'min_child_samples': 50, 'reg_alpha': 1.8018516797961803, 'reg_lambda': 0.28615926475733816, 'feature_fraction': 0.8346439942984378, 'bagging_fraction': 0.8326720783182154, 'bagging_freq': 1}. Best is trial 42 with value: 0.8129674544865404.
# [I 2026-05-24 06:28:52,163] Trial 52 finished with value: 0.8100883959848753 and parameters: {'n_estimators': 129, 'num_leaves': 235, 'max_depth': 3, 'learning_rate': 0.01115085905548821, 'min_child_samples': 47, 'reg_alpha': 1.8153372530479013, 'reg_lambda': 0.2666077050491679, 'feature_fraction': 0.8226374947431637, 'bagging_fraction': 0.8300791793628712, 'bagging_freq': 1}. Best is trial 42 with value: 0.8129674544865404.
# [I 2026-05-24 06:31:01,692] Trial 53 finished with value: 0.8103947637819038 and parameters: {'n_estimators': 165, 'num_leaves': 227, 'max_depth': 4, 'learning_rate': 0.010027145257721767, 'min_child_samples': 61, 'reg_alpha': 1.997664924429085, 'reg_lambda': 0.5650009899478361, 'feature_fraction': 0.8423851170810396, 'bagging_fraction': 0.7909271029467873, 'bagging_freq': 0}. Best is trial 42 with value: 0.8129674544865404.
# [I 2026-05-24 06:32:59,601] Trial 54 finished with value: 0.8088426962048311 and parameters: {'n_estimators': 199, 'num_leaves': 246, 'max_depth': 3, 'learning_rate': 0.021130087386652396, 'min_child_samples': 51, 'reg_alpha': 1.9164071596500836, 'reg_lambda': 0.3238522043215796, 'feature_fraction': 0.9116266663387912, 'bagging_fraction': 0.9194546527209506, 'bagging_freq': 1}. Best is trial 42 with value: 0.8129674544865404.
# [I 2026-05-24 06:36:13,330] Trial 55 finished with value: 0.8120352169964601 and parameters: {'n_estimators': 540, 'num_leaves': 203, 'max_depth': 3, 'learning_rate': 0.01189481367902637, 'min_child_samples': 57, 'reg_alpha': 1.8178752676112846, 'reg_lambda': 0.8132233349351814, 'feature_fraction': 0.827223131680313, 'bagging_fraction': 0.8368788707508418, 'bagging_freq': 2}. Best is trial 42 with value: 0.8129674544865404.
# ...
# [I 2026-05-24 12:44:41,106] Trial 35 finished with value: 0.8122493640326292 and parameters: {'n_estimators': 727, 'max_depth': 12, 'learning_rate': 0.010098948353701051, 'min_child_weight': 2, 'subsample': 0.5430785100237072, 'colsample_bytree': 0.5027292876886564, 'reg_alpha': 0.029118929890269013, 'reg_lambda': 1.7102823814216948}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 12:56:15,432] Trial 36 finished with value: 0.8125813322120454 and parameters: {'n_estimators': 797, 'max_depth': 12, 'learning_rate': 0.010140079778090814, 'min_child_weight': 1, 'subsample': 0.5486780917425551, 'colsample_bytree': 0.5081530967041233, 'reg_alpha': 0.09778185224330727, 'reg_lambda': 1.9199902344061193}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 13:07:29,427] Trial 37 finished with value: 0.8121734086479679 and parameters: {'n_estimators': 796, 'max_depth': 12, 'learning_rate': 0.01007941693979771, 'min_child_weight': 1, 'subsample': 0.5484115546855831, 'colsample_bytree': 0.5283192393277216, 'reg_alpha': 0.03185598158803645, 'reg_lambda': 1.8883449233598768}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 13
. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 14:24:56,261] Trial 47 finished with value: 0.8073218274255411 and parameters: {'n_estimators': 729, 'max_depth': 7, 'learning_rate': 0.011901341747574734, 'min_child_weight': 5, 'subsample': 0.563161027209573, 'colsample_bytree': 0.5541968974419615, 'reg_alpha': 0.5302273987303429, 'reg_lambda': 1.9262394165818444}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 14:33:44,853] Trial 48 finished with value: 0.7929958308229363 and parameters: {'n_estimators': 772, 'max_depth': 8, 'learning_rate': 0.07683017888660519, 'min_child_weight': 1, 'subsample': 0.6581580543393712, 'colsample_bytree': 0.6354839735925212, 'reg_alpha': 0.3221395018200781, 'reg_lambda': 1.6246218005376207}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 14:39:54,266] Trial 49 finished with value: 0.8065087377390343 and parameters: {'n_estimators': 646, 'max_depth': 9, 'learning_rate': 0.015499246972919652, 'min_child_weight': 20, 'subsample': 0.7627268872117703, 'colsample_bytree': 0.562682455288169, 'reg_alpha': 0.15088674857615994, 'reg_lambda': 1.7909091123442196}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 14:48:05,943] Trial 50 finished with value: 0.8111230889768313 and parameters: {'n_estimators': 741, 'max_depth': 10, 'learning_rate': 0.011480164377084113, 'min_child_weight': 3, 'subsample': 0.9690634132749897, 'colsample_bytree': 0.5137875093840462, 'reg_alpha': 0.39241275648841806, 'reg_lambda': 0.861958898265033}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 14:58:05,827] Trial 51 finished with value: 0.8105902559532399 and parameters: {'n_estimators': 800, 'max_depth': 12, 'learning_rate': 0.01889473145979877, 'min_child_weight': 3, 'subsample': 0.5944134570701398, 'colsample_bytree': 0.5335574328491177, 'reg_alpha': 0.09614139765000562, 'reg_lambda': 1.214445447208283}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 15:01:11,457] Trial 52 finished with value: 0.8097371642445738 and parameters: {'n_estimators': 228, 'max_depth': 10, 'learning_rate': 0.024173688471225325, 'min_child_weight': 2, 'subsample': 0.5769604762497342, 'colsample_bytree': 0.5971321795163972, 'reg_alpha': 0.5037827059203541, 'reg_lambda': 1.4277372145107172}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 15:08:50,043] Trial 53 finished with value: 0.8099613904285183 and parameters: {'n_estimators': 722, 'max_depth': 11, 'learning_rate': 0.029737537727451396, 'min_child_weight': 7, 'subsample': 0.6823186037915486, 'colsample_bytree': 0.5772880951605233, 'reg_alpha': 0.22612565850658506, 'reg_lambda': 1.8079680916525211}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 15:14:14,778] Trial 54 finished with value: 0.8116844370353983 and parameters: {'n_estimators': 359, 'max_depth': 11, 'learning_rate': 0.01660158194067334, 'min_child_weight': 1, 'subsample': 0.6444041603164763, 'colsample_bytree': 0.9843410159000081, 'reg_alpha': 0.3438180818419878, 'reg_lambda': 1.620062990616465}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 15:21:55,003] Trial 55 finished with value: 0.8116408318090886 and parameters: {'n_estimators': 665, 'max_depth': 12, 'learning_rate': 0.02204610338859948, 'min_child_weight': 5, 'subsample': 0.5999565438118132, 'colsample_bytree': 0.5519464043612206, 'reg_alpha': 0.08585834693268243, 'reg_lambda': 1.3336466021063917}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 15:28:26,987] Trial 56 finished with value: 0.806863156052436 and parameters: {'n_estimators': 778, 'max_depth': 6, 'learning_rate': 0.012767512819757564, 'min_child_weight': 3, 'subsample': 0.5636276057366011, 'colsample_bytree': 0.5186407517138609, 'reg_alpha': 0.2615781181975339, 'reg_lambda': 1.9544425063773632}. Best is trial 34 with value: 0.8129898087350882.
# [I 2026-05-24 15

#       [patience] no improvement for 40 trials -> stopping
#     Optuna done: 75 trials
#     Best AUC: 0.8130  (trial 34)
#     Best params: {'n_estimators': 734, 'max_depth': 12, 'learning_rate': 0.010512649118874492, 'min_child_weight': 2, 'subsample': 0.5581890006562221, 'colsample_bytree': 0.6227818193697767, 'reg_alpha': 0.21407953799342228, 'reg_lambda': 1.7287662217436988}
#     Delta vs baseline: +0.0076

# %% [markdown]
# ## CELL OPTUNA-FINAL -- refit + save per classifier with `mean_folds_auc`

# %%
import importlib, nb11_finalize
importlib.reload(nb11_finalize)
nb11_finalize.finalize_group_b_r5(globals())
# Out:
#   === refit RF-200 ===
#     Tuned OOF AUC (refit): 0.8129  (study.best=0.8129)  delta=+0.0000
#     mean(folds)=0.7181  std(folds)=0.0799
#     saved oof -> oof_NB11e_all_multimodal__fusion_composite_blockstats__RF-200-Optuna__20260521_183421_7bcb82.parquet  TP=5516 FN=1670 FP=96442 TN=376685
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11e_all_multimodal__fusion_composite_blockstats__RF-200__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11e_all_multimodal__fusion_composite_blockstats__RF-200__best.json
#   REG: R5_RF-200_all_multimodal__OPTUNA              AUC=0.8129 F1=0.1011 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]
#
#   === refit ExtraTrees ===
#     Tuned OOF AUC (refit): 0.8106  (study.best=0.8106)  delta=+0.0000
#     mean(folds)=0.7139  std(folds)=0.0716
#     saved oof -> oof_NB11e_all_multimodal__fusion_composite_blockstats__ExtraTrees-Optuna__20260521_183421_7bcb82.parquet  TP=5674 FN=1512 FP=104331 TN=368796
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11e_all_multimodal__fusion_composite_blockstats__ExtraTrees__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11e_all_multimodal__fusion_composite_blockstats__ExtraTrees__best.json
#   REG: R5_ExtraTrees_all_multimodal__OPTUNA          AUC=0.8106 F1=0.0968 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]
#
#   === refit LightGBM ===
#     Tuned OOF AUC (refit): 0.8131  (study.best=0.8131)  delta=+0.0000
#     mean(folds)=0.7113  std(folds)=0.0760
#     saved oof -> oof_NB11e_all_multimodal__fusion_composite_blockstats__LightGBM-Optuna__20260521_183421_7bcb82.parquet  TP=5672 FN=1514 FP=105550 TN=367577
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11e_all_multimodal__fusion_composite_blockstats__LightGBM__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11e_all_multimodal__fusion_composite_blockstats__LightGBM__best.json
#   REG: R5_LightGBM_all_multimodal__OPTUNA            AUC=0.8131 F1=0.0958 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]
#
#   === refit XGBoost ===
#     Tuned OOF AUC (refit): 0.8130  (study.best=0.8130)  delta=+0.0000
#     mean(folds)=0.7142  std(folds)=0.0721
#     saved oof -> oof_NB11e_all_multimodal__fusion_composite_blockstats__XGBoost-Optuna__20260521_183421_7bcb82.parquet  TP=5 FN=7181 FP=1 TN=473126
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11e_all_multimodal__fusion_composite_blockstats__XGBoost__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11e_all_multimodal__fusion_composite_blockstats__XGBoost__best.json
#   REG: R5_XGBoost_all_multimodal__OPTUNA             AUC=0.8130 F1=0.0014 n=480313 feat=915 cities=19 [NB09a_v2/cell_r5]

# %% [markdown]
# ## CELL SUMMARY -- multi-row CSV with `mean_folds_auc`/`std_folds_auc` + per-fold AUC print

# %%
# @title CELL SUMMARY
rows = []
for clf_name, info in NB11_OPTUNA_RESULTS.items():
    rows.append({
        'notebook': NB11_NAME,
        'parquet_id': NB11_PARQUET_ID,
        'manifest_key': NB11_MANIFEST_KEY,
        'feature_set': NB11_FEATURE_SET,
        'classifier': clf_name,
        'baseline_auc': info['baseline_auc'],
        'baseline_auc_expected': NB11_BASELINE_AUC[clf_name],
        'tuned_auc': info['tuned_auc_refit'],
        'delta_auc': info['tuned_auc_refit'] - info['baseline_auc'],
        'mean_folds_auc': info['mean_folds_auc'],
        'std_folds_auc': info['std_folds_auc'],
        'n_trials_requested': info['n_trials_requested'],
        'n_trials_done': info['n_trials_done'],
        'early_stopped': info['n_trials_done'] < info['n_trials_requested'],
        'patience': OPTUNA_PATIENCE,
        'n_features': len(clean_cols_NB11),
        'n_buildings': len(y_NB11),
        'n_cities': int(len(np.unique(groups_NB11))),
        'study_tag': info['study_tag'],
    })
df_summary = pd.DataFrame(rows).sort_values('tuned_auc', ascending=False)
summary_path = NB11_OUT_DIR / "summary" / f"{NB11_NAME}_summary.csv"
df_summary.to_csv(summary_path, index=False)
print(df_summary.to_string(index=False))
print(f"\n  Saved summary: {summary_path}")

print("\n  Per-fold AUC (tuned models):")
for clf_name, info in NB11_OPTUNA_RESULTS.items():
    fold_aucs = info['fold_aucs']
    print(f"    {clf_name:12s} pooled={info['tuned_auc_refit']:.4f}  "
          f"mean(folds)={info['mean_folds_auc']:.4f}  std={info['std_folds_auc']:.4f}  "
          f"folds={[f'{a:.3f}' for a in fold_aucs]}")

print(f"\n  {NB11_NAME} complete.")
# Out:
#             notebook parquet_id                manifest_key    feature_set classifier  baseline_auc  baseline_auc_expected  tuned_auc  delta_auc  mean_folds_auc  std_folds_auc  n_trials_requested  n_trials_done  early_stopped  patience  n_features  n_buildings  n_cities                                                     study_tag
# NB11e_all_multimodal         F8 fusion_composite_blockstats all_multimodal   LightGBM      0.792068                  0.792   0.813052   0.020984        0.711308       0.075953                 200            125           True        40         915       480313        19   NB11e_all_multimodal__fusion_composite_blockstats__LightGBM
# NB11e_all_multimodal         F8 fusion_composite_blockstats all_multimodal    XGBoost      0.805427                  0.805   0.812990   0.007563        0.714161       0.072137                 200             75           True        40         915       480313        19    NB11e_all_multimodal__fusion_composite_blockstats__XGBoost
# NB11e_all_multimodal         F8 fusion_composite_blockstats all_multimodal     RF-200      0.773675                  0.774   0.812856   0.039181        0.718112       0.079891                 200             20           True        40         915       480313        19     NB11e_all_multimodal__fusion_composite_blockstats__RF-200
# NB11e_all_multimodal         F8 fusion_composite_blockstats all_multimodal ExtraTrees      0.784557                  0.785   0.810630   0.026073        0.713925       0.071615                 200             88           True        40         915       480313        19 NB11e_all_multimodal__fusion_composite_blockstats__ExtraTrees
#
#   Saved summary: /content/drive_f/masterthesis/data/outputs/NB11_V2/summary/NB11e_all_multimodal_summary.csv
#
#   Per-fold AUC (tuned models):
#     RF-200       pooled=0.8129  mean(folds)=0.7181  std=0.0799  folds=['0.810', '0.615', '0.646', '0.714', '0.805']
#     ExtraTrees   pooled=0.8106  mean(folds)=0.7139  std=0.0716  folds=['0.783', '0.620', '0.649', '0.714', '0.803']
#     LightGBM     pooled=0.8131  mean(folds)=0.7113  std=0.0760  folds=['0.797', '0.606', '0.649', '0.713', '0.792']
#     XGBoost      pooled=0.8130  mean(folds)=0.7142  std=0.0721  folds=['0.761', '0.605', '0.672', '0.717', '0.815']
#
#   NB11e_all_multimodal complete.
