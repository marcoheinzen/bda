# %% [markdown]
# # NB11c_A13_A14_A19_card_changes -- LightGBM-MIA tuning (NB08c_v2 v8 prep chain)
#
# > Copyright (C) 2024-2026 Marco Heinzen - SPDX-License-Identifier: AGPL-3.0-or-later
# > Part of the Master Thesis "Building Damage Assessment with Multimodal Satellite Time Series and Machine Learning in the Russia-Ukraine War 2022-2026"
# > Code hosted at https://github.com/marcoheinzen/bda
# > Parts of this code were written or improved with the assistance of Claude (Anthropic); all other code, and the concept, research, architecture, design, execution, testing and validation throughout, are the author's work.
#
#
# | pq_id | manifest_key | Baseline AUC |
# |---|---|---|
# | A13 | `prepost_single_card` | 0.802 |
# | A14 | `coh_drop` | 0.807 |
# | A19 | `card_drop` | 0.802 |
#
# **Source experiment:** NB08c_v2 v8 (verbatim CONFIG, S0, OOF helpers, LightGBM-MIA classifier, audit_parquet).
#
# **Strategy:** replicate source experiment cell verbatim per parquet; assert baseline AUC within +/- 0.005; run Optuna with PATIENCE=40, RESUME-IF-EXISTS via SQLite; refit best params; save OOF + joblib + JSON + registry entry with `mean_folds_auc`, `std_folds_auc`, `fold_aucs` recorded (publishable cross-city metric).
#
# **Output dir:** `OUTPUTS_DIR / "NB11_V2"` (shared across all NB11 notebooks).

# %% [markdown]
# ## CELL 1 -- CONFIG (verbatim NB08c_v2 v8 CELL 1) + NB11 additions

# %%
# @title CELL 1: NB08c CONFIG
TIER_SELECTION = [0,1,2]
CITY_FILTER = None
CITY_SELECTION = None
REQUIRE_UNOSAT = True
RANDOM_STATE = 42
N_FOLDS = 5

USE_V2 = True

# === NB11 ADDITIONS ===
NB11_NAME = 'NB11c_A13_A14_A19_card_changes'
NB11_CELL_ID = 'cell_c5'                # source registry cell_id, preserved

# Per-parquet config: (pq_id, manifest_key, baseline_auc_expected)
NB11_PARQUETS = [
    ('A13', 'prepost_single_card', 0.802),
    ('A14', 'coh_drop', 0.807),
    ('A19', 'card_drop', 0.802),
]
NB11_BASELINE_TOL = 0.005

OPTUNA_BASE_BUDGET = 200
OPTUNA_LOW_AUC_BUDGET = 100
OPTUNA_LOW_AUC_CUTOFF = 0.70
OPTUNA_PATIENCE = 40                       # raised from 20 -- TPE needs room to explore beyond baseline
OPTUNA_DIRECTION = 'maximize'
OPTUNA_SEED = 42

# === THREAD BUDGET (avoid oversubscription when running parallel notebooks) ===
import os as _os, multiprocessing as _mp
NB11_PARALLEL_NOTEBOOKS = 1                                  # set to N if running N notebooks concurrently
NB11_CORES_TOTAL = _mp.cpu_count()
NB11_THREADS_PER_NB = max(1, NB11_CORES_TOTAL // NB11_PARALLEL_NOTEBOOKS)
# Env vars must be set BEFORE numpy/BLAS imports (i.e. before CELL 2 global_setup).
# Run with a fresh kernel for these to take effect at numpy import time.
_os.environ['OMP_NUM_THREADS']      = str(NB11_THREADS_PER_NB)
_os.environ['MKL_NUM_THREADS']      = str(NB11_THREADS_PER_NB)
_os.environ['OPENBLAS_NUM_THREADS'] = str(NB11_THREADS_PER_NB)
_os.environ['NUMEXPR_NUM_THREADS']  = str(NB11_THREADS_PER_NB)
_os.environ['BLIS_NUM_THREADS']     = str(NB11_THREADS_PER_NB)
print(f"[threads] cores={NB11_CORES_TOTAL}  parallel_nbs={NB11_PARALLEL_NOTEBOOKS}  "
      f"threads_per_nb={NB11_THREADS_PER_NB}")
# Out:
# [threads] cores=24  parallel_nbs=1  threads_per_nb=24

# %% [markdown]
# ## CELL 1b -- enforce thread cap dynamically (BLAS/OpenMP)
#
# Belt-and-suspenders to the env vars: if numpy/BLAS were imported on an earlier kernel state with no env-var limit, `threadpoolctl` clamps the active pools NOW without a kernel restart. Without this, LightGBM/XGBoost's OpenMP and sklearn's BLAS still spawn 24 threads each.
#
# Set `NB11_PARALLEL_NOTEBOOKS` in CELL 1 to match the number of NB11 notebooks you'll run concurrently:
# - 1 notebook  -> 24 threads per nb (no contention)
# - 2 notebooks -> 12 threads each
# - 3 notebooks ->  8 threads each
# - 4 notebooks ->  6 threads each

# %%
# @title CELL 1b: dynamic thread cap via threadpoolctl
try:
    from threadpoolctl import threadpool_limits, threadpool_info
    _tp_limit = threadpool_limits(limits=NB11_THREADS_PER_NB)
    print(f"[threadpoolctl] limited BLAS/OpenMP pools to {NB11_THREADS_PER_NB} threads")
    for info in threadpool_info():
        print(f"  {info.get('prefix'):20s} ({info.get('user_api')})  "
              f"current_threads={info.get('num_threads')}  max={info.get('num_threads')}")
except ImportError:
    print("[threadpoolctl] NOT INSTALLED -- run: pip install threadpoolctl")
    print("                env vars only; may not affect pools loaded before this cell.")
# Out:
# [threadpoolctl] limited BLAS/OpenMP pools to 24 threads

# %% [markdown]
# ## CELL 2 -- LOAD GLOBAL SETUP (verbatim NB08c_v2 v8)

# %%
# @title CELL 2: LOAD GLOBAL SETUP
import platform, os, json
if platform.system() == "Windows":
    _setup = r"F:\PROJECTS\masterthesis\gdrive\masterthesis\notebooks\global_setup.py"
elif os.path.exists("/content/drive_f"):
    _setup = "/content/drive_f/masterthesis/notebooks/global_setup.py"
else:
    _setup = "/mnt/f/PROJECTS/masterthesis/gdrive/masterthesis/notebooks/global_setup.py"
with open(_setup) as f:
    exec(f.read())
# Out:
# /home/alpineobotics/miniconda3/envs/bda/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
# ======================================================================
# BDA GLOBAL SETUP
# ======================================================================
# Started: 2026-05-20 20:35:27
# Python: 3.12.12
# ======================================================================
#
# [1/7] Directory Structure
# ----------------------------------------------------------------------
#   GDrive (G:):       /content/drive_f/masterthesis OK
#   GDrive (F:):       /content/drive_f/masterthesis OK
#   Local data (G:):   /content/masterthesis_local/data OK
#   Data stack (F:):   /mnt/f/PROJECTS/masterthesis/data_stack OK
#
#   TIER_SELECTION: [0, 1, 2]
#   CITY_SELECTION: None (tier filter)
#   REQUIRE_UNOSAT: True
#   CITIES_TO_PROCESS: 21 cities
#
# [2/7] Credentials
# ----------------------------------------------------------------------
#   Copernicus: inf***
#   OpenTopography: OK
#   Earthdata: marcoheinzen
#
# [3/7] Python Packages
# ----------------------------------------------------------------------
# <string>:564: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   Already installed: 23
#   Newly installed:   0
#   Failed:            0
#
# [4/7] Global Imports & Configuration
# ----------------------------------------------------------------------
#   All imports loaded
#
# [5/7] Processing Config & SNAP
# ----------------------------------------------------------------------
#   GPT: Usage:
#   Temporal baseline: 10-24 days
#   Wavelength: 0.0555
#
# [6/7] GPU Status
# ----------------------------------------------------------------------
#   CUDA available: NVIDIA GeForce RTX 2070 SUPER
#     CUDA version: 12.8
#
# [7/7] Disk Space
# ----------------------------------------------------------------------
#   GDrive (G:)     910.8/7452.0 GB (6541.2 GB free)
#   GDrive (F:)     1403.9/3726.0 GB (2322.1 GB free)
#   Local data      11563.0/14901.9 GB (3338.9 GB free)
#   Data stack      1403.9/3726.0 GB (2322.1 GB free)
#   WSL ext4        69.1/1006.9 GB (886.5 GB free)
#
# ======================================================================
# GLOBAL SETUP COMPLETE
# ======================================================================
#   Torch device: cuda
#   Cities: 21, CITY=Avdiivka
#   Functions: load_aoi(), load_aoi_gdf(), load_aoi_bbox(), load_buildings()
#   Functions: set_city_paths(), resolve_cities(), load_tracker(), load_dietrich_tracker()
#   Completed: 2026-05-20 20:36:35
# ======================================================================

# %% [markdown]
# ## CELL S0 -- MANIFEST + BUILDINGS + SHARED HELPERS (verbatim NB08c_v2 v8)

# %%
# @title CELL S0: LOAD MANIFEST + BUILDINGS + SHARED HELPERS
import sys, importlib, re, gc, time
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import GroupKFold
from sklearn.metrics import (roc_auc_score, f1_score, precision_score,
                             recall_score)
from sklearn.base import clone
import warnings
warnings.filterwarnings("ignore")

print("=" * 70)
print("CELL S0: NB08c v2 - LOAD MANIFEST + BUILDINGS + SHARED HELPERS")
print("=" * 70)

if str(NOTEBOOKS_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOKS_DIR))

import metadata_filter
importlib.reload(metadata_filter)
from metadata_filter import (
    ID_COLS, LABEL_COLS, META_COLS_SET,
    is_metadata, is_non_feature,
    select_feature_columns, build_role_overrides,
)

# --- load v2 manifest -------------------------------------------------
MANIFEST_V2_PATH = DATASET_ROOT_V2 / 'parquet_manifest.json'
if not MANIFEST_V2_PATH.exists():
    raise FileNotFoundError(f"V2 manifest not found: {MANIFEST_V2_PATH}")
with open(MANIFEST_V2_PATH) as _f:
    MANIFEST = json.load(_f)
print(f"  Manifest: {MANIFEST_V2_PATH}")
print(f"  Version: {MANIFEST['version']}  Created: {MANIFEST['created']}")
print(f"  Parquets in manifest: {len(MANIFEST['parquets'])}")

# --- load building metadata (v2 path) --------------------------------
_tiers = TIER_SELECTION if isinstance(TIER_SELECTION, list) else [0, 1, 2]
_bldg_pattern = str(DATASET_ROOT_V2 / 'bda_buildings_t{tier}.parquet')
df_bldg = load_tier_parquets(_bldg_pattern, _tiers)
CITIES_TO_PROCESS, _battle_dates = resolve_cities(
    tier_selection=TIER_SELECTION,
    city_selection=[CITY_FILTER] if isinstance(CITY_FILTER, str) else CITY_FILTER,
    require_unosat=REQUIRE_UNOSAT,
)
df_bldg = df_bldg[df_bldg['city'].isin(CITIES_TO_PROCESS)].copy()
df_bldg = df_bldg[df_bldg['damage_binary'] >= 0].copy()
print(f"  Cities: {len(CITIES_TO_PROCESS)}")
print(f"  Buildings: {len(df_bldg)} (damaged={int((df_bldg['damage_binary']==1).sum())}, "
      f"undamaged={int((df_bldg['damage_binary']==0).sum())})")

TARGET_COL = 'damage_binary'
AUDIT_LOG = {}

# ---- NB12 overlap-analysis: canonical OOF predictions schema ----
import hashlib as _hashlib, datetime as _dt
EXPERIMENT_ID = _dt.datetime.now().strftime('%Y%m%d_%H%M%S') + '_' + _hashlib.md5(
    f'nb08c_{TIER_SELECTION}_{REQUIRE_UNOSAT}'.encode()).hexdigest()[:6]
print(f"  EXPERIMENT_ID: {EXPERIMENT_ID}")

def save_oof_from_result(res, model_id, oof_dir, variant_id='',
                         is_final=False, threshold=0.5):
    '''Canonical OOF schema: building_id, city, fold_id, y_true, y_proba, y_pred,
       cm_class, model_id, experiment_id, variant_id, is_final.'''
    if res is None:
        return None
    needed = ('y_true', 'y_proba', 'groups', 'building_id', 'fold_id')
    if not all(k in res for k in needed):
        print(f"    [save_oof] skipped {model_id}: missing keys (need {needed})")
        return None
    y_proba = np.asarray(res['y_proba'])
    yt = np.asarray(res['y_true']).astype(int)
    fold = np.asarray(res['fold_id']).astype(int)
    bid = np.asarray(res['building_id'])
    cty = np.asarray(res['groups'])
    yp = (y_proba >= threshold).astype(int)
    cm_class = np.where(yt == 1,
                        np.where(yp == 1, 'TP', 'FN'),
                        np.where(yp == 1, 'FP', 'TN'))
    oof_df = pd.DataFrame({
        'building_id':   bid,
        'city':          cty,
        'fold_id':       fold,
        'y_true':        yt,
        'y_proba':       y_proba.astype(float),
        'y_pred':        yp,
        'cm_class':      cm_class,
        'model_id':      model_id,
        'experiment_id': EXPERIMENT_ID,
        'variant_id':    variant_id,
        'is_final':      bool(is_final),
    })
    oof_dir = Path(oof_dir)
    oof_dir.mkdir(parents=True, exist_ok=True)
    out = oof_dir / f'oof_{model_id}__{EXPERIMENT_ID}.parquet'
    oof_df.to_parquet(out, index=False)
    n_tp = int((cm_class == 'TP').sum()); n_fn = int((cm_class == 'FN').sum())
    n_fp = int((cm_class == 'FP').sum()); n_tn = int((cm_class == 'TN').sum())
    print(f"    saved oof -> {out.name}  TP={n_tp} FN={n_fn} FP={n_fp} TN={n_tn}")
    return out

# --- leakage filter ---------------------------------------------------
LEAKAGE_EXCLUDE_PATTERNS = [
    r's1__coh__scenes_observed',
    r's1__vv__scenes_observed',
    r's2__scenes_observed',
    r's2__lu__scenes_observed',
    r's2__obs_count__',
    r's2__qa__cloud_freq__',
    r's2__visibility__cloud__freq',
    r'was_observed_',
]
# -- leaky filter (legacy NB08c behavior, keeps was_observed_ flags; used by C10 for delta comparison) --
LEAKAGE_LEAKY_PATTERNS = [
    r's1__coh__scenes_observed',
    r's1__vv__scenes_observed',
    r's2__scenes_observed',
    r's2__lu__scenes_observed',
    r's2__obs_count__',
    r's2__qa__cloud_freq__',
    r's2__visibility__cloud__freq',
]
_LEAKAGE_LEAKY_RE = [re.compile(p) for p in LEAKAGE_LEAKY_PATTERNS]

def drop_leakage_leaky(cols):
    '''LEGACY filter that keeps was_observed_* flags. For C10 delta only. Do not use elsewhere.'''
    return [c for c in cols if not any(rx.search(c) for rx in _LEAKAGE_LEAKY_RE)]
_LEAKAGE_RE = [re.compile(p) for p in LEAKAGE_EXCLUDE_PATTERNS]

def drop_leakage(cols):
    return [c for c in cols if not any(rx.search(c) for rx in _LEAKAGE_RE)]

def _has_count_stat(c):
    parts = c.split('__')
    if len(parts) < 4:
        return False
    return parts[3].split('_')[0] == 'count'

# --- v2 manifest-driven loader (copy of NB09a v2 signature) ----------
def load_v2(manifest_key, tiers=None, columns=None, sample_frac=None):
    '''Load a v2 parquet by manifest key, merge with buildings, return df.'''
    if manifest_key not in MANIFEST['parquets']:
        raise KeyError(f"Manifest key not found: {manifest_key}")
    info = MANIFEST['parquets'][manifest_key]
    fname_tmpl = Path(info['pattern']).name
    tiers = tiers if tiers is not None else _tiers

    frames = []
    for t in tiers:
        pf = DATASET_ROOT_V2 / fname_tmpl.format(tier=t)
        if not pf.exists():
            continue
        if columns is not None:
            join_cols = info.get('join_keys', ['city', 'building_id'])
            read_cols = list(dict.fromkeys(join_cols + list(columns)))
            try:
                df_t = pd.read_parquet(pf, columns=read_cols)
            except Exception:
                df_t = pd.read_parquet(pf)
                keep = [c for c in read_cols if c in df_t.columns]
                df_t = df_t[keep]
        else:
            df_t = pd.read_parquet(pf)
        if sample_frac is not None and 0 < sample_frac < 1:
            df_t = df_t.sample(frac=sample_frac, random_state=RANDOM_STATE)
        frames.append(df_t)
    if not frames:
        raise FileNotFoundError(f"No v2 parquets found for key={manifest_key} tiers={tiers}")
    df = pd.concat(frames, ignore_index=True)
    del frames

    df = df.loc[:, ~df.columns.duplicated()]
    df = df[df['city'].isin(CITIES_TO_PROCESS)].copy()
    if TARGET_COL not in df.columns:
        df = df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['building_id', 'city'], how='inner')
    df = df[df[TARGET_COL] >= 0].copy()
    df = df.loc[:, ~df.columns.duplicated()]
    return df

# --- v8: direction-aware temporal aggregation (matched-filter principle) ---
# Damage at the temporal axis is a sparse-event spike. Per Kay 1998 (Detection
# Theory) and Glaz-Naus-Wallenstein 2001 (Scan Statistics), the rolling extremum
# is the Neyman-Pearson optimal detector for a 1-of-N spike on stationary noise.
# v7 universal mean+std attenuated the spike; v8 dispatches per modality direction.
# Reference: DECISION_Rolling_Block_Accumulators.md Sec 5; DECISION_NB05b_v29 Sec 1.

DIRECTION_BY_MODALITY = {
    # SAR drop signals (damage -> coherence loss, VV backscatter loss on rough->smooth or rubble)
    'coh_vv': 'drop', 'coh_vh': 'drop',
    'vv': 'drop',
    # SAR mixed-sign (volume scattering can go either direction with rubble)
    'vh': 'mixed',
    # MS visible bands -- no clean damage direction (illumination + atmosphere dominate)
    'b02': 'unknown', 'b03': 'unknown', 'b04': 'unknown',
    'b05': 'unknown', 'b07': 'unknown',
    # MS NIR -- vegetation loss after damage drives NIR drop
    'b08': 'drop', 'b8a': 'drop',
    # MS SWIR -- rubble / bare soil exposure drives SWIR rise (Aimaiti 2022)
    'b11': 'rise', 'b12': 'rise',
    # MS derived indices
    'nbr':   'mixed',  # burn / vegetation loss / rubble (sign depends on land cover)
    'ndvi':  'drop',   # vegetation loss
    'savi':  'drop',   # soil-adjusted vegetation
    'bsi':   'rise',   # bare-soil exposure rises with rubble
    'mndwi': 'mixed',  # water -- flood-rise vs drying-drop
    'ndbi':  'drop',   # built-up index drops with built-up loss
    'ndsi':  'mixed',  # snow seasonal noise, no damage direction
    'ibi':   'drop',   # built-up index variant
    'baei':  'drop',   # built-up area extraction index
    'ui':    'drop',   # urban index
}

# Manifest keys whose long parquets are already pixel-temporal-extremized in NB03e R2b.
# For these, mean+std-over-time preserves the per-rolling-window pattern; a second
# temporal extremum would collapse to the full-post-battle accumulators (A14/A19/A20/A21),
# making A23/A24/A25 redundant.
ACCUM_LONG_KEYS = {'rolling_accum_coh', 'rolling_accum_card', 'rolling_accum_ms'}

def _parse_modality_token(col):
    '''Return the modality token (second `__`-separated piece) of a feature column.
       Examples:
         s2__b02__mean              -> b02
         s1__coh_vv__zscore__mean   -> coh_vv
         s1__vv__roll7__min         -> vv
         s2__landuse__urban_frac    -> landuse  (returns 'landuse', falls into 'unknown')
       Returns None if the column has fewer than 2 `__`-separated pieces.'''
    parts = col.split('__')
    if len(parts) < 2:
        return None
    return parts[1].lower()

def _temporal_reductions_for_column(col):
    '''Return the list of pandas agg names to apply over the date axis for `col`,
       chosen by modality direction:
         drop    -> [min, mean, std]
         rise    -> [max, mean, std]
         mixed   -> [min, max, mean, std]
         unknown -> [mean, std]   (legacy v7 fallback for non-mappable columns)
       The `mean` and `std` slots are kept in every direction so v7 features are
       a strict subset of v8 features (additive change, no information lost).'''
    modality = _parse_modality_token(col)
    direction = DIRECTION_BY_MODALITY.get(modality, 'unknown')
    if direction == 'drop':
        return ['min', 'mean', 'std']
    if direction == 'rise':
        return ['max', 'mean', 'std']
    if direction == 'mixed':
        return ['min', 'max', 'mean', 'std']
    return ['mean', 'std']

# --- long-format aggregation (v8: direction-aware temporal collapse) ---------
def aggregate_long_to_wide(df, feat_cols, manifest_key=None):
    '''Collapse a long-format per-scene parquet to per-building summary.

    v8: direction-aware temporal aggregation per matched-filter principle.
    - manifest_key in ACCUM_LONG_KEYS  -> universal mean+std (already extremized in R2b)
    - otherwise                        -> per-column dispatch via _temporal_reductions_for_column

    Backward compatible call: `aggregate_long_to_wide(df, feat_cols)` (manifest_key=None)
    falls through to per-column dispatch with v7-equivalent fallback for unknown columns.
    '''
    feat_cols = [c for c in feat_cols if c in df.columns]
    if not feat_cols:
        return (df.groupby(['city', 'building_id'], sort=False, observed=True)
                  .size().reset_index()[['city', 'building_id']])

    if manifest_key in ACCUM_LONG_KEYS:
        agg_dict = {c: ['mean', 'std'] for c in feat_cols}
    else:
        agg_dict = {c: _temporal_reductions_for_column(c) for c in feat_cols}

    agg = df.groupby(['city', 'building_id'], sort=False, observed=True).agg(agg_dict)
    agg.columns = [f"{a}_{b}" for a, b in agg.columns]
    agg = agg.reset_index()
    return agg

# --- manifest-derived feature set for a given parquet ----------------
def get_parquet_features(manifest_key, df):
    '''Return the cleaned feature column list for a parquet: manifest features,
       intersected with df columns, minus leakage, minus count stats, minus all-NaN.

       Uses metadata_filter.select_feature_columns() so that id/label/metadata
       columns (including any was_observed_* flag, regardless of suffix) are
       excluded centrally rather than by a locally-maintained list.'''
    info = MANIFEST['parquets'][manifest_key]
    raw = [c for c in info.get('feature_columns', []) if c in df.columns]
    if not raw:
        # fallback: metadata_filter picks numeric features, excluding id/label/meta
        # and any was_observed_* via the centralized pattern rule.
        raw = select_feature_columns(df)
    else:
        # manifest-declared features: still scrub in case the manifest lists a
        # column that is actually metadata (defensive, typically a no-op).
        raw = [c for c in raw if not is_non_feature(c)]
    clean = drop_leakage(raw)
    clean = [c for c in clean if not _has_count_stat(c)]
    nan_rate = df[clean].isna().mean() if clean else pd.Series(dtype=float)
    clean = [c for c in clean if nan_rate.get(c, 1.0) < 1.0]
    return clean

# --- LightGBM feature prep (no imputation, native NaN) --------------
def prepare_features_mia(df, feat_cols):
    '''Return X (with NaN preserved), y, groups, building_ids, clean_cols.'''
    if not feat_cols:
        return None
    X = df[feat_cols].to_numpy(dtype=np.float32, copy=False)
    y = df[TARGET_COL].values
    groups = df['city'].values
    building_ids = df['building_id'].values
    return X, y, groups, building_ids, feat_cols

# --- single-protocol GroupKFold evaluator ---------------------------
def evaluate_audit(clf, X, y, groups, experiment_name, n_folds=N_FOLDS,
                   building_ids=None):
    n_cities = len(np.unique(groups))
    n_folds_actual = min(n_folds, n_cities)
    if n_folds_actual < 2:
        print(f"    SKIP {experiment_name}: only {n_cities} cities")
        return None
    gkf = GroupKFold(n_splits=n_folds_actual)
    y_proba_oof = np.full(len(y), np.nan)
    fold_id = np.full(len(y), -1, dtype=int)
    fold_aucs = []
    for fold_idx, (tr, te) in enumerate(gkf.split(X, y, groups)):
        clf_c = clone(clf)
        clf_c.fit(X[tr], y[tr])
        proba = clf_c.predict_proba(X[te])[:, 1]
        y_proba_oof[te] = proba
        fold_id[te] = fold_idx
        if len(np.unique(y[te])) > 1:
            fold_aucs.append(roc_auc_score(y[te], proba))
    valid = ~np.isnan(y_proba_oof)
    y_v, p_v = y[valid], y_proba_oof[valid]
    pred_v = (p_v >= 0.5).astype(int)
    bid_v = np.asarray(building_ids)[valid] if building_ids is not None else np.arange(len(y))[valid].astype(str)
    result = {
        'experiment': experiment_name,
        'auc_groupkfold': roc_auc_score(y_v, p_v),
        'f1_groupkfold': f1_score(y_v, pred_v),
        'precision': precision_score(y_v, pred_v, zero_division=0),
        'recall': recall_score(y_v, pred_v, zero_division=0),
        'fold_aucs': fold_aucs,
        'auc_mean': float(np.mean(fold_aucs)) if fold_aucs else float('nan'),
        'auc_std': float(np.std(fold_aucs)) if fold_aucs else float('nan'),
        'n_features': X.shape[1], 'n_buildings': int(valid.sum()),
        'n_cities': int(len(np.unique(groups))),
        'y_true': y_v, 'y_proba': p_v, 'groups': groups[valid],
        'building_id': bid_v, 'fold_id': fold_id[valid],
    }
    AUDIT_LOG[experiment_name] = result
    print(f"    {experiment_name:40s} AUC={result['auc_groupkfold']:.3f}  "
          f"F1={result['f1_groupkfold']:.3f}  n={result['n_buildings']:,}  "
          f"cities={result['n_cities']}  nfeat={result['n_features']}")
    return result

# --- output paths + registry ----------------------------------------
import matplotlib.pyplot as plt
from datetime import datetime as _dt

OUT_DIR = OUTPUTS_DIR / "NB08c_v2"
OUT_DIR.mkdir(parents=True, exist_ok=True)

def save_result(data, name, cell_id, fmt='csv'):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    if fmt == 'csv' and isinstance(data, pd.DataFrame):
        path = cell_dir / f"{name}_{ts}.csv"
        data.to_csv(path, index=False)
    elif fmt == 'json':
        path = cell_dir / f"{name}_{ts}.json"
        with open(path, 'w') as fh:
            json.dump(data, fh, indent=2, default=str)
    else:
        raise ValueError(f"Unknown fmt={fmt}")
    print(f"  Saved: {path.relative_to(OUT_DIR)} ({path.stat().st_size / 1024:.1f} KB)")
    return path

def save_fig(fig, name, cell_id, dpi=150):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    path = cell_dir / f"{name}_{ts}.png"
    fig.savefig(path, dpi=dpi, bbox_inches='tight', facecolor='white')
    plt.show()
    print(f"  Plot: {path.relative_to(OUT_DIR)}")
    return path

from bda_results import ResultRegistry
registry = ResultRegistry(RESULTS_ROOT, notebook='NB08c_v2')

def log_audit(res, cell_id, manifest_key, note=''):
    if res is None:
        return
    registry.log_experiment(
        cell_id=cell_id, experiment_name=res['experiment'],
        parquet_name=f'bda_{manifest_key}_v2', feature_set_name='manifest_default_minus_leakage',
        classifier_name='LightGBM-300-MIA', classifier_params=LGBM_PARAMS,
        feature_cols=[], cv_method='GroupKFold', n_folds=N_FOLDS,
        imputation='native_nan', y_true=res['y_true'], y_proba=res['y_proba'],
        groups=res['groups'], note=note, tags=['nb08c_audit'],
    )

print(f"  Helpers: load_v2(), get_parquet_features(), aggregate_long_to_wide(), evaluate_audit()")
print(f"  Output:  {OUT_DIR}")
print(f"  Registry: NB08c_v2")
# Out:
# ======================================================================
# CELL S0: NB08c v2 - LOAD MANIFEST + BUILDINGS + SHARED HELPERS
# ======================================================================
#   Manifest: /mnt/f/PROJECTS/masterthesis/data_stack/dataset/V2/parquet_manifest.json
#   Version: v2  Created: 2026-04-26T16:31:26.125203
#   Parquets in manifest: 37
#   load_tier_parquets: 3 tiers, 907371 rows
#   Cities: 21
#   Buildings: 598595 (damaged=7332, undamaged=591263)
#   EXPERIMENT_ID: 20260520_203726_115af1
#   ResultRegistry: /content/drive_f/masterthesis/results/registry (run_id=20260520_203726)
#   Helpers: load_v2(), get_parquet_features(), aggregate_long_to_wide(), evaluate_audit()
#   Output:  /content/drive_f/masterthesis/data/outputs/NB08c_v2
#   Registry: NB08c_v2

# %% [markdown]
# ## CELL S0b -- OOF PLOT + SUMMARY HELPERS (verbatim NB08c_v2 v8)

# %%
# @title CELL S0b: OOF PLOT + SUMMARY HELPERS
# TP=red, TN=green, FP=pink, FN=gold
import matplotlib.pyplot as plt

CM_COLORS = {'TP': '#d62728', 'TN': '#2ca02c', 'FP': '#ff9ecb', 'FN': '#ffd700'}
CM_LABELS = {'TP': 'Destroyed (TP)', 'TN': 'Not destroyed (TN)',
             'FP': 'False positive (FP)', 'FN': 'False negative (FN)'}

# alias df_bldg to df_buildings for plotting helper compatibility
df_buildings = df_bldg

def print_cm_summary(oof_path_or_df):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else '(unknown)'
    print(f"  model_id: {model_id}   n={len(oof)}")
    overall = oof['cm_class'].value_counts()
    for cls in ['TP', 'TN', 'FP', 'FN']:
        n = int(overall.get(cls, 0))
        pct = 100.0 * n / len(oof) if len(oof) else 0
        print(f"    {cls:3s} {CM_LABELS[cls]:28s}  n={n:6d}  ({pct:5.1f}%)")
    by_city = (oof.groupby('city')['cm_class']
                 .value_counts().unstack(fill_value=0))
    for cls in ['TP', 'TN', 'FP', 'FN']:
        if cls not in by_city.columns:
            by_city[cls] = 0
    by_city = by_city[['TP', 'TN', 'FP', 'FN']]
    by_city['recall']    = by_city['TP'] / (by_city['TP'] + by_city['FN']).replace(0, np.nan)
    by_city['precision'] = by_city['TP'] / (by_city['TP'] + by_city['FP']).replace(0, np.nan)
    print(f"\n  Per-city:")
    print(by_city.to_string(float_format=lambda x: f'{x:.3f}' if pd.notna(x) else '-'))
    return by_city

def plot_cm_spatial(oof_path_or_df, save_name=None, figsize=(14, 10),
                    buildings_df=None, point_size=4):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    bdf = buildings_df if buildings_df is not None else df_buildings
    if 'centroid_x' not in bdf.columns or 'centroid_y' not in bdf.columns:
        print("  plot_cm_spatial: no centroid_x/centroid_y in buildings_df")
        return None
    plot_df = oof.merge(bdf[['building_id', 'city', 'centroid_x', 'centroid_y']],
                        on=['building_id', 'city'], how='inner')
    if len(plot_df) == 0:
        print("  plot_cm_spatial: no building matches")
        return None
    cities = sorted(plot_df['city'].unique())
    ncols = min(3, len(cities))
    nrows = (len(cities) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, squeeze=False)
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else ''
    fig.suptitle(f'Confusion-matrix map: {model_id}', fontsize=11)
    draw_order = ['TN', 'FP', 'FN', 'TP']
    for i, city in enumerate(cities):
        ax = axes[i // ncols][i % ncols]
        cdf = plot_df[plot_df['city'] == city]
        for cls in draw_order:
            pts = cdf[cdf['cm_class'] == cls]
            if len(pts) == 0:
                continue
            ax.scatter(pts['centroid_x'], pts['centroid_y'],
                       c=CM_COLORS[cls], s=point_size, alpha=0.75,
                       edgecolors='none',
                       label=f"{CM_LABELS[cls]} (n={len(pts)})")
        ax.set_title(f"{city}  (n={len(cdf)})", fontsize=9)
        ax.set_aspect('equal')
        ax.legend(loc='best', fontsize=6, markerscale=2, framealpha=0.85)
        ax.tick_params(labelsize=7)
    for j in range(len(cities), nrows * ncols):
        axes[j // ncols][j % ncols].axis('off')
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    if save_name:
        fig.savefig(OUT_DIR / f'{save_name}.png', dpi=150, bbox_inches='tight')
        plt.close(fig)
    return fig

def plot_cm_oof_all(oof_dir, skip_variants=()):
    d = Path(oof_dir)
    files = sorted(d.glob('oof_*.parquet'))
    print(f"  Found {len(files)} OOF parquets in {d}")
    for p in files:
        oof = pd.read_parquet(p)
        v = oof['variant_id'].iloc[0] if 'variant_id' in oof.columns else ''
        if any(sv in v for sv in skip_variants):
            print(f"  skip {p.name}  (variant_id={v})")
            continue
        print(f"\n  {p.name}")
        print_cm_summary(oof)
        plot_cm_spatial(oof, save_name=p.stem)

# %% [markdown]
# ## CELL H -- CLASSIFIER (verbatim LightGBM-MIA from NB08c_v2 v8)

# %%
# @title CELL H: CLASSIFIER (LightGBM native NaN)
try:
    from lightgbm import LGBMClassifier
except ImportError:
    raise ImportError("LightGBM required for NB08c single-protocol audit. pip install lightgbm")

LGBM_PARAMS = {
    'n_estimators': 150,
    'max_depth': 6,
    'learning_rate': 0.05,
    'num_leaves': 31,
    'min_child_samples': 20,
    'random_state': RANDOM_STATE,
    'n_jobs': -1,
    'verbose': -1,
    'is_unbalance': True,
    'force_col_wise': True,
}
LGBM = LGBMClassifier(**LGBM_PARAMS)

print(f"  Classifier: LightGBM n_estimators={LGBM_PARAMS['n_estimators']} "
      f"max_depth={LGBM_PARAMS['max_depth']} is_unbalance=True native_nan=MIA")
# Out:
#   Classifier: LightGBM n_estimators=150 max_depth=6 is_unbalance=True native_nan=MIA

# %% [markdown]
# ## CELL AUDIT_RUN -- parquet audit runner (verbatim NB08c_v2 v8)

# %%
# @title CELL AUDIT_RUN: parquet audit runner
def audit_parquet(manifest_key, cell_id, pq_id=None):
    '''Run the single audit protocol on one manifest parquet (v8: direction-aware temporal collapse).
    - load parquet
    - if long-format (date column present), aggregate to per-building mean+std
    - select manifest features, drop leakage + count stats + all-NaN
    - fit LightGBM with GroupKFold
    - log to AUDIT_LOG and registry
    Returns: result dict or None (skip).
    '''
    info = MANIFEST['parquets'].get(manifest_key)
    if info is None:
        print(f"\n  [{manifest_key}] SKIP: not in manifest")
        return None
    _pq_id = pq_id or info.get('id', '?')
    print(f"\n  --- [{_pq_id}] {manifest_key} ---")

    try:
        df = load_v2(manifest_key)
    except (FileNotFoundError, KeyError) as e:
        print(f"    SKIP load: {e}")
        return None
    if len(df) == 0:
        print(f"    SKIP: empty dataframe")
        del df; gc.collect()
        return None

    is_long = 'date' in df.columns
    n_rows_raw = len(df)
    n_cities_raw = df['city'].nunique()

    # manifest feature set, cleaned
    feat_cols = get_parquet_features(manifest_key, df)
    if is_long and feat_cols:
        print(f"    Long format: {n_rows_raw:,} rows, {n_cities_raw} cities -> aggregating per-building")
        df = aggregate_long_to_wide(df, feat_cols, manifest_key=manifest_key)
        # re-merge target after aggregation
        df = df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['building_id', 'city'], how='inner')
        df = df[df[TARGET_COL] >= 0].copy()
        feat_cols = [c for c in df.columns
                     if c not in ('city', 'building_id', TARGET_COL)]
        feat_cols = drop_leakage(feat_cols)
        feat_cols = [c for c in feat_cols if not _has_count_stat(c)]
        nan_rate = df[feat_cols].isna().mean()
        feat_cols = [c for c in feat_cols if nan_rate[c] < 1.0]

    n_rows = len(df)
    n_cities = df['city'].nunique()
    print(f"    Wide: {n_rows:,} rows, {n_cities} cities, {len(feat_cols)} features")

    if len(feat_cols) < 2:
        print(f"    SKIP: {len(feat_cols)} feature columns after cleaning")
        del df; gc.collect()
        return None

    # overall NaN rate on the post-cleaning feature matrix
    overall_nan = float(df[feat_cols].isna().mean().mean())
    print(f"    Overall NaN rate: {overall_nan*100:.1f}%")

    prep = prepare_features_mia(df, feat_cols)
    if prep is None:
        del df; gc.collect()
        return None
    X, y, groups, building_ids, clean = prep

    exp_name = f"C_{_pq_id}_{manifest_key}"
    res = evaluate_audit(LGBM, X, y, groups, exp_name, building_ids=building_ids)
    if res is not None:
        res['manifest_key'] = manifest_key
        res['parquet_id'] = _pq_id
        res['format'] = 'long->wide' if is_long else 'wide'
        res['overall_nan_pct'] = overall_nan * 100
        res['n_rows_raw'] = n_rows_raw
        res['n_cities_raw'] = n_cities_raw
        log_audit(res, cell_id=cell_id, manifest_key=manifest_key,
                  note=f'{_pq_id} {manifest_key} audit sweep')

    del df, X, y, groups
    gc.collect()
    return res

# %% [markdown]
# ## CELL BASELINE -- replicate source experiment cell legs

# %%
# @title CELL BASELINE: replicate source experiment cell (verbatim audit_parquet calls)
print("=" * 70)
print(f"CELL BASELINE: {NB11_NAME} baseline replication")
print("=" * 70)

NB11_BASELINE_RESULTS = {}
NB11_PREP = {}        # pq_id -> dict(X, y, groups, building_ids, clean_cols, ...)

for pq_id, manifest_key, expected_auc in NB11_PARQUETS:
    print(f"\n  --- [{pq_id}] {manifest_key} (expected AUC={expected_auc:.4f}) ---")
    res = audit_parquet(manifest_key, cell_id=NB11_CELL_ID, pq_id=pq_id)
    assert res is not None, f"audit_parquet returned None for {pq_id}/{manifest_key}"

    got = res['auc_groupkfold']
    delta = got - expected_auc
    ok = abs(delta) <= NB11_BASELINE_TOL
    flag = 'OK' if ok else 'FAIL'
    print(f"    Replicated baseline AUC = {got:.4f}  expected = {expected_auc:.4f}  "
          f"delta = {delta:+.4f}  [{flag}]")
    if not ok:
        raise AssertionError(
            f"Baseline AUC mismatch for {pq_id}/{manifest_key}: got {got:.4f}, "
            f"expected {expected_auc:.4f} (tol {NB11_BASELINE_TOL}). "
            "Do not proceed to Optuna -- investigate prep-chain drift first."
        )

    NB11_BASELINE_RESULTS[pq_id] = res

    # Rebuild X/y/groups/building_ids/clean_cols on the same prep path (matches audit_parquet)
    print(f"    Rebuilding X, y, groups for Optuna (same prep path)...")
    _df = load_v2(manifest_key)
    _is_long = 'date' in _df.columns
    _feat_cols = get_parquet_features(manifest_key, _df)
    if _is_long and _feat_cols:
        _df = aggregate_long_to_wide(_df, _feat_cols, manifest_key=manifest_key)
        _df = _df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                        on=['building_id', 'city'], how='inner')
        _df = _df[_df[TARGET_COL] >= 0].copy()
        _feat_cols = [c for c in _df.columns
                      if c not in ('city', 'building_id', TARGET_COL)]
        _feat_cols = drop_leakage(_feat_cols)
        _feat_cols = [c for c in _feat_cols if not _has_count_stat(c)]
        _nan_rate = _df[_feat_cols].isna().mean()
        _feat_cols = [c for c in _feat_cols if _nan_rate[c] < 1.0]

    _prep = prepare_features_mia(_df, _feat_cols)
    assert _prep is not None, f"prepare_features_mia returned None for {pq_id}"
    X, y, groups, building_ids, clean_cols = _prep
    NB11_PREP[pq_id] = {
        'X': X, 'y': y, 'groups': groups,
        'building_ids': building_ids, 'clean_cols': clean_cols,
        'manifest_key': manifest_key, 'baseline_auc': got, 'expected_auc': expected_auc,
    }
    print(f"    X shape: {X.shape}  cities: {len(np.unique(groups))}  n_feat: {len(clean_cols)}")

    del _df, _feat_cols
    gc.collect()

print("\n  -> All baselines match source; safe to proceed to Optuna.")
# Out:
# ======================================================================
# CELL BASELINE: NB11c_A13_A14_A19_card_changes baseline replication
# ======================================================================
#
#   --- [A13] prepost_single_card (expected AUC=0.8020) ---
#
#   --- [A13] prepost_single_card ---
#     Wide: 598,595 rows, 21 cities, 12 features
#     Overall NaN rate: 15.6%
#     C_A13_prepost_single_card                AUC=0.802  F1=0.084  n=598,595  cities=21  nfeat=12
#   REG: C_A13_prepost_single_card                     AUC=0.8024 F1=0.0837 n=598595 feat=0 cities=21 [NB08c_v2/cell_c5]
#     Replicated baseline AUC = 0.8024  expected = 0.8020  delta = +0.0004  [OK]
#     Rebuilding X, y, groups for Optuna (same prep path)...
#     X shape: (598595, 12)  cities: 21  n_feat: 12
#
#   --- [A14] coh_drop (expected AUC=0.8070) ---
#
#   --- [A14] coh_drop ---
#     Wide: 584,986 rows, 20 cities, 10 features
#     Overall NaN rate: 13.6%
#     C_A14_coh_drop                           AUC=0.807  F1=0.073  n=584,986  cities=20  nfeat=10
#   REG: C_A14_coh_drop                                AUC=0.8075 F1=0.0734 n=584986 feat=0 cities=20 [NB08c_v2/cell_c5]
#     Replicated baseline AUC = 0.8075  expected = 0.8070  delta = +0.0005  [OK]
#     Rebuilding X, y, groups for Optuna (same prep path)...
#     X shape: (584986, 10)  cities: 20  n_feat: 10
#
#   --- [A19] card_drop (expected AUC=0.8020) ---
#
#   --- [A19] card_drop ---
#     Wide: 598,595 rows, 21 cities, 10 features
#     Overall NaN rate: 15.6%
#     C_A19_card_drop                          AUC=0.802  F1=0.065  n=598,595  cities=21  nfeat=10
#   REG: C_A19_card_drop                               AUC=0.8024 F1=0.0654 n=598595 feat=0 cities=21 [NB08c_v2/cell_c5]
#     Replicated baseline AUC = 0.8024  expected = 0.8020  delta = +0.0004  [OK]
#     Rebuilding X, y, groups for Optuna (same prep path)...
#     X shape: (598595, 10)  cities: 21  n_feat: 10
#
#   -> All baselines match source; safe to proceed to Optuna.

# %% [markdown]
# ## CELL OPTUNA -- LightGBM-MIA hyperparameter search per parquet
#
# Search space (10D): `n_estimators [100,800]`, `num_leaves [15,255]`, `max_depth [3,12]`, `learning_rate [0.01,0.2]` log, `min_child_samples [5,100]`, `reg_alpha [0,2]`, `reg_lambda [0,2]`, `feature_fraction [0.5,1]`, `bagging_fraction [0.5,1]`, `bagging_freq [0,10]`. Fixed: `is_unbalance=True`, `force_col_wise=True`, `random_state`, `n_jobs=-1`, `verbose=-1`.

# %%
# @title CELL OPTUNA: LightGBM-MIA search per parquet
import optuna
from optuna.samplers import TPESampler
import joblib

NB11_OUT_DIR = OUTPUTS_DIR / "NB11_V2"
(NB11_OUT_DIR / "studies").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "oof").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "models").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "best_params").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "summary").mkdir(parents=True, exist_ok=True)

# LGBM_PARAMS comes from CELL H (verbatim source); fixed for all trials
FIXED_LGBM = dict(
    random_state=RANDOM_STATE,
    n_jobs=NB11_THREADS_PER_NB,
    verbose=-1,
    is_unbalance=True,
    force_col_wise=True,
)

BASELINE_TRIAL_LGBM = {
    'n_estimators': LGBM_PARAMS['n_estimators'],
    'num_leaves': LGBM_PARAMS['num_leaves'],
    'max_depth': LGBM_PARAMS['max_depth'],
    'learning_rate': LGBM_PARAMS['learning_rate'],
    'min_child_samples': LGBM_PARAMS['min_child_samples'],
    'reg_alpha': 0.0, 'reg_lambda': 0.0,
    'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0,
}

def _oof_auc_lgbm(params, X, y, groups):
    gkf = GroupKFold(n_splits=min(N_FOLDS, len(np.unique(groups))))
    y_proba_oof = np.full(len(y), np.nan)
    for tr, te in gkf.split(X, y, groups):
        clf = LGBMClassifier(**{**FIXED_LGBM, **params})
        clf.fit(X[tr], y[tr])
        y_proba_oof[te] = clf.predict_proba(X[te])[:, 1]
    valid = ~np.isnan(y_proba_oof)
    return roc_auc_score(y[valid], y_proba_oof[valid])

def suggest_lgbm(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 800),
        'num_leaves': trial.suggest_int('num_leaves', 15, 255),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 2.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 2.0),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 0, 10),
    }

def patience_stop_factory(patience):
    def cb(study, trial):
        best = study.best_trial
        if (trial.number - best.number) >= patience:
            print(f"      [patience] no improvement for {patience} trials -> stopping")
            study.stop()
    return cb

NB11_OPTUNA_RESULTS = {}      # pq_id -> dict
for pq_id, manifest_key, _expected in NB11_PARQUETS:
    prep = NB11_PREP[pq_id]
    X_pq, y_pq, groups_pq = prep['X'], prep['y'], prep['groups']
    baseline_auc = prep['baseline_auc']
    n_trials = OPTUNA_BASE_BUDGET if baseline_auc >= OPTUNA_LOW_AUC_CUTOFF else OPTUNA_LOW_AUC_BUDGET

    STUDY_TAG = f"{NB11_NAME}__{manifest_key}__LightGBM-MIA"
    STUDY_DB  = NB11_OUT_DIR / "studies" / f"{STUDY_TAG}.sqlite"
    storage_url = f"sqlite:///{STUDY_DB.as_posix()}"

    print(f"\n  === [{pq_id}] {manifest_key} ===")
    print(f"    baseline_auc = {baseline_auc:.4f}   budget = {n_trials} trials   patience = {OPTUNA_PATIENCE}")
    print(f"    DB: {STUDY_DB}")

    def objective(trial, X=X_pq, y=y_pq, g=groups_pq):
        params = suggest_lgbm(trial)
        return _oof_auc_lgbm(params, X, y, g)

    study = optuna.create_study(
        direction=OPTUNA_DIRECTION,
        storage=storage_url,
        study_name=STUDY_TAG,
        load_if_exists=True,
        sampler=TPESampler(seed=OPTUNA_SEED),
    )

    # RESUME-IF-EXISTS: any complete trial -> use as-is, no further optimization.
    # To force re-run, delete the corresponding sqlite file under NB11_V2/studies/.
    completed_trials = [t for t in study.trials if t.state.name == 'COMPLETE']
    if len(completed_trials) > 0:
        best = study.best_trial
        n_trials_done = len(study.trials)
        print(f"    RESUME: {n_trials_done} trials in study ({len(completed_trials)} complete) -- using as-is")
        print(f"    Best AUC: {best.value:.4f}  (trial {best.number})")
        print(f"    Best params: {best.params}")
        print(f"    Delta vs baseline: {best.value - baseline_auc:+.4f}")
    else:
        study.enqueue_trial(BASELINE_TRIAL_LGBM)
        print(f"    enqueued baseline params as trial 0: {BASELINE_TRIAL_LGBM}")
        study.optimize(objective, n_trials=n_trials,
                       callbacks=[patience_stop_factory(OPTUNA_PATIENCE)],
                       show_progress_bar=False)
        n_trials_done = len(study.trials)
        best = study.best_trial
        print(f"    Optuna done: {n_trials_done} trials")
        print(f"    Best AUC: {best.value:.4f}  (trial {best.number})")
        print(f"    Best params: {best.params}")
        print(f"    Delta vs baseline: {best.value - baseline_auc:+.4f}")

    NB11_OPTUNA_RESULTS[pq_id] = {
        'manifest_key': manifest_key,
        'baseline_auc': baseline_auc,
        'tuned_auc': best.value,
        'best_params': best.params,
        'n_trials_done': n_trials_done,
        'n_trials_requested': n_trials,
        'study_tag': STUDY_TAG,
        'study_db': STUDY_DB,
    }
# Out:
#   === [A13] prepost_single_card ===
#     baseline_auc = 0.8024   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11c_A13_A14_A19_card_changes__prepost_single_card__LightGBM-MIA.sqlite
# [I 2026-05-20 20:55:36,764] A new study created in RDB with name: NB11c_A13_A14_A19_card_changes__prepost_single_card__LightGBM-MIA
#     enqueued baseline params as trial 0: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}
# [I 2026-05-20 21:01:01,107] Trial 0 finished with value: 0.8023623669485858 and parameters: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}. Best is trial 0 with value: 0.8023623669485858.
# [I 2026-05-20 21:01:40,405] Trial 1 finished with value: 0.756765576973772 and parameters: {'n_estimators': 362, 'num_leaves': 244, 'max_depth': 10, 'learning_rate': 0.060099747183803134, 'min_child_samples': 19, 'reg_alpha': 0.3119890406724053, 'reg_lambda': 0.11616722433639892, 'feature_fraction': 0.9330880728874675, 'bagging_fraction': 0.8005575058716043, 'bagging_freq': 7}. Best is trial 0 with value: 0.8023623669485858.
# [I 2026-05-20 21:01:55,221] Trial 2 finished with value: 0.7995586200998066 and parameters: {'n_estimators': 114, 'num_leaves': 248, 'max_depth': 11, 'learning_rate': 0.018891200276189388, 'min_child_samples': 22, 'reg_alpha': 0.36680901970686763, 'reg_lambda': 0.6084844859190754, 'feature_fraction': 0.762378215816119, 'bagging_fraction': 0.7159725093210578, 'bagging_freq': 3}. Best is trial 0 with value: 0.8023623669485858.
# [I 2026-05-20 21:02:13,448] Trial 3 finished with value: 0.8033191874198151 and parameters: {'n_estimators': 528, 'num_leaves': 48, 'max_depth': 5, 'learning_rate': 0.029967309097101588, 'min_child_samples': 48, 'reg_alpha': 1.5703519227860272, 'reg_lambda': 0.39934756431671947, 'feature_fraction': 0.7571172192068059, 'bagging_fraction': 0.7962072844310213, 'bagging_freq': 0}. Best is trial 3 with value: 0.8033191874198151.
# [I 2026-05-20 21:02:28,055] Trial 4 finished with value: 0.8122882253668673 and parameters: {'n_estimators': 525, 'num_leaves': 56, 'max_depth': 3, 'learning_rate': 0.17160445029754812, 'min_child_samples': 97, 'reg_alpha': 1.6167946962329223, 'reg_lambda': 0.6092275383467414, 'feature_fraction': 0.5488360570031919, 'bagging_fraction': 0.8421165132560784, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:02:34,237] Trial 5 finished with value: 0.7312169618363974 and parameters: {'n_estimators': 185, 'num_leaves': 134, 'max_depth': 3, 'learning_rate': 0.15242391728466367, 'min_child_samples': 29, 'reg_alpha': 1.325044568707964, 'reg_lambda': 0.6234221521788219, 'feature_fraction': 0.7600340105889054, 'bagging_fraction': 0.7733551396716398, 'bagging_freq': 2}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:03:24,343] Trial 6 finished with value: 0.7389217743834615 and parameters: {'n_estimators': 779, 'num_leaves': 201, 'max_depth': 12, 'learning_rate': 0.1459476894296684, 'min_child_samples': 62, 'reg_alpha': 1.8437484700462337, 'reg_lambda': 0.176985004103839, 'feature_fraction': 0.5979914312095727, 'bagging_fraction': 0.522613644455269, 'bagging_freq': 3}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:03:48,633] Trial 7 finished with value: 0.7893198196770892 and parameters: {'n_estimators': 372, 'num_leaves': 80, 'max_depth': 11, 'learning_rate': 0.02911701023242742, 'min_child_samples': 31, 'reg_alpha': 1.085392166316497, 'reg_lambda': 0.2818484499495253, 'feature_fraction': 0.9010984903770198, 'bagging_fraction': 0.5372753218398854, 'bagging_freq': 10}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:04:06,887] Trial 8 finished with value: 0.46176627296508477 and parameters: {'n_estimators': 641, 'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.11506408247250169, 'min_child_samples': 72, 'reg_alpha': 1.4580143360819746, 'reg_lambda': 1.5425406933718915, 'feature_fraction': 0.5370223258670452, 'bagging_fraction': 0.6792328642721364, 'bagging_freq': 1}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:04:45,103] Trial 9 finished with value: 0.8053590381179256 and parameters: {'n_estimators': 705, 'num_leaves': 165, 'max_depth': 6, 'learning_rate': 0.012097379927033842, 'min_child_samples': 34, 'reg_alpha': 0.6503666440534941, 'reg_lambda': 1.4592123566761281, 'feature_fraction': 0.8187787356776066, 'bagging_fraction': 0.9436063712881633, 'bagging_freq': 5}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:05:19,889] Trial 10 finished with value: 0.762464319159537 and parameters: {'n_estimators': 510, 'num_leaves': 106, 'max_depth': 8, 'learning_rate': 0.08378051621835425, 'min_child_samples': 99, 'reg_alpha': 1.8153295905650353, 'reg_lambda': 1.0649386926357898, 'feature_fraction': 0.638143009777776, 'bagging_fraction': 0.8918148105745084, 'bagging_freq': 6}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:05:49,852] Trial 11 finished with value: 0.8043354582158813 and parameters: {'n_estimators': 702, 'num_leaves': 173, 'max_depth': 5, 'learning_rate': 0.011677129654416162, 'min_child_samples': 100, 'reg_alpha': 0.7471087429082798, 'reg_lambda': 1.971599641281598, 'feature_fraction': 0.8558287498365654, 'bagging_fraction': 0.9335550136952496, 'bagging_freq': 5}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:06:32,910] Trial 12 finished with value: 0.8031469408613255 and parameters: {'n_estimators': 613, 'num_leaves': 181, 'max_depth': 8, 'learning_rate': 0.01295294608936321, 'min_child_samples': 79, 'reg_alpha': 0.8257281319576956, 'reg_lambda': 1.2010006709763976, 'feature_fraction': 0.6713996441331581, 'bagging_fraction': 0.8781531019763853, 'bagging_freq': 8}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:07:09,099] Trial 13 finished with value: 0.7840249761825702 and parameters: {'n_estimators': 800, 'num_leaves': 133, 'max_depth': 6, 'learning_rate': 0.19791194503090667, 'min_child_samples': 43, 'reg_alpha': 1.0698278622426602, 'reg_lambda': 1.4596696590634026, 'feature_fraction': 0.5245919441343214, 'bagging_fraction': 0.9964388943631123, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:07:25,897] Trial 14 finished with value: 0.8069541810650818 and parameters: {'n_estimators': 429, 'num_leaves': 84, 'max_depth': 4, 'learning_rate': 0.03168507863861446, 'min_child_samples': 83, 'reg_alpha': 0.43164388481165517, 'reg_lambda': 0.7912427920095692, 'feature_fraction': 0.8289013643072972, 'bagging_fraction': 0.8555094876582201, 'bagging_freq': 5}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:07:39,028] Trial 15 finished with value: 0.804303557403008 and parameters: {'n_estimators': 383, 'num_leaves': 91, 'max_depth': 4, 'learning_rate': 0.03053176420972853, 'min_child_samples': 83, 'reg_alpha': 0.4433320524781534, 'reg_lambda': 0.701872069034599, 'feature_fraction': 0.685998376501779, 'bagging_fraction': 0.627528534606948, 'bagging_freq': 8}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:07:53,103] Trial 16 finished with value: 0.8037545132368444 and parameters: {'n_estimators': 459, 'num_leaves': 21, 'max_depth': 3, 'learning_rate': 0.07436902054944462, 'min_child_samples': 88, 'reg_alpha': 0.04739082301166442, 'reg_lambda': 0.8850394773509477, 'feature_fraction': 0.821049534392583, 'bagging_fraction': 0.8526260973490012, 'bagging_freq': 5}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:08:06,025] Trial 17 finished with value: 0.8053880443301434 and parameters: {'n_estimators': 276, 'num_leaves': 110, 'max_depth': 5, 'learning_rate': 0.03735371964171442, 'min_child_samples': 60, 'reg_alpha': 1.2958497064758978, 'reg_lambda': 0.899890784144478, 'feature_fraction': 0.5852306392660565, 'bagging_fraction': 0.8264423346529435, 'bagging_freq': 3}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:08:15,532] Trial 18 finished with value: 0.8010647232531238 and parameters: {'n_estimators': 275, 'num_leaves': 53, 'max_depth': 4, 'learning_rate': 0.020294719242692348, 'min_child_samples': 91, 'reg_alpha': 1.63641942611213, 'reg_lambda': 0.3988094046888191, 'feature_fraction': 0.692294230790441, 'bagging_fraction': 0.7268302678751436, 'bagging_freq': 7}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:08:46,129] Trial 19 finished with value: 0.7675874353405819 and parameters: {'n_estimators': 557, 'num_leaves': 74, 'max_depth': 7, 'learning_rate': 0.09360400390909199, 'min_child_samples': 6, 'reg_alpha': 1.9540992684138767, 'reg_lambda': 1.177090372911294, 'feature_fraction': 0.5058104808137766, 'bagging_fraction': 0.6379559879909951, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:09:19,968] Trial 20 finished with value: 0.7980962612053086 and parameters: {'n_estimators': 433, 'num_leaves': 108, 'max_depth': 9, 'learning_rate': 0.020819603789608305, 'min_child_samples': 73, 'reg_alpha': 0.9030285369710931, 'reg_lambda': 0.7632988231956273, 'feature_fraction': 0.9393135032915165, 'bagging_fraction': 0.9312404495902853, 'bagging_freq': 10}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:09:28,527] Trial 21 finished with value: 0.7999904672520408 and parameters: {'n_estimators': 225, 'num_leaves': 109, 'max_depth': 4, 'learning_rate': 0.04095444837297438, 'min_child_samples': 58, 'reg_alpha': 1.2425808073670386, 'reg_lambda': 0.8993994368520548, 'feature_fraction': 0.5969937303029026, 'bagging_fraction': 0.8368647352606681, 'bagging_freq': 2}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:09:41,937] Trial 22 finished with value: 0.8030475672612577 and parameters: {'n_estimators': 294, 'num_leaves': 38, 'max_depth': 5, 'learning_rate': 0.04218455053420511, 'min_child_samples': 63, 'reg_alpha': 1.268025985147443, 'reg_lambda': 0.48796217978776635, 'feature_fraction': 0.5601114473236429, 'bagging_fraction': 0.8278188713622066, 'bagging_freq': 3}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:09:52,483] Trial 23 finished with value: 0.8023192380101036 and parameters: {'n_estimators': 317, 'num_leaves': 97, 'max_depth': 4, 'learning_rate': 0.05808381432960484, 'min_child_samples': 72, 'reg_alpha': 1.58863000979306, 'reg_lambda': 0.9810512136494828, 'feature_fraction': 0.5960698293784443, 'bagging_fraction': 0.756205129520176, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:10:06,811] Trial 24 finished with value: 0.8034761223631868 and parameters: {'n_estimators': 458, 'num_leaves': 127, 'max_depth': 3, 'learning_rate': 0.035974789144459514, 'min_child_samples': 92, 'reg_alpha': 0.5853931980843803, 'reg_lambda': 0.7899989115108159, 'feature_fraction': 0.717710798011912, 'bagging_fraction': 0.8885719084847913, 'bagging_freq': 6}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:10:28,422] Trial 25 finished with value: 0.8064891049999408 and parameters: {'n_estimators': 580, 'num_leaves': 68, 'max_depth': 5, 'learning_rate': 0.024884035023906875, 'min_child_samples': 83, 'reg_alpha': 1.423837831690284, 'reg_lambda': 1.2167437452842558, 'feature_fraction': 0.6241757919395692, 'bagging_fraction': 0.810163140366425, 'bagging_freq': 2}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:10:50,622] Trial 26 finished with value: 0.8020529495128803 and parameters: {'n_estimators': 588, 'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.016594414160168595, 'min_child_samples': 82, 'reg_alpha': 1.7240235924535343, 'reg_lambda': 1.263166960592036, 'feature_fraction': 0.6412676810680954, 'bagging_fraction': 0.8661691466357341, 'bagging_freq': 1}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:11:09,059] Trial 27 finished with value: 0.8051469740477946 and parameters: {'n_estimators': 494, 'num_leaves': 17, 'max_depth': 7, 'learning_rate': 0.025610449736499886, 'min_child_samples': 95, 'reg_alpha': 1.456140855470508, 'reg_lambda': 1.8457787867324078, 'feature_fraction': 0.8056650292065699, 'bagging_fraction': 0.7929236605378103, 'bagging_freq': 2}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:11:25,578] Trial 28 finished with value: 0.8026715496744719 and parameters: {'n_estimators': 652, 'num_leaves': 85, 'max_depth': 3, 'learning_rate': 0.023960037735886144, 'min_child_samples': 86, 'reg_alpha': 0.2058564876261669, 'reg_lambda': 1.3122536759395715, 'feature_fraction': 0.6510554274698591, 'bagging_fraction': 0.7246152735468137, 'bagging_freq': 6}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:11:40,895] Trial 29 finished with value: 0.7989913722552735 and parameters: {'n_estimators': 415, 'num_leaves': 38, 'max_depth': 6, 'learning_rate': 0.05083976182499547, 'min_child_samples': 75, 'reg_alpha': 1.9969933750988411, 'reg_lambda': 1.7042965114014081, 'feature_fraction': 0.9763551405686438, 'bagging_fraction': 0.9748251286050778, 'bagging_freq': 0}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:12:09,676] Trial 30 finished with value: 0.8063602591127756 and parameters: {'n_estimators': 564, 'num_leaves': 56, 'max_depth': 6, 'learning_rate': 0.016074124255242173, 'min_child_samples': 67, 'reg_alpha': 1.125482397640071, 'reg_lambda': 0.00918126214320869, 'feature_fraction': 0.8560053993642494, 'bagging_fraction': 0.9026946348596583, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:12:38,782] Trial 31 finished with value: 0.805684835876948 and parameters: {'n_estimators': 572, 'num_leaves': 58, 'max_depth': 6, 'learning_rate': 0.015950752008145677, 'min_child_samples': 67, 'reg_alpha': 0.9771402038674069, 'reg_lambda': 0.11702784947907537, 'feature_fraction': 0.8640787827924524, 'bagging_fraction': 0.9152506753200569, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:13:00,187] Trial 32 finished with value: 0.8063522265008042 and parameters: {'n_estimators': 532, 'num_leaves': 32, 'max_depth': 5, 'learning_rate': 0.015536138326802345, 'min_child_samples': 77, 'reg_alpha': 1.1457222387728558, 'reg_lambda': 0.5086177316104029, 'feature_fraction': 0.8670763036081761, 'bagging_fraction': 0.8165219874856618, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:13:28,363] Trial 33 finished with value: 0.80628849938245 and parameters: {'n_estimators': 489, 'num_leaves': 47, 'max_depth': 7, 'learning_rate': 0.010397748223512474, 'min_child_samples': 68, 'reg_alpha': 1.4530239505795643, 'reg_lambda': 1.0767058138948171, 'feature_fraction': 0.7995875033051456, 'bagging_fraction': 0.8999936480201651, 'bagging_freq': 1}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:13:58,372] Trial 34 finished with value: 0.8046374531698088 and parameters: {'n_estimators': 689, 'num_leaves': 65, 'max_depth': 4, 'learning_rate': 0.023291522211913298, 'min_child_samples': 54, 'reg_alpha': 1.3495571364795045, 'reg_lambda': 0.047967279155189606, 'feature_fraction': 0.8886936204686723, 'bagging_fraction': 0.8572906393500376, 'bagging_freq': 3}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:14:19,634] Trial 35 finished with value: 0.8031701350356015 and parameters: {'n_estimators': 543, 'num_leaves': 154, 'max_depth': 5, 'learning_rate': 0.032943700440170545, 'min_child_samples': 87, 'reg_alpha': 1.1491553802952645, 'reg_lambda': 0.2684044191237233, 'feature_fraction': 0.7423993115970436, 'bagging_fraction': 0.7851248034085209, 'bagging_freq': 2}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:14:43,272] Trial 36 finished with value: 0.8020743069530669 and parameters: {'n_estimators': 604, 'num_leaves': 79, 'max_depth': 5, 'learning_rate': 0.04787876292299161, 'min_child_samples': 80, 'reg_alpha': 1.5094129058954855, 'reg_lambda': 0.6207885622579189, 'feature_fraction': 0.7844088499340728, 'bagging_fraction': 0.9612672418745122, 'bagging_freq': 7}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:15:20,421] Trial 37 finished with value: 0.8050466380797996 and parameters: {'n_estimators': 747, 'num_leaves': 215, 'max_depth': 6, 'learning_rate': 0.017686693218701078, 'min_child_samples': 95, 'reg_alpha': 0.9833048638835199, 'reg_lambda': 0.0029000235855067835, 'feature_fraction': 0.837568842060499, 'bagging_fraction': 0.8041254812237157, 'bagging_freq': 5}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:15:33,930] Trial 38 finished with value: 0.8042328205922827 and parameters: {'n_estimators': 411, 'num_leaves': 45, 'max_depth': 3, 'learning_rate': 0.014168632687645856, 'min_child_samples': 51, 'reg_alpha': 1.6742886647167736, 'reg_lambda': 0.3985543799053884, 'feature_fraction': 0.9181051533685242, 'bagging_fraction': 0.7656004773555639, 'bagging_freq': 6}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:15:53,060] Trial 39 finished with value: 0.8046567150607543 and parameters: {'n_estimators': 637, 'num_leaves': 28, 'max_depth': 4, 'learning_rate': 0.027480038946822535, 'min_child_samples': 67, 'reg_alpha': 0.5010975061550502, 'reg_lambda': 0.20718943397744527, 'feature_fraction': 0.5630557320992007, 'bagging_fraction': 0.6844857869907903, 'bagging_freq': 3}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:16:24,931] Trial 40 finished with value: 0.7658158095245378 and parameters: {'n_estimators': 348, 'num_leaves': 125, 'max_depth': 10, 'learning_rate': 0.06594774012640131, 'min_child_samples': 84, 'reg_alpha': 0.2389586046187616, 'reg_lambda': 1.0645177477960246, 'feature_fraction': 0.7301877385905007, 'bagging_fraction': 0.8455348831866955, 'bagging_freq': 2}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:16:48,182] Trial 41 finished with value: 0.8058531717200361 and parameters: {'n_estimators': 528, 'num_leaves': 56, 'max_depth': 5, 'learning_rate': 0.014376746845424625, 'min_child_samples': 78, 'reg_alpha': 1.174787835085738, 'reg_lambda': 0.5286414241901845, 'feature_fraction': 0.8750380770311709, 'bagging_fraction': 0.8089937019804692, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:17:07,098] Trial 42 finished with value: 0.8064528300495268 and parameters: {'n_estimators': 470, 'num_leaves': 34, 'max_depth': 5, 'learning_rate': 0.02124087686927494, 'min_child_samples': 91, 'reg_alpha': 1.3901704162860455, 'reg_lambda': 0.5507982833233711, 'feature_fraction': 0.9485652580361437, 'bagging_fraction': 0.8188867891914127, 'bagging_freq': 4}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:17:22,475] Trial 43 finished with value: 0.8032229760011302 and parameters: {'n_estimators': 476, 'num_leaves': 69, 'max_depth': 3, 'learning_rate': 0.021863405744854403, 'min_child_samples': 97, 'reg_alpha': 1.3438820304180672, 'reg_lambda': 0.7234649067246484, 'feature_fraction': 0.9973833239454636, 'bagging_fraction': 0.9104504905259436, 'bagging_freq': 5}. Best is trial 4 with value: 0.8122882253668673.
# [I 2026-05-20 21:17:46,052] Trial 44 finished with value: 0.807156832867783 and parameters: {'n_estimators': 510, 'num_leaves': 97, 'max_depth': 6, 'learning_rate': 0.018686036180924213, 'min_child_samples': 91, 'reg_alpha': 1.5324809471877097, 'reg_lambda': 0.6347571436163536, 'feature_fraction': 0.9615735751986948, 'bagging_fraction': 0.875246135508748, 'bagging_freq': 5}. Best is trial 4 with value: 0.8122882253668673.
#       [patience] no improvement for 40 trials -> stopping
#     Optuna done: 45 trials
#     Best AUC: 0.8123  (trial 4)
#     Best params: {'n_estimators': 525, 'num_leaves': 56, 'max_depth': 3, 'learning_rate': 0.17160445029754812, 'min_child_samples': 97, 'reg_alpha': 1.6167946962329223, 'reg_lambda': 0.6092275383467414, 'feature_fraction': 0.5488360570031919, 'bagging_fraction': 0.8421165132560784, 'bagging_freq': 4}
#     Delta vs baseline: +0.0099
#
#   === [A14] coh_drop ===
#     baseline_auc = 0.8075   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11c_A13_A14_A19_card_changes__coh_drop__LightGBM-MIA.sqlite
# [I 2026-05-20 21:17:46,284] A new study created in RDB with name: NB11c_A13_A14_A19_card_changes__coh_drop__LightGBM-MIA
#     enqueued baseline params as trial 0: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}
# [I 2026-05-20 21:17:52,651] Trial 0 finished with value: 0.807481397942976 and parameters: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}. Best is trial 0 with value: 0.807481397942976.
# [I 2026-05-20 21:18:31,122] Trial 1 finished with value: 0.7984095274160057 and parameters: {'n_estimators': 362, 'num_leaves': 244, 'max_depth': 10, 'learning_rate': 0.060099747183803134, 'min_child_samples': 19, 'reg_alpha': 0.3119890406724053, 'reg_lambda': 0.11616722433639892, 'feature_fraction': 0.9330880728874675, 'bagging_fraction': 0.8005575058716043, 'bagging_freq': 7}. Best is trial 0 with value: 0.807481397942976.
# [I 2026-05-20 21:18:38,917] Trial 2 finished with value: 0.80801495910407 and parameters: {'n_estimators': 114, 'num_leaves': 248, 'max_depth': 11, 'learning_rate': 0.018891200276189388, 'min_child_samples': 22, 'reg_alpha': 0.36680901970686763, 'reg_lambda': 0.6084844859190754, 'feature_fraction': 0.762378215816119, 'bagging_fraction': 0.7159725093210578, 'bagging_freq': 3}. Best is trial 2 with value: 0.80801495910407.
# [I 2026-05-20 21:18:53,626] Trial 3 finished with value: 0.8078067931211658 and parameters: {'n_estimators': 528, 'num_leaves': 48, 'max_depth': 5, 'learning_rate': 0.029967309097101588, 'min_child_samples': 48, 'reg_alpha': 1.5703519227860272, 'reg_lambda': 0.39934756431671947, 'feature_fraction': 0.7571172192068059, 'bagging_fraction': 0.7962072844310213, 'bagging_freq': 0}. Best is trial 2 with value: 0.80801495910407.
# [I 2026-05-20 21:19:06,701] Trial 4 finished with value: 0.8098761572577604 and parameters: {'n_estimators': 525, 'num_leaves': 56, 'max_depth': 3, 'learning_rate': 0.17160445029754812, 'min_child_samples': 97, 'reg_alpha': 1.6167946962329223, 'reg_lambda': 0.6092275383467414, 'feature_fraction': 0.5488360570031919, 'bagging_fraction': 0.8421165132560784, 'bagging_freq': 4}. Best is trial 4 with value: 0.8098761572577604.
# [I 2026-05-20 21:19:12,079] Trial 5 finished with value: 0.7989269965407286 and parameters: {'n_estimators': 185, 'num_leaves': 134, 'max_depth': 3, 'learning_rate': 0.15242391728466367, 'min_child_samples': 29, 'reg_alpha': 1.325044568707964, 'reg_lambda': 0.6234221521788219, 'feature_fraction': 0.7600340105889054, 'bagging_fraction': 0.7733551396716398, 'bagging_freq': 2}. Best is trial 4 with value: 0.8098761572577604.
# [I 2026-05-20 21:19:33,781] Trial 6 finished with value: 0.7890978599289892 and parameters: {'n_estimators': 779, 'num_leaves': 201, 'max_depth': 12, 'learning_rate': 0.1459476894296684, 'min_child_samples': 62, 'reg_alpha': 1.8437484700462337, 'reg_lambda': 0.176985004103839, 'feature_fraction': 0.5979914312095727, 'bagging_fraction': 0.522613644455269, 'bagging_freq': 3}. Best is trial 4 with value: 0.8098761572577604.
# [I 2026-05-20 21:19:50,597] Trial 7 finished with value: 0.8032781311964248 and parameters: {'n_estimators': 372, 'num_leaves': 80, 'max_depth': 11, 'learning_rate': 0.02911701023242742, 'min_child_samples': 31, 'reg_alpha': 1.085392166316497, 'reg_lambda': 0.2818484499495253, 'feature_fraction': 0.9010984903770198, 'bagging_fraction': 0.5372753218398854, 'bagging_freq': 10}. Best is trial 4 with value: 0.8098761572577604.
# [I 2026-05-20 21:20:07,819] Trial 8 finished with value: 0.8186758259147677 and parameters: {'n_estimators': 641, 'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.11506408247250169, 'min_child_samples': 72, 'reg_alpha': 1.4580143360819746, 'reg_lambda': 1.5425406933718915, 'feature_fraction': 0.5370223258670452, 'bagging_fraction': 0.6792328642721364, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:20:37,576] Trial 9 finished with value: 0.8097175945376773 and parameters: {'n_estimators': 705, 'num_leaves': 165, 'max_depth': 6, 'learning_rate': 0.012097379927033842, 'min_child_samples': 34, 'reg_alpha': 0.6503666440534941, 'reg_lambda': 1.4592123566761281, 'feature_fraction': 0.8187787356776066, 'bagging_fraction': 0.9436063712881633, 'bagging_freq': 5}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:20:59,929] Trial 10 finished with value: 0.79884776186732 and parameters: {'n_estimators': 644, 'num_leaves': 102, 'max_depth': 8, 'learning_rate': 0.08469851546015271, 'min_child_samples': 84, 'reg_alpha': 1.0818878163510957, 'reg_lambda': 1.9314017687518916, 'feature_fraction': 0.6395810818399249, 'bagging_fraction': 0.6510992184921498, 'bagging_freq': 7}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:21:15,422] Trial 11 finished with value: 0.72253873294461 and parameters: {'n_estimators': 561, 'num_leaves': 17, 'max_depth': 3, 'learning_rate': 0.1970249389544837, 'min_child_samples': 100, 'reg_alpha': 1.8792622798273524, 'reg_lambda': 1.1465819553024583, 'feature_fraction': 0.502634131303547, 'bagging_fraction': 0.8897860844614501, 'bagging_freq': 5}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:21:28,443] Trial 12 finished with value: 0.37257271937205005 and parameters: {'n_estimators': 461, 'num_leaves': 73, 'max_depth': 4, 'learning_rate': 0.09715120775835191, 'min_child_samples': 75, 'reg_alpha': 1.5064487880529445, 'reg_lambda': 1.5438591675203863, 'feature_fraction': 0.5061425796867053, 'bagging_fraction': 0.6494891289751392, 'bagging_freq': 2}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:21:51,765] Trial 13 finished with value: 0.7958454890128825 and parameters: {'n_estimators': 612, 'num_leaves': 115, 'max_depth': 8, 'learning_rate': 0.10736737551591524, 'min_child_samples': 100, 'reg_alpha': 1.523710049331429, 'reg_lambda': 1.042435947207893, 'feature_fraction': 0.6139626810719457, 'bagging_fraction': 0.8708095519591971, 'bagging_freq': 7}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:22:12,296] Trial 14 finished with value: 0.2329533173012814 and parameters: {'n_estimators': 800, 'num_leaves': 64, 'max_depth': 5, 'learning_rate': 0.19354083711642037, 'min_child_samples': 83, 'reg_alpha': 1.970335690427925, 'reg_lambda': 0.7912427920095692, 'feature_fraction': 0.5708223811623806, 'bagging_fraction': 0.6869888528707923, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:22:23,087] Trial 15 finished with value: 0.8089530576208291 and parameters: {'n_estimators': 446, 'num_leaves': 99, 'max_depth': 3, 'learning_rate': 0.06850658252300178, 'min_child_samples': 64, 'reg_alpha': 1.2789369325417557, 'reg_lambda': 1.9611900936949587, 'feature_fraction': 0.6619973560815415, 'bagging_fraction': 0.5851844040992087, 'bagging_freq': 5}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:22:35,675] Trial 16 finished with value: 0.7975318505515836 and parameters: {'n_estimators': 317, 'num_leaves': 153, 'max_depth': 7, 'learning_rate': 0.1280880785928108, 'min_child_samples': 6, 'reg_alpha': 0.794680857150835, 'reg_lambda': 1.3376021344516908, 'feature_fraction': 0.6892752514126932, 'bagging_fraction': 0.8274498753583368, 'bagging_freq': 3}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:22:57,801] Trial 17 finished with value: 0.8051303963485704 and parameters: {'n_estimators': 691, 'num_leaves': 44, 'max_depth': 5, 'learning_rate': 0.03714602823116445, 'min_child_samples': 87, 'reg_alpha': 1.7655879638812968, 'reg_lambda': 1.7069397576499241, 'feature_fraction': 0.5551194360277596, 'bagging_fraction': 0.7128359989368286, 'bagging_freq': 4}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:23:12,119] Trial 18 finished with value: 0.8025062180422398 and parameters: {'n_estimators': 480, 'num_leaves': 16, 'max_depth': 4, 'learning_rate': 0.07921982446828886, 'min_child_samples': 69, 'reg_alpha': 1.6711661247781866, 'reg_lambda': 0.8926440169000723, 'feature_fraction': 0.7026490412940231, 'bagging_fraction': 0.8682647501338387, 'bagging_freq': 9}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:23:31,801] Trial 19 finished with value: 0.79683068111961 and parameters: {'n_estimators': 583, 'num_leaves': 84, 'max_depth': 9, 'learning_rate': 0.12376405893924652, 'min_child_samples': 54, 'reg_alpha': 1.2907401008703252, 'reg_lambda': 1.2013254882108513, 'feature_fraction': 0.5485971935805384, 'bagging_fraction': 0.6099484571364099, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:23:39,802] Trial 20 finished with value: 0.8113861561239081 and parameters: {'n_estimators': 233, 'num_leaves': 57, 'max_depth': 4, 'learning_rate': 0.049385549414285454, 'min_child_samples': 91, 'reg_alpha': 0.9247620802520199, 'reg_lambda': 0.5026313693671761, 'feature_fraction': 0.8564969956012847, 'bagging_fraction': 0.7400690107410504, 'bagging_freq': 4}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:23:46,866] Trial 21 finished with value: 0.8108271117065626 and parameters: {'n_estimators': 218, 'num_leaves': 55, 'max_depth': 4, 'learning_rate': 0.05641924863769935, 'min_child_samples': 89, 'reg_alpha': 0.6799480758499495, 'reg_lambda': 0.6029325189572573, 'feature_fraction': 0.8638687768356053, 'bagging_fraction': 0.7565668834974402, 'bagging_freq': 4}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:23:54,676] Trial 22 finished with value: 0.8126384502909502 and parameters: {'n_estimators': 254, 'num_leaves': 39, 'max_depth': 4, 'learning_rate': 0.041640056357536016, 'min_child_samples': 89, 'reg_alpha': 0.8229428960199952, 'reg_lambda': 0.4258591348729863, 'feature_fraction': 0.8452144881545222, 'bagging_fraction': 0.759232420486218, 'bagging_freq': 4}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:24:08,532] Trial 23 finished with value: 0.8058368425607307 and parameters: {'n_estimators': 291, 'num_leaves': 35, 'max_depth': 6, 'learning_rate': 0.03798225981449454, 'min_child_samples': 76, 'reg_alpha': 0.8403910949224509, 'reg_lambda': 0.47985472734874074, 'feature_fraction': 0.8248273999877506, 'bagging_fraction': 0.7128214244292036, 'bagging_freq': 6}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:24:18,164] Trial 24 finished with value: 0.8150421281939566 and parameters: {'n_estimators': 268, 'num_leaves': 92, 'max_depth': 4, 'learning_rate': 0.022455510094993813, 'min_child_samples': 92, 'reg_alpha': 0.9110060675467962, 'reg_lambda': 0.7750343954886796, 'feature_fraction': 0.8124664468361472, 'bagging_fraction': 0.6742828416729889, 'bagging_freq': 2}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:24:27,702] Trial 25 finished with value: 0.8135245704799376 and parameters: {'n_estimators': 283, 'num_leaves': 119, 'max_depth': 5, 'learning_rate': 0.0207375774898643, 'min_child_samples': 78, 'reg_alpha': 0.41703149768736414, 'reg_lambda': 0.8341241148645062, 'feature_fraction': 0.7934979291580881, 'bagging_fraction': 0.6587743245816029, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:24:40,278] Trial 26 finished with value: 0.8130132304014526 and parameters: {'n_estimators': 400, 'num_leaves': 126, 'max_depth': 5, 'learning_rate': 0.017617022399952602, 'min_child_samples': 78, 'reg_alpha': 0.45110853057416456, 'reg_lambda': 0.8002539496277645, 'feature_fraction': 0.7968057241120248, 'bagging_fraction': 0.5869912166974145, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:24:55,026] Trial 27 finished with value: 0.8090043987543944 and parameters: {'n_estimators': 307, 'num_leaves': 156, 'max_depth': 7, 'learning_rate': 0.020590495803959285, 'min_child_samples': 70, 'reg_alpha': 0.11563750054517374, 'reg_lambda': 0.9815463450911497, 'feature_fraction': 0.722306114239487, 'bagging_fraction': 0.6521588981232443, 'bagging_freq': 2}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:25:07,680] Trial 28 finished with value: 0.8166190710543945 and parameters: {'n_estimators': 413, 'num_leaves': 98, 'max_depth': 3, 'learning_rate': 0.01107929027148618, 'min_child_samples': 55, 'reg_alpha': 0.46404713652064294, 'reg_lambda': 1.2562748088334574, 'feature_fraction': 0.7931221456569207, 'bagging_fraction': 0.6181176190750675, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:25:18,252] Trial 29 finished with value: 0.8163138838562682 and parameters: {'n_estimators': 414, 'num_leaves': 99, 'max_depth': 3, 'learning_rate': 0.01276727360729141, 'min_child_samples': 46, 'reg_alpha': 0.5822522951630547, 'reg_lambda': 1.7042965114014081, 'feature_fraction': 0.9763551405686438, 'bagging_fraction': 0.6149667137940208, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:25:28,896] Trial 30 finished with value: 0.8162643099214257 and parameters: {'n_estimators': 410, 'num_leaves': 108, 'max_depth': 3, 'learning_rate': 0.013287701688228579, 'min_child_samples': 48, 'reg_alpha': 0.010917150754625626, 'reg_lambda': 1.6982607145630058, 'feature_fraction': 0.9891461873372949, 'bagging_fraction': 0.5515578066841212, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:25:40,620] Trial 31 finished with value: 0.8163728170510142 and parameters: {'n_estimators': 418, 'num_leaves': 108, 'max_depth': 3, 'learning_rate': 0.010087648286798088, 'min_child_samples': 44, 'reg_alpha': 0.14587314201092982, 'reg_lambda': 1.7430675607351067, 'feature_fraction': 0.9966193431932526, 'bagging_fraction': 0.5486762787996226, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:25:59,959] Trial 32 finished with value: 0.8164573347712716 and parameters: {'n_estimators': 347, 'num_leaves': 139, 'max_depth': 3, 'learning_rate': 0.010114570587380564, 'min_child_samples': 42, 'reg_alpha': 0.20806393423062225, 'reg_lambda': 1.7669706008853991, 'feature_fraction': 0.9820781492966695, 'bagging_fraction': 0.593869889559305, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:26:10,840] Trial 33 finished with value: 0.8163885040103449 and parameters: {'n_estimators': 359, 'num_leaves': 185, 'max_depth': 3, 'learning_rate': 0.010159340876659149, 'min_child_samples': 38, 'reg_alpha': 0.22911517974290374, 'reg_lambda': 1.8330657391324887, 'feature_fraction': 0.9464611664631825, 'bagging_fraction': 0.505624760403558, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:26:21,128] Trial 34 finished with value: 0.815238653726606 and parameters: {'n_estimators': 347, 'num_leaves': 198, 'max_depth': 4, 'learning_rate': 0.01600480629108629, 'min_child_samples': 39, 'reg_alpha': 0.2357206531054832, 'reg_lambda': 1.8438782309875372, 'feature_fraction': 0.9352491298660028, 'bagging_fraction': 0.5741915457441081, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:26:34,523] Trial 35 finished with value: 0.8160090607512123 and parameters: {'n_estimators': 492, 'num_leaves': 187, 'max_depth': 3, 'learning_rate': 0.011385999122766832, 'min_child_samples': 52, 'reg_alpha': 0.2630840672049254, 'reg_lambda': 1.5065953174601356, 'feature_fraction': 0.9404130423338777, 'bagging_fraction': 0.5130537772139548, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:26:44,884] Trial 36 finished with value: 0.8140190752959221 and parameters: {'n_estimators': 360, 'num_leaves': 218, 'max_depth': 5, 'learning_rate': 0.014543816844335302, 'min_child_samples': 57, 'reg_alpha': 0.5346013257539775, 'reg_lambda': 1.3311024298026033, 'feature_fraction': 0.8950967130394578, 'bagging_fraction': 0.5035798623168922, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:26:50,561] Trial 37 finished with value: 0.8161756961854616 and parameters: {'n_estimators': 173, 'num_leaves': 230, 'max_depth': 3, 'learning_rate': 0.010027324299467335, 'min_child_samples': 20, 'reg_alpha': 0.3550654366632542, 'reg_lambda': 1.591988387488772, 'feature_fraction': 0.960436899572196, 'bagging_fraction': 0.6158779741613593, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:27:07,015] Trial 38 finished with value: 0.8069262095281773 and parameters: {'n_estimators': 523, 'num_leaves': 171, 'max_depth': 6, 'learning_rate': 0.025023967796344103, 'min_child_samples': 40, 'reg_alpha': 0.12807181713599897, 'reg_lambda': 1.8286025248432736, 'feature_fraction': 0.8951174073552461, 'bagging_fraction': 0.6278615967938862, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:27:11,574] Trial 39 finished with value: 0.8156566832058543 and parameters: {'n_estimators': 126, 'num_leaves': 142, 'max_depth': 4, 'learning_rate': 0.015661055221874165, 'min_child_samples': 61, 'reg_alpha': 0.5061200477547251, 'reg_lambda': 1.284032165674088, 'feature_fraction': 0.9566693288136429, 'bagging_fraction': 0.5710355535536564, 'bagging_freq': 2}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:27:25,185] Trial 40 finished with value: 0.8073817541296491 and parameters: {'n_estimators': 339, 'num_leaves': 185, 'max_depth': 10, 'learning_rate': 0.011251796957847594, 'min_child_samples': 28, 'reg_alpha': 0.017444999295531005, 'reg_lambda': 1.5940161516863414, 'feature_fraction': 0.9139016703778273, 'bagging_fraction': 0.5328098810487434, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:27:37,364] Trial 41 finished with value: 0.8162244994461944 and parameters: {'n_estimators': 427, 'num_leaves': 142, 'max_depth': 3, 'learning_rate': 0.01009234877905158, 'min_child_samples': 42, 'reg_alpha': 0.16737292756471164, 'reg_lambda': 1.4382949295544005, 'feature_fraction': 0.9967411011074679, 'bagging_fraction': 0.5563463009493856, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:27:47,874] Trial 42 finished with value: 0.8162495378947672 and parameters: {'n_estimators': 396, 'num_leaves': 130, 'max_depth': 3, 'learning_rate': 0.013716418151794528, 'min_child_samples': 35, 'reg_alpha': 0.2852127913091226, 'reg_lambda': 1.830145288069541, 'feature_fraction': 0.9748647094266599, 'bagging_fraction': 0.5955992769570361, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:27:57,147] Trial 43 finished with value: 0.8159210113908403 and parameters: {'n_estimators': 374, 'num_leaves': 80, 'max_depth': 3, 'learning_rate': 0.017247121428156955, 'min_child_samples': 25, 'reg_alpha': 0.17589255523072606, 'reg_lambda': 1.9941757442772217, 'feature_fraction': 0.9205798184930423, 'bagging_fraction': 0.5487590171776725, 'bagging_freq': 3}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:28:11,627] Trial 44 finished with value: 0.8154875424854153 and parameters: {'n_estimators': 506, 'num_leaves': 73, 'max_depth': 4, 'learning_rate': 0.011410801790288482, 'min_child_samples': 36, 'reg_alpha': 0.3535123504150267, 'reg_lambda': 1.6908906296873911, 'feature_fraction': 0.8727183909104845, 'bagging_fraction': 0.5282116926663797, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:28:23,832] Trial 45 finished with value: 0.8159706489949703 and parameters: {'n_estimators': 447, 'num_leaves': 113, 'max_depth': 3, 'learning_rate': 0.010041748548677109, 'min_child_samples': 45, 'reg_alpha': 0.07314548059127243, 'reg_lambda': 1.4266769442789926, 'feature_fraction': 0.9503923424680376, 'bagging_fraction': 0.6893644616593335, 'bagging_freq': 2}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:28:39,281] Trial 46 finished with value: 0.8054958274764952 and parameters: {'n_estimators': 323, 'num_leaves': 167, 'max_depth': 12, 'learning_rate': 0.014541603417231805, 'min_child_samples': 12, 'reg_alpha': 1.1027298214987695, 'reg_lambda': 1.8798349186908025, 'feature_fraction': 0.9995210738527381, 'bagging_fraction': 0.6377774451516057, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:28:56,213] Trial 47 finished with value: 0.8159937813755871 and parameters: {'n_estimators': 751, 'num_leaves': 252, 'max_depth': 3, 'learning_rate': 0.012360978782555009, 'min_child_samples': 50, 'reg_alpha': 0.23297272800844085, 'reg_lambda': 1.7706200224862259, 'feature_fraction': 0.7540710364101086, 'bagging_fraction': 0.5062556948437348, 'bagging_freq': 0}. Best is trial 8 with value: 0.8186758259147677.
# [I 2026-05-20 21:29:17,380] Trial 48 finished with value: 0.8106756814506588 and parameters: {'n_estimators': 654, 'num_leaves': 92, 'max_depth': 4, 'learning_rate': 0.02830966103983888, 'min_child_samples': 58, 'reg_alpha': 0.6972680137709515, 'reg_lambda': 1.567066968494795, 'feature_fraction': 0.7768838042909116, 'bagging_fraction': 0.9766151977884774, 'bagging_freq': 1}. Best is trial 8 with value: 0.8186758259147677.
#       [patience] no improvement for 40 trials -> stopping
#     Optuna done: 49 trials
#     Best AUC: 0.8187  (trial 8)
#     Best params: {'n_estimators': 641, 'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.11506408247250169, 'min_child_samples': 72, 'reg_alpha': 1.4580143360819746, 'reg_lambda': 1.5425406933718915, 'feature_fraction': 0.5370223258670452, 'bagging_fraction': 0.6792328642721364, 'bagging_freq': 1}
#     Delta vs baseline: +0.0112
#
#   === [A19] card_drop ===
#     baseline_auc = 0.8024   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11c_A13_A14_A19_card_changes__card_drop__LightGBM-MIA.sqlite
# [I 2026-05-20 21:29:17,622] A new study created in RDB with name: NB11c_A13_A14_A19_card_changes__card_drop__LightGBM-MIA
#     enqueued baseline params as trial 0: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}
# [I 2026-05-20 21:29:22,500] Trial 0 finished with value: 0.8023527900959412 and parameters: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:29:49,210] Trial 1 finished with value: 0.7772007594690274 and parameters: {'n_estimators': 362, 'num_leaves': 244, 'max_depth': 10, 'learning_rate': 0.060099747183803134, 'min_child_samples': 19, 'reg_alpha': 0.3119890406724053, 'reg_lambda': 0.11616722433639892, 'feature_fraction': 0.9330880728874675, 'bagging_fraction': 0.8005575058716043, 'bagging_freq': 7}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:29:58,672] Trial 2 finished with value: 0.7959657737638959 and parameters: {'n_estimators': 114, 'num_leaves': 248, 'max_depth': 11, 'learning_rate': 0.018891200276189388, 'min_child_samples': 22, 'reg_alpha': 0.36680901970686763, 'reg_lambda': 0.6084844859190754, 'feature_fraction': 0.762378215816119, 'bagging_fraction': 0.7159725093210578, 'bagging_freq': 3}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:30:13,675] Trial 3 finished with value: 0.8018106436303871 and parameters: {'n_estimators': 528, 'num_leaves': 48, 'max_depth': 5, 'learning_rate': 0.029967309097101588, 'min_child_samples': 48, 'reg_alpha': 1.5703519227860272, 'reg_lambda': 0.39934756431671947, 'feature_fraction': 0.7571172192068059, 'bagging_fraction': 0.7962072844310213, 'bagging_freq': 0}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:30:27,584] Trial 4 finished with value: 0.4739021606561534 and parameters: {'n_estimators': 525, 'num_leaves': 56, 'max_depth': 3, 'learning_rate': 0.17160445029754812, 'min_child_samples': 97, 'reg_alpha': 1.6167946962329223, 'reg_lambda': 0.6092275383467414, 'feature_fraction': 0.5488360570031919, 'bagging_fraction': 0.8421165132560784, 'bagging_freq': 4}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:30:33,972] Trial 5 finished with value: 0.7850114403309663 and parameters: {'n_estimators': 185, 'num_leaves': 134, 'max_depth': 3, 'learning_rate': 0.15242391728466367, 'min_child_samples': 29, 'reg_alpha': 1.325044568707964, 'reg_lambda': 0.6234221521788219, 'feature_fraction': 0.7600340105889054, 'bagging_fraction': 0.7733551396716398, 'bagging_freq': 2}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:31:06,528] Trial 6 finished with value: 0.7943468729928878 and parameters: {'n_estimators': 779, 'num_leaves': 201, 'max_depth': 12, 'learning_rate': 0.1459476894296684, 'min_child_samples': 62, 'reg_alpha': 1.8437484700462337, 'reg_lambda': 0.176985004103839, 'feature_fraction': 0.5979914312095727, 'bagging_fraction': 0.522613644455269, 'bagging_freq': 3}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:31:26,294] Trial 7 finished with value: 0.7887804776190317 and parameters: {'n_estimators': 372, 'num_leaves': 80, 'max_depth': 11, 'learning_rate': 0.02911701023242742, 'min_child_samples': 31, 'reg_alpha': 1.085392166316497, 'reg_lambda': 0.2818484499495253, 'feature_fraction': 0.9010984903770198, 'bagging_fraction': 0.5372753218398854, 'bagging_freq': 10}. Best is trial 0 with value: 0.8023527900959412.
# [I 2026-05-20 21:31:42,607] Trial 8 finished with value: 0.8322482863320542 and parameters: {'n_estimators': 641, 'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.11506408247250169, 'min_child_samples': 72, 'reg_alpha': 1.4580143360819746, 'reg_lambda': 1.5425406933718915, 'feature_fraction': 0.5370223258670452, 'bagging_fraction': 0.6792328642721364, 'bagging_freq': 1}. Best is trial 8 with value: 0.8322482863320542.
# [I 2026-05-20 21:32:16,245] Trial 9 finished with value: 0.8023324281252628 and parameters: {'n_estimators': 705, 'num_leaves': 165, 'max_depth': 6, 'learning_rate': 0.012097379927033842, 'min_child_samples': 34, 'reg_alpha': 0.6503666440534941, 'reg_lambda': 1.4592123566761281, 'feature_fraction': 0.8187787356776066, 'bagging_fraction': 0.9436063712881633, 'bagging_freq': 5}. Best is trial 8 with value: 0.8322482863320542.
# [I 2026-05-20 21:32:46,899] Trial 10 finished with value: 0.779490182942443 and parameters: {'n_estimators': 644, 'num_leaves': 102, 'max_depth': 8, 'learning_rate': 0.08469851546015271, 'min_child_samples': 84, 'reg_alpha': 1.0818878163510957, 'reg_lambda': 1.9314017687518916, 'feature_fraction': 0.6395810818399249, 'bagging_fraction': 0.6510992184921498, 'bagging_freq': 7}. Best is trial 8 with value: 0.8322482863320542.
# [I 2026-05-20 21:32:54,472] Trial 11 finished with value: 0.8027008962447617 and parameters: {'n_estimators': 258, 'num_leaves': 16, 'max_depth': 5, 'learning_rate': 0.08054717879684725, 'min_child_samples': 73, 'reg_alpha': 0.7453826222714207, 'reg_lambda': 1.2143685480664512, 'feature_fraction': 0.990638041536278, 'bagging_fraction': 0.9566262370156119, 'bagging_freq': 0}. Best is trial 8 with value: 0.8322482863320542.
# ...
# [I 2026-05-20 21:36:35,000] Trial 26 finished with value: 0.8036663192057103 and parameters: {'n_estimators': 400, 'num_leaves': 161, 'max_depth': 5, 'learning_rate': 0.04328343852791387, 'min_child_samples': 97, 'reg_alpha': 1.52874454960615, 'reg_lambda': 1.426049021651877, 'feature_fraction': 0.6323585999023396, 'bagging_fraction': 0.5130071485474988, 'bagging_freq': 1}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:36:55,359] Trial 27 finished with value: 0.4311375976924665 and parameters: {'n_estimators': 656, 'num_leaves': 117, 'max_depth': 4, 'learning_rate': 0.14301406926465957, 'min_child_samples': 84, 'reg_alpha': 0.9669158069553925, 'reg_lambda': 1.62701323275668, 'feature_fraction': 0.7977414792254335, 'bagging_fraction': 0.5532150653236609, 'bagging_freq': 5}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:39:22,929] Trial 28 finished with value: 0.8118383621887821 and parameters: {'n_estimators': 712, 'num_leaves': 64, 'max_depth': 7, 'learning_rate': 0.10982738790578327, 'min_child_samples': 59, 'reg_alpha': 1.947358522140576, 'reg_lambda': 1.3481485272269296, 'feature_fraction': 0.6859751716563139, 'bagging_fraction': 0.6028042887212727, 'bagging_freq': 7}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:39:38,257] Trial 29 finished with value: 0.8016459245099091 and parameters: {'n_estimators': 196, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.049254647962116885, 'min_child_samples': 39, 'reg_alpha': 1.266148159796628, 'reg_lambda': 1.1090756009929754, 'feature_fraction': 0.8642573464455381, 'bagging_fraction': 0.6765483548057258, 'bagging_freq': 0}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:39:51,700] Trial 30 finished with value: 0.8070329981217614 and parameters: {'n_estimators': 327, 'num_leaves': 93, 'max_depth': 3, 'learning_rate': 0.09613289531001488, 'min_child_samples': 51, 'reg_alpha': 0.010917150754625626, 'reg_lambda': 0.8035660950640899, 'feature_fraction': 0.5480218227145845, 'bagging_fraction': 0.5019956135132058, 'bagging_freq': 6}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:40:10,139] Trial 31 finished with value: 0.4564758161797871 and parameters: {'n_estimators': 330, 'num_leaves': 37, 'max_depth': 4, 'learning_rate': 0.1277059789425219, 'min_child_samples': 53, 'reg_alpha': 1.4529285983763434, 'reg_lambda': 1.5354839254050043, 'feature_fraction': 0.6126318971703624, 'bagging_fraction': 0.7307232092406797, 'bagging_freq': 3}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:40:28,039] Trial 32 finished with value: 0.7988028490609991 and parameters: {'n_estimators': 253, 'num_leaves': 33, 'max_depth': 6, 'learning_rate': 0.069063589718841, 'min_child_samples': 67, 'reg_alpha': 1.6707493484289295, 'reg_lambda': 1.097306739306457, 'feature_fraction': 0.7308374699940435, 'bagging_fraction': 0.759912824827416, 'bagging_freq': 2}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:40:43,282] Trial 33 finished with value: 0.8054718326215304 and parameters: {'n_estimators': 389, 'num_leaves': 44, 'max_depth': 5, 'learning_rate': 0.15743043483819463, 'min_child_samples': 16, 'reg_alpha': 1.090166334854573, 'reg_lambda': 1.8566467603043217, 'feature_fraction': 0.6655840886197464, 'bagging_fraction': 0.7054528318999216, 'bagging_freq': 3}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:40:49,224] Trial 34 finished with value: 0.7936092030982832 and parameters: {'n_estimators': 102, 'num_leaves': 57, 'max_depth': 9, 'learning_rate': 0.0980533471974076, 'min_child_samples': 56, 'reg_alpha': 1.4125952492883667, 'reg_lambda': 1.698732990596295, 'feature_fraction': 0.6174027370336452, 'bagging_fraction': 0.7424854810677135, 'bagging_freq': 1}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:41:03,316] Trial 35 finished with value: 0.8020844461865856 and parameters: {'n_estimators': 341, 'num_leaves': 75, 'max_depth': 3, 'learning_rate': 0.11870980422501061, 'min_child_samples': 78, 'reg_alpha': 1.5428792264418556, 'reg_lambda': 0.7565479271024185, 'feature_fraction': 0.5898606175535714, 'bagging_fraction': 0.8075827180392825, 'bagging_freq': 4}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:41:26,175] Trial 36 finished with value: 0.7969159817617308 and parameters: {'n_estimators': 504, 'num_leaves': 45, 'max_depth': 5, 'learning_rate': 0.06021669124945739, 'min_child_samples': 46, 'reg_alpha': 1.2984234778454833, 'reg_lambda': 1.5122204692886114, 'feature_fraction': 0.5303385917132849, 'bagging_fraction': 0.7822384418231956, 'bagging_freq': 2}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:41:32,556] Trial 37 finished with value: 0.8096090584533688 and parameters: {'n_estimators': 148, 'num_leaves': 215, 'max_depth': 4, 'learning_rate': 0.02196865491401709, 'min_child_samples': 25, 'reg_alpha': 0.5557428660787027, 'reg_lambda': 0.0029000235855067835, 'feature_fraction': 0.7292142793540475, 'bagging_fraction': 0.6626266909598918, 'bagging_freq': 3}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:41:59,024] Trial 38 finished with value: 0.5967037947890035 and parameters: {'n_estimators': 411, 'num_leaves': 87, 'max_depth': 6, 'learning_rate': 0.1672447602835904, 'min_child_samples': 37, 'reg_alpha': 1.5772533265390214, 'reg_lambda': 0.4207716854944823, 'feature_fraction': 0.7785668591246981, 'bagging_fraction': 0.8401200642032264, 'bagging_freq': 0}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:42:27,979] Trial 39 finished with value: 0.792340870449463 and parameters: {'n_estimators': 563, 'num_leaves': 104, 'max_depth': 3, 'learning_rate': 0.13698240376639795, 'min_child_samples': 62, 'reg_alpha': 1.1248957973079965, 'reg_lambda': 1.37122964957351, 'feature_fraction': 0.5725438295591173, 'bagging_fraction': 0.5913986792351238, 'bagging_freq': 4}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:43:01,447] Trial 40 finished with value: 0.7845024692621736 and parameters: {'n_estimators': 298, 'num_leaves': 59, 'max_depth': 10, 'learning_rate': 0.08949234794156202, 'min_child_samples': 89, 'reg_alpha': 1.750973756145214, 'reg_lambda': 1.1129132221124478, 'feature_fraction': 0.64466269661332, 'bagging_fraction': 0.6234873022059475, 'bagging_freq': 8}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:44:33,980] Trial 41 finished with value: 0.7797376516336041 and parameters: {'n_estimators': 732, 'num_leaves': 67, 'max_depth': 7, 'learning_rate': 0.10918139941181021, 'min_child_samples': 60, 'reg_alpha': 1.9989419903336336, 'reg_lambda': 1.358504122965634, 'feature_fraction': 0.6787702139026648, 'bagging_fraction': 0.5983726491987682, 'bagging_freq': 7}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:45:50,341] Trial 42 finished with value: 0.777840153190557 and parameters: {'n_estimators': 683, 'num_leaves': 63, 'max_depth': 7, 'learning_rate': 0.10980023014413379, 'min_child_samples': 70, 'reg_alpha': 1.8697842964806768, 'reg_lambda': 1.3111283981181816, 'feature_fraction': 0.6841217782438633, 'bagging_fraction': 0.7063846554355981, 'bagging_freq': 6}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:46:26,306] Trial 43 finished with value: 0.8045880622656182 and parameters: {'n_estimators': 740, 'num_leaves': 24, 'max_depth': 8, 'learning_rate': 0.01154690629632985, 'min_child_samples': 57, 'reg_alpha': 1.6233576923924629, 'reg_lambda': 1.2088039340394154, 'feature_fraction': 0.7265777097817114, 'bagging_fraction': 0.6503051898453494, 'bagging_freq': 7}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:46:51,527] Trial 44 finished with value: 0.7939921188470246 and parameters: {'n_estimators': 355, 'num_leaves': 46, 'max_depth': 6, 'learning_rate': 0.07294056301759463, 'min_child_samples': 46, 'reg_alpha': 1.871321902371189, 'reg_lambda': 1.644398938206317, 'feature_fraction': 0.6258417826781828, 'bagging_fraction': 0.5368324735055879, 'bagging_freq': 9}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:47:24,978] Trial 45 finished with value: 0.7687352436321926 and parameters: {'n_estimators': 587, 'num_leaves': 83, 'max_depth': 7, 'learning_rate': 0.16138517838005867, 'min_child_samples': 54, 'reg_alpha': 1.3068437479089083, 'reg_lambda': 1.4609967629535903, 'feature_fraction': 0.7452454343541355, 'bagging_fraction': 0.6238625039788025, 'bagging_freq': 8}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:47:40,709] Trial 46 finished with value: 0.4581336635563701 and parameters: {'n_estimators': 263, 'num_leaves': 128, 'max_depth': 9, 'learning_rate': 0.14438879529428378, 'min_child_samples': 75, 'reg_alpha': 0.8911026500536009, 'reg_lambda': 0.9532039247527477, 'feature_fraction': 0.6852972511019793, 'bagging_fraction': 0.5731135659364582, 'bagging_freq': 2}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:48:00,379] Trial 47 finished with value: 0.8001062934914238 and parameters: {'n_estimators': 681, 'num_leaves': 146, 'max_depth': 3, 'learning_rate': 0.10791002162758453, 'min_child_samples': 60, 'reg_alpha': 1.4451273916214968, 'reg_lambda': 1.8759189978083937, 'feature_fraction': 0.6579648497673366, 'bagging_fraction': 0.6864792555471557, 'bagging_freq': 5}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:48:34,410] Trial 48 finished with value: 0.7785669493886803 and parameters: {'n_estimators': 422, 'num_leaves': 180, 'max_depth': 12, 'learning_rate': 0.07888926064706878, 'min_child_samples': 63, 'reg_alpha': 1.030068280268209, 'reg_lambda': 1.4972394864342229, 'feature_fraction': 0.5824520405615708, 'bagging_fraction': 0.6433308295836789, 'bagging_freq': 7}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:49:07,384] Trial 49 finished with value: 0.8051056073360094 and parameters: {'n_estimators': 614, 'num_leaves': 24, 'max_depth': 8, 'learning_rate': 0.014340650637896975, 'min_child_samples': 90, 'reg_alpha': 1.7543488447682263, 'reg_lambda': 1.5675473281748125, 'feature_fraction': 0.5560989623693416, 'bagging_fraction': 0.5422089885192757, 'bagging_freq': 1}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:49:35,846] Trial 50 finished with value: 0.7871021129134775 and parameters: {'n_estimators': 798, 'num_leaves': 99, 'max_depth': 5, 'learning_rate': 0.08818238958317329, 'min_child_samples': 32, 'reg_alpha': 1.152599767646279, 'reg_lambda': 1.3495328231818915, 'feature_fraction': 0.5256658220665718, 'bagging_fraction': 0.6132372010809939, 'bagging_freq': 3}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:49:44,902] Trial 51 finished with value: 0.8090561779638601 and parameters: {'n_estimators': 223, 'num_leaves': 225, 'max_depth': 4, 'learning_rate': 0.019962951281369445, 'min_child_samples': 25, 'reg_alpha': 0.5288218471080884, 'reg_lambda': 0.03931553612852921, 'feature_fraction': 0.770217848942191, 'bagging_fraction': 0.6626865154686529, 'bagging_freq': 3}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:49:50,077] Trial 52 finished with value: 0.8117620049140757 and parameters: {'n_estimators': 145, 'num_leaves': 231, 'max_depth': 3, 'learning_rate': 0.02950589313582916, 'min_child_samples': 14, 'reg_alpha': 0.2925234189232802, 'reg_lambda': 0.17993419243679198, 'feature_fraction': 0.6976951564579684, 'bagging_fraction': 0.7282095054340636, 'bagging_freq': 2}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:49:56,356] Trial 53 finished with value: 0.8118956255025171 and parameters: {'n_estimators': 172, 'num_leaves': 253, 'max_depth': 3, 'learning_rate': 0.02860553834530273, 'min_child_samples': 14, 'reg_alpha': 0.8263123764256045, 'reg_lambda': 0.40120380751407425, 'feature_fraction': 0.7058465574267294, 'bagging_fraction': 0.7306941900993317, 'bagging_freq': 2}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:50:05,686] Trial 54 finished with value: 0.810198673509326 and parameters: {'n_estimators': 294, 'num_leaves': 187, 'max_depth': 3, 'learning_rate': 0.03352073359480061, 'min_child_samples': 7, 'reg_alpha': 1.3436905279973341, 'reg_lambda': 0.4492672843072253, 'feature_fraction': 0.6463084221976122, 'bagging_fraction': 0.7630789933081121, 'bagging_freq': 6}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:50:16,538] Trial 55 finished with value: 0.8088773731401409 and parameters: {'n_estimators': 191, 'num_leaves': 250, 'max_depth': 4, 'learning_rate': 0.02439281771296884, 'min_child_samples': 10, 'reg_alpha': 0.7425674099041532, 'reg_lambda': 0.5230041900576775, 'feature_fraction': 0.5995127329063621, 'bagging_fraction': 0.7940610504472391, 'bagging_freq': 0}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:50:50,635] Trial 56 finished with value: 0.8081447074664884 and parameters: {'n_estimators': 471, 'num_leaves': 51, 'max_depth': 3, 'learning_rate': 0.17730695308212613, 'min_child_samples': 18, 'reg_alpha': 1.014143589882976, 'reg_lambda': 0.7434364791456879, 'feature_fraction': 0.9840692607965609, 'bagging_fraction': 0.7188071018024584, 'bagging_freq': 1}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:51:12,247] Trial 57 finished with value: 0.8081202331721713 and parameters: {'n_estimators': 514, 'num_leaves': 67, 'max_depth': 4, 'learning_rate': 0.01700574461263419, 'min_child_samples': 70, 'reg_alpha': 0.9106043610099787, 'reg_lambda': 1.2035314806504611, 'feature_fraction': 0.7481791020792588, 'bagging_fraction': 0.7460051777057383, 'bagging_freq': 2}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:51:33,416] Trial 58 finished with value: 0.7870884459971422 and parameters: {'n_estimators': 230, 'num_leaves': 106, 'max_depth': 11, 'learning_rate': 0.04156002757296151, 'min_child_samples': 12, 'reg_alpha': 1.244591239579656, 'reg_lambda': 1.6950702488555036, 'feature_fraction': 0.7177516262989891, 'bagging_fraction': 0.6362321765460478, 'bagging_freq': 1}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:51:50,924] Trial 59 finished with value: 0.8328609324764472 and parameters: {'n_estimators': 376, 'num_leaves': 84, 'max_depth': 3, 'learning_rate': 0.13219314925174191, 'min_child_samples': 5, 'reg_alpha': 0.82453050020321, 'reg_lambda': 0.8471182666063769, 'feature_fraction': 0.662185443028745, 'bagging_fraction': 0.6909219060353683, 'bagging_freq': 5}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:52:04,924] Trial 60 finished with value: 0.8311447303566355 and parameters: {'n_estimators': 359, 'num_leaves': 87, 'max_depth': 3, 'learning_rate': 0.1326490772568109, 'min_child_samples': 6, 'reg_alpha': 0.7844365171982051, 'reg_lambda': 0.6495653340011516, 'feature_fraction': 0.6603553928066711, 'bagging_fraction': 0.6935135569157603, 'bagging_freq': 4}. Best is trial 21 with value: 0.8365864054306655.
# [I 2026-05-20 21:52:15,974] Trial 61 finished with value: 0.8285666405636131 and parameters: {'n_estimators': 352, 'num_leaves': 87, 'max_depth': 3, 'learning_rate': 0.13373739197620138, 'min_child_samples': 5, 'reg_alpha': 0.77606933910261, 'reg_lambda': 0.32696757420097444, 'feature_fraction': 0.6632174303878688, 'bagging_fraction': 0.6918324453851619, 'bagging_freq': 5}. Best is trial 21 with value: 0.8365864054306655.
#       [patience] no improvement for 40 trials -> stopping
#     Optuna done: 62 trials
#     Best AUC: 0.8366  (trial 21)
#     Best params: {'n_estimators': 323, 'num_leaves': 88, 'max_depth': 3, 'learning_rate': 0.11103214336439576, 'min_child_samples': 58, 'reg_alpha': 1.305359289514985, 'reg_lambda': 1.5867049502182788, 'feature_fraction': 0.6733645826655641, 'bagging_fraction': 0.6481317060028783, 'bagging_freq': 2}
#     Delta vs baseline: +0.0342

# %% [markdown]
# ## CELL OPTUNA-FINAL -- refit + save OOF/model/JSON/registry with `mean_folds_auc`

# %%
# @title CELL OPTUNA-FINAL: persist tuned models, OOF, registry logs per parquet
import json as _json
for pq_id, info in NB11_OPTUNA_RESULTS.items():
    manifest_key = info['manifest_key']
    prep = NB11_PREP[pq_id]
    X_pq, y_pq, groups_pq = prep['X'], prep['y'], prep['groups']
    building_ids_pq, clean_cols_pq = prep['building_ids'], prep['clean_cols']

    print(f"\n  === refit [{pq_id}] {manifest_key} ===")
    best_params_full = {**FIXED_LGBM, **info['best_params']}
    best_clf = LGBMClassifier(**best_params_full)

    gkf = GroupKFold(n_splits=min(N_FOLDS, len(np.unique(groups_pq))))
    y_proba_oof = np.full(len(y_pq), np.nan)
    fold_id = np.full(len(y_pq), -1, dtype=int)
    fold_aucs = []
    for fi, (tr, te) in enumerate(gkf.split(X_pq, y_pq, groups_pq)):
        clf_c = clone(best_clf)
        clf_c.fit(X_pq[tr], y_pq[tr])
        proba = clf_c.predict_proba(X_pq[te])[:, 1]
        y_proba_oof[te] = proba
        fold_id[te] = fi
        if len(np.unique(y_pq[te])) > 1:
            fold_aucs.append(roc_auc_score(y_pq[te], proba))
    valid = ~np.isnan(y_proba_oof)
    tuned_auc = roc_auc_score(y_pq[valid], y_proba_oof[valid])
    mean_folds_auc = float(np.mean(fold_aucs))
    std_folds_auc = float(np.std(fold_aucs))
    drift = tuned_auc - info['tuned_auc']
    print(f"    Tuned OOF AUC (refit): {tuned_auc:.4f}  (study.best={info['tuned_auc']:.4f})  "
          f"delta={drift:+.4f}")
    print(f"    mean(folds)={mean_folds_auc:.4f}  std(folds)={std_folds_auc:.4f}")
    if abs(drift) >= 5e-3:
        print(f"    WARNING: large OOF drift {drift:+.4f} between search and refit "
              f"(LightGBM multi-thread nondeterminism); proceeding with refit value")

    info['fold_aucs'] = fold_aucs
    info['tuned_auc_refit'] = tuned_auc
    info['mean_folds_auc'] = mean_folds_auc
    info['std_folds_auc'] = std_folds_auc

    tuned_res = {
        'y_true':       y_pq[valid].astype(int),
        'y_proba':      y_proba_oof[valid],
        'groups':       groups_pq[valid],
        'building_id':  np.asarray(building_ids_pq)[valid],
        'fold_id':      fold_id[valid],
        'experiment':   f'C_{pq_id}_{manifest_key}__OPTUNA',
        'auc_groupkfold': tuned_auc,
        'fold_aucs':    fold_aucs,
    }
    model_id = f"{NB11_NAME}__{manifest_key}__LightGBM-MIA-Optuna"
    save_oof_from_result(tuned_res, model_id=model_id, oof_dir=NB11_OUT_DIR / "oof",
                         variant_id=info['study_tag'], is_final=True)

    best_clf_full = LGBMClassifier(**best_params_full).fit(X_pq, y_pq)
    model_path = NB11_OUT_DIR / "models" / f"{info['study_tag']}__best.joblib"
    joblib.dump({'model': best_clf_full, 'feature_cols': clean_cols_pq,
                 'params': best_params_full, 'tuned_auc': tuned_auc,
                 'mean_folds_auc': mean_folds_auc, 'std_folds_auc': std_folds_auc,
                 'baseline_auc': info['baseline_auc'],
                 'study_tag': info['study_tag']}, model_path)
    print(f"    Saved model: {model_path}")

    bp_path = NB11_OUT_DIR / "best_params" / f"{info['study_tag']}__best.json"
    with open(bp_path, 'w') as f:
        _json.dump({
            'study_tag': info['study_tag'], 'notebook': NB11_NAME,
            'manifest_key': manifest_key, 'parquet_id': pq_id,
            'classifier': 'LightGBM-MIA',
            'best_params': info['best_params'], 'best_params_full': best_params_full,
            'tuned_auc': tuned_auc, 'baseline_auc': info['baseline_auc'],
            'delta_auc': tuned_auc - info['baseline_auc'],
            'mean_folds_auc': mean_folds_auc, 'std_folds_auc': std_folds_auc,
            'fold_aucs': fold_aucs,
            'n_trials_done': info['n_trials_done'],
            'n_trials_requested': info['n_trials_requested'],
            'patience': OPTUNA_PATIENCE,
            'n_features': len(clean_cols_pq), 'n_buildings': int(valid.sum()),
            'n_cities': int(len(np.unique(groups_pq))),
        }, f, indent=2, default=str)
    print(f"    Saved best_params: {bp_path}")

    registry.log_experiment(
        cell_id=NB11_CELL_ID,
        experiment_name=tuned_res['experiment'],
        parquet_name=f'bda_{manifest_key}_v2',
        feature_set_name='manifest_default_minus_leakage',
        classifier_name='LightGBM-MIA-Optuna',
        classifier_params=best_params_full,
        feature_cols=clean_cols_pq,
        cv_method='GroupKFold', n_folds=N_FOLDS,
        imputation='native_nan',
        y_true=tuned_res['y_true'], y_proba=tuned_res['y_proba'],
        groups=tuned_res['groups'],
        note=(f"NB11 Optuna tuned LightGBM-MIA on {manifest_key}; "
              f"budget={info['n_trials_requested']}, trials_done={info['n_trials_done']}, "
              f"patience={OPTUNA_PATIENCE}; "
              f"pooled_auc={tuned_auc:.4f} mean_folds_auc={mean_folds_auc:.4f} "
              f"std_folds_auc={std_folds_auc:.4f} fold_aucs={fold_aucs}"),
        tags=['nb11_optuna', 'lightgbm_mia', pq_id, manifest_key],
    )
# Out:
#   === refit [A13] prepost_single_card ===
#     Tuned OOF AUC (refit): 0.8130  (study.best=0.8123)  delta=+0.0007
#     mean(folds)=0.6887  std(folds)=0.0735
#     saved oof -> oof_NB11c_A13_A14_A19_card_changes__prepost_single_card__LightGBM-MIA-Optuna__20260520_203726_115af1.parquet  TP=5657 FN=1675 FP=137435 TN=453828
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11c_A13_A14_A19_card_changes__prepost_single_card__LightGBM-MIA__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11c_A13_A14_A19_card_changes__prepost_single_card__LightGBM-MIA__best.json
#   REG: C_A13_prepost_single_card__OPTUNA             AUC=0.8130 F1=0.0752 n=598595 feat=12 cities=21 [NB08c_v2/cell_c5]
#
#   === refit [A14] coh_drop ===
#     Tuned OOF AUC (refit): 0.8005  (study.best=0.8187)  delta=-0.0182
#     mean(folds)=0.5372  std(folds)=0.0467
#     WARNING: large OOF drift -0.0182 between search and refit (LightGBM multi-thread nondeterminism); proceeding with refit value
#     saved oof -> oof_NB11c_A13_A14_A19_card_changes__coh_drop__LightGBM-MIA-Optuna__20260520_203726_115af1.parquet  TP=5025 FN=1876 FP=126566 TN=451519
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11c_A13_A14_A19_card_changes__coh_drop__LightGBM-MIA__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11c_A13_A14_A19_card_changes__coh_drop__LightGBM-MIA__best.json
#   REG: C_A14_coh_drop__OPTUNA                        AUC=0.8005 F1=0.0726 n=584986 feat=10 cities=20 [NB08c_v2/cell_c5]
#
#   === refit [A19] card_drop ===
#     Tuned OOF AUC (refit): 0.8037  (study.best=0.8366)  delta=-0.0328
#     mean(folds)=0.6154  std(folds)=0.1318
#     WARNING: large OOF drift -0.0328 between search and refit (LightGBM multi-thread nondeterminism); proceeding with refit value
#     saved oof -> oof_NB11c_A13_A14_A19_card_changes__card_drop__LightGBM-MIA-Optuna__20260520_203726_115af1.parquet  TP=5588 FN=1744 FP=158891 TN=432372
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11c_A13_A14_A19_card_changes__card_drop__LightGBM-MIA__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11c_A13_A14_A19_card_changes__card_drop__LightGBM-MIA__best.json
#   REG: C_A19_card_drop__OPTUNA                       AUC=0.8037 F1=0.0650 n=598595 feat=10 cities=21 [NB08c_v2/cell_c5]

# %% [markdown]
# ## CELL SUMMARY -- multi-row CSV with `mean_folds_auc`/`std_folds_auc` + per-fold AUC print

# %%
# @title CELL SUMMARY
rows = []
for pq_id, info in NB11_OPTUNA_RESULTS.items():
    prep = NB11_PREP[pq_id]
    rows.append({
        'notebook': NB11_NAME,
        'parquet_id': pq_id,
        'manifest_key': info['manifest_key'],
        'classifier': 'LightGBM-MIA',
        'baseline_auc': info['baseline_auc'],
        'baseline_auc_expected': prep['expected_auc'],
        'tuned_auc': info['tuned_auc_refit'],
        'delta_auc': info['tuned_auc_refit'] - info['baseline_auc'],
        'mean_folds_auc': info['mean_folds_auc'],
        'std_folds_auc': info['std_folds_auc'],
        'n_trials_requested': info['n_trials_requested'],
        'n_trials_done': info['n_trials_done'],
        'early_stopped': info['n_trials_done'] < info['n_trials_requested'],
        'patience': OPTUNA_PATIENCE,
        'n_features': len(prep['clean_cols']),
        'n_buildings': len(prep['y']),
        'n_cities': int(len(np.unique(prep['groups']))),
        'study_tag': info['study_tag'],
    })
df_summary = pd.DataFrame(rows).sort_values('tuned_auc', ascending=False)
summary_path = NB11_OUT_DIR / "summary" / f"{NB11_NAME}_summary.csv"
df_summary.to_csv(summary_path, index=False)
print(df_summary.to_string(index=False))
print(f"\n  Saved summary: {summary_path}")

print("\n  Per-fold AUC (tuned models):")
for pq_id, info in NB11_OPTUNA_RESULTS.items():
    fold_aucs = info['fold_aucs']
    print(f"    [{pq_id}] {info['manifest_key']:36s} pooled={info['tuned_auc_refit']:.4f}  "
          f"mean(folds)={info['mean_folds_auc']:.4f}  std={info['std_folds_auc']:.4f}  "
          f"folds={[f'{a:.3f}' for a in fold_aucs]}")

print(f"\n  {NB11_NAME} complete.")
# Out:
#                       notebook parquet_id        manifest_key   classifier  baseline_auc  baseline_auc_expected  tuned_auc  delta_auc  mean_folds_auc  std_folds_auc  n_trials_requested  n_trials_done  early_stopped  patience  n_features  n_buildings  n_cities                                                         study_tag
# NB11c_A13_A14_A19_card_changes        A13 prepost_single_card LightGBM-MIA      0.802362                  0.802   0.812950   0.010588        0.688664       0.073516                 200             45           True        40          12       598595        21 NB11c_A13_A14_A19_card_changes__prepost_single_card__LightGBM-MIA
# NB11c_A13_A14_A19_card_changes        A19           card_drop LightGBM-MIA      0.802353                  0.802   0.803741   0.001388        0.615433       0.131835                 200             62           True        40          10       598595        21           NB11c_A13_A14_A19_card_changes__card_drop__LightGBM-MIA
# NB11c_A13_A14_A19_card_changes        A14            coh_drop LightGBM-MIA      0.807481                  0.807   0.800492  -0.006990        0.537225       0.046682                 200             49           True        40          10       584986        20            NB11c_A13_A14_A19_card_changes__coh_drop__LightGBM-MIA
#
#   Saved summary: /content/drive_f/masterthesis/data/outputs/NB11_V2/summary/NB11c_A13_A14_A19_card_changes_summary.csv
#
#   Per-fold AUC (tuned models):
#     [A13] prepost_single_card                  pooled=0.8130  mean(folds)=0.6887  std=0.0735  folds=['0.724', '0.589', '0.739', '0.615', '0.777']
#     [A14] coh_drop                             pooled=0.8005  mean(folds)=0.5372  std=0.0467  folds=['0.500', '0.500', '0.509', '0.621', '0.556']
#     [A19] card_drop                            pooled=0.8037  mean(folds)=0.6154  std=0.1318  folds=['0.448', '0.500', '0.712', '0.612', '0.806']
#
#   NB11c_A13_A14_A19_card_changes complete.
