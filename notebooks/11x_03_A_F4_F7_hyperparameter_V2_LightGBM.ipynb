# %% [markdown]
# # NB11a_F4_F7 -- LightGBM-MIA tuning (NB08c_v2 v8 prep chain)
#
# > Copyright (C) 2024-2026 Marco Heinzen - SPDX-License-Identifier: AGPL-3.0-or-later
# > Part of the Master Thesis "Building Damage Assessment with Multimodal Satellite Time Series and Machine Learning in the Russia-Ukraine War 2022-2026"
# > Code hosted at https://github.com/marcoheinzen/bda
# > Parts of this code were written or improved with the assistance of Claude (Anthropic); all other code, and the concept, research, architecture, design, execution, testing and validation throughout, are the author's work.
#
#
# | pq_id | manifest_key | Baseline AUC |
# |---|---|---|
# | F4 | `fusion_ms_cohdrop` | 0.813 |
# | F7 | `fusion_composite_cohdrop` | 0.813 |
#
# **Source experiment:** NB08c_v2 v8 (verbatim CONFIG, S0, OOF helpers, LightGBM-MIA classifier, audit_parquet).
#
# **Strategy:** replicate source experiment cell verbatim per parquet; assert baseline AUC within +/- 0.005; run Optuna with PATIENCE=40, RESUME-IF-EXISTS via SQLite; refit best params; save OOF + joblib + JSON + registry entry with `mean_folds_auc`, `std_folds_auc`, `fold_aucs` recorded (publishable cross-city metric).
#
# **Output dir:** `OUTPUTS_DIR / "NB11_V2"` (shared across all NB11 notebooks).

# %% [markdown]
# ## CELL 1 -- CONFIG (verbatim NB08c_v2 v8 CELL 1) + NB11 additions

# %%
# @title CELL 1: NB08c CONFIG
TIER_SELECTION = [0,1,2]
CITY_FILTER = None
CITY_SELECTION = None
REQUIRE_UNOSAT = True
RANDOM_STATE = 42
N_FOLDS = 5

USE_V2 = True

# === NB11 ADDITIONS ===
NB11_NAME = 'NB11a_F4_F7'
NB11_CELL_ID = 'cell_c7'                # source registry cell_id, preserved

# Per-parquet config: (pq_id, manifest_key, baseline_auc_expected)
NB11_PARQUETS = [
    ('F4', 'fusion_ms_cohdrop', 0.813),
    ('F7', 'fusion_composite_cohdrop', 0.813),
]
NB11_BASELINE_TOL = 0.005

OPTUNA_BASE_BUDGET = 200
OPTUNA_LOW_AUC_BUDGET = 100
OPTUNA_LOW_AUC_CUTOFF = 0.70
OPTUNA_PATIENCE = 40                       # raised from 20 -- TPE needs room to explore beyond baseline
OPTUNA_DIRECTION = 'maximize'
OPTUNA_SEED = 42

# === THREAD BUDGET (avoid oversubscription when running parallel notebooks) ===
import os as _os, multiprocessing as _mp
NB11_PARALLEL_NOTEBOOKS = 1                                  # set to N if running N notebooks concurrently
NB11_CORES_TOTAL = _mp.cpu_count()
NB11_THREADS_PER_NB = max(1, NB11_CORES_TOTAL // NB11_PARALLEL_NOTEBOOKS)
# Env vars must be set BEFORE numpy/BLAS imports (i.e. before CELL 2 global_setup).
# Run with a fresh kernel for these to take effect at numpy import time.
_os.environ['OMP_NUM_THREADS']      = str(NB11_THREADS_PER_NB)
_os.environ['MKL_NUM_THREADS']      = str(NB11_THREADS_PER_NB)
_os.environ['OPENBLAS_NUM_THREADS'] = str(NB11_THREADS_PER_NB)
_os.environ['NUMEXPR_NUM_THREADS']  = str(NB11_THREADS_PER_NB)
_os.environ['BLIS_NUM_THREADS']     = str(NB11_THREADS_PER_NB)
print(f"[threads] cores={NB11_CORES_TOTAL}  parallel_nbs={NB11_PARALLEL_NOTEBOOKS}  "
      f"threads_per_nb={NB11_THREADS_PER_NB}")
# Out:
# [threads] cores=24  parallel_nbs=1  threads_per_nb=24

# %% [markdown]
# ## CELL 1b -- enforce thread cap dynamically (BLAS/OpenMP)
#
# Belt-and-suspenders to the env vars: if numpy/BLAS were imported on an earlier kernel state with no env-var limit, `threadpoolctl` clamps the active pools NOW without a kernel restart. Without this, LightGBM/XGBoost's OpenMP and sklearn's BLAS still spawn 24 threads each.
#
# Set `NB11_PARALLEL_NOTEBOOKS` in CELL 1 to match the number of NB11 notebooks you'll run concurrently:
# - 1 notebook  -> 24 threads per nb (no contention)
# - 2 notebooks -> 12 threads each
# - 3 notebooks ->  8 threads each
# - 4 notebooks ->  6 threads each

# %%
# @title CELL 1b: dynamic thread cap via threadpoolctl
try:
    from threadpoolctl import threadpool_limits, threadpool_info
    _tp_limit = threadpool_limits(limits=NB11_THREADS_PER_NB)
    print(f"[threadpoolctl] limited BLAS/OpenMP pools to {NB11_THREADS_PER_NB} threads")
    for info in threadpool_info():
        print(f"  {info.get('prefix'):20s} ({info.get('user_api')})  "
              f"current_threads={info.get('num_threads')}  max={info.get('num_threads')}")
except ImportError:
    print("[threadpoolctl] NOT INSTALLED -- run: pip install threadpoolctl")
    print("                env vars only; may not affect pools loaded before this cell.")
# Out:
# [threadpoolctl] limited BLAS/OpenMP pools to 24 threads

# %% [markdown]
# ## CELL 2 -- LOAD GLOBAL SETUP (verbatim NB08c_v2 v8)

# %%
# @title CELL 2: LOAD GLOBAL SETUP
import platform, os, json
if platform.system() == "Windows":
    _setup = r"F:\PROJECTS\masterthesis\gdrive\masterthesis\notebooks\global_setup.py"
elif os.path.exists("/content/drive_f"):
    _setup = "/content/drive_f/masterthesis/notebooks/global_setup.py"
else:
    _setup = "/mnt/f/PROJECTS/masterthesis/gdrive/masterthesis/notebooks/global_setup.py"
with open(_setup) as f:
    exec(f.read())
# Out:
# ======================================================================
# BDA GLOBAL SETUP
# ======================================================================
# Started: 2026-05-17 09:29:28
# Python: 3.12.12
# ======================================================================
#
# [1/7] Directory Structure
# ----------------------------------------------------------------------
# /home/alpineobotics/miniconda3/envs/bda/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
#   GDrive (G:):       /content/drive_f/masterthesis OK
#   GDrive (F:):       /content/drive_f/masterthesis OK
#   Local data (G:):   /content/masterthesis_local/data OK
#   Data stack (F:):   /mnt/f/PROJECTS/masterthesis/data_stack OK
#
#   TIER_SELECTION: [0, 1, 2]
#   CITY_SELECTION: None (tier filter)
#   REQUIRE_UNOSAT: True
#   CITIES_TO_PROCESS: 21 cities
#
# [2/7] Credentials
# ----------------------------------------------------------------------
#   Copernicus: inf***
#   OpenTopography: OK
#   Earthdata: marcoheinzen
#
# [3/7] Python Packages
# ----------------------------------------------------------------------
# <string>:564: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   Already installed: 23
#   Newly installed:   0
#   Failed:            0
#
# [4/7] Global Imports & Configuration
# ----------------------------------------------------------------------
#   All imports loaded
#
# [5/7] Processing Config & SNAP
# ----------------------------------------------------------------------
#   GPT: Usage:
#   Temporal baseline: 10-24 days
#   Wavelength: 0.0555
#
# [6/7] GPU Status
# ----------------------------------------------------------------------
#   CUDA available: NVIDIA GeForce RTX 2070 SUPER
#     CUDA version: 12.8
#
# [7/7] Disk Space
# ----------------------------------------------------------------------
#   GDrive (G:)     908.1/7452.0 GB (6543.9 GB free)
#   GDrive (F:)     1403.7/3726.0 GB (2322.3 GB free)
#   Local data      11564.7/14901.9 GB (3337.2 GB free)
#   Data stack      1403.7/3726.0 GB (2322.3 GB free)
#   WSL ext4        69.1/1006.9 GB (886.5 GB free)
#
# ======================================================================
# GLOBAL SETUP COMPLETE
# ======================================================================
#   Torch device: cuda
#   Cities: 21, CITY=Avdiivka
#   Functions: load_aoi(), load_aoi_gdf(), load_aoi_bbox(), load_buildings()
#   Functions: set_city_paths(), resolve_cities(), load_tracker(), load_dietrich_tracker()
#   Completed: 2026-05-17 09:30:13
# ======================================================================

# %% [markdown]
# ## CELL S0 -- MANIFEST + BUILDINGS + SHARED HELPERS (verbatim NB08c_v2 v8)

# %%
# @title CELL S0: LOAD MANIFEST + BUILDINGS + SHARED HELPERS
import sys, importlib, re, gc, time
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import GroupKFold
from sklearn.metrics import (roc_auc_score, f1_score, precision_score,
                             recall_score)
from sklearn.base import clone
import warnings
warnings.filterwarnings("ignore")

print("=" * 70)
print("CELL S0: NB08c v2 - LOAD MANIFEST + BUILDINGS + SHARED HELPERS")
print("=" * 70)

if str(NOTEBOOKS_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOKS_DIR))

import metadata_filter
importlib.reload(metadata_filter)
from metadata_filter import (
    ID_COLS, LABEL_COLS, META_COLS_SET,
    is_metadata, is_non_feature,
    select_feature_columns, build_role_overrides,
)

# --- load v2 manifest -------------------------------------------------
MANIFEST_V2_PATH = DATASET_ROOT_V2 / 'parquet_manifest.json'
if not MANIFEST_V2_PATH.exists():
    raise FileNotFoundError(f"V2 manifest not found: {MANIFEST_V2_PATH}")
with open(MANIFEST_V2_PATH) as _f:
    MANIFEST = json.load(_f)
print(f"  Manifest: {MANIFEST_V2_PATH}")
print(f"  Version: {MANIFEST['version']}  Created: {MANIFEST['created']}")
print(f"  Parquets in manifest: {len(MANIFEST['parquets'])}")

# --- load building metadata (v2 path) --------------------------------
_tiers = TIER_SELECTION if isinstance(TIER_SELECTION, list) else [0, 1, 2]
_bldg_pattern = str(DATASET_ROOT_V2 / 'bda_buildings_t{tier}.parquet')
df_bldg = load_tier_parquets(_bldg_pattern, _tiers)
CITIES_TO_PROCESS, _battle_dates = resolve_cities(
    tier_selection=TIER_SELECTION,
    city_selection=[CITY_FILTER] if isinstance(CITY_FILTER, str) else CITY_FILTER,
    require_unosat=REQUIRE_UNOSAT,
)
df_bldg = df_bldg[df_bldg['city'].isin(CITIES_TO_PROCESS)].copy()
df_bldg = df_bldg[df_bldg['damage_binary'] >= 0].copy()
print(f"  Cities: {len(CITIES_TO_PROCESS)}")
print(f"  Buildings: {len(df_bldg)} (damaged={int((df_bldg['damage_binary']==1).sum())}, "
      f"undamaged={int((df_bldg['damage_binary']==0).sum())})")

TARGET_COL = 'damage_binary'
AUDIT_LOG = {}

# ---- NB12 overlap-analysis: canonical OOF predictions schema ----
import hashlib as _hashlib, datetime as _dt
EXPERIMENT_ID = _dt.datetime.now().strftime('%Y%m%d_%H%M%S') + '_' + _hashlib.md5(
    f'nb08c_{TIER_SELECTION}_{REQUIRE_UNOSAT}'.encode()).hexdigest()[:6]
print(f"  EXPERIMENT_ID: {EXPERIMENT_ID}")

def save_oof_from_result(res, model_id, oof_dir, variant_id='',
                         is_final=False, threshold=0.5):
    '''Canonical OOF schema: building_id, city, fold_id, y_true, y_proba, y_pred,
       cm_class, model_id, experiment_id, variant_id, is_final.'''
    if res is None:
        return None
    needed = ('y_true', 'y_proba', 'groups', 'building_id', 'fold_id')
    if not all(k in res for k in needed):
        print(f"    [save_oof] skipped {model_id}: missing keys (need {needed})")
        return None
    y_proba = np.asarray(res['y_proba'])
    yt = np.asarray(res['y_true']).astype(int)
    fold = np.asarray(res['fold_id']).astype(int)
    bid = np.asarray(res['building_id'])
    cty = np.asarray(res['groups'])
    yp = (y_proba >= threshold).astype(int)
    cm_class = np.where(yt == 1,
                        np.where(yp == 1, 'TP', 'FN'),
                        np.where(yp == 1, 'FP', 'TN'))
    oof_df = pd.DataFrame({
        'building_id':   bid,
        'city':          cty,
        'fold_id':       fold,
        'y_true':        yt,
        'y_proba':       y_proba.astype(float),
        'y_pred':        yp,
        'cm_class':      cm_class,
        'model_id':      model_id,
        'experiment_id': EXPERIMENT_ID,
        'variant_id':    variant_id,
        'is_final':      bool(is_final),
    })
    oof_dir = Path(oof_dir)
    oof_dir.mkdir(parents=True, exist_ok=True)
    out = oof_dir / f'oof_{model_id}__{EXPERIMENT_ID}.parquet'
    oof_df.to_parquet(out, index=False)
    n_tp = int((cm_class == 'TP').sum()); n_fn = int((cm_class == 'FN').sum())
    n_fp = int((cm_class == 'FP').sum()); n_tn = int((cm_class == 'TN').sum())
    print(f"    saved oof -> {out.name}  TP={n_tp} FN={n_fn} FP={n_fp} TN={n_tn}")
    return out

# --- leakage filter ---------------------------------------------------
LEAKAGE_EXCLUDE_PATTERNS = [
    r's1__coh__scenes_observed',
    r's1__vv__scenes_observed',
    r's2__scenes_observed',
    r's2__lu__scenes_observed',
    r's2__obs_count__',
    r's2__qa__cloud_freq__',
    r's2__visibility__cloud__freq',
    r'was_observed_',
]
# -- leaky filter (legacy NB08c behavior, keeps was_observed_ flags; used by C10 for delta comparison) --
LEAKAGE_LEAKY_PATTERNS = [
    r's1__coh__scenes_observed',
    r's1__vv__scenes_observed',
    r's2__scenes_observed',
    r's2__lu__scenes_observed',
    r's2__obs_count__',
    r's2__qa__cloud_freq__',
    r's2__visibility__cloud__freq',
]
_LEAKAGE_LEAKY_RE = [re.compile(p) for p in LEAKAGE_LEAKY_PATTERNS]

def drop_leakage_leaky(cols):
    '''LEGACY filter that keeps was_observed_* flags. For C10 delta only. Do not use elsewhere.'''
    return [c for c in cols if not any(rx.search(c) for rx in _LEAKAGE_LEAKY_RE)]
_LEAKAGE_RE = [re.compile(p) for p in LEAKAGE_EXCLUDE_PATTERNS]

def drop_leakage(cols):
    return [c for c in cols if not any(rx.search(c) for rx in _LEAKAGE_RE)]

def _has_count_stat(c):
    parts = c.split('__')
    if len(parts) < 4:
        return False
    return parts[3].split('_')[0] == 'count'

# --- v2 manifest-driven loader (copy of NB09a v2 signature) ----------
def load_v2(manifest_key, tiers=None, columns=None, sample_frac=None):
    '''Load a v2 parquet by manifest key, merge with buildings, return df.'''
    if manifest_key not in MANIFEST['parquets']:
        raise KeyError(f"Manifest key not found: {manifest_key}")
    info = MANIFEST['parquets'][manifest_key]
    fname_tmpl = Path(info['pattern']).name
    tiers = tiers if tiers is not None else _tiers

    frames = []
    for t in tiers:
        pf = DATASET_ROOT_V2 / fname_tmpl.format(tier=t)
        if not pf.exists():
            continue
        if columns is not None:
            join_cols = info.get('join_keys', ['city', 'building_id'])
            read_cols = list(dict.fromkeys(join_cols + list(columns)))
            try:
                df_t = pd.read_parquet(pf, columns=read_cols)
            except Exception:
                df_t = pd.read_parquet(pf)
                keep = [c for c in read_cols if c in df_t.columns]
                df_t = df_t[keep]
        else:
            df_t = pd.read_parquet(pf)
        if sample_frac is not None and 0 < sample_frac < 1:
            df_t = df_t.sample(frac=sample_frac, random_state=RANDOM_STATE)
        frames.append(df_t)
    if not frames:
        raise FileNotFoundError(f"No v2 parquets found for key={manifest_key} tiers={tiers}")
    df = pd.concat(frames, ignore_index=True)
    del frames

    df = df.loc[:, ~df.columns.duplicated()]
    df = df[df['city'].isin(CITIES_TO_PROCESS)].copy()
    if TARGET_COL not in df.columns:
        df = df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['building_id', 'city'], how='inner')
    df = df[df[TARGET_COL] >= 0].copy()
    df = df.loc[:, ~df.columns.duplicated()]
    return df

# --- v8: direction-aware temporal aggregation (matched-filter principle) ---
# Damage at the temporal axis is a sparse-event spike. Per Kay 1998 (Detection
# Theory) and Glaz-Naus-Wallenstein 2001 (Scan Statistics), the rolling extremum
# is the Neyman-Pearson optimal detector for a 1-of-N spike on stationary noise.
# v7 universal mean+std attenuated the spike; v8 dispatches per modality direction.
# Reference: DECISION_Rolling_Block_Accumulators.md Sec 5; DECISION_NB05b_v29 Sec 1.

DIRECTION_BY_MODALITY = {
    # SAR drop signals (damage -> coherence loss, VV backscatter loss on rough->smooth or rubble)
    'coh_vv': 'drop', 'coh_vh': 'drop',
    'vv': 'drop',
    # SAR mixed-sign (volume scattering can go either direction with rubble)
    'vh': 'mixed',
    # MS visible bands -- no clean damage direction (illumination + atmosphere dominate)
    'b02': 'unknown', 'b03': 'unknown', 'b04': 'unknown',
    'b05': 'unknown', 'b07': 'unknown',
    # MS NIR -- vegetation loss after damage drives NIR drop
    'b08': 'drop', 'b8a': 'drop',
    # MS SWIR -- rubble / bare soil exposure drives SWIR rise (Aimaiti 2022)
    'b11': 'rise', 'b12': 'rise',
    # MS derived indices
    'nbr':   'mixed',  # burn / vegetation loss / rubble (sign depends on land cover)
    'ndvi':  'drop',   # vegetation loss
    'savi':  'drop',   # soil-adjusted vegetation
    'bsi':   'rise',   # bare-soil exposure rises with rubble
    'mndwi': 'mixed',  # water -- flood-rise vs drying-drop
    'ndbi':  'drop',   # built-up index drops with built-up loss
    'ndsi':  'mixed',  # snow seasonal noise, no damage direction
    'ibi':   'drop',   # built-up index variant
    'baei':  'drop',   # built-up area extraction index
    'ui':    'drop',   # urban index
}

# Manifest keys whose long parquets are already pixel-temporal-extremized in NB03e R2b.
# For these, mean+std-over-time preserves the per-rolling-window pattern; a second
# temporal extremum would collapse to the full-post-battle accumulators (A14/A19/A20/A21),
# making A23/A24/A25 redundant.
ACCUM_LONG_KEYS = {'rolling_accum_coh', 'rolling_accum_card', 'rolling_accum_ms'}

def _parse_modality_token(col):
    '''Return the modality token (second `__`-separated piece) of a feature column.
       Examples:
         s2__b02__mean              -> b02
         s1__coh_vv__zscore__mean   -> coh_vv
         s1__vv__roll7__min         -> vv
         s2__landuse__urban_frac    -> landuse  (returns 'landuse', falls into 'unknown')
       Returns None if the column has fewer than 2 `__`-separated pieces.'''
    parts = col.split('__')
    if len(parts) < 2:
        return None
    return parts[1].lower()

def _temporal_reductions_for_column(col):
    '''Return the list of pandas agg names to apply over the date axis for `col`,
       chosen by modality direction:
         drop    -> [min, mean, std]
         rise    -> [max, mean, std]
         mixed   -> [min, max, mean, std]
         unknown -> [mean, std]   (legacy v7 fallback for non-mappable columns)
       The `mean` and `std` slots are kept in every direction so v7 features are
       a strict subset of v8 features (additive change, no information lost).'''
    modality = _parse_modality_token(col)
    direction = DIRECTION_BY_MODALITY.get(modality, 'unknown')
    if direction == 'drop':
        return ['min', 'mean', 'std']
    if direction == 'rise':
        return ['max', 'mean', 'std']
    if direction == 'mixed':
        return ['min', 'max', 'mean', 'std']
    return ['mean', 'std']

# --- long-format aggregation (v8: direction-aware temporal collapse) ---------
def aggregate_long_to_wide(df, feat_cols, manifest_key=None):
    '''Collapse a long-format per-scene parquet to per-building summary.

    v8: direction-aware temporal aggregation per matched-filter principle.
    - manifest_key in ACCUM_LONG_KEYS  -> universal mean+std (already extremized in R2b)
    - otherwise                        -> per-column dispatch via _temporal_reductions_for_column

    Backward compatible call: `aggregate_long_to_wide(df, feat_cols)` (manifest_key=None)
    falls through to per-column dispatch with v7-equivalent fallback for unknown columns.
    '''
    feat_cols = [c for c in feat_cols if c in df.columns]
    if not feat_cols:
        return (df.groupby(['city', 'building_id'], sort=False, observed=True)
                  .size().reset_index()[['city', 'building_id']])

    if manifest_key in ACCUM_LONG_KEYS:
        agg_dict = {c: ['mean', 'std'] for c in feat_cols}
    else:
        agg_dict = {c: _temporal_reductions_for_column(c) for c in feat_cols}

    agg = df.groupby(['city', 'building_id'], sort=False, observed=True).agg(agg_dict)
    agg.columns = [f"{a}_{b}" for a, b in agg.columns]
    agg = agg.reset_index()
    return agg

# --- manifest-derived feature set for a given parquet ----------------
def get_parquet_features(manifest_key, df):
    '''Return the cleaned feature column list for a parquet: manifest features,
       intersected with df columns, minus leakage, minus count stats, minus all-NaN.

       Uses metadata_filter.select_feature_columns() so that id/label/metadata
       columns (including any was_observed_* flag, regardless of suffix) are
       excluded centrally rather than by a locally-maintained list.'''
    info = MANIFEST['parquets'][manifest_key]
    raw = [c for c in info.get('feature_columns', []) if c in df.columns]
    if not raw:
        # fallback: metadata_filter picks numeric features, excluding id/label/meta
        # and any was_observed_* via the centralized pattern rule.
        raw = select_feature_columns(df)
    else:
        # manifest-declared features: still scrub in case the manifest lists a
        # column that is actually metadata (defensive, typically a no-op).
        raw = [c for c in raw if not is_non_feature(c)]
    clean = drop_leakage(raw)
    clean = [c for c in clean if not _has_count_stat(c)]
    nan_rate = df[clean].isna().mean() if clean else pd.Series(dtype=float)
    clean = [c for c in clean if nan_rate.get(c, 1.0) < 1.0]
    return clean

# --- LightGBM feature prep (no imputation, native NaN) --------------
def prepare_features_mia(df, feat_cols):
    '''Return X (with NaN preserved), y, groups, building_ids, clean_cols.'''
    if not feat_cols:
        return None
    X = df[feat_cols].to_numpy(dtype=np.float32, copy=False)
    y = df[TARGET_COL].values
    groups = df['city'].values
    building_ids = df['building_id'].values
    return X, y, groups, building_ids, feat_cols

# --- single-protocol GroupKFold evaluator ---------------------------
def evaluate_audit(clf, X, y, groups, experiment_name, n_folds=N_FOLDS,
                   building_ids=None):
    n_cities = len(np.unique(groups))
    n_folds_actual = min(n_folds, n_cities)
    if n_folds_actual < 2:
        print(f"    SKIP {experiment_name}: only {n_cities} cities")
        return None
    gkf = GroupKFold(n_splits=n_folds_actual)
    y_proba_oof = np.full(len(y), np.nan)
    fold_id = np.full(len(y), -1, dtype=int)
    fold_aucs = []
    for fold_idx, (tr, te) in enumerate(gkf.split(X, y, groups)):
        clf_c = clone(clf)
        clf_c.fit(X[tr], y[tr])
        proba = clf_c.predict_proba(X[te])[:, 1]
        y_proba_oof[te] = proba
        fold_id[te] = fold_idx
        if len(np.unique(y[te])) > 1:
            fold_aucs.append(roc_auc_score(y[te], proba))
    valid = ~np.isnan(y_proba_oof)
    y_v, p_v = y[valid], y_proba_oof[valid]
    pred_v = (p_v >= 0.5).astype(int)
    bid_v = np.asarray(building_ids)[valid] if building_ids is not None else np.arange(len(y))[valid].astype(str)
    result = {
        'experiment': experiment_name,
        'auc_groupkfold': roc_auc_score(y_v, p_v),
        'f1_groupkfold': f1_score(y_v, pred_v),
        'precision': precision_score(y_v, pred_v, zero_division=0),
        'recall': recall_score(y_v, pred_v, zero_division=0),
        'fold_aucs': fold_aucs,
        'auc_mean': float(np.mean(fold_aucs)) if fold_aucs else float('nan'),
        'auc_std': float(np.std(fold_aucs)) if fold_aucs else float('nan'),
        'n_features': X.shape[1], 'n_buildings': int(valid.sum()),
        'n_cities': int(len(np.unique(groups))),
        'y_true': y_v, 'y_proba': p_v, 'groups': groups[valid],
        'building_id': bid_v, 'fold_id': fold_id[valid],
    }
    AUDIT_LOG[experiment_name] = result
    print(f"    {experiment_name:40s} AUC={result['auc_groupkfold']:.3f}  "
          f"F1={result['f1_groupkfold']:.3f}  n={result['n_buildings']:,}  "
          f"cities={result['n_cities']}  nfeat={result['n_features']}")
    return result

# --- output paths + registry ----------------------------------------
import matplotlib.pyplot as plt
from datetime import datetime as _dt

OUT_DIR = OUTPUTS_DIR / "NB08c_v2"
OUT_DIR.mkdir(parents=True, exist_ok=True)

def save_result(data, name, cell_id, fmt='csv'):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    if fmt == 'csv' and isinstance(data, pd.DataFrame):
        path = cell_dir / f"{name}_{ts}.csv"
        data.to_csv(path, index=False)
    elif fmt == 'json':
        path = cell_dir / f"{name}_{ts}.json"
        with open(path, 'w') as fh:
            json.dump(data, fh, indent=2, default=str)
    else:
        raise ValueError(f"Unknown fmt={fmt}")
    print(f"  Saved: {path.relative_to(OUT_DIR)} ({path.stat().st_size / 1024:.1f} KB)")
    return path

def save_fig(fig, name, cell_id, dpi=150):
    cell_dir = OUT_DIR / cell_id
    cell_dir.mkdir(parents=True, exist_ok=True)
    ts = _dt.now().strftime('%Y%m%d_%H%M%S')
    path = cell_dir / f"{name}_{ts}.png"
    fig.savefig(path, dpi=dpi, bbox_inches='tight', facecolor='white')
    plt.show()
    print(f"  Plot: {path.relative_to(OUT_DIR)}")
    return path

from bda_results import ResultRegistry
registry = ResultRegistry(RESULTS_ROOT, notebook='NB08c_v2')

def log_audit(res, cell_id, manifest_key, note=''):
    if res is None:
        return
    registry.log_experiment(
        cell_id=cell_id, experiment_name=res['experiment'],
        parquet_name=f'bda_{manifest_key}_v2', feature_set_name='manifest_default_minus_leakage',
        classifier_name='LightGBM-300-MIA', classifier_params=LGBM_PARAMS,
        feature_cols=[], cv_method='GroupKFold', n_folds=N_FOLDS,
        imputation='native_nan', y_true=res['y_true'], y_proba=res['y_proba'],
        groups=res['groups'], note=note, tags=['nb08c_audit'],
    )

print(f"  Helpers: load_v2(), get_parquet_features(), aggregate_long_to_wide(), evaluate_audit()")
print(f"  Output:  {OUT_DIR}")
print(f"  Registry: NB08c_v2")
# Out:
# ======================================================================
# CELL S0: NB08c v2 - LOAD MANIFEST + BUILDINGS + SHARED HELPERS
# ======================================================================
#   Manifest: /mnt/f/PROJECTS/masterthesis/data_stack/dataset/V2/parquet_manifest.json
#   Version: v2  Created: 2026-04-26T16:31:26.125203
#   Parquets in manifest: 37
#   load_tier_parquets: 3 tiers, 907371 rows
#   Cities: 21
#   Buildings: 598595 (damaged=7332, undamaged=591263)
#   EXPERIMENT_ID: 20260517_093056_115af1
#   ResultRegistry: /content/drive_f/masterthesis/results/registry (run_id=20260517_093056)
#   Helpers: load_v2(), get_parquet_features(), aggregate_long_to_wide(), evaluate_audit()
#   Output:  /content/drive_f/masterthesis/data/outputs/NB08c_v2
#   Registry: NB08c_v2

# %% [markdown]
# ## CELL S0b -- OOF PLOT + SUMMARY HELPERS (verbatim NB08c_v2 v8)

# %%
# @title CELL S0b: OOF PLOT + SUMMARY HELPERS
# TP=red, TN=green, FP=pink, FN=gold
import matplotlib.pyplot as plt

CM_COLORS = {'TP': '#d62728', 'TN': '#2ca02c', 'FP': '#ff9ecb', 'FN': '#ffd700'}
CM_LABELS = {'TP': 'Destroyed (TP)', 'TN': 'Not destroyed (TN)',
             'FP': 'False positive (FP)', 'FN': 'False negative (FN)'}

# alias df_bldg to df_buildings for plotting helper compatibility
df_buildings = df_bldg

def print_cm_summary(oof_path_or_df):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else '(unknown)'
    print(f"  model_id: {model_id}   n={len(oof)}")
    overall = oof['cm_class'].value_counts()
    for cls in ['TP', 'TN', 'FP', 'FN']:
        n = int(overall.get(cls, 0))
        pct = 100.0 * n / len(oof) if len(oof) else 0
        print(f"    {cls:3s} {CM_LABELS[cls]:28s}  n={n:6d}  ({pct:5.1f}%)")
    by_city = (oof.groupby('city')['cm_class']
                 .value_counts().unstack(fill_value=0))
    for cls in ['TP', 'TN', 'FP', 'FN']:
        if cls not in by_city.columns:
            by_city[cls] = 0
    by_city = by_city[['TP', 'TN', 'FP', 'FN']]
    by_city['recall']    = by_city['TP'] / (by_city['TP'] + by_city['FN']).replace(0, np.nan)
    by_city['precision'] = by_city['TP'] / (by_city['TP'] + by_city['FP']).replace(0, np.nan)
    print(f"\n  Per-city:")
    print(by_city.to_string(float_format=lambda x: f'{x:.3f}' if pd.notna(x) else '-'))
    return by_city

def plot_cm_spatial(oof_path_or_df, save_name=None, figsize=(14, 10),
                    buildings_df=None, point_size=4):
    if isinstance(oof_path_or_df, (str, Path)):
        oof = pd.read_parquet(oof_path_or_df)
    else:
        oof = oof_path_or_df
    bdf = buildings_df if buildings_df is not None else df_buildings
    if 'centroid_x' not in bdf.columns or 'centroid_y' not in bdf.columns:
        print("  plot_cm_spatial: no centroid_x/centroid_y in buildings_df")
        return None
    plot_df = oof.merge(bdf[['building_id', 'city', 'centroid_x', 'centroid_y']],
                        on=['building_id', 'city'], how='inner')
    if len(plot_df) == 0:
        print("  plot_cm_spatial: no building matches")
        return None
    cities = sorted(plot_df['city'].unique())
    ncols = min(3, len(cities))
    nrows = (len(cities) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, squeeze=False)
    model_id = oof['model_id'].iloc[0] if 'model_id' in oof.columns else ''
    fig.suptitle(f'Confusion-matrix map: {model_id}', fontsize=11)
    draw_order = ['TN', 'FP', 'FN', 'TP']
    for i, city in enumerate(cities):
        ax = axes[i // ncols][i % ncols]
        cdf = plot_df[plot_df['city'] == city]
        for cls in draw_order:
            pts = cdf[cdf['cm_class'] == cls]
            if len(pts) == 0:
                continue
            ax.scatter(pts['centroid_x'], pts['centroid_y'],
                       c=CM_COLORS[cls], s=point_size, alpha=0.75,
                       edgecolors='none',
                       label=f"{CM_LABELS[cls]} (n={len(pts)})")
        ax.set_title(f"{city}  (n={len(cdf)})", fontsize=9)
        ax.set_aspect('equal')
        ax.legend(loc='best', fontsize=6, markerscale=2, framealpha=0.85)
        ax.tick_params(labelsize=7)
    for j in range(len(cities), nrows * ncols):
        axes[j // ncols][j % ncols].axis('off')
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    if save_name:
        fig.savefig(OUT_DIR / f'{save_name}.png', dpi=150, bbox_inches='tight')
        plt.close(fig)
    return fig

def plot_cm_oof_all(oof_dir, skip_variants=()):
    d = Path(oof_dir)
    files = sorted(d.glob('oof_*.parquet'))
    print(f"  Found {len(files)} OOF parquets in {d}")
    for p in files:
        oof = pd.read_parquet(p)
        v = oof['variant_id'].iloc[0] if 'variant_id' in oof.columns else ''
        if any(sv in v for sv in skip_variants):
            print(f"  skip {p.name}  (variant_id={v})")
            continue
        print(f"\n  {p.name}")
        print_cm_summary(oof)
        plot_cm_spatial(oof, save_name=p.stem)

# %% [markdown]
# ## CELL H -- CLASSIFIER (verbatim LightGBM-MIA from NB08c_v2 v8)

# %%
# @title CELL H: CLASSIFIER (LightGBM native NaN)
try:
    from lightgbm import LGBMClassifier
except ImportError:
    raise ImportError("LightGBM required for NB08c single-protocol audit. pip install lightgbm")

LGBM_PARAMS = {
    'n_estimators': 150,
    'max_depth': 6,
    'learning_rate': 0.05,
    'num_leaves': 31,
    'min_child_samples': 20,
    'random_state': RANDOM_STATE,
    'n_jobs': -1,
    'verbose': -1,
    'is_unbalance': True,
    'force_col_wise': True,
}
LGBM = LGBMClassifier(**LGBM_PARAMS)

print(f"  Classifier: LightGBM n_estimators={LGBM_PARAMS['n_estimators']} "
      f"max_depth={LGBM_PARAMS['max_depth']} is_unbalance=True native_nan=MIA")
# Out:
#   Classifier: LightGBM n_estimators=150 max_depth=6 is_unbalance=True native_nan=MIA

# %% [markdown]
# ## CELL AUDIT_RUN -- parquet audit runner (verbatim NB08c_v2 v8)

# %%
# @title CELL AUDIT_RUN: parquet audit runner
def audit_parquet(manifest_key, cell_id, pq_id=None):
    '''Run the single audit protocol on one manifest parquet (v8: direction-aware temporal collapse).
    - load parquet
    - if long-format (date column present), aggregate to per-building mean+std
    - select manifest features, drop leakage + count stats + all-NaN
    - fit LightGBM with GroupKFold
    - log to AUDIT_LOG and registry
    Returns: result dict or None (skip).
    '''
    info = MANIFEST['parquets'].get(manifest_key)
    if info is None:
        print(f"\n  [{manifest_key}] SKIP: not in manifest")
        return None
    _pq_id = pq_id or info.get('id', '?')
    print(f"\n  --- [{_pq_id}] {manifest_key} ---")

    try:
        df = load_v2(manifest_key)
    except (FileNotFoundError, KeyError) as e:
        print(f"    SKIP load: {e}")
        return None
    if len(df) == 0:
        print(f"    SKIP: empty dataframe")
        del df; gc.collect()
        return None

    is_long = 'date' in df.columns
    n_rows_raw = len(df)
    n_cities_raw = df['city'].nunique()

    # manifest feature set, cleaned
    feat_cols = get_parquet_features(manifest_key, df)
    if is_long and feat_cols:
        print(f"    Long format: {n_rows_raw:,} rows, {n_cities_raw} cities -> aggregating per-building")
        df = aggregate_long_to_wide(df, feat_cols, manifest_key=manifest_key)
        # re-merge target after aggregation
        df = df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                      on=['building_id', 'city'], how='inner')
        df = df[df[TARGET_COL] >= 0].copy()
        feat_cols = [c for c in df.columns
                     if c not in ('city', 'building_id', TARGET_COL)]
        feat_cols = drop_leakage(feat_cols)
        feat_cols = [c for c in feat_cols if not _has_count_stat(c)]
        nan_rate = df[feat_cols].isna().mean()
        feat_cols = [c for c in feat_cols if nan_rate[c] < 1.0]

    n_rows = len(df)
    n_cities = df['city'].nunique()
    print(f"    Wide: {n_rows:,} rows, {n_cities} cities, {len(feat_cols)} features")

    if len(feat_cols) < 2:
        print(f"    SKIP: {len(feat_cols)} feature columns after cleaning")
        del df; gc.collect()
        return None

    # overall NaN rate on the post-cleaning feature matrix
    overall_nan = float(df[feat_cols].isna().mean().mean())
    print(f"    Overall NaN rate: {overall_nan*100:.1f}%")

    prep = prepare_features_mia(df, feat_cols)
    if prep is None:
        del df; gc.collect()
        return None
    X, y, groups, building_ids, clean = prep

    exp_name = f"C_{_pq_id}_{manifest_key}"
    res = evaluate_audit(LGBM, X, y, groups, exp_name, building_ids=building_ids)
    if res is not None:
        res['manifest_key'] = manifest_key
        res['parquet_id'] = _pq_id
        res['format'] = 'long->wide' if is_long else 'wide'
        res['overall_nan_pct'] = overall_nan * 100
        res['n_rows_raw'] = n_rows_raw
        res['n_cities_raw'] = n_cities_raw
        log_audit(res, cell_id=cell_id, manifest_key=manifest_key,
                  note=f'{_pq_id} {manifest_key} audit sweep')

    del df, X, y, groups
    gc.collect()
    return res

# %% [markdown]
# ## CELL BASELINE -- replicate source experiment cell legs

# %%
# @title CELL BASELINE: replicate source experiment cell (verbatim audit_parquet calls)
print("=" * 70)
print(f"CELL BASELINE: {NB11_NAME} baseline replication")
print("=" * 70)

NB11_BASELINE_RESULTS = {}
NB11_PREP = {}        # pq_id -> dict(X, y, groups, building_ids, clean_cols, ...)

for pq_id, manifest_key, expected_auc in NB11_PARQUETS:
    print(f"\n  --- [{pq_id}] {manifest_key} (expected AUC={expected_auc:.4f}) ---")
    res = audit_parquet(manifest_key, cell_id=NB11_CELL_ID, pq_id=pq_id)
    assert res is not None, f"audit_parquet returned None for {pq_id}/{manifest_key}"

    got = res['auc_groupkfold']
    delta = got - expected_auc
    ok = abs(delta) <= NB11_BASELINE_TOL
    flag = 'OK' if ok else 'FAIL'
    print(f"    Replicated baseline AUC = {got:.4f}  expected = {expected_auc:.4f}  "
          f"delta = {delta:+.4f}  [{flag}]")
    if not ok:
        raise AssertionError(
            f"Baseline AUC mismatch for {pq_id}/{manifest_key}: got {got:.4f}, "
            f"expected {expected_auc:.4f} (tol {NB11_BASELINE_TOL}). "
            "Do not proceed to Optuna -- investigate prep-chain drift first."
        )

    NB11_BASELINE_RESULTS[pq_id] = res

    # Rebuild X/y/groups/building_ids/clean_cols on the same prep path (matches audit_parquet)
    print(f"    Rebuilding X, y, groups for Optuna (same prep path)...")
    _df = load_v2(manifest_key)
    _is_long = 'date' in _df.columns
    _feat_cols = get_parquet_features(manifest_key, _df)
    if _is_long and _feat_cols:
        _df = aggregate_long_to_wide(_df, _feat_cols, manifest_key=manifest_key)
        _df = _df.merge(df_bldg[['building_id', 'city', TARGET_COL]].drop_duplicates(),
                        on=['building_id', 'city'], how='inner')
        _df = _df[_df[TARGET_COL] >= 0].copy()
        _feat_cols = [c for c in _df.columns
                      if c not in ('city', 'building_id', TARGET_COL)]
        _feat_cols = drop_leakage(_feat_cols)
        _feat_cols = [c for c in _feat_cols if not _has_count_stat(c)]
        _nan_rate = _df[_feat_cols].isna().mean()
        _feat_cols = [c for c in _feat_cols if _nan_rate[c] < 1.0]

    _prep = prepare_features_mia(_df, _feat_cols)
    assert _prep is not None, f"prepare_features_mia returned None for {pq_id}"
    X, y, groups, building_ids, clean_cols = _prep
    NB11_PREP[pq_id] = {
        'X': X, 'y': y, 'groups': groups,
        'building_ids': building_ids, 'clean_cols': clean_cols,
        'manifest_key': manifest_key, 'baseline_auc': got, 'expected_auc': expected_auc,
    }
    print(f"    X shape: {X.shape}  cities: {len(np.unique(groups))}  n_feat: {len(clean_cols)}")

    del _df, _feat_cols
    gc.collect()

print("\n  -> All baselines match source; safe to proceed to Optuna.")
# Out:
# ======================================================================
# CELL BASELINE: NB11a_F4_F7 baseline replication
# ======================================================================
#
#   --- [F4] fusion_ms_cohdrop (expected AUC=0.8130) ---
#
#   --- [F4] fusion_ms_cohdrop ---
#     Long format: 6,443,542 rows, 18 cities -> aggregating per-building
#     Wide: 466,704 rows, 18 cities, 88 features
#     Overall NaN rate: 45.8%
#     C_F4_fusion_ms_cohdrop                   AUC=0.813  F1=0.098  n=466,704  cities=18  nfeat=88
#   REG: C_F4_fusion_ms_cohdrop                        AUC=0.8126 F1=0.0980 n=466704 feat=0 cities=18 [NB08c_v2/cell_c7]
#     Replicated baseline AUC = 0.8126  expected = 0.8130  delta = -0.0004  [OK]
#     Rebuilding X, y, groups for Optuna (same prep path)...
#     X shape: (466704, 88)  cities: 18  n_feat: 88
#
#   --- [F7] fusion_composite_cohdrop (expected AUC=0.8130) ---
#
#   --- [F7] fusion_composite_cohdrop ---
#     Wide: 466,704 rows, 18 cities, 145 features
#     Overall NaN rate: 17.1%
#     C_F7_fusion_composite_cohdrop            AUC=0.813  F1=0.100  n=466,704  cities=18  nfeat=145
#   REG: C_F7_fusion_composite_cohdrop                 AUC=0.8130 F1=0.0996 n=466704 feat=0 cities=18 [NB08c_v2/cell_c7]
#     Replicated baseline AUC = 0.8130  expected = 0.8130  delta = -0.0000  [OK]
#     Rebuilding X, y, groups for Optuna (same prep path)...
#     X shape: (466704, 145)  cities: 18  n_feat: 145
#
#   -> All baselines match source; safe to proceed to Optuna.

# %% [markdown]
# ## CELL OPTUNA -- LightGBM-MIA hyperparameter search per parquet
#
# Search space (10D): `n_estimators [100,800]`, `num_leaves [15,255]`, `max_depth [3,12]`, `learning_rate [0.01,0.2]` log, `min_child_samples [5,100]`, `reg_alpha [0,2]`, `reg_lambda [0,2]`, `feature_fraction [0.5,1]`, `bagging_fraction [0.5,1]`, `bagging_freq [0,10]`. Fixed: `is_unbalance=True`, `force_col_wise=True`, `random_state`, `n_jobs=-1`, `verbose=-1`.

# %%
# @title CELL OPTUNA: LightGBM-MIA search per parquet
import optuna
from optuna.samplers import TPESampler
import joblib

NB11_OUT_DIR = OUTPUTS_DIR / "NB11_V2"
(NB11_OUT_DIR / "studies").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "oof").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "models").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "best_params").mkdir(parents=True, exist_ok=True)
(NB11_OUT_DIR / "summary").mkdir(parents=True, exist_ok=True)

# LGBM_PARAMS comes from CELL H (verbatim source); fixed for all trials
FIXED_LGBM = dict(
    random_state=RANDOM_STATE,
    n_jobs=NB11_THREADS_PER_NB,
    verbose=-1,
    is_unbalance=True,
    force_col_wise=True,
)

BASELINE_TRIAL_LGBM = {
    'n_estimators': LGBM_PARAMS['n_estimators'],
    'num_leaves': LGBM_PARAMS['num_leaves'],
    'max_depth': LGBM_PARAMS['max_depth'],
    'learning_rate': LGBM_PARAMS['learning_rate'],
    'min_child_samples': LGBM_PARAMS['min_child_samples'],
    'reg_alpha': 0.0, 'reg_lambda': 0.0,
    'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0,
}

def _oof_auc_lgbm(params, X, y, groups):
    gkf = GroupKFold(n_splits=min(N_FOLDS, len(np.unique(groups))))
    y_proba_oof = np.full(len(y), np.nan)
    for tr, te in gkf.split(X, y, groups):
        clf = LGBMClassifier(**{**FIXED_LGBM, **params})
        clf.fit(X[tr], y[tr])
        y_proba_oof[te] = clf.predict_proba(X[te])[:, 1]
    valid = ~np.isnan(y_proba_oof)
    return roc_auc_score(y[valid], y_proba_oof[valid])

def suggest_lgbm(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 800),
        'num_leaves': trial.suggest_int('num_leaves', 15, 255),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 2.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 2.0),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 0, 10),
    }

def patience_stop_factory(patience):
    def cb(study, trial):
        best = study.best_trial
        if (trial.number - best.number) >= patience:
            print(f"      [patience] no improvement for {patience} trials -> stopping")
            study.stop()
    return cb

NB11_OPTUNA_RESULTS = {}      # pq_id -> dict
for pq_id, manifest_key, _expected in NB11_PARQUETS:
    prep = NB11_PREP[pq_id]
    X_pq, y_pq, groups_pq = prep['X'], prep['y'], prep['groups']
    baseline_auc = prep['baseline_auc']
    n_trials = OPTUNA_BASE_BUDGET if baseline_auc >= OPTUNA_LOW_AUC_CUTOFF else OPTUNA_LOW_AUC_BUDGET

    STUDY_TAG = f"{NB11_NAME}__{manifest_key}__LightGBM-MIA"
    STUDY_DB  = NB11_OUT_DIR / "studies" / f"{STUDY_TAG}.sqlite"
    storage_url = f"sqlite:///{STUDY_DB.as_posix()}"

    print(f"\n  === [{pq_id}] {manifest_key} ===")
    print(f"    baseline_auc = {baseline_auc:.4f}   budget = {n_trials} trials   patience = {OPTUNA_PATIENCE}")
    print(f"    DB: {STUDY_DB}")

    def objective(trial, X=X_pq, y=y_pq, g=groups_pq):
        params = suggest_lgbm(trial)
        return _oof_auc_lgbm(params, X, y, g)

    study = optuna.create_study(
        direction=OPTUNA_DIRECTION,
        storage=storage_url,
        study_name=STUDY_TAG,
        load_if_exists=True,
        sampler=TPESampler(seed=OPTUNA_SEED),
    )

    # RESUME-IF-EXISTS: any complete trial -> use as-is, no further optimization.
    # To force re-run, delete the corresponding sqlite file under NB11_V2/studies/.
    completed_trials = [t for t in study.trials if t.state.name == 'COMPLETE']
    if len(completed_trials) > 0:
        best = study.best_trial
        n_trials_done = len(study.trials)
        print(f"    RESUME: {n_trials_done} trials in study ({len(completed_trials)} complete) -- using as-is")
        print(f"    Best AUC: {best.value:.4f}  (trial {best.number})")
        print(f"    Best params: {best.params}")
        print(f"    Delta vs baseline: {best.value - baseline_auc:+.4f}")
    else:
        study.enqueue_trial(BASELINE_TRIAL_LGBM)
        print(f"    enqueued baseline params as trial 0: {BASELINE_TRIAL_LGBM}")
        study.optimize(objective, n_trials=n_trials,
                       callbacks=[patience_stop_factory(OPTUNA_PATIENCE)],
                       show_progress_bar=False)
        n_trials_done = len(study.trials)
        best = study.best_trial
        print(f"    Optuna done: {n_trials_done} trials")
        print(f"    Best AUC: {best.value:.4f}  (trial {best.number})")
        print(f"    Best params: {best.params}")
        print(f"    Delta vs baseline: {best.value - baseline_auc:+.4f}")

    NB11_OPTUNA_RESULTS[pq_id] = {
        'manifest_key': manifest_key,
        'baseline_auc': baseline_auc,
        'tuned_auc': best.value,
        'best_params': best.params,
        'n_trials_done': n_trials_done,
        'n_trials_requested': n_trials,
        'study_tag': STUDY_TAG,
        'study_db': STUDY_DB,
    }
# Out:
#   === [F4] fusion_ms_cohdrop ===
#     baseline_auc = 0.8126   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11a_F4_F7__fusion_ms_cohdrop__LightGBM-MIA.sqlite
# [I 2026-05-17 10:05:59,941] A new study created in RDB with name: NB11a_F4_F7__fusion_ms_cohdrop__LightGBM-MIA
#     enqueued baseline params as trial 0: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}
# [I 2026-05-17 10:16:25,029] Trial 0 finished with value: 0.8126126225699284 and parameters: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}. Best is trial 0 with value: 0.8126126225699284.
# [I 2026-05-17 12:14:47,614] Trial 1 finished with value: 0.7624045178027246 and parameters: {'n_estimators': 362, 'num_leaves': 244, 'max_depth': 10, 'learning_rate': 0.060099747183803134, 'min_child_samples': 19, 'reg_alpha': 0.3119890406724053, 'reg_lambda': 0.11616722433639892, 'feature_fraction': 0.9330880728874675, 'bagging_fraction': 0.8005575058716043, 'bagging_freq': 7}. Best is trial 0 with value: 0.8126126225699284.
# [I 2026-05-17 12:46:32,972] Trial 2 finished with value: 0.8077386486670611 and parameters: {'n_estimators': 114, 'num_leaves': 248, 'max_depth': 11, 'learning_rate': 0.018891200276189388, 'min_child_samples': 22, 'reg_alpha': 0.36680901970686763, 'reg_lambda': 0.6084844859190754, 'feature_fraction': 0.762378215816119, 'bagging_fraction': 0.7159725093210578, 'bagging_freq': 3}. Best is trial 0 with value: 0.8126126225699284.
# [I 2026-05-17 13:07:03,009] Trial 3 finished with value: 0.8138026199824919 and parameters: {'n_estimators': 528, 'num_leaves': 48, 'max_depth': 5, 'learning_rate': 0.029967309097101588, 'min_child_samples': 48, 'reg_alpha': 1.5703519227860272, 'reg_lambda': 0.39934756431671947, 'feature_fraction': 0.7571172192068059, 'bagging_fraction': 0.7962072844310213, 'bagging_freq': 0}. Best is trial 3 with value: 0.8138026199824919.
# [I 2026-05-17 13:15:09,480] Trial 4 finished with value: 0.8271627519724095 and parameters: {'n_estimators': 525, 'num_leaves': 56, 'max_depth': 3, 'learning_rate': 0.17160445029754812, 'min_child_samples': 97, 'reg_alpha': 1.6167946962329223, 'reg_lambda': 0.6092275383467414, 'feature_fraction': 0.5488360570031919, 'bagging_fraction': 0.8421165132560784, 'bagging_freq': 4}. Best is trial 4 with value: 0.8271627519724095.
# [I 2026-05-17 13:17:39,805] Trial 5 finished with value: 0.8466620139018116 and parameters: {'n_estimators': 185, 'num_leaves': 134, 'max_depth': 3, 'learning_rate': 0.15242391728466367, 'min_child_samples': 29, 'reg_alpha': 1.325044568707964, 'reg_lambda': 0.6234221521788219, 'feature_fraction': 0.7600340105889054, 'bagging_fraction': 0.7733551396716398, 'bagging_freq': 2}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 14:57:10,066] Trial 6 finished with value: 0.4054829863277459 and parameters: {'n_estimators': 779, 'num_leaves': 201, 'max_depth': 12, 'learning_rate': 0.1459476894296684, 'min_child_samples': 62, 'reg_alpha': 1.8437484700462337, 'reg_lambda': 0.176985004103839, 'feature_fraction': 0.5979914312095727, 'bagging_fraction': 0.522613644455269, 'bagging_freq': 3}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 15:55:32,024] Trial 7 finished with value: 0.7964760673213312 and parameters: {'n_estimators': 372, 'num_leaves': 80, 'max_depth': 11, 'learning_rate': 0.02911701023242742, 'min_child_samples': 31, 'reg_alpha': 1.085392166316497, 'reg_lambda': 0.2818484499495253, 'feature_fraction': 0.9010984903770198, 'bagging_fraction': 0.5372753218398854, 'bagging_freq': 10}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 16:05:50,635] Trial 8 finished with value: 0.8459134083927391 and parameters: {'n_estimators': 641, 'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.11506408247250169, 'min_child_samples': 72, 'reg_alpha': 1.4580143360819746, 'reg_lambda': 1.5425406933718915, 'feature_fraction': 0.5370223258670452, 'bagging_fraction': 0.6792328642721364, 'bagging_freq': 1}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 16:51:14,719] Trial 9 finished with value: 0.8175714914770609 and parameters: {'n_estimators': 705, 'num_leaves': 165, 'max_depth': 6, 'learning_rate': 0.012097379927033842, 'min_child_samples': 34, 'reg_alpha': 0.6503666440534941, 'reg_lambda': 1.4592123566761281, 'feature_fraction': 0.8187787356776066, 'bagging_fraction': 0.9436063712881633, 'bagging_freq': 5}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 17:34:05,961] Trial 10 finished with value: 0.7728702293497126 and parameters: {'n_estimators': 245, 'num_leaves': 129, 'max_depth': 8, 'learning_rate': 0.08514785533006224, 'min_child_samples': 6, 'reg_alpha': 1.0818878163510957, 'reg_lambda': 1.074320561648162, 'feature_fraction': 0.6626799989856424, 'bagging_fraction': 0.6168322274083794, 'bagging_freq': 7}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 17:43:37,938] Trial 11 finished with value: 0.8109643817089823 and parameters: {'n_estimators': 629, 'num_leaves': 113, 'max_depth': 3, 'learning_rate': 0.09358365090420791, 'min_child_samples': 74, 'reg_alpha': 1.3515925880951236, 'reg_lambda': 1.9769322339957278, 'feature_fraction': 0.6611338252944818, 'bagging_fraction': 0.6722310134986551, 'bagging_freq': 1}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 17:51:12,169] Trial 12 finished with value: 0.4513146394457768 and parameters: {'n_estimators': 286, 'num_leaves': 93, 'max_depth': 4, 'learning_rate': 0.11724422289838711, 'min_child_samples': 82, 'reg_alpha': 1.9699403716641846, 'reg_lambda': 1.229711440100951, 'feature_fraction': 0.5091744587091867, 'bagging_fraction': 0.6494891289751392, 'bagging_freq': 2}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 18:49:04,553] Trial 13 finished with value: 0.7695241939730456 and parameters: {'n_estimators': 612, 'num_leaves': 159, 'max_depth': 8, 'learning_rate': 0.19850091648419882, 'min_child_samples': 51, 'reg_alpha': 1.3710092162578684, 'reg_lambda': 1.7230757529347773, 'feature_fraction': 0.684018474248477, 'bagging_fraction': 0.8749672201797924, 'bagging_freq': 2}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 19:11:26,458] Trial 14 finished with value: 0.8037750846508342 and parameters: {'n_estimators': 465, 'num_leaves': 167, 'max_depth': 5, 'learning_rate': 0.07881563835198471, 'min_child_samples': 71, 'reg_alpha': 0.80826335165884, 'reg_lambda': 0.8023979576997946, 'feature_fraction': 0.5990755998931668, 'bagging_fraction': 0.7446172304527945, 'bagging_freq': 1}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 19:14:57,524] Trial 15 finished with value: 0.8441283670527762 and parameters: {'n_estimators': 225, 'num_leaves': 81, 'max_depth': 3, 'learning_rate': 0.12878259317545493, 'min_child_samples': 41, 'reg_alpha': 1.2789369325417557, 'reg_lambda': 1.495574743127153, 'feature_fraction': 0.8366358953823301, 'bagging_fraction': 0.5851844040992087, 'bagging_freq': 5}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 19:54:32,386] Trial 16 finished with value: 0.7992626061095222 and parameters: {'n_estimators': 792, 'num_leaves': 21, 'max_depth': 7, 'learning_rate': 0.06027687452715004, 'min_child_samples': 88, 'reg_alpha': 1.6661389952294028, 'reg_lambda': 0.899035280568458, 'feature_fraction': 0.7320458111344645, 'bagging_fraction': 0.7075507487115216, 'bagging_freq': 7}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 20:26:24,407] Trial 17 finished with value: 0.8102589258363355 and parameters: {'n_estimators': 657, 'num_leaves': 206, 'max_depth': 5, 'learning_rate': 0.03714602823116445, 'min_child_samples': 60, 'reg_alpha': 0.8654912223609827, 'reg_lambda': 1.2083170990023986, 'feature_fraction': 0.8280219172107682, 'bagging_fraction': 0.7819873495107165, 'bagging_freq': 2}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 20:37:22,928] Trial 18 finished with value: 0.807044401838141 and parameters: {'n_estimators': 381, 'num_leaves': 112, 'max_depth': 4, 'learning_rate': 0.11115133859449101, 'min_child_samples': 61, 'reg_alpha': 1.1940247773996284, 'reg_lambda': 1.9806742466154337, 'feature_fraction': 0.6020914931801977, 'bagging_fraction': 0.6736090919905596, 'bagging_freq': 0}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 22:48:24,228] Trial 19 finished with value: 0.7618897682343531 and parameters: {'n_estimators': 539, 'num_leaves': 139, 'max_depth': 9, 'learning_rate': 0.07103204233602432, 'min_child_samples': 6, 'reg_alpha': 1.4871549515117775, 'reg_lambda': 1.4691961416289856, 'feature_fraction': 0.7188282543140466, 'bagging_fraction': 0.8687165605562626, 'bagging_freq': 4}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 22:52:30,523] Trial 20 finished with value: 0.8374124573676907 and parameters: {'n_estimators': 174, 'num_leaves': 60, 'max_depth': 4, 'learning_rate': 0.1506869870819441, 'min_child_samples': 41, 'reg_alpha': 1.7512102104300158, 'reg_lambda': 0.6681230627740807, 'feature_fraction': 0.5062945235048643, 'bagging_fraction': 0.5869695757087998, 'bagging_freq': 10}. Best is trial 5 with value: 0.8466620139018116.
# [I 2026-05-17 22:55:43,487] Trial 21 finished with value: 0.8513135940494057 and parameters: {'n_estimators': 227, 'num_leaves': 83, 'max_depth': 3, 'learning_rate': 0.11932898303078252, 'min_child_samples': 35, 'reg_alpha': 1.2425808073670386, 'reg_lambda': 1.5709336964955298, 'feature_fraction': 0.8046212457199804, 'bagging_fraction': 0.5821718262630846, 'bagging_freq': 5}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-17 22:59:43,614] Trial 22 finished with value: 0.7303326367730928 and parameters: {'n_estimators': 308, 'num_leaves': 103, 'max_depth': 3, 'learning_rate': 0.19733858585229686, 'min_child_samples': 30, 'reg_alpha': 0.9170820231103505, 'reg_lambda': 1.710459202296581, 'feature_fraction': 0.7933588075144931, 'bagging_fraction': 0.6281246082179722, 'bagging_freq': 5}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-17 23:04:57,917] Trial 23 finished with value: 0.8140065871783593 and parameters: {'n_estimators': 198, 'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.09715925451188605, 'min_child_samples': 40, 'reg_alpha': 1.5113793902458899, 'reg_lambda': 1.7284948908665714, 'feature_fraction': 0.8841784996325672, 'bagging_fraction': 0.5721956773232654, 'bagging_freq': 6}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-17 23:32:10,427] Trial 24 finished with value: 0.7808578276722307 and parameters: {'n_estimators': 435, 'num_leaves': 130, 'max_depth': 6, 'learning_rate': 0.1253512068224737, 'min_child_samples': 71, 'reg_alpha': 1.1998766076038287, 'reg_lambda': 1.3154131151994972, 'feature_fraction': 0.8728768445140653, 'bagging_fraction': 0.7127799410287791, 'bagging_freq': 3}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-17 23:34:06,194] Trial 25 finished with value: 0.8446928497120297 and parameters: {'n_estimators': 114, 'num_leaves': 39, 'max_depth': 3, 'learning_rate': 0.16551817667582053, 'min_child_samples': 15, 'reg_alpha': 1.411411894610433, 'reg_lambda': 1.0111520274878472, 'feature_fraction': 0.7753945321977921, 'bagging_fraction': 0.7465743303658744, 'bagging_freq': 1}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-17 23:49:10,003] Trial 26 finished with value: 0.795871853967448 and parameters: {'n_estimators': 330, 'num_leaves': 80, 'max_depth': 5, 'learning_rate': 0.10693222251178826, 'min_child_samples': 27, 'reg_alpha': 0.6856012105919231, 'reg_lambda': 0.4583094267549167, 'feature_fraction': 0.7022688044849109, 'bagging_fraction': 0.5456257834960837, 'bagging_freq': 9}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-17 23:56:16,082] Trial 27 finished with value: 0.8155877604548694 and parameters: {'n_estimators': 263, 'num_leaves': 146, 'max_depth': 4, 'learning_rate': 0.06826895633473593, 'min_child_samples': 46, 'reg_alpha': 0.9860628080655317, 'reg_lambda': 1.5713019146639644, 'feature_fraction': 0.6349082125382739, 'bagging_fraction': 0.5051742194845482, 'bagging_freq': 4}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 00:41:16,465] Trial 28 finished with value: 0.7930739361942487 and parameters: {'n_estimators': 438, 'num_leaves': 187, 'max_depth': 7, 'learning_rate': 0.043249331961052476, 'min_child_samples': 59, 'reg_alpha': 1.1813368607625077, 'reg_lambda': 1.8188177377000825, 'feature_fraction': 0.9322720171024578, 'bagging_fraction': 0.6751194510758654, 'bagging_freq': 8}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 00:43:32,612] Trial 29 finished with value: 0.8216426284857357 and parameters: {'n_estimators': 159, 'num_leaves': 21, 'max_depth': 3, 'learning_rate': 0.05100605864951619, 'min_child_samples': 13, 'reg_alpha': 1.8086772939299296, 'reg_lambda': 1.3484409288676864, 'feature_fraction': 0.9763551405686438, 'bagging_fraction': 0.9250421171320747, 'bagging_freq': 1}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 01:28:18,589] Trial 30 finished with value: 0.4083940676144123 and parameters: {'n_estimators': 702, 'num_leaves': 95, 'max_depth': 6, 'learning_rate': 0.13696452405298867, 'min_child_samples': 36, 'reg_alpha': 0.010917150754625626, 'reg_lambda': 0.7896488800446473, 'feature_fraction': 0.7994218592712723, 'bagging_fraction': 0.6239579195798051, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 01:30:03,193] Trial 31 finished with value: 0.8444248144919115 and parameters: {'n_estimators': 109, 'num_leaves': 41, 'max_depth': 3, 'learning_rate': 0.15598893690052873, 'min_child_samples': 22, 'reg_alpha': 1.4264308233383372, 'reg_lambda': 1.0661545348673638, 'feature_fraction': 0.7762758243714855, 'bagging_fraction': 0.7617992588305393, 'bagging_freq': 1}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 01:35:16,567] Trial 32 finished with value: 0.8305063685825342 and parameters: {'n_estimators': 207, 'num_leaves': 32, 'max_depth': 4, 'learning_rate': 0.16584802048946798, 'min_child_samples': 15, 'reg_alpha': 1.3359372074020788, 'reg_lambda': 0.9461381420454963, 'feature_fraction': 0.8548317010757426, 'bagging_fraction': 0.8264202386547738, 'bagging_freq': 2}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 01:37:17,486] Trial 33 finished with value: 0.8302580557240972 and parameters: {'n_estimators': 136, 'num_leaves': 68, 'max_depth': 3, 'learning_rate': 0.17443065350106918, 'min_child_samples': 26, 'reg_alpha': 1.6715247885726505, 'reg_lambda': 1.5971839448462397, 'feature_fraction': 0.7422738417663594, 'bagging_fraction': 0.7252779851664102, 'bagging_freq': 3}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 01:41:38,482] Trial 34 finished with value: 0.8070361389260904 and parameters: {'n_estimators': 102, 'num_leaves': 38, 'max_depth': 5, 'learning_rate': 0.10468975062953108, 'min_child_samples': 17, 'reg_alpha': 1.498930064290606, 'reg_lambda': 1.1555151462726068, 'feature_fraction': 0.7749128399061372, 'bagging_fraction': 0.760429683392497, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 01:46:11,294] Trial 35 finished with value: 0.8137564995922157 and parameters: {'n_estimators': 173, 'num_leaves': 50, 'max_depth': 4, 'learning_rate': 0.08411859287373914, 'min_child_samples': 11, 'reg_alpha': 1.2526675319568803, 'reg_lambda': 0.4756707760675405, 'feature_fraction': 0.803281895172879, 'bagging_fraction': 0.8041172140142502, 'bagging_freq': 1}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 01:54:00,330] Trial 36 finished with value: 0.8329221608306301 and parameters: {'n_estimators': 566, 'num_leaves': 119, 'max_depth': 3, 'learning_rate': 0.13002243135345184, 'min_child_samples': 19, 'reg_alpha': 1.0882659580227818, 'reg_lambda': 0.6996776712925201, 'feature_fraction': 0.7550404564733104, 'bagging_fraction': 0.6956053894557361, 'bagging_freq': 6}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 02:00:43,077] Trial 37 finished with value: 0.8204733988312245 and parameters: {'n_estimators': 259, 'num_leaves': 68, 'max_depth': 4, 'learning_rate': 0.017686693218701078, 'min_child_samples': 100, 'reg_alpha': 1.6005634844402328, 'reg_lambda': 0.0029000235855067835, 'feature_fraction': 0.848137281106128, 'bagging_fraction': 0.7297941645661415, 'bagging_freq': 3}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 02:21:08,185] Trial 38 finished with value: 0.7943744036475167 and parameters: {'n_estimators': 475, 'num_leaves': 90, 'max_depth': 5, 'learning_rate': 0.1794319853368483, 'min_child_samples': 25, 'reg_alpha': 1.9277553125999, 'reg_lambda': 0.35919098388676474, 'feature_fraction': 0.564056017889179, 'bagging_fraction': 0.7905476416746003, 'bagging_freq': 2}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 02:23:13,190] Trial 39 finished with value: 0.8470652900356399 and parameters: {'n_estimators': 144, 'num_leaves': 234, 'max_depth': 3, 'learning_rate': 0.14994390094992147, 'min_child_samples': 56, 'reg_alpha': 1.4333717162701376, 'reg_lambda': 1.355892196650431, 'feature_fraction': 0.6811168842122033, 'bagging_fraction': 0.851888856538356, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 03:41:35,826] Trial 40 finished with value: 0.39116194388873926 and parameters: {'n_estimators': 348, 'num_leaves': 221, 'max_depth': 10, 'learning_rate': 0.14567126786987294, 'min_child_samples': 66, 'reg_alpha': 1.102728963852158, 'reg_lambda': 1.3494307189772075, 'feature_fraction': 0.627668188628883, 'bagging_fraction': 0.9774607334206787, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 03:43:47,611] Trial 41 finished with value: 0.812195260138414 and parameters: {'n_estimators': 151, 'num_leaves': 255, 'max_depth': 3, 'learning_rate': 0.11601046006109583, 'min_child_samples': 56, 'reg_alpha': 1.4201322912801122, 'reg_lambda': 1.6117681482164095, 'feature_fraction': 0.7165909775528978, 'bagging_fraction': 0.8459599072249591, 'bagging_freq': 1}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 03:45:47,205] Trial 42 finished with value: 0.8467430916644012 and parameters: {'n_estimators': 127, 'num_leaves': 188, 'max_depth': 3, 'learning_rate': 0.16084977908987869, 'min_child_samples': 81, 'reg_alpha': 1.5328893058178894, 'reg_lambda': 1.3952795775982494, 'feature_fraction': 0.5418752033956902, 'bagging_fraction': 0.8150142841428445, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 03:51:07,022] Trial 43 finished with value: 0.8133297548248273 and parameters: {'n_estimators': 199, 'num_leaves': 233, 'max_depth': 4, 'learning_rate': 0.09724741319917071, 'min_child_samples': 83, 'reg_alpha': 1.5814610632741615, 'reg_lambda': 1.876669240774471, 'feature_fraction': 0.5403317102892632, 'bagging_fraction': 0.9040271284869948, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 03:53:16,634] Trial 44 finished with value: 0.8498174004259433 and parameters: {'n_estimators': 139, 'num_leaves': 183, 'max_depth': 3, 'learning_rate': 0.1423461985532099, 'min_child_samples': 77, 'reg_alpha': 1.296636125248045, 'reg_lambda': 1.370984612896547, 'feature_fraction': 0.5708788532969804, 'bagging_fraction': 0.8151145822244882, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 03:56:37,210] Trial 45 finished with value: 0.8262560507002048 and parameters: {'n_estimators': 230, 'num_leaves': 183, 'max_depth': 3, 'learning_rate': 0.19277333531308605, 'min_child_samples': 90, 'reg_alpha': 1.290302596634424, 'reg_lambda': 1.3970083502511594, 'feature_fraction': 0.5741879552299755, 'bagging_fraction': 0.8212408744458215, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 04:41:42,715] Trial 46 finished with value: 0.7832473646359714 and parameters: {'n_estimators': 143, 'num_leaves': 214, 'max_depth': 12, 'learning_rate': 0.14414618829214215, 'min_child_samples': 79, 'reg_alpha': 0.9886745024360775, 'reg_lambda': 1.2718926184945887, 'feature_fraction': 0.6753166184103644, 'bagging_fraction': 0.8635062442071775, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 04:49:19,694] Trial 47 finished with value: 0.8206950701751201 and parameters: {'n_estimators': 285, 'num_leaves': 180, 'max_depth': 4, 'learning_rate': 0.02556748949293813, 'min_child_samples': 47, 'reg_alpha': 1.7423558551805525, 'reg_lambda': 1.4184483361496796, 'feature_fraction': 0.6401396429145281, 'bagging_fraction': 0.8965683710908677, 'bagging_freq': 4}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 04:52:15,629] Trial 48 finished with value: 0.8092824932788425 and parameters: {'n_estimators': 187, 'num_leaves': 239, 'max_depth': 3, 'learning_rate': 0.13483537197855888, 'min_child_samples': 67, 'reg_alpha': 1.1384882779159713, 'reg_lambda': 1.1875978087236012, 'feature_fraction': 0.5728919074033701, 'bagging_fraction': 0.8197468324682918, 'bagging_freq': 2}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 04:57:29,725] Trial 49 finished with value: 0.8179472422729377 and parameters: {'n_estimators': 134, 'num_leaves': 149, 'max_depth': 5, 'learning_rate': 0.1724929480260491, 'min_child_samples': 94, 'reg_alpha': 1.3442419419242988, 'reg_lambda': 1.1532143131695602, 'feature_fraction': 0.60885732600977, 'bagging_fraction': 0.7782813316417597, 'bagging_freq': 1}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 06:00:22,741] Trial 50 finished with value: 0.8134170312600503 and parameters: {'n_estimators': 233, 'num_leaves': 198, 'max_depth': 11, 'learning_rate': 0.010421938634545404, 'min_child_samples': 78, 'reg_alpha': 1.5553573402744982, 'reg_lambda': 1.659130332697038, 'feature_fraction': 0.5277789077982316, 'bagging_fraction': 0.846726669873422, 'bagging_freq': 6}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 06:02:12,877] Trial 51 finished with value: 0.8497449085603976 and parameters: {'n_estimators': 127, 'num_leaves': 169, 'max_depth': 3, 'learning_rate': 0.11994006822003736, 'min_child_samples': 86, 'reg_alpha': 1.4613685569731591, 'reg_lambda': 1.5054142291694792, 'feature_fraction': 0.5257064709406503, 'bagging_fraction': 0.8084148441853932, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 06:04:14,187] Trial 52 finished with value: 0.8487544252705814 and parameters: {'n_estimators': 130, 'num_leaves': 164, 'max_depth': 3, 'learning_rate': 0.12321562515991259, 'min_child_samples': 84, 'reg_alpha': 1.2657795239856364, 'reg_lambda': 1.539813339794904, 'feature_fraction': 0.5169344579057181, 'bagging_fraction': 0.7962328976384846, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 06:06:10,755] Trial 53 finished with value: 0.8161567206484881 and parameters: {'n_estimators': 134, 'num_leaves': 170, 'max_depth': 3, 'learning_rate': 0.08858431931927956, 'min_child_samples': 86, 'reg_alpha': 1.2519918025475678, 'reg_lambda': 1.5102870447523176, 'feature_fraction': 0.5231683028380587, 'bagging_fraction': 0.804190341409941, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 06:10:21,999] Trial 54 finished with value: 0.8203541357775387 and parameters: {'n_estimators': 159, 'num_leaves': 193, 'max_depth': 4, 'learning_rate': 0.07575519484662666, 'min_child_samples': 94, 'reg_alpha': 1.6888629836663398, 'reg_lambda': 1.4379433983266923, 'feature_fraction': 0.558278651196194, 'bagging_fraction': 0.888268195026204, 'bagging_freq': 0}. Best is trial 21 with value: 0.8513135940494057.
# [I 2026-05-18 06:12:08,573] Trial 55 finished with value: 0.8514857036920641 and parameters: {'n_estimators': 104, 'num_leaves': 157, 'max_depth': 3, 'learning_rate': 0.11861495521123717, 'min_child_samples': 75, 'reg_alpha': 1.3868856002811674, 'reg_lambda': 1.845085662159181, 'feature_fraction': 0.5795281394665144, 'bagging_fraction': 0.8493507534942323, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:14:51,869] Trial 56 finished with value: 0.8502759246958573 and parameters: {'n_estimators': 102, 'num_leaves': 154, 'max_depth': 4, 'learning_rate': 0.11716230413868499, 'min_child_samples': 77, 'reg_alpha': 1.4085858763187187, 'reg_lambda': 1.8077296072630784, 'feature_fraction': 0.5847149922165837, 'bagging_fraction': 0.8389411092353848, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:19:41,570] Trial 57 finished with value: 0.8206329946158434 and parameters: {'n_estimators': 177, 'num_leaves': 158, 'max_depth': 4, 'learning_rate': 0.0590954014199375, 'min_child_samples': 75, 'reg_alpha': 1.0465582588409543, 'reg_lambda': 1.8499240069495335, 'feature_fraction': 0.5885074065949072, 'bagging_fraction': 0.9213463089403207, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:21:29,791] Trial 58 finished with value: 0.8510348596094068 and parameters: {'n_estimators': 106, 'num_leaves': 171, 'max_depth': 3, 'learning_rate': 0.11771805142034479, 'min_child_samples': 66, 'reg_alpha': 1.1891378728840607, 'reg_lambda': 1.791438415165106, 'feature_fraction': 0.5079070892263309, 'bagging_fraction': 0.8305385737710241, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:24:43,046] Trial 59 finished with value: 0.8144697470151563 and parameters: {'n_estimators': 118, 'num_leaves': 171, 'max_depth': 4, 'learning_rate': 0.10180766977979733, 'min_child_samples': 66, 'reg_alpha': 1.3755446329959662, 'reg_lambda': 1.7776516911467628, 'feature_fraction': 0.6190432244128359, 'bagging_fraction': 0.8785411838133641, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:27:39,124] Trial 60 finished with value: 0.8490802727124355 and parameters: {'n_estimators': 105, 'num_leaves': 153, 'max_depth': 4, 'learning_rate': 0.11660528010463382, 'min_child_samples': 76, 'reg_alpha': 1.1661755809303658, 'reg_lambda': 1.9338823426000191, 'feature_fraction': 0.5038582450343441, 'bagging_fraction': 0.8398020625934802, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:30:26,750] Trial 61 finished with value: 0.8490437111974144 and parameters: {'n_estimators': 104, 'num_leaves': 155, 'max_depth': 4, 'learning_rate': 0.11686302358671471, 'min_child_samples': 75, 'reg_alpha': 1.1999129250179505, 'reg_lambda': 1.9167049131960352, 'feature_fraction': 0.5001520332182297, 'bagging_fraction': 0.8324549267379011, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:45:33,532] Trial 62 finished with value: 0.8006664051040744 and parameters: {'n_estimators': 214, 'num_leaves': 141, 'max_depth': 6, 'learning_rate': 0.08242698881812971, 'min_child_samples': 78, 'reg_alpha': 0.9304985877031786, 'reg_lambda': 1.921270671581554, 'feature_fraction': 0.5883213459420382, 'bagging_fraction': 0.8597534138780588, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:47:11,233] Trial 63 finished with value: 0.8156918935847197 and parameters: {'n_estimators': 100, 'num_leaves': 177, 'max_depth': 3, 'learning_rate': 0.0932737258152073, 'min_child_samples': 70, 'reg_alpha': 1.1642877936232754, 'reg_lambda': 1.7615002296869335, 'feature_fraction': 0.5539032510727258, 'bagging_fraction': 0.8376716109371984, 'bagging_freq': 3}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 06:49:56,838] Trial 64 finished with value: 0.45667682697205797 and parameters: {'n_estimators': 165, 'num_leaves': 125, 'max_depth': 3, 'learning_rate': 0.11284049300299631, 'min_child_samples': 69, 'reg_alpha': 1.031864273242535, 'reg_lambda': 1.6824828694770069, 'feature_fraction': 0.5322826985578885, 'bagging_fraction': 0.7662717142646097, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 07:00:48,814] Trial 65 finished with value: 0.8420717896379136 and parameters: {'n_estimators': 401, 'num_leaves': 149, 'max_depth': 4, 'learning_rate': 0.13161872985561474, 'min_child_samples': 88, 'reg_alpha': 1.304824274104347, 'reg_lambda': 1.9846161215702778, 'feature_fraction': 0.5123975519916352, 'bagging_fraction': 0.8783567366964562, 'bagging_freq': 4}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 07:04:01,481] Trial 66 finished with value: 0.8209320186931097 and parameters: {'n_estimators': 186, 'num_leaves': 173, 'max_depth': 3, 'learning_rate': 0.06882803604888012, 'min_child_samples': 74, 'reg_alpha': 1.479094844696265, 'reg_lambda': 1.8044605896530057, 'feature_fraction': 0.5000097980017881, 'bagging_fraction': 0.9127987823428134, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 08:04:07,431] Trial 67 finished with value: 0.7762411659520729 and parameters: {'n_estimators': 157, 'num_leaves': 138, 'max_depth': 9, 'learning_rate': 0.10560570157829602, 'min_child_samples': 65, 'reg_alpha': 1.2244557902014486, 'reg_lambda': 1.6460383109442047, 'feature_fraction': 0.5725442176903573, 'bagging_fraction': 0.7847684667169211, 'bagging_freq': 9}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 08:12:12,608] Trial 68 finished with value: 0.814417139567041 and parameters: {'n_estimators': 119, 'num_leaves': 155, 'max_depth': 4, 'learning_rate': 0.09204081808931829, 'min_child_samples': 81, 'reg_alpha': 0.7495963493440814, 'reg_lambda': 1.889026404658141, 'feature_fraction': 0.5433733334344651, 'bagging_fraction': 0.9561507613630715, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 08:35:24,871] Trial 69 finished with value: 0.80137068780253 and parameters: {'n_estimators': 210, 'num_leaves': 206, 'max_depth': 5, 'learning_rate': 0.11789942120368631, 'min_child_samples': 90, 'reg_alpha': 0.4982771538036853, 'reg_lambda': 1.7434159044029174, 'feature_fraction': 0.582802823917844, 'bagging_fraction': 0.8117186554515866, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 08:39:09,905] Trial 70 finished with value: 0.8220040853852012 and parameters: {'n_estimators': 103, 'num_leaves': 163, 'max_depth': 3, 'learning_rate': 0.06173871064839844, 'min_child_samples': 63, 'reg_alpha': 1.3776729321158365, 'reg_lambda': 1.9392412747840917, 'feature_fraction': 0.6457196962657855, 'bagging_fraction': 0.8397094990126873, 'bagging_freq': 7}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 08:45:56,318] Trial 71 finished with value: 0.8481367577490839 and parameters: {'n_estimators': 102, 'num_leaves': 156, 'max_depth': 4, 'learning_rate': 0.12473411096698322, 'min_child_samples': 74, 'reg_alpha': 1.1466358412506474, 'reg_lambda': 1.841506574615124, 'feature_fraction': 0.5029408037978881, 'bagging_fraction': 0.8317455597696772, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 08:55:52,619] Trial 72 finished with value: 0.8110809543475613 and parameters: {'n_estimators': 149, 'num_leaves': 131, 'max_depth': 4, 'learning_rate': 0.1101130748837409, 'min_child_samples': 74, 'reg_alpha': 1.224928771264815, 'reg_lambda': 1.9327214746763246, 'feature_fraction': 0.5237269245934212, 'bagging_fraction': 0.8643195385539129, 'bagging_freq': 3}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 09:00:39,279] Trial 73 finished with value: 0.4523188281137578 and parameters: {'n_estimators': 123, 'num_leaves': 144, 'max_depth': 3, 'learning_rate': 0.13970740561108144, 'min_child_samples': 77, 'reg_alpha': 1.3175440065064452, 'reg_lambda': 1.711288438991993, 'feature_fraction': 0.5576752683515909, 'bagging_fraction': 0.8347663019375501, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 09:21:31,427] Trial 74 finished with value: 0.8073532405072316 and parameters: {'n_estimators': 186, 'num_leaves': 151, 'max_depth': 5, 'learning_rate': 0.10197795310271023, 'min_child_samples': 85, 'reg_alpha': 1.1062235262188553, 'reg_lambda': 1.8004817639803614, 'feature_fraction': 0.5190353669979384, 'bagging_fraction': 0.803105237327149, 'bagging_freq': 5}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 09:39:41,330] Trial 75 finished with value: 0.8307415937092463 and parameters: {'n_estimators': 168, 'num_leaves': 163, 'max_depth': 5, 'learning_rate': 0.15672365285189288, 'min_child_samples': 72, 'reg_alpha': 1.4596356031675308, 'reg_lambda': 1.6067927184431376, 'feature_fraction': 0.5342571861349558, 'bagging_fraction': 0.7448561506834175, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 09:47:52,413] Trial 76 finished with value: 0.8194273976879092 and parameters: {'n_estimators': 127, 'num_leaves': 176, 'max_depth': 4, 'learning_rate': 0.07765167630837712, 'min_child_samples': 81, 'reg_alpha': 0.9438296489158465, 'reg_lambda': 1.98325465922369, 'feature_fraction': 0.6087470662551944, 'bagging_fraction': 0.6561678185700692, 'bagging_freq': 3}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 09:53:36,261] Trial 77 finished with value: 0.8510559580770564 and parameters: {'n_estimators': 145, 'num_leaves': 109, 'max_depth': 3, 'learning_rate': 0.12075173334099393, 'min_child_samples': 76, 'reg_alpha': 0.8402428561992903, 'reg_lambda': 1.879759411929327, 'feature_fraction': 0.5010991349918663, 'bagging_fraction': 0.8817950839555149, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 09:59:01,410] Trial 78 finished with value: 0.8392705526990498 and parameters: {'n_estimators': 142, 'num_leaves': 114, 'max_depth': 3, 'learning_rate': 0.18388327520395234, 'min_child_samples': 34, 'reg_alpha': 1.642209322589385, 'reg_lambda': 1.5159399104883373, 'feature_fraction': 0.5482929586165235, 'bagging_fraction': 0.8538936283988332, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:08:20,904] Trial 79 finished with value: 0.8489250657901684 and parameters: {'n_estimators': 240, 'num_leaves': 101, 'max_depth': 3, 'learning_rate': 0.13415684873790962, 'min_child_samples': 68, 'reg_alpha': 0.7776216771942677, 'reg_lambda': 1.6636434150273816, 'feature_fraction': 0.5122129617635659, 'bagging_fraction': 0.8793565123876775, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:17:51,575] Trial 80 finished with value: 0.8140652175643733 and parameters: {'n_estimators': 265, 'num_leaves': 123, 'max_depth': 3, 'learning_rate': 0.09945376922430012, 'min_child_samples': 50, 'reg_alpha': 0.8582569516846369, 'reg_lambda': 1.8481277620227343, 'feature_fraction': 0.5598205543431749, 'bagging_fraction': 0.9383567405596362, 'bagging_freq': 0}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:25:31,318] Trial 81 finished with value: 0.8491466037237202 and parameters: {'n_estimators': 115, 'num_leaves': 81, 'max_depth': 4, 'learning_rate': 0.1182818267438479, 'min_child_samples': 72, 'reg_alpha': 1.1814488258244957, 'reg_lambda': 1.9169846035673166, 'feature_fraction': 0.5042870959792102, 'bagging_fraction': 0.8958054663122906, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:31:35,613] Trial 82 finished with value: 0.8510981971758176 and parameters: {'n_estimators': 157, 'num_leaves': 83, 'max_depth': 3, 'learning_rate': 0.12215500283754069, 'min_child_samples': 71, 'reg_alpha': 1.2867221787591394, 'reg_lambda': 1.7461740847119103, 'feature_fraction': 0.5343810345739525, 'bagging_fraction': 0.8902208004309439, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:39:04,452] Trial 83 finished with value: 0.8485978913257655 and parameters: {'n_estimators': 193, 'num_leaves': 80, 'max_depth': 3, 'learning_rate': 0.12434829846928029, 'min_child_samples': 58, 'reg_alpha': 1.3884210816417915, 'reg_lambda': 1.5669735087487893, 'feature_fraction': 0.5379631612304931, 'bagging_fraction': 0.890411404188735, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:45:01,388] Trial 84 finished with value: 0.8166842674712983 and parameters: {'n_estimators': 166, 'num_leaves': 89, 'max_depth': 3, 'learning_rate': 0.08786341774464032, 'min_child_samples': 72, 'reg_alpha': 1.0473000286660499, 'reg_lambda': 1.7608775472150044, 'feature_fraction': 0.5697332240545067, 'bagging_fraction': 0.9099371431519, 'bagging_freq': 0}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:52:41,023] Trial 85 finished with value: 0.8396870417675552 and parameters: {'n_estimators': 219, 'num_leaves': 98, 'max_depth': 3, 'learning_rate': 0.1464188885333279, 'min_child_samples': 71, 'reg_alpha': 1.3132136281222926, 'reg_lambda': 1.7193892052078166, 'feature_fraction': 0.8200248750269579, 'bagging_fraction': 0.932413637320062, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 10:58:35,259] Trial 86 finished with value: 0.8134589026354881 and parameters: {'n_estimators': 149, 'num_leaves': 85, 'max_depth': 3, 'learning_rate': 0.10719668298404761, 'min_child_samples': 62, 'reg_alpha': 0.5258378085946099, 'reg_lambda': 1.4761959679269308, 'feature_fraction': 0.5302939081509882, 'bagging_fraction': 0.8944700660797823, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 11:28:56,050] Trial 87 finished with value: 0.422051993055665 and parameters: {'n_estimators': 122, 'num_leaves': 106, 'max_depth': 7, 'learning_rate': 0.16107155899139575, 'min_child_samples': 44, 'reg_alpha': 1.2578446015216393, 'reg_lambda': 1.8148634717945218, 'feature_fraction': 0.5984764737802729, 'bagging_fraction': 0.9506142758103865, 'bagging_freq': 0}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 11:35:17,345] Trial 88 finished with value: 0.8128486555614469 and parameters: {'n_estimators': 175, 'num_leaves': 74, 'max_depth': 3, 'learning_rate': 0.13697984340846484, 'min_child_samples': 79, 'reg_alpha': 1.5049773173586871, 'reg_lambda': 1.6190454807232126, 'feature_fraction': 0.5473675995828827, 'bagging_fraction': 0.8722500928207579, 'bagging_freq': 0}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 11:44:15,449] Trial 89 finished with value: 0.45155917271998125 and parameters: {'n_estimators': 141, 'num_leaves': 135, 'max_depth': 4, 'learning_rate': 0.1222377760035169, 'min_child_samples': 54, 'reg_alpha': 1.4355211613637924, 'reg_lambda': 1.8774563454102449, 'feature_fraction': 0.5797165456837264, 'bagging_fraction': 0.9743631164960143, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 11:49:08,214] Trial 90 finished with value: 0.8193696807362861 and parameters: {'n_estimators': 122, 'num_leaves': 107, 'max_depth': 3, 'learning_rate': 0.033573989323189384, 'min_child_samples': 65, 'reg_alpha': 0.04045353100163385, 'reg_lambda': 1.6729516779391465, 'feature_fraction': 0.5167800289820198, 'bagging_fraction': 0.8523988445564498, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 11:55:45,157] Trial 91 finished with value: 0.8493486524820659 and parameters: {'n_estimators': 100, 'num_leaves': 58, 'max_depth': 4, 'learning_rate': 0.11253426802346177, 'min_child_samples': 77, 'reg_alpha': 1.1264868997097515, 'reg_lambda': 1.993034627499982, 'feature_fraction': 0.513232920063397, 'bagging_fraction': 0.8223900347615948, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 12:35:15,553] Trial 92 finished with value: 0.8242021266867229 and parameters: {'n_estimators': 156, 'num_leaves': 48, 'max_depth': 8, 'learning_rate': 0.11234465272105851, 'min_child_samples': 80, 'reg_alpha': 1.1318231519747932, 'reg_lambda': 1.7778690223240456, 'feature_fraction': 0.5260626671232054, 'bagging_fraction': 0.8221017990573888, 'bagging_freq': 3}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 12:42:53,170] Trial 93 finished with value: 0.7923369182344854 and parameters: {'n_estimators': 118, 'num_leaves': 57, 'max_depth': 4, 'learning_rate': 0.15021895374389582, 'min_child_samples': 86, 'reg_alpha': 1.3477694056487093, 'reg_lambda': 1.9972807287885668, 'feature_fraction': 0.5488168552679775, 'bagging_fraction': 0.5567612501110855, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 13:12:40,276] Trial 94 finished with value: 0.8102345090076677 and parameters: {'n_estimators': 757, 'num_leaves': 186, 'max_depth': 3, 'learning_rate': 0.09510102347889693, 'min_child_samples': 83, 'reg_alpha': 0.8571657459104295, 'reg_lambda': 1.8869522426581442, 'feature_fraction': 0.5143140560198853, 'bagging_fraction': 0.6104875544522774, 'bagging_freq': 1}. Best is trial 55 with value: 0.8514857036920641.
# [I 2026-05-18 13:21:39,232] Trial 95 finished with value: 0.8460208051676646 and parameters: {'n_estimators': 138, 'num_leaves': 74, 'max_depth': 4, 'learning_rate': 0.1289893453523657, 'min_child_samples': 77, 'reg_alpha': 0.9966810916068267, 'reg_lambda': 1.954377153962497, 'feature_fraction': 0.5347982474253534, 'bagging_fraction': 0.7927583560766497, 'bagging_freq': 2}. Best is trial 55 with value: 0.8514857036920641.
#       [patience] no improvement for 40 trials -> stopping
#     Optuna done: 96 trials
#     Best AUC: 0.8515  (trial 55)
#     Best params: {'n_estimators': 104, 'num_leaves': 157, 'max_depth': 3, 'learning_rate': 0.11861495521123717, 'min_child_samples': 75, 'reg_alpha': 1.3868856002811674, 'reg_lambda': 1.845085662159181, 'feature_fraction': 0.5795281394665144, 'bagging_fraction': 0.8493507534942323, 'bagging_freq': 1}
#     Delta vs baseline: +0.0389
#
#   === [F7] fusion_composite_cohdrop ===
#     baseline_auc = 0.8130   budget = 200 trials   patience = 40
#     DB: /content/drive_f/masterthesis/data/outputs/NB11_V2/studies/NB11a_F4_F7__fusion_composite_cohdrop__LightGBM-MIA.sqlite
# [I 2026-05-18 13:21:40,685] A new study created in RDB with name: NB11a_F4_F7__fusion_composite_cohdrop__LightGBM-MIA
#     enqueued baseline params as trial 0: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}
# [I 2026-05-18 13:37:33,009] Trial 0 finished with value: 0.8129649691039427 and parameters: {'n_estimators': 150, 'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.05, 'min_child_samples': 20, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'bagging_freq': 0}. Best is trial 0 with value: 0.8129649691039427.
# [I 2026-05-18 17:58:34,489] Trial 1 finished with value: 0.7561695298760628 and parameters: {'n_estimators': 362, 'num_leaves': 244, 'max_depth': 10, 'learning_rate': 0.060099747183803134, 'min_child_samples': 19, 'reg_alpha': 0.3119890406724053, 'reg_lambda': 0.11616722433639892, 'feature_fraction': 0.9330880728874675, 'bagging_fraction': 0.8005575058716043, 'bagging_freq': 7}. Best is trial 0 with value: 0.8129649691039427.
# [I 2026-05-18 19:08:20,108] Trial 2 finished with value: 0.7986060666118425 and parameters: {'n_estimators': 114, 'num_leaves': 248, 'max_depth': 11, 'learning_rate': 0.018891200276189388, 'min_child_samples': 22, 'reg_alpha': 0.36680901970686763, 'reg_lambda': 0.6084844859190754, 'feature_fraction': 0.762378215816119, 'bagging_fraction': 0.7159725093210578, 'bagging_freq': 3}. Best is trial 0 with value: 0.8129649691039427.
# [I 2026-05-18 19:46:28,329] Trial 3 finished with value: 0.8111615403103803 and parameters: {'n_estimators': 528, 'num_leaves': 48, 'max_depth': 5, 'learning_rate': 0.029967309097101588, 'min_child_samples': 48, 'reg_alpha': 1.5703519227860272, 'reg_lambda': 0.39934756431671947, 'feature_fraction': 0.7571172192068059, 'bagging_fraction': 0.7962072844310213, 'bagging_freq': 0}. Best is trial 0 with value: 0.8129649691039427.
# [I 2026-05-18 20:00:28,000] Trial 4 finished with value: 0.8091384471215284 and parameters: {'n_estimators': 525, 'num_leaves': 56, 'max_depth': 3, 'learning_rate': 0.17160445029754812, 'min_child_samples': 97, 'reg_alpha': 1.6167946962329223, 'reg_lambda': 0.6092275383467414, 'feature_fraction': 0.5488360570031919, 'bagging_fraction': 0.8421165132560784, 'bagging_freq': 4}. Best is trial 0 with value: 0.8129649691039427.
# [I 2026-05-18 20:05:33,900] Trial 5 finished with value: 0.8449109804516205 and parameters: {'n_estimators': 185, 'num_leaves': 134, 'max_depth': 3, 'learning_rate': 0.15242391728466367, 'min_child_samples': 29, 'reg_alpha': 1.325044568707964, 'reg_lambda': 0.6234221521788219, 'feature_fraction': 0.7600340105889054, 'bagging_fraction': 0.7733551396716398, 'bagging_freq': 2}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-18 23:05:49,180] Trial 6 finished with value: 0.7703841409546809 and parameters: {'n_estimators': 779, 'num_leaves': 201, 'max_depth': 12, 'learning_rate': 0.1459476894296684, 'min_child_samples': 62, 'reg_alpha': 1.8437484700462337, 'reg_lambda': 0.176985004103839, 'feature_fraction': 0.5979914312095727, 'bagging_fraction': 0.522613644455269, 'bagging_freq': 3}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 00:27:23,239] Trial 7 finished with value: 0.7887929189664817 and parameters: {'n_estimators': 372, 'num_leaves': 80, 'max_depth': 11, 'learning_rate': 0.02911701023242742, 'min_child_samples': 31, 'reg_alpha': 1.085392166316497, 'reg_lambda': 0.2818484499495253, 'feature_fraction': 0.9010984903770198, 'bagging_fraction': 0.5372753218398854, 'bagging_freq': 10}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 00:40:35,898] Trial 8 finished with value: 0.8001694311363157 and parameters: {'n_estimators': 641, 'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.11506408247250169, 'min_child_samples': 72, 'reg_alpha': 1.4580143360819746, 'reg_lambda': 1.5425406933718915, 'feature_fraction': 0.5370223258670452, 'bagging_fraction': 0.6792328642721364, 'bagging_freq': 1}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 01:42:53,279] Trial 9 finished with value: 0.8118977661764029 and parameters: {'n_estimators': 705, 'num_leaves': 165, 'max_depth': 6, 'learning_rate': 0.012097379927033842, 'min_child_samples': 34, 'reg_alpha': 0.6503666440534941, 'reg_lambda': 1.4592123566761281, 'feature_fraction': 0.8187787356776066, 'bagging_fraction': 0.9436063712881633, 'bagging_freq': 5}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 02:46:43,090] Trial 10 finished with value: 0.7655463130475257 and parameters: {'n_estimators': 245, 'num_leaves': 129, 'max_depth': 8, 'learning_rate': 0.08514785533006224, 'min_child_samples': 6, 'reg_alpha': 1.0818878163510957, 'reg_lambda': 1.074320561648162, 'feature_fraction': 0.6626799989856424, 'bagging_fraction': 0.6168322274083794, 'bagging_freq': 7}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 02:51:51,640] Trial 11 finished with value: 0.8152161281602136 and parameters: {'n_estimators': 111, 'num_leaves': 17, 'max_depth': 5, 'learning_rate': 0.05364472224420192, 'min_child_samples': 44, 'reg_alpha': 0.7453826222714207, 'reg_lambda': 0.9408241214154992, 'feature_fraction': 0.9978334368734647, 'bagging_fraction': 0.9599238887377374, 'bagging_freq': 1}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 03:00:27,476] Trial 12 finished with value: 0.8101676197328344 and parameters: {'n_estimators': 249, 'num_leaves': 98, 'max_depth': 4, 'learning_rate': 0.0832872507080424, 'min_child_samples': 50, 'reg_alpha': 0.8257281319576956, 'reg_lambda': 1.0300298477013423, 'feature_fraction': 0.8559889011067058, 'bagging_fraction': 0.9234980616943328, 'bagging_freq': 2}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 03:09:44,081] Trial 13 finished with value: 0.8022405829472623 and parameters: {'n_estimators': 197, 'num_leaves': 16, 'max_depth': 8, 'learning_rate': 0.19811301916514282, 'min_child_samples': 40, 'reg_alpha': 1.282758491709649, 'reg_lambda': 0.7987624978620653, 'feature_fraction': 0.689969468538783, 'bagging_fraction': 0.8740389464202111, 'bagging_freq': 2}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 03:28:51,579] Trial 14 finished with value: 0.8140659810127084 and parameters: {'n_estimators': 318, 'num_leaves': 116, 'max_depth': 5, 'learning_rate': 0.03314262382875343, 'min_child_samples': 72, 'reg_alpha': 0.7698982036689086, 'reg_lambda': 1.8516552618153717, 'feature_fraction': 0.984634926024359, 'bagging_fraction': 0.6360031009379752, 'bagging_freq': 1}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 03:33:29,245] Trial 15 finished with value: 0.8150231210505317 and parameters: {'n_estimators': 126, 'num_leaves': 176, 'max_depth': 4, 'learning_rate': 0.07457800207385139, 'min_child_samples': 5, 'reg_alpha': 1.2789369325417557, 'reg_lambda': 1.3239153270012034, 'feature_fraction': 0.830876777218877, 'bagging_fraction': 0.7575860442612082, 'bagging_freq': 6}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 04:09:49,206] Trial 16 finished with value: 0.8107095602281873 and parameters: {'n_estimators': 276, 'num_leaves': 152, 'max_depth': 7, 'learning_rate': 0.11615061377572228, 'min_child_samples': 61, 'reg_alpha': 0.5374310370861742, 'reg_lambda': 0.7718534804150351, 'feature_fraction': 0.6753024996723805, 'bagging_fraction': 0.999220682671344, 'bagging_freq': 4}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 04:20:03,996] Trial 17 finished with value: 0.8165082023487433 and parameters: {'n_estimators': 499, 'num_leaves': 206, 'max_depth': 3, 'learning_rate': 0.04394451158649236, 'min_child_samples': 41, 'reg_alpha': 0.9386925355271922, 'reg_lambda': 1.2083170990023986, 'feature_fraction': 0.9134336554829187, 'bagging_fraction': 0.8943276128168958, 'bagging_freq': 2}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 04:29:07,954] Trial 18 finished with value: 0.8171585631290158 and parameters: {'n_estimators': 456, 'num_leaves': 207, 'max_depth': 3, 'learning_rate': 0.037532955974443526, 'min_child_samples': 100, 'reg_alpha': 1.870642858051605, 'reg_lambda': 1.2350280158096227, 'feature_fraction': 0.9061080132164645, 'bagging_fraction': 0.8844733612622201, 'bagging_freq': 9}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 06:25:29,295] Trial 19 finished with value: 0.7985362316881208 and parameters: {'n_estimators': 411, 'num_leaves': 192, 'max_depth': 9, 'learning_rate': 0.018097172900494365, 'min_child_samples': 100, 'reg_alpha': 1.9183649539548955, 'reg_lambda': 1.7321611184095838, 'feature_fraction': 0.7227614191571716, 'bagging_fraction': 0.837868002238605, 'bagging_freq': 9}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 06:45:45,607] Trial 20 finished with value: 0.8184586577092248 and parameters: {'n_estimators': 613, 'num_leaves': 226, 'max_depth': 4, 'learning_rate': 0.018981474140498007, 'min_child_samples': 86, 'reg_alpha': 1.7880199390607547, 'reg_lambda': 0.5122519962664578, 'feature_fraction': 0.7814154168201569, 'bagging_fraction': 0.7488920940707727, 'bagging_freq': 8}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 07:05:59,494] Trial 21 finished with value: 0.8181582526981127 and parameters: {'n_estimators': 608, 'num_leaves': 218, 'max_depth': 4, 'learning_rate': 0.019416428412957702, 'min_child_samples': 88, 'reg_alpha': 1.7511633755788933, 'reg_lambda': 0.6147683150067963, 'feature_fraction': 0.7918773934793681, 'bagging_fraction': 0.7360258331251365, 'bagging_freq': 9}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 07:26:43,764] Trial 22 finished with value: 0.820215784906182 and parameters: {'n_estimators': 587, 'num_leaves': 227, 'max_depth': 4, 'learning_rate': 0.010159637105341695, 'min_child_samples': 84, 'reg_alpha': 1.6964337718577083, 'reg_lambda': 0.47685618000276164, 'feature_fraction': 0.7823123076095564, 'bagging_fraction': 0.7396039091739656, 'bagging_freq': 8}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 08:22:44,749] Trial 23 finished with value: 0.8156105551167542 and parameters: {'n_estimators': 596, 'num_leaves': 232, 'max_depth': 6, 'learning_rate': 0.010389324078241034, 'min_child_samples': 81, 'reg_alpha': 1.3876027818467576, 'reg_lambda': 0.4598412269805245, 'feature_fraction': 0.7305789988835102, 'bagging_fraction': 0.6791604236889837, 'bagging_freq': 7}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 08:45:42,754] Trial 24 finished with value: 0.81945954877606 and parameters: {'n_estimators': 681, 'num_leaves': 143, 'max_depth': 4, 'learning_rate': 0.015209951155307355, 'min_child_samples': 87, 'reg_alpha': 1.6470030534415296, 'reg_lambda': 0.3456965692810361, 'feature_fraction': 0.6286336132175702, 'bagging_fraction': 0.778533647373548, 'bagging_freq': 8}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 09:26:29,161] Trial 25 finished with value: 0.816510582492267 and parameters: {'n_estimators': 709, 'num_leaves': 142, 'max_depth': 5, 'learning_rate': 0.014033374793242329, 'min_child_samples': 60, 'reg_alpha': 1.6594243824678385, 'reg_lambda': 0.3254581062026884, 'feature_fraction': 0.6229982796232436, 'bagging_fraction': 0.7891901597909639, 'bagging_freq': 6}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 09:53:17,898] Trial 26 finished with value: 0.8199160747875469 and parameters: {'n_estimators': 795, 'num_leaves': 108, 'max_depth': 4, 'learning_rate': 0.014256422515907599, 'min_child_samples': 74, 'reg_alpha': 1.219689172740044, 'reg_lambda': 0.7210129965814682, 'feature_fraction': 0.6238551165222478, 'bagging_fraction': 0.6909855736924586, 'bagging_freq': 10}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 11:47:13,652] Trial 27 finished with value: 0.7923132938214167 and parameters: {'n_estimators': 758, 'num_leaves': 99, 'max_depth': 7, 'learning_rate': 0.023992144070509244, 'min_child_samples': 72, 'reg_alpha': 1.2187840229199494, 'reg_lambda': 0.8592733752382945, 'feature_fraction': 0.5074955629375242, 'bagging_fraction': 0.6147213965035336, 'bagging_freq': 10}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 11:58:20,516] Trial 28 finished with value: 0.8211372538504933 and parameters: {'n_estimators': 560, 'num_leaves': 109, 'max_depth': 3, 'learning_rate': 0.010570734738736242, 'min_child_samples': 55, 'reg_alpha': 1.445607491990402, 'reg_lambda': 0.6877046390976875, 'feature_fraction': 0.715333093376281, 'bagging_fraction': 0.692619475461286, 'bagging_freq': 10}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 12:51:09,861] Trial 29 finished with value: 0.8144658106858399 and parameters: {'n_estimators': 558, 'num_leaves': 82, 'max_depth': 6, 'learning_rate': 0.010785548748385053, 'min_child_samples': 16, 'reg_alpha': 1.9969933750988411, 'reg_lambda': 0.0016288331664340294, 'feature_fraction': 0.708215529601483, 'bagging_fraction': 0.5765089884838234, 'bagging_freq': 8}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 13:00:14,636] Trial 30 finished with value: 0.8209167273572419 and parameters: {'n_estimators': 451, 'num_leaves': 127, 'max_depth': 3, 'learning_rate': 0.013059622616307089, 'min_child_samples': 29, 'reg_alpha': 1.4645944295381985, 'reg_lambda': 0.6834365738525665, 'feature_fraction': 0.8463905528473809, 'bagging_fraction': 0.6465800763995545, 'bagging_freq': 5}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 13:09:48,228] Trial 31 finished with value: 0.8211307222152533 and parameters: {'n_estimators': 469, 'num_leaves': 123, 'max_depth': 3, 'learning_rate': 0.01007579345309494, 'min_child_samples': 28, 'reg_alpha': 1.4879092234809228, 'reg_lambda': 0.6891472678679463, 'feature_fraction': 0.840693460425985, 'bagging_fraction': 0.6412469077896025, 'bagging_freq': 5}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 13:18:33,341] Trial 32 finished with value: 0.820739896855201 and parameters: {'n_estimators': 432, 'num_leaves': 128, 'max_depth': 3, 'learning_rate': 0.012694878122850225, 'min_child_samples': 29, 'reg_alpha': 1.4671399536207665, 'reg_lambda': 0.9346540466316762, 'feature_fraction': 0.8534754631708981, 'bagging_fraction': 0.6506207903323692, 'bagging_freq': 5}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 13:28:11,078] Trial 33 finished with value: 0.8204530525468632 and parameters: {'n_estimators': 478, 'num_leaves': 162, 'max_depth': 3, 'learning_rate': 0.022759097292276296, 'min_child_samples': 25, 'reg_alpha': 1.3961383708939301, 'reg_lambda': 0.7165114265999464, 'feature_fraction': 0.8806982555276481, 'bagging_fraction': 0.5886070773350953, 'bagging_freq': 4}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 13:36:09,793] Trial 34 finished with value: 0.820572964306333 and parameters: {'n_estimators': 392, 'num_leaves': 117, 'max_depth': 3, 'learning_rate': 0.016146789249001745, 'min_child_samples': 13, 'reg_alpha': 1.4883962942362083, 'reg_lambda': 0.6414885174584262, 'feature_fraction': 0.7429829917440651, 'bagging_fraction': 0.7096763211890255, 'bagging_freq': 5}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 13:57:13,933] Trial 35 finished with value: 0.8193825566851256 and parameters: {'n_estimators': 341, 'num_leaves': 86, 'max_depth': 5, 'learning_rate': 0.0126782563008098, 'min_child_samples': 36, 'reg_alpha': 0.0848060789773164, 'reg_lambda': 0.5654661642806827, 'feature_fraction': 0.8164451106613354, 'bagging_fraction': 0.5623097958760342, 'bagging_freq': 6}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 14:08:07,383] Trial 36 finished with value: 0.8196022437714383 and parameters: {'n_estimators': 538, 'num_leaves': 128, 'max_depth': 3, 'learning_rate': 0.024625945385823425, 'min_child_samples': 55, 'reg_alpha': 1.5518636777150534, 'reg_lambda': 0.20538553580114216, 'feature_fraction': 0.7633898974775319, 'bagging_fraction': 0.6657884910190576, 'bagging_freq': 3}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 14:36:41,776] Trial 37 finished with value: 0.7975996502003322 and parameters: {'n_estimators': 474, 'num_leaves': 100, 'max_depth': 5, 'learning_rate': 0.06661581830061482, 'min_child_samples': 25, 'reg_alpha': 1.08081574158777, 'reg_lambda': 0.8595729671764489, 'feature_fraction': 0.9662492212166012, 'bagging_fraction': 0.7076577529091327, 'bagging_freq': 3}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 14:40:20,083] Trial 38 finished with value: 0.819091867455282 and parameters: {'n_estimators': 168, 'num_leaves': 65, 'max_depth': 3, 'learning_rate': 0.011692761096311937, 'min_child_samples': 21, 'reg_alpha': 1.3720500780978524, 'reg_lambda': 1.1310332931174303, 'feature_fraction': 0.93849146808152, 'bagging_fraction': 0.8223154651617264, 'bagging_freq': 0}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 14:57:15,986] Trial 39 finished with value: 0.8295252434892055 and parameters: {'n_estimators': 513, 'num_leaves': 178, 'max_depth': 4, 'learning_rate': 0.11491846300395636, 'min_child_samples': 54, 'reg_alpha': 1.550155273706916, 'reg_lambda': 0.42573270442031197, 'feature_fraction': 0.8737331401856875, 'bagging_fraction': 0.6202917907252864, 'bagging_freq': 4}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 17:05:08,741] Trial 40 finished with value: 0.7747841262528288 and parameters: {'n_estimators': 504, 'num_leaves': 185, 'max_depth': 10, 'learning_rate': 0.13356958126034046, 'min_child_samples': 56, 'reg_alpha': 1.562865107130278, 'reg_lambda': 0.07063295376207901, 'feature_fraction': 0.807069478216268, 'bagging_fraction': 0.6066729661283992, 'bagging_freq': 4}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 17:14:11,978] Trial 41 finished with value: 0.43654177431337815 and parameters: {'n_estimators': 435, 'num_leaves': 159, 'max_depth': 3, 'learning_rate': 0.15408133882960698, 'min_child_samples': 46, 'reg_alpha': 1.1795015069543333, 'reg_lambda': 0.4203273869650317, 'feature_fraction': 0.8580410399493059, 'bagging_fraction': 0.6396959185267673, 'bagging_freq': 5}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 17:33:56,777] Trial 42 finished with value: 0.7985196247556807 and parameters: {'n_estimators': 545, 'num_leaves': 117, 'max_depth': 4, 'learning_rate': 0.10791801303965075, 'min_child_samples': 37, 'reg_alpha': 1.5503426741729283, 'reg_lambda': 0.2515559821291828, 'feature_fraction': 0.8716671434851786, 'bagging_fraction': 0.5575235127614966, 'bagging_freq': 4}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 17:41:03,007] Trial 43 finished with value: 0.8111586828507178 and parameters: {'n_estimators': 360, 'num_leaves': 141, 'max_depth': 3, 'learning_rate': 0.09870141499851924, 'min_child_samples': 31, 'reg_alpha': 1.3393366787202583, 'reg_lambda': 0.643422908782852, 'feature_fraction': 0.8413366270202699, 'bagging_fraction': 0.5123658116767131, 'bagging_freq': 6}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 17:58:28,971] Trial 44 finished with value: 0.8203373008083594 and parameters: {'n_estimators': 506, 'num_leaves': 174, 'max_depth': 4, 'learning_rate': 0.13670574480857187, 'min_child_samples': 50, 'reg_alpha': 0.9794915469163505, 'reg_lambda': 0.5343047105485043, 'feature_fraction': 0.883043580820383, 'bagging_fraction': 0.6526615724298876, 'bagging_freq': 3}. Best is trial 5 with value: 0.8449109804516205.
# [I 2026-05-19 18:11:24,469] Trial 45 finished with value: 0.7473575700510637 and parameters: {'n_estimators': 644, 'num_leaves': 132, 'max_depth': 3, 'learning_rate': 0.18742396988240673, 'min_child_samples': 67, 'reg_alpha': 1.4684074448372684, 'reg_lambda': 0.710067564780636, 'feature_fraction': 0.9520780923880593, 'bagging_fraction': 0.6960682513315853, 'bagging_freq': 5}. Best is trial 5 with value: 0.8449109804516205.
#       [patience] no improvement for 40 trials -> stopping
#     Optuna done: 46 trials
#     Best AUC: 0.8449  (trial 5)
#     Best params: {'n_estimators': 185, 'num_leaves': 134, 'max_depth': 3, 'learning_rate': 0.15242391728466367, 'min_child_samples': 29, 'reg_alpha': 1.325044568707964, 'reg_lambda': 0.6234221521788219, 'feature_fraction': 0.7600340105889054, 'bagging_fraction': 0.7733551396716398, 'bagging_freq': 2}
#     Delta vs baseline: +0.0319

# %% [markdown]
# ## CELL OPTUNA-FINAL -- refit + save OOF/model/JSON/registry with `mean_folds_auc`

# %%
# @title CELL OPTUNA-FINAL: persist tuned models, OOF, registry logs per parquet
import json as _json
for pq_id, info in NB11_OPTUNA_RESULTS.items():
    manifest_key = info['manifest_key']
    prep = NB11_PREP[pq_id]
    X_pq, y_pq, groups_pq = prep['X'], prep['y'], prep['groups']
    building_ids_pq, clean_cols_pq = prep['building_ids'], prep['clean_cols']

    print(f"\n  === refit [{pq_id}] {manifest_key} ===")
    best_params_full = {**FIXED_LGBM, **info['best_params']}
    best_clf = LGBMClassifier(**best_params_full)

    gkf = GroupKFold(n_splits=min(N_FOLDS, len(np.unique(groups_pq))))
    y_proba_oof = np.full(len(y_pq), np.nan)
    fold_id = np.full(len(y_pq), -1, dtype=int)
    fold_aucs = []
    for fi, (tr, te) in enumerate(gkf.split(X_pq, y_pq, groups_pq)):
        clf_c = clone(best_clf)
        clf_c.fit(X_pq[tr], y_pq[tr])
        proba = clf_c.predict_proba(X_pq[te])[:, 1]
        y_proba_oof[te] = proba
        fold_id[te] = fi
        if len(np.unique(y_pq[te])) > 1:
            fold_aucs.append(roc_auc_score(y_pq[te], proba))
    valid = ~np.isnan(y_proba_oof)
    tuned_auc = roc_auc_score(y_pq[valid], y_proba_oof[valid])
    mean_folds_auc = float(np.mean(fold_aucs))
    std_folds_auc = float(np.std(fold_aucs))
    print(f"    Tuned OOF AUC (refit): {tuned_auc:.4f}  (study.best={info['tuned_auc']:.4f})  "
          f"delta={tuned_auc - info['tuned_auc']:+.4f}")
    print(f"    mean(folds)={mean_folds_auc:.4f}  std(folds)={std_folds_auc:.4f}")
    assert abs(tuned_auc - info['tuned_auc']) < 1e-3, \
        f"OOF drift too large: refit={tuned_auc:.4f} vs study.best={info['tuned_auc']:.4f}"

    info['fold_aucs'] = fold_aucs
    info['tuned_auc_refit'] = tuned_auc
    info['mean_folds_auc'] = mean_folds_auc
    info['std_folds_auc'] = std_folds_auc

    tuned_res = {
        'y_true':       y_pq[valid].astype(int),
        'y_proba':      y_proba_oof[valid],
        'groups':       groups_pq[valid],
        'building_id':  np.asarray(building_ids_pq)[valid],
        'fold_id':      fold_id[valid],
        'experiment':   f'C_{pq_id}_{manifest_key}__OPTUNA',
        'auc_groupkfold': tuned_auc,
        'fold_aucs':    fold_aucs,
    }
    model_id = f"{NB11_NAME}__{manifest_key}__LightGBM-MIA-Optuna"
    save_oof_from_result(tuned_res, model_id=model_id, oof_dir=NB11_OUT_DIR / "oof",
                         variant_id=info['study_tag'], is_final=True)

    best_clf_full = LGBMClassifier(**best_params_full).fit(X_pq, y_pq)
    model_path = NB11_OUT_DIR / "models" / f"{info['study_tag']}__best.joblib"
    joblib.dump({'model': best_clf_full, 'feature_cols': clean_cols_pq,
                 'params': best_params_full, 'tuned_auc': tuned_auc,
                 'mean_folds_auc': mean_folds_auc, 'std_folds_auc': std_folds_auc,
                 'baseline_auc': info['baseline_auc'],
                 'study_tag': info['study_tag']}, model_path)
    print(f"    Saved model: {model_path}")

    bp_path = NB11_OUT_DIR / "best_params" / f"{info['study_tag']}__best.json"
    with open(bp_path, 'w') as f:
        _json.dump({
            'study_tag': info['study_tag'], 'notebook': NB11_NAME,
            'manifest_key': manifest_key, 'parquet_id': pq_id,
            'classifier': 'LightGBM-MIA',
            'best_params': info['best_params'], 'best_params_full': best_params_full,
            'tuned_auc': tuned_auc, 'baseline_auc': info['baseline_auc'],
            'delta_auc': tuned_auc - info['baseline_auc'],
            'mean_folds_auc': mean_folds_auc, 'std_folds_auc': std_folds_auc,
            'fold_aucs': fold_aucs,
            'n_trials_done': info['n_trials_done'],
            'n_trials_requested': info['n_trials_requested'],
            'patience': OPTUNA_PATIENCE,
            'n_features': len(clean_cols_pq), 'n_buildings': int(valid.sum()),
            'n_cities': int(len(np.unique(groups_pq))),
        }, f, indent=2, default=str)
    print(f"    Saved best_params: {bp_path}")

    registry.log_experiment(
        cell_id=NB11_CELL_ID,
        experiment_name=tuned_res['experiment'],
        parquet_name=f'bda_{manifest_key}_v2',
        feature_set_name='manifest_default_minus_leakage',
        classifier_name='LightGBM-MIA-Optuna',
        classifier_params=best_params_full,
        feature_cols=clean_cols_pq,
        cv_method='GroupKFold', n_folds=N_FOLDS,
        imputation='native_nan',
        y_true=tuned_res['y_true'], y_proba=tuned_res['y_proba'],
        groups=tuned_res['groups'],
        note=(f"NB11 Optuna tuned LightGBM-MIA on {manifest_key}; "
              f"budget={info['n_trials_requested']}, trials_done={info['n_trials_done']}, "
              f"patience={OPTUNA_PATIENCE}; "
              f"pooled_auc={tuned_auc:.4f} mean_folds_auc={mean_folds_auc:.4f} "
              f"std_folds_auc={std_folds_auc:.4f} fold_aucs={fold_aucs}"),
        tags=['nb11_optuna', 'lightgbm_mia', pq_id, manifest_key],
    )
# Out:
#   === refit [F4] fusion_ms_cohdrop ===
#     Tuned OOF AUC (refit): 0.8514  (study.best=0.8515)  delta=-0.0001
#     mean(folds)=0.7331  std(folds)=0.0488
#     saved oof -> oof_NB11a_F4_F7__fusion_ms_cohdrop__LightGBM-MIA-Optuna__20260517_093056_115af1.parquet  TP=5513 FN=1242 FP=110488 TN=349461
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11a_F4_F7__fusion_ms_cohdrop__LightGBM-MIA__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11a_F4_F7__fusion_ms_cohdrop__LightGBM-MIA__best.json
#   REG: C_F4_fusion_ms_cohdrop__OPTUNA                AUC=0.8514 F1=0.0898 n=466704 feat=88 cities=18 [NB08c_v2/cell_c7]
#
#   === refit [F7] fusion_composite_cohdrop ===
#     Tuned OOF AUC (refit): 0.8449  (study.best=0.8449)  delta=-0.0000
#     mean(folds)=0.6783  std(folds)=0.1052
#     saved oof -> oof_NB11a_F4_F7__fusion_composite_cohdrop__LightGBM-MIA-Optuna__20260517_093056_115af1.parquet  TP=5505 FN=1250 FP=109465 TN=350484
#     Saved model: /content/drive_f/masterthesis/data/outputs/NB11_V2/models/NB11a_F4_F7__fusion_composite_cohdrop__LightGBM-MIA__best.joblib
#     Saved best_params: /content/drive_f/masterthesis/data/outputs/NB11_V2/best_params/NB11a_F4_F7__fusion_composite_cohdrop__LightGBM-MIA__best.json
#   REG: C_F7_fusion_composite_cohdrop__OPTUNA         AUC=0.8449 F1=0.0904 n=466704 feat=145 cities=18 [NB08c_v2/cell_c7]

# %% [markdown]
# ## CELL SUMMARY -- multi-row CSV with `mean_folds_auc`/`std_folds_auc` + per-fold AUC print

# %%
# @title CELL SUMMARY
rows = []
for pq_id, info in NB11_OPTUNA_RESULTS.items():
    prep = NB11_PREP[pq_id]
    rows.append({
        'notebook': NB11_NAME,
        'parquet_id': pq_id,
        'manifest_key': info['manifest_key'],
        'classifier': 'LightGBM-MIA',
        'baseline_auc': info['baseline_auc'],
        'baseline_auc_expected': prep['expected_auc'],
        'tuned_auc': info['tuned_auc_refit'],
        'delta_auc': info['tuned_auc_refit'] - info['baseline_auc'],
        'mean_folds_auc': info['mean_folds_auc'],
        'std_folds_auc': info['std_folds_auc'],
        'n_trials_requested': info['n_trials_requested'],
        'n_trials_done': info['n_trials_done'],
        'early_stopped': info['n_trials_done'] < info['n_trials_requested'],
        'patience': OPTUNA_PATIENCE,
        'n_features': len(prep['clean_cols']),
        'n_buildings': len(prep['y']),
        'n_cities': int(len(np.unique(prep['groups']))),
        'study_tag': info['study_tag'],
    })
df_summary = pd.DataFrame(rows).sort_values('tuned_auc', ascending=False)
summary_path = NB11_OUT_DIR / "summary" / f"{NB11_NAME}_summary.csv"
df_summary.to_csv(summary_path, index=False)
print(df_summary.to_string(index=False))
print(f"\n  Saved summary: {summary_path}")

print("\n  Per-fold AUC (tuned models):")
for pq_id, info in NB11_OPTUNA_RESULTS.items():
    fold_aucs = info['fold_aucs']
    print(f"    [{pq_id}] {info['manifest_key']:36s} pooled={info['tuned_auc_refit']:.4f}  "
          f"mean(folds)={info['mean_folds_auc']:.4f}  std={info['std_folds_auc']:.4f}  "
          f"folds={[f'{a:.3f}' for a in fold_aucs]}")

print(f"\n  {NB11_NAME} complete.")
# Out:
#    notebook parquet_id             manifest_key   classifier  baseline_auc  baseline_auc_expected  tuned_auc  delta_auc  mean_folds_auc  std_folds_auc  n_trials_requested  n_trials_done  early_stopped  patience  n_features  n_buildings  n_cities                                           study_tag
# NB11a_F4_F7         F4        fusion_ms_cohdrop LightGBM-MIA      0.812613                  0.813   0.851432   0.038820        0.733103       0.048777                 200             96           True        40          88       466704        18        NB11a_F4_F7__fusion_ms_cohdrop__LightGBM-MIA
# NB11a_F4_F7         F7 fusion_composite_cohdrop LightGBM-MIA      0.812965                  0.813   0.844908   0.031943        0.678253       0.105205                 200             46           True        40         145       466704        18 NB11a_F4_F7__fusion_composite_cohdrop__LightGBM-MIA
#
#   Saved summary: /content/drive_f/masterthesis/data/outputs/NB11_V2/summary/NB11a_F4_F7_summary.csv
#
#   Per-fold AUC (tuned models):
#     [F4] fusion_ms_cohdrop                    pooled=0.8514  mean(folds)=0.7331  std=0.0488  folds=['0.690', '0.782', '0.662', '0.753', '0.779']
#     [F7] fusion_composite_cohdrop             pooled=0.8449  mean(folds)=0.6783  std=0.1052  folds=['0.479', '0.756', '0.664', '0.749', '0.743']
#
#   NB11a_F4_F7 complete.
